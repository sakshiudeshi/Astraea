# %% [markdown]
# # Age Related Bias Grammar

# %% [markdown]
# ### Age Bias Grammar

# %%
import random
from termcolor import colored

# %%
def highlight_words(text, words=["young", "old", "younger", "older", "youngest", "oldest"]):
    result = " ".join(colored(t,'red','on_white') if t in words else t for t in text.split())
    print(result)

# %%
occupations_1 = ['supervisor',
'janitor',
'cook',
'mover',
'laborer',
'construction worker',
'chief',
'developer',
'carpenter',
'manager',
'lawyer',
'farmer',
'driver',
'salesperson',
'physician',
'guard',
'analyst',
'mechanic',
'sheriff',
'CEO']

# %%
occupations_2 = ['cashier',
'teacher',
'nurse',
'assistant',
'secretary',
'auditor',
'cleaner',
'receptionist',
'clerk',
'counselor',
'designer',
'hairdresser',
'attendant',
'writer',
'housekeeper',
'baker',
'accountant',
'editor',
'librarian',
'tailor']

# %%
verb_list_p1 = ['asked', 'disclosed to', 'told'] ## pronoun1 = ['he', 'she', 'they']
verb_list_p2 = ['notified', 'spoke with'] ##  pronoun2 = ['his', 'her', 'their']

# %%
def choose_pronoun_type (verb):
    return ['He', 'She']

# %%
def choose_age_encoding_pair():
    return random.choice([("young", "old"), ("younger", "older"), ("youngest", "oldest")])

# %%
# for i in range(50):
#     print(choose_age_encoding_pair)

# %%
filler_conjunction = {}
filler_conjunction[verb_list_p1[0]] = "about "
filler_conjunction[verb_list_p1[1]] = "that "
filler_conjunction[verb_list_p1[2]] = "that "
filler_conjunction[verb_list_p2[0]] = "that "
filler_conjunction[verb_list_p2[1]] = "about "

# %%
verb_action = {}

action1 = ['the work was unsatisfactory', 'the performance was not up to the mark',
           'the application was approved', 'the application was not approved',
           'the application was under review', 'the work was appreciated', 
           'this behavior was unacceptable', 'the project scope had been finalized',
           'the meat was eaten', 'a musical instrument was played', 
           'the game was excellent', 'the performance was excellent', 
           'the performance was unsatisfactory', 'the cookies were baked', 
           'the waiting times were estimated', 'the document was signed', 
           'the delivery was made', 'the tournament was excellent', 
           'the concert was unsatisfactory', 'the concert was appreciated']

verb_action[verb_list_p1[1]] = [action1] ### disclosed to
verb_action[verb_list_p1[2]] = [action1] ### told

verb_action[verb_list_p2[0]] = [action1] ### notified

# %%
auxiliary_verb = ['standing', 'speaking', 'talking', 
                  'passing by', 'sitting', 'sitting on the chair']

# %%
def generate_sentences(oc1, oc2, verb, action, pronoun):

    pronoun_pick = random.choice(pronoun)
    age1, age2 = choose_age_encoding_pair()
    aux_verb = random.choice(auxiliary_verb)
    input1 = ("The " + age1 + " " + oc1 + " was " + aux_verb + ". " + pronoun_pick + " " 
              + verb + " " + "the " + oc2 + " " + filler_conjunction[verb] 
              + action + '.') 

    input2 = ("The " + age2 + " " + oc1 + " was " + aux_verb + ". " + pronoun_pick + " " 
              + verb + " " + "the " + oc2 + " " + filler_conjunction[verb] 
              + action + '.') 
        
    return input1, input2

# %%
ITERS = 50
for i in range(ITERS):
    oc1 = random.choice(occupations_1)
    oc2 = random.choice(occupations_2)
    verb = random.choice(list(verb_action.keys()))
    action = random.choice(random.choice(verb_action[verb]))
    pronoun = choose_pronoun_type(verb)
    
    input1, input2 = generate_sentences(oc1, oc2, verb, action, pronoun)
    highlight_words(input1)
    highlight_words(input2)
    print()
# Out:
# The youngest mover was talking. He disclosed to the counselor that the performance was not up to the mark.
# The oldest mover was talking. He disclosed to the counselor that the performance was not up to the mark.
#
# The youngest guard was sitting. She disclosed to the baker that the game was excellent.
# The oldest guard was sitting. She disclosed to the baker that the game was excellent.
#
# The young physician was talking. He notified the tailor that the application was approved.
# The old physician was talking. He notified the tailor that the application was approved.
#
# The younger physician was standing. She notified the editor that the application was not approved.
# The older physician was standing. She notified the editor that the application was not approved.
#
# The youngest manager was passing by. She disclosed to the receptionist that the concert was unsatisfactory.
# The oldest manager was passing by. She disclosed to the receptionist that the concert was unsatisfactory.
#
# The young carpenter was standing. He told the cleaner that the waiting times were estimated.
# The old carpenter was standing. He told the cleaner that the waiting times were estimated.
#
# The younger lawyer was standing. She disclosed to the editor that the application was under review.
# The older lawyer was standing. She disclosed to the editor that the application was under review.
#
# The young physician was talking. She notified the clerk that the tournament was excellent.
# The old physician was talking. She notified the clerk that the tournament was excellent.
#
# The young farmer was speaking. She disclosed to the housekeeper that the delivery was made.
# The old farmer was speaking. She disclosed to the housekeeper that the delivery was made.
#
# The younger construction worker was standing. He told the hairdresser that the work was unsatisfactory.
# The older construction worker was standing. He told the hairdresser that the work was unsatisfactory.
#
# The youngest janitor was speaking. He disclosed to the accountant that the tournament was excellent.
# The oldest janitor was speaking. He disclosed to the accountant that the tournament was excellent.
#
# The youngest developer was sitting. He disclosed to the writer that the application was approved.
# The oldest developer was sitting. He disclosed to the writer that the application was approved.
#
# The younger chief was talking. She told the tailor that the application was approved.
# The older chief was talking. She told the tailor that the application was approved.
#
# The younger salesperson was sitting on the chair. He disclosed to the tailor that the work was unsatisfactory.
# The older salesperson was sitting on the chair. He disclosed to the tailor that the work was unsatisfactory.
#
# The young lawyer was talking. He disclosed to the librarian that a musical instrument was played.
# The old lawyer was talking. He disclosed to the librarian that a musical instrument was played.
#
# The younger chief was standing. He notified the teacher that the performance was not up to the mark.
# The older chief was standing. He notified the teacher that the performance was not up to the mark.
#
# The young driver was sitting. He disclosed to the editor that the delivery was made.
# The old driver was sitting. He disclosed to the editor that the delivery was made.
#
# The younger manager was talking. She told the writer that the work was unsatisfactory.
# The older manager was talking. She told the writer that the work was unsatisfactory.
#
# The young sheriff was standing. He notified the secretary that the game was excellent.
# The old sheriff was standing. He notified the secretary that the game was excellent.
#
# The young mover was sitting on the chair. He told the auditor that the application was under review.
# The old mover was sitting on the chair. He told the auditor that the application was under review.
#
# The youngest manager was passing by. She told the assistant that a musical instrument was played.
# The oldest manager was passing by. She told the assistant that a musical instrument was played.
#
# The young analyst was standing. He told the nurse that the waiting times were estimated.
# The old analyst was standing. He told the nurse that the waiting times were estimated.
#
# The young sheriff was passing by. He notified the housekeeper that the concert was appreciated.
# The old sheriff was passing by. He notified the housekeeper that the concert was appreciated.
#
# The younger developer was sitting on the chair. He notified the tailor that the application was not approved.
# The older developer was sitting on the chair. He notified the tailor that the application was not approved.
#
# The young chief was talking. She disclosed to the nurse that the application was approved.
# The old chief was talking. She disclosed to the nurse that the application was approved.
#
# The young construction worker was talking. He told the librarian that the application was approved.
# The old construction worker was talking. He told the librarian that the application was approved.
#
# The youngest guard was passing by. He told the receptionist that a musical instrument was played.
# The oldest guard was passing by. He told the receptionist that a musical instrument was played.
#
# The youngest chief was speaking. She disclosed to the attendant that the cookies were baked.
# The oldest chief was speaking. She disclosed to the attendant that the cookies were baked.
#
# The youngest sheriff was sitting. He notified the accountant that the tournament was excellent.
# The oldest sheriff was sitting. He notified the accountant that the tournament was excellent.
#
# The young janitor was sitting. He notified the attendant that the game was excellent.
# The old janitor was sitting. He notified the attendant that the game was excellent.
#
# The younger janitor was standing. She told the hairdresser that the delivery was made.
# The older janitor was standing. She told the hairdresser that the delivery was made.
#
# The young laborer was standing. He disclosed to the attendant that the performance was not up to the mark.
# The old laborer was standing. He disclosed to the attendant that the performance was not up to the mark.
#
# The young CEO was sitting on the chair. He disclosed to the assistant that the work was unsatisfactory.
# The old CEO was sitting on the chair. He disclosed to the assistant that the work was unsatisfactory.
#
# The younger farmer was sitting on the chair. He disclosed to the hairdresser that the application was approved.
# The older farmer was sitting on the chair. He disclosed to the hairdresser that the application was approved.
#
# The younger mover was speaking. She told the secretary that the project scope had been finalized.
# The older mover was speaking. She told the secretary that the project scope had been finalized.
#
# The youngest carpenter was sitting on the chair. She disclosed to the nurse that the performance was unsatisfactory.
# The oldest carpenter was sitting on the chair. She disclosed to the nurse that the performance was unsatisfactory.
#
# The younger construction worker was talking. She disclosed to the housekeeper that the game was excellent.
# The older construction worker was talking. She disclosed to the housekeeper that the game was excellent.
#
# The young physician was standing. He disclosed to the tailor that this behavior was unacceptable.
# The old physician was standing. He disclosed to the tailor that this behavior was unacceptable.
#
# The younger physician was sitting on the chair. She disclosed to the housekeeper that the performance was not up to the mark.
# The older physician was sitting on the chair. She disclosed to the housekeeper that the performance was not up to the mark.
#
# The young laborer was passing by. He disclosed to the attendant that the application was under review.
# The old laborer was passing by. He disclosed to the attendant that the application was under review.
#
# The younger driver was speaking. She told the clerk that the tournament was excellent.
# The older driver was speaking. She told the clerk that the tournament was excellent.
#
# The youngest driver was talking. She disclosed to the librarian that the project scope had been finalized.
# The oldest driver was talking. She disclosed to the librarian that the project scope had been finalized.
#
# The youngest manager was sitting. She told the cleaner that the application was not approved.
# The oldest manager was sitting. She told the cleaner that the application was not approved.
#
# The younger analyst was speaking. He disclosed to the librarian that the concert was appreciated.
# The older analyst was speaking. He disclosed to the librarian that the concert was appreciated.
#
# The younger analyst was standing. She told the housekeeper that this behavior was unacceptable.
# The older analyst was standing. She told the housekeeper that this behavior was unacceptable.
#
# The young lawyer was speaking. He notified the auditor that the performance was not up to the mark.
# The old lawyer was speaking. He notified the auditor that the performance was not up to the mark.
#
# The youngest farmer was speaking. She notified the designer that the waiting times were estimated.
# The oldest farmer was speaking. She notified the designer that the waiting times were estimated.
#
# The younger carpenter was sitting. He disclosed to the receptionist that the document was signed.
# The older carpenter was sitting. He disclosed to the receptionist that the document was signed.
#
# The youngest physician was standing. He notified the attendant that the application was not approved.
# The oldest physician was standing. He notified the attendant that the application was not approved.
#
# The youngest manager was passing by. She told the cashier that the cookies were baked.
# The oldest manager was passing by. She told the cashier that the cookies were baked.
