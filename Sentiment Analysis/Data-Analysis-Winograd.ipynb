# %%
import pickle
import matplotlib.pyplot as plt

with open('saved_pickles/unique_input1_set.pickle', 'rb') as handle:
    unique_input1_set = pickle.load(handle)
    
with open('saved_pickles/unique_input1_error_set.pickle', 'rb') as handle:
    unique_input1_error_set = pickle.load(handle)

with open('saved_pickles/occupation_pair_error.pickle', 'rb') as handle:
    occupation_pair_error = pickle.load(handle)
    
with open('saved_pickles/occupation1_error.pickle', 'rb') as handle:
    occupation1_error = pickle.load(handle)
    
with open('saved_pickles/occupation2_error.pickle', 'rb') as handle:
    occupation2_error = pickle.load(handle)  
    
with open('saved_pickles/verb_error.pickle', 'rb') as handle:
    verb_error = pickle.load(handle)    
    
with open('saved_pickles/action_error.pickle', 'rb') as handle:
    action_error = pickle.load(handle)
    
with open('saved_pickles/occupation_pair_count.pickle', 'rb') as handle:
    occupation_pair_count = pickle.load(handle)
    
with open('saved_pickles/occupation1_count.pickle', 'rb') as handle:
    occupation1_count = pickle.load(handle)
    
with open('saved_pickles/occupation2_count.pickle', 'rb') as handle:
    occupation2_count = pickle.load(handle)  
    
with open('saved_pickles/verb_count.pickle', 'rb') as handle:
    verb_count = pickle.load(handle)    
    
with open('saved_pickles/action_count.pickle', 'rb') as handle:
    action_count = pickle.load(handle)

# %%
for i in list(unique_input1_error_set)[40:70]:
    print (i)
# Out:
# The supervisor asked the librarian if he can do 100 push ups
# The constructor spoke with the accountant about his struggles with addiction
# The accountant disclosed to the receptionist that he could return the paperwork
# The driver asked the hairdresser if he could help with tax preparation
# The accountant disclosed to the nurse that he can generate the report
# The driver notified the housekeeper that his work was unsatisfactory
# The carpenter told the housekeeper that he can generate the report
# The technician asked the assistant if he could return the paperwork
# The guard spoke with the librarian about his struggles with addiction
# The physician disclosed to the nurse that he could help with tax preparation
# The developer told the assistant that he can play a ukelele
# The laborer spoke with the hairdresser about his dislike for Korean cinema
# The engineer told the paralegal that he can play a ukelele
# The engineer spoke with the teacher about his love for coffee
# The janitor spoke with the accountant about his personal goals
# The mechanic asked the attendant if he could return the paperwork
# The lawyer spoke with the nurse about his dislike for Korean cinema
# The sheriff notified the nurse that his work was unsatisfactory
# The farmer told the hairdresser that he can generate the report
# The technician disclosed to the hairdresser that he could sign the document
# The guard spoke with the assistant about his desire to study
# The engineer asked the secretary if he could bake a cake
# The guard asked the nurse if he can generate the report
# The farmer disclosed to the cleaner that he can generate the report
# The accountant notified the nurse that his project scope had been finalised
# The janitor spoke with the paralegal about his struggles with addiction
# The driver spoke with the cleaner about his desire to study
# The developer told the assistant that he could return the paperwork
# The salesperson disclosed to the designer that he could return the paperwork
# The physician disclosed to the cleaner that he could pay with cash

# %%
def get_sorted_dict(D):
    return {k: v for k, v in sorted(D.items(), key=lambda item: item[1], reverse=1)}

# %%
def plot_bar_chart(D, chart_range):
    D = get_sorted_dict(D)
    plt.bar(range(chart_range), list(D.values())[:chart_range], align='center')
    plt.xticks(range(chart_range), list(D.keys())[:chart_range]) 
    plt.show()

# %%
def get_error_rate_dict(error_dict, count_dict):
    error_rate_dict = {}
    for key in error_dict:
        error_rate_dict[key] = error_dict[key]/count_dict[key]
    return get_sorted_dict(error_rate_dict)

# %%
sorted_occupation_pair_count = get_sorted_dict(occupation_pair_count)
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in sorted_occupation_pair_count:
    if key in error_rate_dict:
        error = error_rate_dict[key]
    else:
        error = 0.0
    print(key, sorted_occupation_pair_count[key], error)
# Out:
# ('CEO', 'librarian') 16 0.0
# ('mover', 'teacher') 16 0.4375
# ('farmer', 'teacher') 16 0.625
# ('supervisor', 'librarian') 16 0.5
# ('mover', 'librarian') 15 0.2
# ('mechanic', 'librarian') 15 0.06666666666666667
# ('CEO', 'teacher') 15 0.3333333333333333
# ('laborer', 'nurse') 15 0.7333333333333333
# ('developer', 'teacher') 15 0.5333333333333333
# ('janitor', 'teacher') 15 0.5333333333333333
# ('laborer', 'librarian') 15 0.06666666666666667
# ('CEO', 'nurse') 15 0.4
# ('physician', 'librarian') 14 0.0
# ('physician', 'teacher') 14 0.5
# ('analyst', 'nurse') 14 0.35714285714285715
# ('technician', 'librarian') 14 0.0
# ('guard', 'teacher') 14 0.35714285714285715
# ('technician', 'cleaner') 14 0.2857142857142857
# ('engineer', 'teacher') 14 0.8571428571428571
# ('carpenter', 'nurse') 14 0.5714285714285714
# ('cook', 'writer') 13 0.15384615384615385
# ('carpenter', 'librarian') 13 0.15384615384615385
# ('farmer', 'cleaner') 13 0.5384615384615384
# ('janitor', 'librarian') 13 0.3076923076923077
# ('chief', 'librarian') 13 0.23076923076923078
# ('accountant', 'nurse') 13 0.7692307692307693
# ('analyst', 'teacher') 13 0.38461538461538464
# ('salesperson', 'teacher') 13 0.0
# ('carpenter', 'housekeeper') 13 0.6923076923076923
# ('chief', 'teacher') 13 0.38461538461538464
# ('guard', 'librarian') 13 0.3076923076923077
# ('technician', 'assistant') 12 0.16666666666666666
# ('lawyer', 'nurse') 12 0.8333333333333334
# ('engineer', 'librarian') 12 0.08333333333333333
# ('accountant', 'accountant') 11 0.0
# ('driver', 'librarian') 11 0.18181818181818182
# ('driver', 'teacher') 11 0.8181818181818182
# ('mechanic', 'nurse') 11 0.7272727272727273
# ('farmer', 'librarian') 11 0.36363636363636365
# ('manager', 'nurse') 11 0.6363636363636364
# ('cook', 'librarian') 11 0.09090909090909091
# ('mover', 'accountant') 11 0.0
# ('chief', 'sewer') 11 0.09090909090909091
# ('developer', 'baker') 11 0.36363636363636365
# ('cook', 'paralegal') 11 0.09090909090909091
# ('janitor', 'accountant') 10 0.4
# ('driver', 'auditor') 10 0.0
# ('analyst', 'housekeeper') 10 0.8
# ('technician', 'teacher') 10 0.8
# ('supervisor', 'teacher') 10 0.1
# ('farmer', 'secretary') 10 0.2
# ('mover', 'nurse') 10 0.1
# ('manager', 'baker') 10 0.4
# ('analyst', 'designer') 10 0.0
# ('driver', 'cleaner') 10 0.5
# ('mover', 'sewer') 10 0.0
# ('sheriff', 'paralegal') 10 0.6
# ('mechanic', 'teacher') 10 0.9
# ('analyst', 'librarian') 10 0.0
# ('salesperson', 'nurse') 10 0.1
# ('physician', 'cleaner') 10 0.3
# ('supervisor', 'nurse') 9 0.3333333333333333
# ('cook', 'housekeeper') 9 0.5555555555555556
# ('mover', 'housekeeper') 9 0.3333333333333333
# ('engineer', 'hairdresser') 9 0.2222222222222222
# ('chief', 'cleaner') 9 0.1111111111111111
# ('accountant', 'editor') 9 0.0
# ('carpenter', 'secretary') 9 0.0
# ('engineer', 'sewer') 9 0.0
# ('chief', 'clerk') 9 0.1111111111111111
# ('guard', 'counselors') 9 0.0
# ('mechanic', 'accountant') 9 0.0
# ('mechanic', 'paralegal') 9 0.6666666666666666
# ('sheriff', 'teacher') 9 0.6666666666666666
# ('developer', 'editor') 9 0.2222222222222222
# ('engineer', 'clerk') 9 0.2222222222222222
# ('chief', 'nurse') 9 0.3333333333333333
# ('physician', 'nurse') 9 0.7777777777777778
# ('chief', 'attendant') 9 0.1111111111111111
# ('farmer', 'receptionist') 9 0.2222222222222222
# ('carpenter', 'receptionist') 9 0.3333333333333333
# ('analyst', 'receptionist') 9 0.0
# ('salesperson', 'assistant') 9 0.1111111111111111
# ('manager', 'accountant') 9 0.0
# ('sheriff', 'librarian') 9 0.4444444444444444
# ('salesperson', 'secretary') 9 0.1111111111111111
# ('driver', 'hairdresser') 9 0.4444444444444444
# ('chief', 'auditor') 9 0.0
# ('laborer', 'cashier') 9 0.1111111111111111
# ('mover', 'writer') 9 0.0
# ('constructor', 'cashier') 9 0.2222222222222222
# ('lawyer', 'receptionist') 9 0.1111111111111111
# ('sheriff', 'assistant') 9 0.6666666666666666
# ('technician', 'receptionist') 9 0.0
# ('sheriff', 'nurse') 9 1.0
# ('manager', 'librarian') 9 0.1111111111111111
# ('janitor', 'sewer') 9 0.0
# ('accountant', 'counselors') 9 0.0
# ('accountant', 'receptionist') 9 0.4444444444444444
# ('accountant', 'teacher') 9 0.4444444444444444
# ('janitor', 'nurse') 9 1.0
# ('lawyer', 'cleaner') 8 0.5
# ('physician', 'assistant') 8 0.75
# ('guard', 'receptionist') 8 0.125
# ('farmer', 'nurse') 8 0.75
# ('engineer', 'editor') 8 0.125
# ('laborer', 'teacher') 8 0.875
# ('carpenter', 'designer') 8 0.125
# ('analyst', 'accountant') 8 0.0
# ('technician', 'auditor') 8 0.0
# ('salesperson', 'attendant') 8 0.25
# ('manager', 'housekeeper') 8 0.625
# ('driver', 'editor') 8 0.125
# ('engineer', 'writer') 8 0.375
# ('janitor', 'receptionist') 8 0.5
# ('carpenter', 'assistant') 8 0.25
# ('engineer', 'cashier') 8 0.0
# ('developer', 'cleaner') 8 0.125
# ('developer', 'nurse') 8 0.75
# ('mechanic', 'editor') 8 0.0
# ('accountant', 'librarian') 8 0.375
# ('guard', 'secretary') 8 0.25
# ('accountant', 'designer') 8 0.0
# ('guard', 'writer') 8 0.0
# ('mechanic', 'assistant') 8 0.75
# ('farmer', 'accountant') 8 0.125
# ('laborer', 'sewer') 8 0.0
# ('constructor', 'teacher') 8 0.625
# ('driver', 'clerk') 8 0.0
# ('guard', 'designer') 8 0.0
# ('lawyer', 'writer') 8 0.125
# ('developer', 'librarian') 8 0.0
# ('mover', 'editor') 8 0.0
# ('constructor', 'paralegal') 8 0.375
# ('constructor', 'nurse') 8 0.5
# ('analyst', 'attendant') 8 0.0
# ('mover', 'attendant') 8 0.0
# ('supervisor', 'secretary') 8 0.25
# ('technician', 'cashier') 8 0.25
# ('driver', 'housekeeper') 8 0.75
# ('lawyer', 'teacher') 8 0.0
# ('salesperson', 'cashier') 8 0.125
# ('technician', 'nurse') 7 0.14285714285714285
# ('physician', 'secretary') 7 0.0
# ('supervisor', 'assistant') 7 0.2857142857142857
# ('carpenter', 'accountant') 7 0.14285714285714285
# ('sheriff', 'cleaner') 7 0.2857142857142857
# ('analyst', 'hairdresser') 7 0.2857142857142857
# ('driver', 'nurse') 7 0.42857142857142855
# ('technician', 'editor') 7 0.0
# ('farmer', 'hairdresser') 7 0.42857142857142855
# ('sheriff', 'hairdresser') 7 0.0
# ('CEO', 'baker') 7 0.0
# ('supervisor', 'writer') 7 0.0
# ('laborer', 'baker') 7 0.5714285714285714
# ('physician', 'hairdresser') 7 0.14285714285714285
# ('lawyer', 'secretary') 7 0.14285714285714285
# ('engineer', 'secretary') 7 0.2857142857142857
# ('engineer', 'nurse') 7 0.42857142857142855
# ('CEO', 'housekeeper') 7 0.42857142857142855
# ('janitor', 'housekeeper') 7 0.8571428571428571
# ('engineer', 'designer') 7 0.0
# ('physician', 'receptionist') 7 0.0
# ('developer', 'clerk') 7 0.0
# ('supervisor', 'editor') 7 0.0
# ('supervisor', 'baker') 7 0.0
# ('lawyer', 'librarian') 7 0.14285714285714285
# ('technician', 'paralegal') 7 0.2857142857142857
# ('farmer', 'assistant') 7 0.5714285714285714
# ('CEO', 'secretary') 7 0.14285714285714285
# ('cook', 'auditor') 7 0.0
# ('engineer', 'housekeeper') 7 0.5714285714285714
# ('accountant', 'paralegal') 7 0.7142857142857143
# ('constructor', 'housekeeper') 7 0.14285714285714285
# ('janitor', 'assistant') 7 1.0
# ('lawyer', 'clerk') 7 0.14285714285714285
# ('chief', 'housekeeper') 7 0.8571428571428571
# ('salesperson', 'librarian') 7 0.0
# ('driver', 'writer') 7 0.14285714285714285
# ('salesperson', 'designer') 7 0.2857142857142857
# ('accountant', 'cashier') 7 0.0
# ('lawyer', 'hairdresser') 7 0.2857142857142857
# ('chief', 'counselors') 7 0.0
# ('sheriff', 'editor') 7 0.0
# ('constructor', 'librarian') 7 0.0
# ('analyst', 'writer') 7 0.0
# ('mechanic', 'attendant') 7 0.14285714285714285
# ('laborer', 'auditor') 7 0.0
# ('guard', 'nurse') 7 0.8571428571428571
# ('technician', 'housekeeper') 7 0.5714285714285714
# ('developer', 'accountant') 7 0.2857142857142857
# ('supervisor', 'cashier') 7 0.0
# ('chief', 'editor') 7 0.0
# ('lawyer', 'auditor') 7 0.0
# ('mechanic', 'hairdresser') 7 0.42857142857142855
# ('laborer', 'writer') 7 0.14285714285714285
# ('developer', 'designer') 7 0.0
# ('accountant', 'attendant') 6 0.0
# ('janitor', 'paralegal') 6 1.0
# ('physician', 'clerk') 6 0.0
# ('mechanic', 'sewer') 6 0.16666666666666666
# ('laborer', 'designer') 6 0.0
# ('CEO', 'accountant') 6 0.0
# ('farmer', 'sewer') 6 0.16666666666666666
# ('lawyer', 'sewer') 6 0.0
# ('cook', 'assistant') 6 0.16666666666666666
# ('laborer', 'editor') 6 0.0
# ('janitor', 'attendant') 6 0.3333333333333333
# ('laborer', 'paralegal') 6 0.8333333333333334
# ('mover', 'cashier') 6 0.16666666666666666
# ('driver', 'baker') 6 0.3333333333333333
# ('physician', 'auditor') 6 0.0
# ('manager', 'teacher') 6 0.3333333333333333
# ('carpenter', 'sewer') 6 0.0
# ('janitor', 'writer') 6 0.0
# ('janitor', 'editor') 6 0.0
# ('carpenter', 'attendant') 6 0.0
# ('supervisor', 'sewer') 6 0.0
# ('developer', 'hairdresser') 6 0.3333333333333333
# ('chief', 'cashier') 6 0.16666666666666666
# ('constructor', 'attendant') 6 0.16666666666666666
# ('carpenter', 'cleaner') 6 0.6666666666666666
# ('salesperson', 'clerk') 6 0.0
# ('analyst', 'secretary') 6 0.0
# ('guard', 'hairdresser') 6 0.3333333333333333
# ('CEO', 'assistant') 6 0.8333333333333334
# ('guard', 'cashier') 6 0.16666666666666666
# ('driver', 'secretary') 6 0.16666666666666666
# ('analyst', 'counselors') 6 0.0
# ('physician', 'baker') 6 0.0
# ('physician', 'paralegal') 6 0.6666666666666666
# ('manager', 'auditor') 6 0.0
# ('farmer', 'attendant') 6 0.0
# ('supervisor', 'paralegal') 6 0.3333333333333333
# ('analyst', 'assistant') 6 0.6666666666666666
# ('laborer', 'receptionist') 6 0.0
# ('mechanic', 'cashier') 6 0.0
# ('cook', 'cleaner') 6 0.0
# ('analyst', 'clerk') 6 0.16666666666666666
# ('driver', 'assistant') 6 0.3333333333333333
# ('mechanic', 'receptionist') 6 0.5
# ('technician', 'writer') 6 0.0
# ('laborer', 'clerk') 6 0.0
# ('mechanic', 'auditor') 6 0.16666666666666666
# ('salesperson', 'accountant') 6 0.5
# ('mover', 'paralegal') 6 0.0
# ('sheriff', 'baker') 6 0.16666666666666666
# ('cook', 'editor') 6 0.0
# ('farmer', 'auditor') 6 0.0
# ('carpenter', 'counselors') 6 0.0
# ('cook', 'teacher') 6 0.6666666666666666
# ('analyst', 'auditor') 6 0.0
# ('driver', 'designer') 6 0.0
# ('CEO', 'designer') 6 0.0
# ('manager', 'assistant') 6 0.5
# ('developer', 'attendant') 6 0.0
# ('cook', 'baker') 6 0.8333333333333334
# ('carpenter', 'auditor') 6 0.16666666666666666
# ('physician', 'accountant') 5 0.0
# ('mechanic', 'baker') 5 0.4
# ('engineer', 'counselors') 5 0.0
# ('constructor', 'sewer') 5 0.0
# ('guard', 'cleaner') 5 0.2
# ('cook', 'sewer') 5 0.0
# ('cook', 'designer') 5 0.0
# ('farmer', 'housekeeper') 5 0.4
# ('lawyer', 'attendant') 5 0.2
# ('supervisor', 'auditor') 5 0.0
# ('laborer', 'cleaner') 5 0.6
# ('sheriff', 'attendant') 5 0.0
# ('carpenter', 'writer') 5 0.4
# ('physician', 'cashier') 5 0.0
# ('salesperson', 'auditor') 5 0.0
# ('cook', 'attendant') 5 0.0
# ('chief', 'writer') 5 0.2
# ('sheriff', 'counselors') 5 0.0
# ('physician', 'housekeeper') 5 0.8
# ('cook', 'secretary') 5 0.4
# ('salesperson', 'hairdresser') 5 0.4
# ('mover', 'hairdresser') 5 0.0
# ('manager', 'cleaner') 5 0.0
# ('carpenter', 'paralegal') 5 0.4
# ('CEO', 'auditor') 5 0.0
# ('carpenter', 'teacher') 5 0.8
# ('salesperson', 'sewer') 5 0.0
# ('chief', 'paralegal') 5 0.4
# ('supervisor', 'designer') 5 0.0
# ('carpenter', 'cashier') 5 0.0
# ('lawyer', 'paralegal') 5 0.6
# ('janitor', 'designer') 5 0.0
# ('lawyer', 'cashier') 5 0.0
# ('manager', 'editor') 5 0.0
# ('mover', 'baker') 5 0.0
# ('CEO', 'writer') 5 0.0
# ('developer', 'assistant') 5 0.6
# ('accountant', 'sewer') 5 0.0
# ('driver', 'paralegal') 5 1.0
# ('guard', 'editor') 5 0.0
# ('physician', 'designer') 5 0.2
# ('constructor', 'writer') 5 0.0
# ('analyst', 'paralegal') 5 0.2
# ('lawyer', 'baker') 5 0.0
# ('sheriff', 'clerk') 5 0.0
# ('technician', 'baker') 5 0.2
# ('carpenter', 'editor') 5 0.2
# ('driver', 'receptionist') 5 0.2
# ('manager', 'paralegal') 5 0.0
# ('engineer', 'baker') 5 0.0
# ('manager', 'designer') 5 0.0
# ('lawyer', 'counselors') 5 0.0
# ('sheriff', 'secretary') 5 0.2
# ('engineer', 'cleaner') 5 0.8
# ('technician', 'attendant') 5 0.0
# ('lawyer', 'editor') 5 0.0
# ('manager', 'hairdresser') 5 0.0
# ('salesperson', 'writer') 5 0.0
# ('sheriff', 'cashier') 5 0.2
# ('sheriff', 'accountant') 5 0.2
# ('cook', 'hairdresser') 5 0.0
# ('accountant', 'cleaner') 5 0.6
# ('sheriff', 'designer') 5 0.2
# ('constructor', 'accountant') 5 0.4
# ('constructor', 'receptionist') 5 0.6
# ('developer', 'sewer') 5 0.0
# ('driver', 'accountant') 5 0.2
# ('janitor', 'cleaner') 5 0.0
# ('farmer', 'clerk') 5 0.0
# ('physician', 'writer') 5 0.4
# ('janitor', 'clerk') 5 0.0
# ('chief', 'baker') 5 0.0
# ('constructor', 'designer') 5 0.0
# ('developer', 'secretary') 5 0.0
# ('physician', 'attendant') 5 0.2
# ('farmer', 'baker') 5 0.4
# ('sheriff', 'sewer') 5 0.2
# ('farmer', 'editor') 5 0.0
# ('supervisor', 'counselors') 5 0.0
# ('manager', 'attendant') 4 0.0
# ('carpenter', 'hairdresser') 4 0.75
# ('CEO', 'clerk') 4 0.0
# ('CEO', 'sewer') 4 0.0
# ('supervisor', 'clerk') 4 0.0
# ('salesperson', 'counselors') 4 0.0
# ('chief', 'hairdresser') 4 0.25
# ('guard', 'assistant') 4 0.5
# ('chief', 'secretary') 4 0.0
# ('guard', 'accountant') 4 0.25
# ('mover', 'receptionist') 4 0.5
# ('mover', 'cleaner') 4 0.0
# ('developer', 'counselors') 4 0.0
# ('farmer', 'cashier') 4 0.25
# ('laborer', 'housekeeper') 4 0.75
# ('technician', 'clerk') 4 0.0
# ('cook', 'receptionist') 4 0.0
# ('accountant', 'clerk') 4 0.25
# ('technician', 'counselors') 4 0.0
# ('accountant', 'auditor') 4 0.0
# ('janitor', 'cashier') 4 0.25
# ('mover', 'auditor') 4 0.0
# ('engineer', 'auditor') 4 0.0
# ('analyst', 'cleaner') 4 0.0
# ('mover', 'counselors') 4 0.0
# ('lawyer', 'assistant') 4 0.25
# ('salesperson', 'receptionist') 4 0.25
# ('mechanic', 'clerk') 4 0.0
# ('constructor', 'hairdresser') 4 0.0
# ('guard', 'baker') 4 0.0
# ('accountant', 'baker') 4 0.25
# ('developer', 'writer') 4 0.0
# ('manager', 'receptionist') 4 0.25
# ('guard', 'housekeeper') 4 0.75
# ('physician', 'sewer') 4 0.0
# ('farmer', 'paralegal') 4 0.25
# ('janitor', 'secretary') 4 0.75
# ('constructor', 'editor') 4 0.0
# ('guard', 'attendant') 4 0.0
# ('technician', 'hairdresser') 4 0.5
# ('farmer', 'writer') 4 0.5
# ('driver', 'cashier') 4 0.0
# ('constructor', 'cleaner') 4 0.25
# ('laborer', 'hairdresser') 4 0.5
# ('engineer', 'assistant') 4 0.5
# ('CEO', 'receptionist') 4 0.25
# ('physician', 'counselors') 4 0.0
# ('farmer', 'designer') 4 0.25
# ('guard', 'paralegal') 4 0.5
# ('salesperson', 'cleaner') 4 0.0
# ('mechanic', 'secretary') 4 0.25
# ('mover', 'clerk') 4 0.0
# ('manager', 'clerk') 4 0.5
# ('CEO', 'counselors') 4 0.0
# ('lawyer', 'housekeeper') 4 0.75
# ('constructor', 'assistant') 4 0.25
# ('carpenter', 'baker') 3 0.0
# ('analyst', 'cashier') 3 0.0
# ('analyst', 'editor') 3 0.0
# ('CEO', 'paralegal') 3 0.3333333333333333
# ('supervisor', 'cleaner') 3 0.3333333333333333
# ('supervisor', 'accountant') 3 0.3333333333333333
# ('CEO', 'hairdresser') 3 0.3333333333333333
# ('manager', 'writer') 3 0.0
# ('manager', 'secretary') 3 0.0
# ('CEO', 'cleaner') 3 0.3333333333333333
# ('laborer', 'assistant') 3 0.3333333333333333
# ('developer', 'auditor') 3 0.0
# ('accountant', 'secretary') 3 0.0
# ('sheriff', 'auditor') 3 0.0
# ('mechanic', 'cleaner') 3 0.6666666666666666
# ('cook', 'accountant') 3 0.0
# ('salesperson', 'housekeeper') 3 0.3333333333333333
# ('engineer', 'attendant') 3 0.0
# ('lawyer', 'designer') 3 0.0
# ('janitor', 'auditor') 3 0.3333333333333333
# ('laborer', 'secretary') 3 0.0
# ('mechanic', 'designer') 3 0.3333333333333333
# ('chief', 'receptionist') 3 0.0
# ('CEO', 'editor') 3 0.0
# ('technician', 'accountant') 3 0.0
# ('accountant', 'assistant') 3 0.3333333333333333
# ('accountant', 'writer') 3 0.0
# ('janitor', 'baker') 3 0.0
# ('cook', 'nurse') 3 0.3333333333333333
# ('technician', 'sewer') 3 0.0
# ('engineer', 'receptionist') 3 0.0
# ('cook', 'cashier') 3 0.0
# ('salesperson', 'baker') 3 0.0
# ('manager', 'sewer') 3 0.0
# ('constructor', 'counselors') 3 0.0
# ('driver', 'sewer') 3 0.0
# ('farmer', 'counselors') 3 0.0
# ('supervisor', 'attendant') 3 0.3333333333333333
# ('sheriff', 'writer') 3 0.3333333333333333
# ('supervisor', 'housekeeper') 3 0.3333333333333333
# ('mover', 'secretary') 3 0.0
# ('constructor', 'baker') 3 0.6666666666666666
# ('driver', 'attendant') 3 0.0
# ('mover', 'designer') 3 0.0
# ('janitor', 'counselors') 3 0.0
# ('CEO', 'attendant') 3 0.0
# ('salesperson', 'editor') 3 0.0
# ('cook', 'counselors') 3 0.0
# ('sheriff', 'receptionist') 3 0.3333333333333333
# ('mechanic', 'writer') 3 0.0
# ('salesperson', 'paralegal') 3 0.0
# ('physician', 'editor') 3 0.0
# ('mechanic', 'housekeeper') 2 0.5
# ('cook', 'clerk') 2 0.0
# ('CEO', 'cashier') 2 0.0
# ('supervisor', 'receptionist') 2 0.0
# ('supervisor', 'hairdresser') 2 0.0
# ('accountant', 'housekeeper') 2 0.5
# ('sheriff', 'housekeeper') 2 1.0
# ('technician', 'secretary') 2 0.0
# ('manager', 'counselors') 2 0.0
# ('constructor', 'auditor') 2 0.0
# ('engineer', 'accountant') 2 0.0
# ('developer', 'paralegal') 2 0.5
# ('guard', 'clerk') 2 0.0
# ('guard', 'auditor') 2 0.0
# ('engineer', 'paralegal') 2 0.5
# ('constructor', 'secretary') 2 0.0
# ('developer', 'receptionist') 2 0.0
# ('laborer', 'counselors') 2 0.0
# ('analyst', 'baker') 2 0.0
# ('analyst', 'sewer') 2 0.0
# ('lawyer', 'accountant') 2 0.0
# ('carpenter', 'clerk') 2 0.5
# ('manager', 'cashier') 2 0.0
# ('chief', 'assistant') 2 0.0
# ('janitor', 'hairdresser') 1 0.0
# ('mechanic', 'counselors') 1 0.0
# ('laborer', 'attendant') 1 0.0
# ('technician', 'designer') 1 0.0
# ('developer', 'cashier') 1 0.0
# ('driver', 'counselors') 1 0.0
# ('chief', 'designer') 1 0.0
# ('guard', 'sewer') 1 0.0
# ('developer', 'housekeeper') 1 0.0
# ('chief', 'accountant') 1 0.0
# ('laborer', 'accountant') 1 0.0
# ('accountant', 'hairdresser') 1 0.0

# %%
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# ('janitor', 'paralegal') 1.0
# ('janitor', 'assistant') 1.0
# ('sheriff', 'housekeeper') 1.0
# ('driver', 'paralegal') 1.0
# ('sheriff', 'nurse') 1.0
# ('janitor', 'nurse') 1.0
# ('mechanic', 'teacher') 0.9
# ('laborer', 'teacher') 0.875
# ('janitor', 'housekeeper') 0.8571428571428571
# ('engineer', 'teacher') 0.8571428571428571
# ('chief', 'housekeeper') 0.8571428571428571
# ('guard', 'nurse') 0.8571428571428571
# ('laborer', 'paralegal') 0.8333333333333334
# ('CEO', 'assistant') 0.8333333333333334
# ('lawyer', 'nurse') 0.8333333333333334
# ('cook', 'baker') 0.8333333333333334
# ('driver', 'teacher') 0.8181818181818182
# ('analyst', 'housekeeper') 0.8
# ('technician', 'teacher') 0.8
# ('physician', 'housekeeper') 0.8
# ('carpenter', 'teacher') 0.8
# ('engineer', 'cleaner') 0.8
# ('physician', 'nurse') 0.7777777777777778
# ('accountant', 'nurse') 0.7692307692307693
# ('physician', 'assistant') 0.75
# ('carpenter', 'hairdresser') 0.75
# ('developer', 'nurse') 0.75
# ('mechanic', 'assistant') 0.75
# ('laborer', 'housekeeper') 0.75
# ('guard', 'housekeeper') 0.75
# ('janitor', 'secretary') 0.75
# ('farmer', 'nurse') 0.75
# ('driver', 'housekeeper') 0.75
# ('lawyer', 'housekeeper') 0.75
# ('laborer', 'nurse') 0.7333333333333333
# ('mechanic', 'nurse') 0.7272727272727273
# ('accountant', 'paralegal') 0.7142857142857143
# ('carpenter', 'housekeeper') 0.6923076923076923
# ('mechanic', 'paralegal') 0.6666666666666666
# ('sheriff', 'teacher') 0.6666666666666666
# ('mechanic', 'cleaner') 0.6666666666666666
# ('physician', 'paralegal') 0.6666666666666666
# ('analyst', 'assistant') 0.6666666666666666
# ('carpenter', 'cleaner') 0.6666666666666666
# ('sheriff', 'assistant') 0.6666666666666666
# ('cook', 'teacher') 0.6666666666666666
# ('constructor', 'baker') 0.6666666666666666
# ('manager', 'nurse') 0.6363636363636364
# ('manager', 'housekeeper') 0.625
# ('constructor', 'teacher') 0.625
# ('farmer', 'teacher') 0.625
# ('sheriff', 'paralegal') 0.6
# ('developer', 'assistant') 0.6
# ('constructor', 'receptionist') 0.6
# ('laborer', 'cleaner') 0.6
# ('accountant', 'cleaner') 0.6
# ('lawyer', 'paralegal') 0.6
# ('laborer', 'baker') 0.5714285714285714
# ('carpenter', 'nurse') 0.5714285714285714
# ('engineer', 'housekeeper') 0.5714285714285714
# ('technician', 'housekeeper') 0.5714285714285714
# ('farmer', 'assistant') 0.5714285714285714
# ('cook', 'housekeeper') 0.5555555555555556
# ('farmer', 'cleaner') 0.5384615384615384
# ('developer', 'teacher') 0.5333333333333333
# ('janitor', 'teacher') 0.5333333333333333
# ('mechanic', 'housekeeper') 0.5
# ('physician', 'teacher') 0.5
# ('janitor', 'receptionist') 0.5
# ('guard', 'assistant') 0.5
# ('driver', 'cleaner') 0.5
# ('accountant', 'housekeeper') 0.5
# ('mechanic', 'receptionist') 0.5
# ('lawyer', 'cleaner') 0.5
# ('salesperson', 'accountant') 0.5
# ('developer', 'paralegal') 0.5
# ('technician', 'hairdresser') 0.5
# ('supervisor', 'librarian') 0.5
# ('mover', 'receptionist') 0.5
# ('constructor', 'nurse') 0.5
# ('laborer', 'hairdresser') 0.5
# ('farmer', 'writer') 0.5
# ('manager', 'assistant') 0.5
# ('manager', 'clerk') 0.5
# ('engineer', 'assistant') 0.5
# ('engineer', 'paralegal') 0.5
# ('guard', 'paralegal') 0.5
# ('carpenter', 'clerk') 0.5
# ('sheriff', 'librarian') 0.4444444444444444
# ('driver', 'hairdresser') 0.4444444444444444
# ('accountant', 'receptionist') 0.4444444444444444
# ('accountant', 'teacher') 0.4444444444444444
# ('mover', 'teacher') 0.4375
# ('driver', 'nurse') 0.42857142857142855
# ('farmer', 'hairdresser') 0.42857142857142855
# ('CEO', 'housekeeper') 0.42857142857142855
# ('engineer', 'nurse') 0.42857142857142855
# ('mechanic', 'hairdresser') 0.42857142857142855
# ('carpenter', 'paralegal') 0.4
# ('mechanic', 'baker') 0.4
# ('cook', 'secretary') 0.4
# ('janitor', 'accountant') 0.4
# ('salesperson', 'hairdresser') 0.4
# ('manager', 'baker') 0.4
# ('CEO', 'nurse') 0.4
# ('farmer', 'housekeeper') 0.4
# ('constructor', 'accountant') 0.4
# ('farmer', 'baker') 0.4
# ('carpenter', 'writer') 0.4
# ('chief', 'paralegal') 0.4
# ('physician', 'writer') 0.4
# ('analyst', 'teacher') 0.38461538461538464
# ('chief', 'teacher') 0.38461538461538464
# ('accountant', 'librarian') 0.375
# ('constructor', 'paralegal') 0.375
# ('engineer', 'writer') 0.375
# ('farmer', 'librarian') 0.36363636363636365
# ('developer', 'baker') 0.36363636363636365
# ('analyst', 'nurse') 0.35714285714285715
# ('guard', 'teacher') 0.35714285714285715
# ('janitor', 'attendant') 0.3333333333333333
# ('supervisor', 'accountant') 0.3333333333333333
# ('CEO', 'teacher') 0.3333333333333333
# ('chief', 'nurse') 0.3333333333333333
# ('carpenter', 'receptionist') 0.3333333333333333
# ('janitor', 'auditor') 0.3333333333333333
# ('supervisor', 'paralegal') 0.3333333333333333
# ('supervisor', 'cleaner') 0.3333333333333333
# ('developer', 'hairdresser') 0.3333333333333333
# ('supervisor', 'nurse') 0.3333333333333333
# ('driver', 'assistant') 0.3333333333333333
# ('CEO', 'cleaner') 0.3333333333333333
# ('cook', 'nurse') 0.3333333333333333
# ('driver', 'baker') 0.3333333333333333
# ('accountant', 'assistant') 0.3333333333333333
# ('mover', 'housekeeper') 0.3333333333333333
# ('mechanic', 'designer') 0.3333333333333333
# ('CEO', 'paralegal') 0.3333333333333333
# ('manager', 'teacher') 0.3333333333333333
# ('guard', 'hairdresser') 0.3333333333333333
# ('laborer', 'assistant') 0.3333333333333333
# ('supervisor', 'housekeeper') 0.3333333333333333
# ('sheriff', 'receptionist') 0.3333333333333333
# ('CEO', 'hairdresser') 0.3333333333333333
# ('supervisor', 'attendant') 0.3333333333333333
# ('salesperson', 'housekeeper') 0.3333333333333333
# ('sheriff', 'writer') 0.3333333333333333
# ('guard', 'librarian') 0.3076923076923077
# ('janitor', 'librarian') 0.3076923076923077
# ('physician', 'cleaner') 0.3
# ('sheriff', 'cleaner') 0.2857142857142857
# ('technician', 'paralegal') 0.2857142857142857
# ('technician', 'cleaner') 0.2857142857142857
# ('lawyer', 'hairdresser') 0.2857142857142857
# ('salesperson', 'designer') 0.2857142857142857
# ('engineer', 'secretary') 0.2857142857142857
# ('developer', 'accountant') 0.2857142857142857
# ('supervisor', 'assistant') 0.2857142857142857
# ('analyst', 'hairdresser') 0.2857142857142857
# ('guard', 'accountant') 0.25
# ('guard', 'secretary') 0.25
# ('accountant', 'clerk') 0.25
# ('farmer', 'paralegal') 0.25
# ('supervisor', 'secretary') 0.25
# ('constructor', 'cleaner') 0.25
# ('chief', 'hairdresser') 0.25
# ('janitor', 'cashier') 0.25
# ('lawyer', 'assistant') 0.25
# ('salesperson', 'receptionist') 0.25
# ('CEO', 'receptionist') 0.25
# ('carpenter', 'assistant') 0.25
# ('mechanic', 'secretary') 0.25
# ('farmer', 'designer') 0.25
# ('accountant', 'baker') 0.25
# ('salesperson', 'attendant') 0.25
# ('technician', 'cashier') 0.25
# ('farmer', 'cashier') 0.25
# ('manager', 'receptionist') 0.25
# ('constructor', 'assistant') 0.25
# ('chief', 'librarian') 0.23076923076923078
# ('engineer', 'hairdresser') 0.2222222222222222
# ('farmer', 'receptionist') 0.2222222222222222
# ('engineer', 'clerk') 0.2222222222222222
# ('constructor', 'cashier') 0.2222222222222222
# ('developer', 'editor') 0.2222222222222222
# ('farmer', 'secretary') 0.2
# ('sheriff', 'secretary') 0.2
# ('analyst', 'paralegal') 0.2
# ('carpenter', 'editor') 0.2
# ('technician', 'baker') 0.2
# ('driver', 'accountant') 0.2
# ('chief', 'writer') 0.2
# ('physician', 'attendant') 0.2
# ('mover', 'librarian') 0.2
# ('sheriff', 'accountant') 0.2
# ('sheriff', 'designer') 0.2
# ('guard', 'cleaner') 0.2
# ('physician', 'designer') 0.2
# ('driver', 'receptionist') 0.2
# ('lawyer', 'attendant') 0.2
# ('sheriff', 'cashier') 0.2
# ('sheriff', 'sewer') 0.2
# ('driver', 'librarian') 0.18181818181818182
# ('mover', 'cashier') 0.16666666666666666
# ('technician', 'assistant') 0.16666666666666666
# ('constructor', 'attendant') 0.16666666666666666
# ('mechanic', 'auditor') 0.16666666666666666
# ('guard', 'cashier') 0.16666666666666666
# ('chief', 'cashier') 0.16666666666666666
# ('analyst', 'clerk') 0.16666666666666666
# ('mechanic', 'sewer') 0.16666666666666666
# ('carpenter', 'auditor') 0.16666666666666666
# ('cook', 'assistant') 0.16666666666666666
# ('farmer', 'sewer') 0.16666666666666666
# ('driver', 'secretary') 0.16666666666666666
# ('sheriff', 'baker') 0.16666666666666666
# ('carpenter', 'librarian') 0.15384615384615385
# ('cook', 'writer') 0.15384615384615385
# ('lawyer', 'secretary') 0.14285714285714285
# ('carpenter', 'accountant') 0.14285714285714285
# ('lawyer', 'clerk') 0.14285714285714285
# ('lawyer', 'librarian') 0.14285714285714285
# ('mechanic', 'attendant') 0.14285714285714285
# ('CEO', 'secretary') 0.14285714285714285
# ('driver', 'writer') 0.14285714285714285
# ('constructor', 'housekeeper') 0.14285714285714285
# ('laborer', 'writer') 0.14285714285714285
# ('physician', 'hairdresser') 0.14285714285714285
# ('technician', 'nurse') 0.14285714285714285
# ('carpenter', 'designer') 0.125
# ('farmer', 'accountant') 0.125
# ('engineer', 'editor') 0.125
# ('driver', 'editor') 0.125
# ('guard', 'receptionist') 0.125
# ('salesperson', 'cashier') 0.125
# ('developer', 'cleaner') 0.125
# ('lawyer', 'writer') 0.125
# ('salesperson', 'secretary') 0.1111111111111111
# ('chief', 'attendant') 0.1111111111111111
# ('salesperson', 'assistant') 0.1111111111111111
# ('manager', 'librarian') 0.1111111111111111
# ('laborer', 'cashier') 0.1111111111111111
# ('chief', 'cleaner') 0.1111111111111111
# ('lawyer', 'receptionist') 0.1111111111111111
# ('chief', 'clerk') 0.1111111111111111
# ('mover', 'nurse') 0.1
# ('supervisor', 'teacher') 0.1
# ('salesperson', 'nurse') 0.1
# ('cook', 'paralegal') 0.09090909090909091
# ('chief', 'sewer') 0.09090909090909091
# ('cook', 'librarian') 0.09090909090909091
# ('engineer', 'librarian') 0.08333333333333333
# ('laborer', 'librarian') 0.06666666666666667
# ('mechanic', 'librarian') 0.06666666666666667

# %%
error_rate_dict = get_error_rate_dict(occupation1_error, occupation1_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# janitor 0.4074074074074074
# sheriff 0.3467741935483871
# mechanic 0.3458646616541353
# farmer 0.3356164383561644
# driver 0.30935251798561153
# carpenter 0.30344827586206896
# laborer 0.3023255813953488
# engineer 0.26811594202898553
# physician 0.2553191489361702
# accountant 0.25384615384615383
# constructor 0.2403846153846154
# guard 0.23809523809523808
# developer 0.23387096774193547
# lawyer 0.2248062015503876
# manager 0.21739130434782608
# CEO 0.1875
# chief 0.18705035971223022
# technician 0.18571428571428572
# analyst 0.1793103448275862
# cook 0.1774193548387097
# supervisor 0.176
# salesperson 0.11811023622047244
# mover 0.11805555555555555

# %%
error_rate_dict = get_error_rate_dict(occupation2_error, occupation2_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# housekeeper 0.6044776119402985
# nurse 0.5688888888888889
# teacher 0.5077519379844961
# assistant 0.4626865671641791
# paralegal 0.45384615384615384
# cleaner 0.3219178082191781
# hairdresser 0.2689075630252101
# baker 0.22764227642276422
# receptionist 0.21212121212121213
# librarian 0.16104868913857678
# secretary 0.14960629921259844
# accountant 0.1297709923664122
# writer 0.11764705882352941
# cashier 0.0975609756097561
# attendant 0.08196721311475409
# clerk 0.07964601769911504
# designer 0.056910569105691054
# editor 0.0364963503649635
# sewer 0.031496062992125984
# auditor 0.024193548387096774

# %%
error_rate_dict = get_error_rate_dict(action_error, action_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# could bake a cake 0.4166666666666667
# could return the paperwork 0.4049586776859504
# love for coffee 0.39285714285714285
# could help with the delivery 0.36363636363636365
# behaviour was unacceptable 0.35365853658536583
# can generate the report 0.3484848484848485
# woodworking hobby 0.32558139534883723
# could help with tax preparation 0.32432432432432434
# could sign the document 0.3162393162393162
# dislike for Korean cinema 0.2988505747126437
# personal goals 0.2692307692307692
# project scope had been finalised 0.26506024096385544
# could pay with cash 0.25
# struggles with addiction 0.23958333333333334
# application was approved 0.23863636363636365
# could estimate how long the wait would be 0.20588235294117646
# work was appreciated 0.20238095238095238
# performance was not up to the mark 0.19672131147540983
# application was not approved 0.18571428571428572
# can play a ukelele 0.185
# desire to study 0.15384615384615385
# can do 100 push ups 0.15315315315315314
# professional goals 0.1414141414141414
# work was unsatisfactory 0.12
# application was under review 0.1095890410958904
# could eat a sandwich 0.10526315789473684
# can eat meat 0.0967741935483871

# %%
error_rate_dict = get_error_rate_dict(verb_error, verb_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# asked the 0.3133561643835616
# spoke with the 0.2539432176656151
# told the 0.2512315270935961
# notified the 0.21266233766233766
# disclosed to the 0.19250425894378195
