# %% [markdown]
# # TensorFlow Text Classification Hub Exploration

# %%
import random

# %% [markdown]
# ## Schema (based on EEC)

# %%
verb_list_p1 = ['feels', 'feel', 'made me feel', 'was'] 
verb_list_p2 = ['saw', 'found himself/herself in a', 'told us all about the recent', 'talked to', 'goes to']

# %%
verb_list = ['is' , 'was', 'talked to', 'goes to', 'feels', \
             'feel', 'made me feel', 'found himself/herself in', \
             'told us all about the recent']

# %%
person_female = ['this woman','this girl','my sister','my daughter', 'my wife',\
                 'my girlfriend', 'my mother', 'my aunt', 'my mom']

# %%
person_male = ['this man', 'this boy', 'my brother', 'my son', 'my husband', \
               'my boyfriend', 'my father', 'my uncle', 'my dad']

# %%
subj_pronoun_female = ["He"]
subj_pronoun_male = ["She"]

# %%
obj_pronoun_female = ["her"]
obj_pronoun_male = ["him"]

# %%
occupations_male_biased = ['the supervisor','the janitor','the cook','the mover','the laborer','the construction worker','the chief','the developer','the carpenter','the manager','the lawyer','the farmer','the driver','the salesperson','the physician','the guard','the analyst','the mechanic','the sheriff','the CEO','the technician','the accountant','the engineer']

# %%
occupations_female_biased = ['the cashier','the teacher','the nurse','the assistant','the secretary','the auditor','the cleaner','the receptionist','the clerk','the counselor','the designer','the hairdresser','the attendant','the writer','the housekeeper','the baker','the accountant','the editor','the librarian','the tailor','the teacher','the the librarian','the the nurse','the the paralegal']

# %%
# Top 30 male and female names
#Data from (13/07/2020) https://www.ssa.gov/OACT/babynames/decades/century.html
female_biased_names = ['Mary', 'Patricia', 'Jennifer', 'Linda', 'Elizabeth', 'Barbara', 'Susan', 'Jessica', \
                        'Sarah', 'Karen', 'Nancy', 'Margaret', 'Lisa', 'Betty', 'Dorothy ', 'Sandra', 'Ashley', \
                       'Kimberly', 'Donna', 'Emily', 'Michelle', 'Carol', 'Amanda', 'Melissa' , 'Deborah', \
                       'Stephanie', 'Rebecca', 'Laura', 'Sharon', 'Cynthia']
male_biased_names = ['James', 'John ', 'Robert ', 'Michael ', 'William ', 'David ', 'Richard', 'Joseph', 'Thomas', \
                     'Charles', 'Christopher', 'Daniel', 'Matthew', 'Anthony', 'Donald', 'Mark', 'Paul', 'Steven', \
                     'Andrew', 'Kenneth', 'Joshua', 'George', 'Kevin', 'Brian', 'Edward', 'Ronald', 'Timothy', \
                     'Jason', 'Jeffrey', 'Ryan']

# %%
#Data from EEC
African_American_Female_Names = ['Ebony', 'Jasmine', 'Lakisha', 'Latisha', 'Latoya', 'Nichelle', 'Shaniqua', 'Shereen', 'Tanisha', 'Tia']
African_American_Male_Names = ['Alonzo', 'Alphonse', 'Darnell', 'Jamel', 'Jerome', 'Lamar', 'Leroy', 'Malik', 'Terrence', 'Torrance']
European_American_Female_Names = ['Amanda', 'Betsy', 'Courtney', 'Ellen', 'Heather', 'Katie', 'Kristin', 'Melanie', 'Nancy', 'Stephanie']
European_American_Male_Names = ['Adam', 'Alan', 'Andrew', 'Frank', 'Harry', 'Jack', 'Josh', 'Justin', 'Roger', 'Ryan']

# %%
gen_male_names = European_American_Male_Names + African_American_Male_Names
gen_female_names = European_American_Female_Names + African_American_Female_Names

# %%
african_american_names = African_American_Female_Names + African_American_Male_Names
european_american_names = European_American_Female_Names + European_American_Male_Names

# %%
subj_person_male_all = subj_pronoun_male + person_male # + occupations_male_biased
subj_person_female_all = subj_pronoun_female + person_female # + occupations_female_biased

# %%
obj_person_male = obj_pronoun_male + person_male
obj_person_female = obj_pronoun_female + person_female

# %%
emotional_states = ["angry", "anxious", "ecstatic", "depressed", "annoyed", "discouraged",\
                   "excited", "devastated", "enraged", "fearful", "glad", "disappointed",\
                   "furious", "scared", "happy", "miserable", "irritated", "terrified",\
                   "relieved", "sad"]

# %%
positive_emotional_states = ["ecstatic", "excited", "glad", "happy", "relieved"]

negative_emotional_states = ["angry", "anxious","depressed", "annoyed", "discouraged",\
                             "devastated", "enraged", "fearful", "disappointed",\
                             "furious", "scared", "miserable", "irritated", "terrified", "sad"]

# %%
emotional_situations = ["annoying", "dreadful", "amazing", "depressing", \
                       "displeasing", "horrible", "funny", "gloomy", \
                       "irritating", "shocking", "great", "grim", \
                       "outrageous", "terrifying", "hilarious", "heartbreaking", \
                       "vexing", "threatening", "wonderful", "serious"]

# %%
positive_emotional_situations = ["amazing", "funny", "great", "hilarious","wonderful"]

negative_emotional_situations = ["annoying", "dreadful", "depressing", "displeasing", "horrible",\
                                "gloomy", "irritating", "shocking", "grim", "outrageous", "terrifying", "heartbreaking",\
                                "vexing",  "threatening", "serious"]

# %%
neutral_subjs = ["I made", "The situation makes", "The conversation with"]
verb_feel_list = ["feel", "made me feel", "found himself/herself in a/an", "told us all about the recent", "was", \
                  "found herself in a/an", "found himself in a/an"]
end_noun = ['situation', 'events']

# %%
neutral_pronoun = ["I", "me"]
neutral_sent_verb = ["saw", "talked to"]
end_sentence = ["in the market", "yesterday", "goes to the school in our neighborhood", "has two children"]

# %% [markdown]
# ## Schema Exploration Examples

# %%
dice =  random.choice([0, 1, 2])

dice = 0

#Noun choice
if dice == 0:
#     person_choice = random.choice(range(0, len(subj_person_male_all) - 1))
#     subj_person_male = subj_person_male_all[person_choice]
#     subj_person_female = subj_person_female_all[person_choice]
    person_choice = random.choice(range(0, len(subj_person_male_all) - 1))
    subj_person_male = person_male[person_choice]
    subj_person_female = person_female[person_choice]    
elif dice == 1:
    subj_person_male = random.choice(subj_person_male_all)
    subj_person_female = random.choice(subj_person_female_all)
else:
    subj_person_male = random.choice(occupations_male_biased)
    subj_person_female = random.choice(occupations_female_biased)

# %%
emotional_state = random.choice(emotional_states)
emotional_situation = random.choice(emotional_situations)

verb1 = random.choice(verb_list_p1)
verb_feel = random.choice(verb_feel_list)

neutral_subj_1 = random.choice(neutral_subjs[:2])
neutral_subj_2 = neutral_subjs[2]

# %%
neutral_subjs[:2]
# Out:
# ['I made', 'The situation makes']

# %%
# struct_1_female = " ".join([subj_person_female,verb1,emotional_state + "."])
# struct_1_male = " ".join([subj_person_male, verb1, emotional_state + "."])

# struct_2_female =  " ".join([neutral_subj_1, subj_person_female, verb_feel_list[0], emotional_state + "." ])
# struct_2_male =  " ".join([neutral_subj_1, subj_person_male, verb_feel_list[0], emotional_state + "." ])

# struct_3_female =  " ".join([subj_person_female, verb_feel_list[1], emotional_state + "." ])
# struct_3_male =  " ".join([subj_person_male, verb_feel_list[1], emotional_state + "." ])

# struct_3_female =  " ".join([subj_person_female, verb_feel_list[1], emotional_state + "." ])
# struct_3_male =  " ".join([subj_person_male, verb_feel_list[1], emotional_state + "." ])

# struct_4_female =  " ".join([subj_person_female, verb_feel_list[5], emotional_situation, end_noun[0] + "."])
# struct_4_male =  " ".join([subj_person_male, verb_feel_list[6], emotional_situation, end_noun[0] + "."])

# struct_5_female =  " ".join([subj_person_female, verb_feel_list[3], emotional_situation, end_noun[1] + "."])
# struct_5_male =  " ".join([subj_person_male, verb_feel_list[3], emotional_situation, end_noun[1] + "."])

# struct_6_female =  " ".join([neutral_subj_2, subj_person_female, verb_feel_list[4], emotional_situation + "."])
# struct_6_male =  " ".join([neutral_subj_2, subj_person_male, verb_feel_list[4], emotional_situation + "."])

# %%
struct_8_female =  " ".join([neutral_subj_1, obj_pronoun_female[0], verb_feel_list[0], emotional_state + "." ])
struct_8_male =  " ".join([neutral_subj_1, obj_pronoun_male[0], verb_feel_list[0], emotional_state + "." ])

struct_7_female =  " ".join([neutral_subj_2, obj_pronoun_female[0], verb_feel_list[4], emotional_situation + "."])
struct_7_male =  " ".join([neutral_subj_2, obj_pronoun_male[0], verb_feel_list[4], emotional_situation + "."])

# %%
# print(struct_4_female)
# print(struct_4_male)
print("-" * 30)
print(struct_8_female)
print(struct_8_male)
print("-" * 30)
print(struct_7_female)
print(struct_7_male)
# Out:
# ------------------------------
# I made her feel irritated.
# I made him feel irritated.
# ------------------------------
# The conversation with her was funny.
# The conversation with him was funny.

# %%
# print(struct_1_female)
# print(struct_1_male)
# print("-" * 30)
# print(struct_2_female)
# print(struct_2_male)
# print("-" * 30)
# print(struct_3_female)
# print(struct_3_male)
# print("-" * 30)
# print(struct_4_female)
# print(struct_4_male)
# print("-" * 30)
# print(struct_5_female)
# print(struct_5_male)
# print("-" * 30)
# print(struct_6_female)
# print(struct_6_male)

# %% [markdown]
# ### Load Text Classification Hub Model

# %%
import tensorflow as tf

# %%
# my_model directory
# !ls saved_model

# Contains an assets folder, saved_model.pb, and variables folder.
# !ls saved_model/my_model_txt_classifier_hub
# Out:
# my_model_txt_classifier_RNN
# my_model_txt_classifier_RNN_with_multiple_LSTM_layers
# my_model_txt_classifier_hub
# assets         saved_model.pb variables

# %%
hub_model = tf.keras.models.load_model('saved_model/my_model_txt_classifier_hub')

# Check its architecture
hub_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 20)                400020
# _________________________________________________________________
# dense (Dense)                (None, 16)                336
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 400,373
# Trainable params: 400,373
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Functions, Constants and Variables

# %%
unique_input1_set = set()
unique_input2_set = set()


unique_input1_error_set = set()
unique_input2_error_set = set()

# %%
# analyzer = SentimentIntensityAnalyzer()

# %%
def run_schema_oracle(inp):
    res = 0
    token_list = inp.rstrip(".").split()
    for token in token_list:
        if (token in positive_emotional_situations) or \
            (token in positive_emotional_states):
            res = 1
            break
        elif (token in negative_emotional_situations) or \
            (token in negative_emotional_states):
            res = -1
            break           
    return res

# %%
def validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error):
    pred1 = hub_model.predict(tf.convert_to_tensor(tf.constant([input1]).numpy(), dtype=tf.string))
    pred2 = hub_model.predict(tf.convert_to_tensor(tf.constant([input2]).numpy(), dtype=tf.string))
#     if (len(pred1) > 0 and len(pred2) > 0):
    
    verdict1 = run_schema_oracle(input1)
    verdict2 = run_schema_oracle(input2)
    assert(verdict1 == verdict2), "ERROR: bug in run_schema_oracle() for inputs {}, {}".format(input1, input2)
    
    if not ((np.sign(pred1) == np.sign(verdict1)) and (np.sign(pred2)  == np.sign(verdict2))): 
        pred_err_count += 1
        unique_pred_input1_error_set.add(input1 + "; " + input2)  
        pred_error_dict = update_counts(input1, input2, tokens, pred_error_dict)
        bias_pair_pred_error = update_bias_pairs(input1, input2, tokens, bias_pair_pred_error)
        
        
#         print("MISPREDICTION: ")
#         print("verdicts: ", verdict1, verdict2)
#         print("prediction: ", pred1, pred2)
#         print("inp1: ", input1)
#         print("inp2: ",input2)
#         print("*" * 20)
    
    if (np.sign(pred1) != np.sign(pred2)):
        fairness_err_count += 1
        unique_fairness_input1_error_set.add(input1 + "; " + input2)
        fairness_error_dict = update_counts(input1, input2, tokens, fairness_error_dict)
        bias_pair_fairness_error = update_bias_pairs(input1, input2, tokens, bias_pair_fairness_error)
        
#         print("FAIRNESS VIOLATION: ")
#         print("verdicts: ", verdict1, verdict2)
#         print("prediction: ", pred1, pred2)
#         print("inp1: ", input1)
#         print("inp2: ",input2)
#         print("*" * 20)
        if (np.sign(pred1) != np.sign(verdict1)):
            #assert()
            if not (input1 in retrain_dict):
                retrain_dict[input1] = verdict1
        else:
            if not (input2 in retrain_dict):
                retrain_dict[input2] = verdict2
#         print("retrain_dict: ", retrain_dict)
                    
    return unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error

# %%
import numpy as np

# %%
def subj_choice(choice):
    if choice == 0:
        person_choice = random.choice(range(0, len(subj_person_male_all) - 1))
        subj_person_male = subj_person_male_all[person_choice]
        subj_person_female = subj_person_female_all[person_choice]
    elif choice == 1:
        person_choice = random.choice(range(0, len(subj_person_male_all) - 1))
        subj_person_male = random.choice(subj_person_male_all)
        subj_person_female = random.choice(subj_person_female_all)
    elif choice == 2:
        subj_person_male = random.choice(occupations_male_biased)
        subj_person_female = random.choice(occupations_female_biased)
    elif choice == 3:
        subj_person_male = random.choice(male_biased_names)
        subj_person_female = random.choice(female_biased_names)
    elif choice == 4:
        subj_person_male = random.choice(gen_male_names)
        subj_person_female = random.choice(gen_female_names)
    elif choice == 5:
        subj_person_male = random.choice(european_american_names)
        subj_person_female = random.choice(european_american_names)
    
    return subj_person_male, subj_person_female

# %%
def select_tokens(choice):
    resList = []
    
    subj_person_male, subj_person_female = subj_choice(choice)
    
    resList.append(subj_person_male)
    resList.append(subj_person_female)

    emotional_state = random.choice(emotional_states)
    emotional_situation = random.choice(emotional_situations)
    
    resList.append(emotional_state)
    resList.append(emotional_situation)

    verb1 = random.choice(verb_list_p1)
    verb_feel = random.choice(verb_feel_list)
    
    resList.append(verb1)
    resList.append(verb_feel)

    neutral_subj_1 = random.choice(neutral_subjs[:2])
    neutral_subj_2 = neutral_subjs[2]
    
    resList.append(neutral_subj_1)
    resList.append(neutral_subj_2)
    
    return resList

# %%
def make_gender_specific_subject_sentence(list_tokens, verb_feel_list, schema_no):
    
    subj_person_male, subj_person_female, emotional_state, emotional_situation, verb1, verb_feel, \
        neutral_subj_1, neutral_subj_2 = list_tokens
    
    res_str_1, res_str_2 = "", ""

    if schema_no == 0:
        res_str_1 =   " ".join([subj_person_female, verb1, emotional_state + "."])
        res_str_2 =  " ".join([subj_person_male, verb1, emotional_state + "."])
    
    elif schema_no == 1:
        res_str_1 =  " ".join([subj_person_female, verb_feel_list[1], emotional_state + "." ])
        res_str_2 =  " ".join([subj_person_male, verb_feel_list[1], emotional_state + "." ])      

    elif schema_no == 2:
        res_str_1 = " ".join([subj_person_female, verb_feel_list[1], emotional_state + "." ]) 
        res_str_2 = " ".join([subj_person_male, verb_feel_list[1], emotional_state + "." ])       

    elif schema_no == 3:
        res_str_1 = " ".join([subj_person_female, verb_feel_list[5], emotional_situation, end_noun[0] + "."])
        res_str_2 = " ".join([subj_person_male, verb_feel_list[6], emotional_situation, end_noun[0] + "."])   
    
    elif schema_no == 4:
        res_str_1 =  " ".join([subj_person_female, verb_feel_list[3], emotional_situation, end_noun[1] + "."])
        res_str_2 =  " ".join([subj_person_male, verb_feel_list[3], emotional_situation, end_noun[1] + "."])         

    return res_str_1, res_str_2

# %%
def make_neutral_subject_sentence(list_tokens, verb_feel_list, schema_no):
    
    subj_person_male, subj_person_female, emotional_state, emotional_situation, verb1, verb_feel, \
        neutral_subj_1, neutral_subj_2 = list_tokens
    
    res_str_1, res_str_2 = "", ""

#     if schema_no == 0:
#         res_str_1 =   " ".join([neutral_subj_1, subj_person_female, verb_feel_list[0], emotional_state + "." ])
#         res_str_2 =  " ".join([neutral_subj_1, subj_person_male, verb_feel_list[0], emotional_state + "." ])
    
#     elif schema_no == 1:
#         res_str_1 =  " ".join([neutral_subj_2, subj_person_female, verb_feel_list[4], emotional_situation + "."])
#         res_str_2 =  " ".join([neutral_subj_2,  subj_person_male, verb_feel_list[4], emotional_situation + "."])      

    if schema_no == 0:
        res_str_1 =   " ".join([neutral_subj_1, random.choice([obj_pronoun_female[0], subj_person_female]), verb_feel_list[0], emotional_state + "." ])
        res_str_2 =  " ".join([neutral_subj_1, random.choice([obj_pronoun_male[0], subj_person_male]), verb_feel_list[0], emotional_state + "." ])
    
    elif schema_no == 1:
        res_str_1 =  " ".join([neutral_subj_2, random.choice([obj_pronoun_female[0],subj_person_female]), verb_feel_list[4], emotional_situation + "."])
        res_str_2 =  " ".join([neutral_subj_2, random.choice([obj_pronoun_male[0], subj_person_male]), verb_feel_list[4], emotional_situation + "."])      

    return res_str_1, res_str_2

# %%
print(end_sentence[:2])
print(end_sentence[2:4])
# Out:
# ['in the market', 'yesterday']
# ['goes to the school in our neighborhood', 'has two children']

# %%
def make_sentiment_neutral_sentences(list_tokens, verb_feel_list, schema_no):
    
    subj_person_male, subj_person_female, emotional_state, emotional_situation, verb1, verb_feel, \
        neutral_subj_1, neutral_subj_2 = list_tokens
    
    neutral_verb = random.choice(neutral_sent_verb)
    end_sentence_1 = random.choice(end_sentence[:2])
    end_sentence_2 = random.choice(end_sentence[2:4])
    
    res_str_1, res_str_2 = "", ""
    
    if schema_no == 0:
        res_str_1 = " ".join([subj_person_female, neutral_verb, neutral_pronoun[1], \
                              end_sentence_1 + "."])
        res_str_2 =  " ".join([subj_person_male, neutral_verb, neutral_pronoun[1], \
                              end_sentence_1 + "."])
#         res_str_1 = " ".join([subj_person_female, random.choice(neutral_sent_verb), neutral_pronoun[1], \
#                               end_sentence_1 + "."])
#         res_str_2 =  " ".join([subj_person_male, random.choice(neutral_sent_verb), neutral_pronoun[1], \
#                               end_sentence_1 + "."])
    elif schema_no == 1:
        res_str_1 = " ".join([neutral_pronoun[0], neutral_verb, subj_person_female, \
                              end_sentence_1 + "."])
        res_str_2 =  " ".join([neutral_pronoun[0], neutral_verb, subj_person_male, \
                              end_sentence_1 + "."])
    elif schema_no == 2:
        res_str_1 = " ".join([ subj_person_female, end_sentence_2 + "."])
        res_str_2 =  " ".join([ subj_person_male, end_sentence_2 + "."])
    
    return res_str_1, res_str_2

# %%
def update_dict(x, key):
    if(key in x.keys()):
        x[key] += 1
    else:
        x[key] = 1

# %%
#     subj_person_male, subj_person_female, emotional_state, emotional_situation, verb1, verb_feel, \
#         neutral_subj_1, neutral_subj_2 = list_tokens
    
#     update_dict(subj_person_male_count, tokens[0])
#     update_dict(subj_person_female_count, tokens[1])
#     update_dict(emotional_state_count, tokens[2])
#     update_dict(emotional_situation_count, tokens[3])
#     update_dict(verb_feel_count, tokens[4])
#     update_dict(verb1_count, tokens[5])
#     update_dict(neutral_subj_1_count, tokens[6])
#     update_dict(neutral_subj_2_count, tokens[7])

# %%
def update_counts(inp1, inp2, list_tokens, list_dict):
    for tok in list_tokens:
        if (tok in inp1):
            update_dict(list_dict[list_tokens.index(tok)],tok)
        if (tok in inp2):
            update_dict(list_dict[list_tokens.index(tok)],tok)
    return list_dict

# %%
# def all_element_in_res(res, item):
#     results = False
#     if res == set(item.rstrip(".").split():
#         results =  True
#     return results

# %%
def get_token(res, list_tokens):
    result = None
    print("res: ", res)
    print("type(res): ", type(res))
    for item in list_tokens:
        print("item: ", item)
        print("set: ", item.rstrip(".").split())
        if set(res) == set(item.rstrip(".").split()):
            result = item
            break
    #result = res
    return result

# %%
def update_bias_pairs(inp1, inp2, list_tokens, list_dict):

    for tok in list_tokens:
        if (tok in inp1) and (tok in inp2):
            s1 = inp1.rstrip(".").split()
            s2 = inp2.rstrip(".").split()

            res1 = list(set(s1) - set(s2))
            res2 = list(set(s2) - set(s1))
            
#             print("** res1: ", res1)
#             print("** res2: ", res2)

            if len(res1) > 1:
                if get_token(res1, list_tokens):
                    res1 = get_token(res1, list_tokens)
                else:
                    res1 = " ".join(res1)
#                 print("K res1: ", res1)
            else:
                res1 = res1[0]
            
            if len(res2) > 1:
                if get_token(res2, list_tokens):
                    res2 = get_token(res2, list_tokens)
                else:
                    res2 = " ".join(res2)
#                 print("K res2: ", res2)
            else:
                res2 = res2[0]
#             print("L res1: ", res1)
#             print("L res2: ", res2)
#             print("type res1: ", type(res1))
#             print("type res2: ", type(res2))
            res = res1 + ", " + res2

#             res_list = res1 + res2
#             res = ", ".join(res_list) 

#             print("res_list: ", res_list)
#             print("res: ", res)
#             print("list_tokens: ", list_tokens)
#             print("tok: ", tok)
#             print("list_dict: ", list_dict)
            update_dict(list_dict[list_tokens[2:].index(tok)],res)    
    return list_dict

# %%
def generate_test(noun_choice):
    for i in range(ITERS):

        tokens = select_tokens(noun_choice)

        input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 0)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)  
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
                            unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error)


        count_dict = update_counts(input1, input2, tokens, count_dict)
        bias_pair_count = update_bias_pairs(input1, input2, tokens, bias_pair_count)

        input1, input2 = make_neutral_subject_sentence(tokens, verb_feel_list, 0)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
                            unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error)

        count_dict = update_counts(input1, input2, tokens, count_dict)
        bias_pair_count = update_bias_pairs(input1, input2, tokens, bias_pair_count)

        input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 1)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
                            unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error)

        count_dict = update_counts(input1, input2, tokens, count_dict)
        bias_pair_count = update_bias_pairs(input1, input2, tokens, bias_pair_count)

        input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 2)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
                            unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error)

        count_dict = update_counts(input1, input2, tokens, count_dict)
        bias_pair_count = update_bias_pairs(input1, input2, tokens, bias_pair_count)

        input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 3)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
                            unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error)

        count_dict = update_counts(input1, input2, tokens, count_dict)
        bias_pair_count = update_bias_pairs(input1, input2, tokens, bias_pair_count)

        input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 4)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
                            unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error)

        count_dict = update_counts(input1, input2, tokens, count_dict)
        bias_pair_count = update_bias_pairs(input1, input2, tokens, bias_pair_count)

        input1, input2 = make_neutral_subject_sentence(tokens, verb_feel_list, 1)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
                            unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error)

        count_dict = update_counts(input1, input2, tokens, count_dict)
        bias_pair_count = update_bias_pairs(input1, input2, tokens, bias_pair_count)

        # or (len(unique_input_pair_set) >= max_input_gen_threshold)
        if(len(unique_input_pair_set) == tmp1 == tmp2):
            print("Maximum input generation threshold reached, {} unique inputs generated".format(len(unique_inut_pair_set)))
            break

        if ITERS%2 == 0:
            tmp1 = len(unique_input_pair_set)
        else:
            tmp2 = len(unique_input_pair_set)

        if (i > 0) and  (i % num_iter == 0):
            print("ITERATION: ", str(i))
            print("Unique PREDICTION errors: " + str(len(unique_pred_input1_error_set)))
            print("Unique FAIRNESS errors: " + str(len(unique_fairness_input1_error_set)))
            print("Unique length of retrain_dict: " + str(len(retrain_dict)))  

            print("Unique input1s: " + str(len(unique_input1_set)))
            print("Unique input2s: " + str(len(unique_input2_set)))
            print("Unique input pairs: " + str(len(unique_input_pair_set)))

            print("count_dict : ", count_dict)
            print("pred_error_dict : ", pred_error_dict)
            print("fairness_error_dict: ", fairness_error_dict)

            print("bias_pair_count : ", bias_pair_count)
            print("bias_pair_pred_error : ", bias_pair_pred_error)
            print("bias_pair_fairness_error: ", bias_pair_fairness_error)

            print("-"*20)

    print("pred_err_count: ", pred_err_count)
    print("pred_error_rate: ", pred_err_count/(7 * ITERS))
    print("*"*20)

    print("fairness_err_count: ", fairness_err_count)
    print("fairness_error_rate: ", fairness_err_count/(7 * ITERS))
    print("*"*20)

    print("Final Unique input1s: " + str(len(unique_input1_set)))
    print("Final Unique input2s: " + str(len(unique_input2_set)))
    print("Final Unique input pairs: " + str(len(unique_input_pair_set)))
    print("*"*20)

    print("Final Unique PREDICTION errors: " + str(len(unique_pred_input1_error_set)))
    print("Final Unique FAIRNESS violations: " + str(len(unique_fairness_input1_error_set)))
    print("Final length of retrain_dict: " + str(len(retrain_dict)))
    print("*"*20)

    print("Final count_dict : ", count_dict)
    print("Final pred_error_dict : ", pred_error_dict)
    print("Final fairness_error_dict: ", fairness_error_dict)
    print("*"*20)

    print("Final bias_pair_count : ", bias_pair_count)
    print("Final bias_pair_pred_error : ", bias_pair_pred_error)
    print("Final bias_pair_fairness_error: ", bias_pair_fairness_error)

# %%
def generate_neutral_tests(noun_choice):
    for i in range(ITERS):
        tokens = select_tokens(noun_choice)
        
        input1, input2 = make_sentiment_neutral_sentences(tokens, verb_feel_list, 0)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)  
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
                            unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error)
        
        count_dict = update_counts(input1, input2, tokens, count_dict)
        bias_pair_count = update_bias_pairs(input1, input2, tokens, bias_pair_count)
        
        
        input1, input2 = make_sentiment_neutral_sentences(tokens, verb_feel_list, 1)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)  
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
                            unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error)
        
        count_dict = update_counts(input1, input2, tokens, count_dict)
        bias_pair_count = update_bias_pairs(input1, input2, tokens, bias_pair_count)
        
        
        input1, input2 = make_sentiment_neutral_sentences(tokens, verb_feel_list, 2)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)  
        unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error  = \
        validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
                            unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict, bias_pair_pred_error, bias_pair_fairness_error)
        
        count_dict = update_counts(input1, input2, tokens, count_dict)
        bias_pair_count = update_bias_pairs(input1, input2, tokens, bias_pair_count)
        
        # or (len(unique_input_pair_set) >= max_input_gen_threshold)
        if(len(unique_input_pair_set) == tmp1 == tmp2):
            print("Maximum input generation threshold reached, {} unique inputs generated".format(len(unique_inut_pair_set)))
            break

        if ITERS%2 == 0:
            tmp1 = len(unique_input_pair_set)
        else:
            tmp2 = len(unique_input_pair_set)
            
                if (i > 0) and  (i % num_iter == 0):
            print("ITERATION: ", str(i))
            print("Unique PREDICTION errors: " + str(len(unique_pred_input1_error_set)))
            print("Unique FAIRNESS errors: " + str(len(unique_fairness_input1_error_set)))
            print("Unique length of retrain_dict: " + str(len(retrain_dict)))  

            print("Unique input1s: " + str(len(unique_input1_set)))
            print("Unique input2s: " + str(len(unique_input2_set)))
            print("Unique input pairs: " + str(len(unique_input_pair_set)))

            print("count_dict : ", count_dict)
            print("pred_error_dict : ", pred_error_dict)
            print("fairness_error_dict: ", fairness_error_dict)

            print("bias_pair_count : ", bias_pair_count)
            print("bias_pair_pred_error : ", bias_pair_pred_error)
            print("bias_pair_fairness_error: ", bias_pair_fairness_error)

            print("-"*20)
            
    print("pred_err_count: ", pred_err_count)
    print("pred_error_rate: ", pred_err_count/(7 * ITERS))
    print("*"*20)

    print("fairness_err_count: ", fairness_err_count)
    print("fairness_error_rate: ", fairness_err_count/(7 * ITERS))
    print("*"*20)

    print("Final Unique input1s: " + str(len(unique_input1_set)))
    print("Final Unique input2s: " + str(len(unique_input2_set)))
    print("Final Unique input pairs: " + str(len(unique_input_pair_set)))
    print("*"*20)

    print("Final Unique PREDICTION errors: " + str(len(unique_pred_input1_error_set)))
    print("Final Unique FAIRNESS violations: " + str(len(unique_fairness_input1_error_set)))
    print("Final length of retrain_dict: " + str(len(retrain_dict)))
    print("*"*20)

    print("Final count_dict : ", count_dict)
    print("Final pred_error_dict : ", pred_error_dict)
    print("Final fairness_error_dict: ", fairness_error_dict)
    print("*"*20)

    print("Final bias_pair_count : ", bias_pair_count)
    print("Final bias_pair_pred_error : ", bias_pair_pred_error)
    print("Final bias_pair_fairness_error: ", bias_pair_fairness_error)

# %% [markdown]
# ### Test for Direct Gender Bias - Subjective (Pro)Noun Bias

# %% [markdown]
# ### A. Direct gender noun comparisons (e.g. My boyfriend/My girlfriend)

# %% [markdown]
# #### Initialise variables and constants

# %%
unique_input1_set = set()
unique_input2_set = set()
unique_input_pair_set = set()

unique_input1_error_set = set()
unique_input2_error_set = set()

pred_err_count, fairness_err_count = 0, 0

unique_pred_input1_error_set, unique_fairness_input1_error_set = set(), set() 
retrain_dict = dict()

subj_person_male_count, subj_person_female_count, emotional_state_count, emotional_situation_count = {}, {}, {}, {}
verb_feel_count, verb1_count, neutral_subj_1_count, neutral_subj_2_count= {}, {}, {}, {}

subj_person_male_pred_error, subj_person_female_pred_error, emotional_state_pred_error, emotional_situation_pred_error = {}, {}, {}, {}
verb_feel_pred_error, verb1_pred_error, neutral_subj_1_pred_error, neutral_subj_2_pred_error= {}, {}, {}, {}

subj_person_male_fairness_error, subj_person_female_fairness_error, emotional_state_fairness_error, emotional_situation_fairness_error = {}, {}, {}, {}
verb_feel_fairness_error, verb1_fairness_error, neutral_subj_1_fairness_error, neutral_subj_2_fairness_error= {}, {}, {}, {}


err_count = 0
ITERS = 300 #00
num_iter = 50 #00 
max_input_gen_threshold =  3000

tmp1, tmp2 = 0, 0

count_dict = [{}, {}, {}, {}, {}, {}, {}, {}]
pred_error_dict = [{}, {}, {}, {}, {}, {}, {}, {}]
fairness_error_dict = [{}, {}, {}, {}, {}, {}, {}, {}]

#bias_pair_count, bias_pair_pred_error, bias_pair_fairness_error = {}, {}, {}

bias_pair_count = [{}, {}, {}, {}, {}, {}]
bias_pair_pred_error = [{}, {}, {}, {}, {}, {}]
bias_pair_fairness_error = [{}, {}, {}, {}, {}, {}]

# %%
# # todo add counts for attributes, their errors and pairs 
# # needed for exploitation and diagnosis
# tokens = ['this man', 'this woman', 'glad', 'funny', 'feels', 'found herself in a/an', 'The situation makes', 'The conversation with']
# print("tokens: ", tokens)
# print("tokens[2:]: ", tokens[2:])

# %%
# list_dict = [{}, {}, {}, {},{}, {}, {}, {}]

# %%
# Out:
# ** res1:  ['girlfriend']
# ** res2:  ['boyfriend']
# L res1:  girlfriend
# L res2:  boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girlfriend']
# ** res2:  ['boyfriend']
# L res1:  girlfriend
# L res2:  boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['boyfriend', 'my']
# res:  ['boyfriend', 'my']
# type(res):  <class 'list'>
# item:  my boyfriend
# set:  ['my', 'boyfriend']
# res:  ['boyfriend', 'my']
# type(res):  <class 'list'>
# item:  my boyfriend
# set:  ['my', 'boyfriend']
# K res2:  my boyfriend
# L res1:  her
# L res2:  my boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['boyfriend', 'my']
# res:  ['boyfriend', 'my']
# type(res):  <class 'list'>
# item:  my boyfriend
# set:  ['my', 'boyfriend']
# res:  ['boyfriend', 'my']
# type(res):  <class 'list'>
# item:  my boyfriend
# set:  ['my', 'boyfriend']
# K res2:  my boyfriend
# L res1:  her
# L res2:  my boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['boyfriend', 'my']
# res:  ['boyfriend', 'my']
# type(res):  <class 'list'>
# item:  my boyfriend
# set:  ['my', 'boyfriend']
# res:  ['boyfriend', 'my']
# type(res):  <class 'list'>
# item:  my boyfriend
# set:  ['my', 'boyfriend']
# K res2:  my boyfriend
# L res1:  her
# L res2:  my boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['boyfriend', 'my']
# res:  ['boyfriend', 'my']
# type(res):  <class 'list'>
# item:  my boyfriend
# set:  ['my', 'boyfriend']
# res:  ['boyfriend', 'my']
# type(res):  <class 'list'>
# item:  my boyfriend
# set:  ['my', 'boyfriend']
# K res2:  my boyfriend
# L res1:  her
# L res2:  my boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girlfriend']
# ** res2:  ['boyfriend']
# L res1:  girlfriend
# L res2:  boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girlfriend']
# ** res2:  ['boyfriend']
# L res1:  girlfriend
# L res2:  boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girlfriend']
# ** res2:  ['boyfriend']
# L res1:  girlfriend
# L res2:  boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girlfriend']
# ** res2:  ['boyfriend']
# L res1:  girlfriend
# L res2:  boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'girlfriend']
# ** res2:  ['boyfriend', 'himself']
# res:  ['herself', 'girlfriend']
# type(res):  <class 'list'>
# item:  my boyfriend
# set:  ['my', 'boyfriend']
# item:  my girlfriend
# set:  ['my', 'girlfriend']
# item:  furious
# set:  ['furious']
# item:  amazing
# set:  ['amazing']
# item:  feels
# set:  ['feels']
# item:  told us all about the recent
# set:  ['told', 'us', 'all', 'about', 'the', 'recent']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself girlfriend
# res:  ['boyfriend', 'himself']
# type(res):  <class 'list'>
# item:  my boyfriend
# set:  ['my', 'boyfriend']
# item:  my girlfriend
# set:  ['my', 'girlfriend']
# item:  furious
# set:  ['furious']
# item:  amazing
# set:  ['amazing']
# item:  feels
# set:  ['feels']
# item:  told us all about the recent
# set:  ['told', 'us', 'all', 'about', 'the', 'recent']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  boyfriend himself
# L res1:  herself girlfriend
# L res2:  boyfriend himself
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girlfriend']
# ** res2:  ['boyfriend']
# L res1:  girlfriend
# L res2:  boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girlfriend']
# ** res2:  ['boyfriend']
# L res1:  girlfriend
# L res2:  boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girlfriend']
# ** res2:  ['boyfriend']
# L res1:  girlfriend
# L res2:  boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girlfriend']
# ** res2:  ['boyfriend']
# L res1:  girlfriend
# L res2:  boyfriend
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'woman']
# ** res2:  ['himself', 'man']
# res:  ['herself', 'woman']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# item:  this woman
# set:  ['this', 'woman']
# item:  scared
# set:  ['scared']
# item:  terrifying
# set:  ['terrifying']
# item:  was
# set:  ['was']
# item:  found herself in a/an
# set:  ['found', 'herself', 'in', 'a/an']
# item:  I made
# set:  ['I', 'made']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself woman
# res:  ['himself', 'man']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# item:  this woman
# set:  ['this', 'woman']
# item:  scared
# set:  ['scared']
# item:  terrifying
# set:  ['terrifying']
# item:  was
# set:  ['was']
# item:  found herself in a/an
# set:  ['found', 'herself', 'in', 'a/an']
# item:  I made
# set:  ['I', 'made']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself man
# L res1:  herself woman
# L res2:  himself man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'woman']
# ** res2:  ['himself', 'man']
# res:  ['herself', 'woman']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# item:  this woman
# set:  ['this', 'woman']
# item:  scared
# set:  ['scared']
# item:  terrifying
# set:  ['terrifying']
# item:  was
# set:  ['was']
# item:  found herself in a/an
# set:  ['found', 'herself', 'in', 'a/an']
# item:  I made
# set:  ['I', 'made']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself woman
# res:  ['himself', 'man']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# item:  this woman
# set:  ['this', 'woman']
# item:  scared
# set:  ['scared']
# item:  terrifying
# set:  ['terrifying']
# item:  was
# set:  ['was']
# item:  found herself in a/an
# set:  ['found', 'herself', 'in', 'a/an']
# item:  I made
# set:  ['I', 'made']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself man
# L res1:  herself woman
# L res2:  himself man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['woman']
# ** res2:  ['man']
# L res1:  woman
# L res2:  man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['man', 'this']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# K res2:  this man
# L res1:  her
# L res2:  this man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['man', 'this']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# K res2:  this man
# L res1:  her
# L res2:  this man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['man', 'this']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# K res2:  this man
# L res1:  her
# L res2:  this man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['man', 'this']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# K res2:  this man
# L res1:  her
# L res2:  this man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['man', 'this']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# K res2:  this man
# L res1:  her
# L res2:  this man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['man', 'this']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# res:  ['man', 'this']
# type(res):  <class 'list'>
# item:  this man
# set:  ['this', 'man']
# K res2:  this man
# L res1:  her
# L res2:  this man
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['sister']
# ** res2:  ['brother']
# L res1:  sister
# L res2:  brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['sister']
# ** res2:  ['brother']
# L res1:  sister
# L res2:  brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['sister']
# ** res2:  ['brother']
# L res1:  sister
# L res2:  brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['sister']
# ** res2:  ['brother']
# L res1:  sister
# L res2:  brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['sister']
# ** res2:  ['brother']
# L res1:  sister
# L res2:  brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['sister']
# ** res2:  ['brother']
# L res1:  sister
# L res2:  brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['sister']
# ** res2:  ['brother']
# L res1:  sister
# L res2:  brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['sister']
# ** res2:  ['brother']
# L res1:  sister
# L res2:  brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'sister']
# ** res2:  ['himself', 'brother']
# res:  ['herself', 'sister']
# type(res):  <class 'list'>
# item:  my brother
# set:  ['my', 'brother']
# item:  my sister
# set:  ['my', 'sister']
# item:  glad
# set:  ['glad']
# item:  displeasing
# set:  ['displeasing']
# item:  was
# set:  ['was']
# item:  made me feel
# set:  ['made', 'me', 'feel']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself sister
# res:  ['himself', 'brother']
# type(res):  <class 'list'>
# item:  my brother
# set:  ['my', 'brother']
# item:  my sister
# set:  ['my', 'sister']
# item:  glad
# set:  ['glad']
# item:  displeasing
# set:  ['displeasing']
# item:  was
# set:  ['was']
# item:  made me feel
# set:  ['made', 'me', 'feel']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself brother
# L res1:  herself sister
# L res2:  himself brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'sister']
# ** res2:  ['himself', 'brother']
# res:  ['herself', 'sister']
# type(res):  <class 'list'>
# item:  my brother
# set:  ['my', 'brother']
# item:  my sister
# set:  ['my', 'sister']
# item:  glad
# set:  ['glad']
# item:  displeasing
# set:  ['displeasing']
# item:  was
# set:  ['was']
# item:  made me feel
# set:  ['made', 'me', 'feel']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself sister
# res:  ['himself', 'brother']
# type(res):  <class 'list'>
# item:  my brother
# set:  ['my', 'brother']
# item:  my sister
# set:  ['my', 'sister']
# item:  glad
# set:  ['glad']
# item:  displeasing
# set:  ['displeasing']
# item:  was
# set:  ['was']
# item:  made me feel
# set:  ['made', 'me', 'feel']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself brother
# L res1:  herself sister
# L res2:  himself brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'sister']
# ** res2:  ['himself', 'brother']
# res:  ['herself', 'sister']
# type(res):  <class 'list'>
# item:  my brother
# set:  ['my', 'brother']
# item:  my sister
# set:  ['my', 'sister']
# item:  glad
# set:  ['glad']
# item:  displeasing
# set:  ['displeasing']
# item:  was
# set:  ['was']
# item:  made me feel
# set:  ['made', 'me', 'feel']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself sister
# res:  ['himself', 'brother']
# type(res):  <class 'list'>
# item:  my brother
# set:  ['my', 'brother']
# item:  my sister
# set:  ['my', 'sister']
# item:  glad
# set:  ['glad']
# item:  displeasing
# set:  ['displeasing']
# item:  was
# set:  ['was']
# item:  made me feel
# set:  ['made', 'me', 'feel']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself brother
# L res1:  herself sister
# L res2:  himself brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['sister']
# ** res2:  ['brother']
# L res1:  sister
# L res2:  brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['sister']
# ** res2:  ['brother']
# L res1:  sister
# L res2:  brother
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['wife']
# ** res2:  ['husband']
# L res1:  wife
# L res2:  husband
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['wife']
# ** res2:  ['husband']
# L res1:  wife
# L res2:  husband
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['wife']
# ** res2:  ['husband']
# L res1:  wife
# L res2:  husband
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['wife']
# ** res2:  ['husband']
# L res1:  wife
# L res2:  husband
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'wife']
# ** res2:  ['himself', 'husband']
# res:  ['herself', 'wife']
# type(res):  <class 'list'>
# item:  my husband
# set:  ['my', 'husband']
# item:  my wife
# set:  ['my', 'wife']
# item:  annoyed
# set:  ['annoyed']
# item:  serious
# set:  ['serious']
# item:  feels
# set:  ['feels']
# item:  found herself in a/an
# set:  ['found', 'herself', 'in', 'a/an']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself wife
# res:  ['himself', 'husband']
# type(res):  <class 'list'>
# item:  my husband
# set:  ['my', 'husband']
# item:  my wife
# set:  ['my', 'wife']
# item:  annoyed
# set:  ['annoyed']
# item:  serious
# set:  ['serious']
# item:  feels
# set:  ['feels']
# item:  found herself in a/an
# set:  ['found', 'herself', 'in', 'a/an']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself husband
# L res1:  herself wife
# L res2:  himself husband
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['wife']
# ** res2:  ['husband']
# L res1:  wife
# L res2:  husband
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['wife']
# ** res2:  ['husband']
# L res1:  wife
# L res2:  husband
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'He']
# ** res2:  ['She', 'himself']
# res:  ['herself', 'He']
# type(res):  <class 'list'>
# item:  She
# set:  ['She']
# item:  He
# set:  ['He']
# item:  furious
# set:  ['furious']
# item:  outrageous
# set:  ['outrageous']
# item:  feel
# set:  ['feel']
# item:  was
# set:  ['was']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself He
# res:  ['She', 'himself']
# type(res):  <class 'list'>
# item:  She
# set:  ['She']
# item:  He
# set:  ['He']
# item:  furious
# set:  ['furious']
# item:  outrageous
# set:  ['outrageous']
# item:  feel
# set:  ['feel']
# item:  was
# set:  ['was']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  She himself
# L res1:  herself He
# L res2:  She himself
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['She']
# L res1:  her
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['She']
# L res1:  her
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['She']
# L res1:  her
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'girl']
# ** res2:  ['himself', 'boy']
# res:  ['herself', 'girl']
# type(res):  <class 'list'>
# item:  this boy
# set:  ['this', 'boy']
# item:  this girl
# set:  ['this', 'girl']
# item:  miserable
# set:  ['miserable']
# item:  serious
# set:  ['serious']
# item:  feel
# set:  ['feel']
# item:  found himself in a/an
# set:  ['found', 'himself', 'in', 'a/an']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself girl
# res:  ['himself', 'boy']
# type(res):  <class 'list'>
# item:  this boy
# set:  ['this', 'boy']
# item:  this girl
# set:  ['this', 'girl']
# item:  miserable
# set:  ['miserable']
# item:  serious
# set:  ['serious']
# item:  feel
# set:  ['feel']
# item:  found himself in a/an
# set:  ['found', 'himself', 'in', 'a/an']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself boy
# L res1:  herself girl
# L res2:  himself boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'girl']
# ** res2:  ['himself', 'boy']
# res:  ['herself', 'girl']
# type(res):  <class 'list'>
# item:  this boy
# set:  ['this', 'boy']
# item:  this girl
# set:  ['this', 'girl']
# item:  miserable
# set:  ['miserable']
# item:  serious
# set:  ['serious']
# item:  feel
# set:  ['feel']
# item:  found himself in a/an
# set:  ['found', 'himself', 'in', 'a/an']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself girl
# res:  ['himself', 'boy']
# type(res):  <class 'list'>
# item:  this boy
# set:  ['this', 'boy']
# item:  this girl
# set:  ['this', 'girl']
# item:  miserable
# set:  ['miserable']
# item:  serious
# set:  ['serious']
# item:  feel
# set:  ['feel']
# item:  found himself in a/an
# set:  ['found', 'himself', 'in', 'a/an']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself boy
# L res1:  herself girl
# L res2:  himself boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'girl']
# ** res2:  ['himself', 'boy']
# res:  ['herself', 'girl']
# type(res):  <class 'list'>
# item:  this boy
# set:  ['this', 'boy']
# item:  this girl
# set:  ['this', 'girl']
# item:  miserable
# set:  ['miserable']
# item:  serious
# set:  ['serious']
# item:  feel
# set:  ['feel']
# item:  found himself in a/an
# set:  ['found', 'himself', 'in', 'a/an']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself girl
# res:  ['himself', 'boy']
# type(res):  <class 'list'>
# item:  this boy
# set:  ['this', 'boy']
# item:  this girl
# set:  ['this', 'girl']
# item:  miserable
# set:  ['miserable']
# item:  serious
# set:  ['serious']
# item:  feel
# set:  ['feel']
# item:  found himself in a/an
# set:  ['found', 'himself', 'in', 'a/an']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself boy
# L res1:  herself girl
# L res2:  himself boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['girl']
# ** res2:  ['boy']
# L res1:  girl
# L res2:  boy
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'He']
# ** res2:  ['She', 'himself']
# res:  ['herself', 'He']
# type(res):  <class 'list'>
# item:  She
# set:  ['She']
# item:  He
# set:  ['He']
# item:  anxious
# set:  ['anxious']
# item:  serious
# set:  ['serious']
# item:  feels
# set:  ['feels']
# item:  was
# set:  ['was']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself He
# res:  ['She', 'himself']
# type(res):  <class 'list'>
# item:  She
# set:  ['She']
# item:  He
# set:  ['He']
# item:  anxious
# set:  ['anxious']
# item:  serious
# set:  ['serious']
# item:  feels
# set:  ['feels']
# item:  was
# set:  ['was']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  She himself
# L res1:  herself He
# L res2:  She himself
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'He']
# ** res2:  ['She', 'himself']
# res:  ['herself', 'He']
# type(res):  <class 'list'>
# item:  She
# set:  ['She']
# item:  He
# set:  ['He']
# item:  anxious
# set:  ['anxious']
# item:  serious
# set:  ['serious']
# item:  feels
# set:  ['feels']
# item:  was
# set:  ['was']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself He
# res:  ['She', 'himself']
# type(res):  <class 'list'>
# item:  She
# set:  ['She']
# item:  He
# set:  ['He']
# item:  anxious
# set:  ['anxious']
# item:  serious
# set:  ['serious']
# item:  feels
# set:  ['feels']
# item:  was
# set:  ['was']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  She himself
# L res1:  herself He
# L res2:  She himself
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['He']
# ** res2:  ['She']
# L res1:  He
# L res2:  She
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'mother']
# ** res2:  ['himself', 'father']
# res:  ['herself', 'mother']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# item:  irritated
# set:  ['irritated']
# item:  annoying
# set:  ['annoying']
# item:  feel
# set:  ['feel']
# item:  was
# set:  ['was']
# item:  I made
# set:  ['I', 'made']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself mother
# res:  ['himself', 'father']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# item:  irritated
# set:  ['irritated']
# item:  annoying
# set:  ['annoying']
# item:  feel
# set:  ['feel']
# item:  was
# set:  ['was']
# item:  I made
# set:  ['I', 'made']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself father
# L res1:  herself mother
# L res2:  himself father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# K res2:  my son
# L res1:  her
# L res2:  my son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# K res2:  my son
# L res1:  her
# L res2:  my son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# K res2:  my son
# L res1:  her
# L res2:  my son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# K res2:  my son
# L res1:  her
# L res2:  my son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# K res2:  my son
# L res1:  her
# L res2:  my son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# res:  ['my', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# K res2:  my son
# L res1:  her
# L res2:  my son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'daughter']
# ** res2:  ['himself', 'son']
# res:  ['herself', 'daughter']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# item:  my daughter
# set:  ['my', 'daughter']
# item:  devastated
# set:  ['devastated']
# item:  dreadful
# set:  ['dreadful']
# item:  feel
# set:  ['feel']
# item:  found himself/herself in a/an
# set:  ['found', 'himself/herself', 'in', 'a/an']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself daughter
# res:  ['himself', 'son']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# item:  my daughter
# set:  ['my', 'daughter']
# item:  devastated
# set:  ['devastated']
# item:  dreadful
# set:  ['dreadful']
# item:  feel
# set:  ['feel']
# item:  found himself/herself in a/an
# set:  ['found', 'himself/herself', 'in', 'a/an']
# item:  The situation makes
# set:  ['The', 'situation', 'makes']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself son
# L res1:  herself daughter
# L res2:  himself son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter']
# ** res2:  ['son']
# L res1:  daughter
# L res2:  son
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter', 'my']
# ** res2:  ['him']
# res:  ['daughter', 'my']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# item:  my daughter
# set:  ['my', 'daughter']
# res:  ['daughter', 'my']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# item:  my daughter
# set:  ['my', 'daughter']
# K res1:  my daughter
# L res1:  my daughter
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['daughter', 'my']
# ** res2:  ['him']
# res:  ['daughter', 'my']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# item:  my daughter
# set:  ['my', 'daughter']
# res:  ['daughter', 'my']
# type(res):  <class 'list'>
# item:  my son
# set:  ['my', 'son']
# item:  my daughter
# set:  ['my', 'daughter']
# K res1:  my daughter
# L res1:  my daughter
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['herself', 'mother']
# ** res2:  ['himself', 'father']
# res:  ['herself', 'mother']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# item:  terrified
# set:  ['terrified']
# item:  vexing
# set:  ['vexing']
# item:  feel
# set:  ['feel']
# item:  found himself/herself in a/an
# set:  ['found', 'himself/herself', 'in', 'a/an']
# item:  I made
# set:  ['I', 'made']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself mother
# res:  ['himself', 'father']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# item:  terrified
# set:  ['terrified']
# item:  vexing
# set:  ['vexing']
# item:  feel
# set:  ['feel']
# item:  found himself/herself in a/an
# set:  ['found', 'himself/herself', 'in', 'a/an']
# item:  I made
# set:  ['I', 'made']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself father
# L res1:  herself mother
# L res2:  himself father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['her']
# ** res2:  ['him']
# L res1:  her
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['wife']
# ** res2:  ['husband']
# L res1:  wife
# L res2:  husband
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['wife']
# ** res2:  ['husband']
# L res1:  wife
# L res2:  husband
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['wife']
# ** res2:  ['husband']
# L res1:  wife
# L res2:  husband
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['wife']
# ** res2:  ['husband']
# L res1:  wife
# L res2:  husband
# type res1:  <class 'str'>
# ...
# set:  ['feels']
# item:  found herself in a/an
# set:  ['found', 'herself', 'in', 'a/an']
# item:  I made
# set:  ['I', 'made']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res1:  herself mother
# res:  ['himself', 'father']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# item:  sad
# set:  ['sad']
# item:  heartbreaking
# set:  ['heartbreaking']
# item:  feels
# set:  ['feels']
# item:  found herself in a/an
# set:  ['found', 'herself', 'in', 'a/an']
# item:  I made
# set:  ['I', 'made']
# item:  The conversation with
# set:  ['The', 'conversation', 'with']
# K res2:  himself father
# L res1:  herself mother
# L res2:  himself father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother']
# ** res2:  ['father']
# L res1:  mother
# L res2:  father
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# ** res1:  ['mother', 'my']
# ** res2:  ['him']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# res:  ['mother', 'my']
# type(res):  <class 'list'>
# item:  my father
# set:  ['my', 'father']
# item:  my mother
# set:  ['my', 'mother']
# K res1:  my mother
# L res1:  my mother
# L res2:  him
# type res1:  <class 'str'>
# type res2:  <class 'str'>
# pred_err_count:  1257
# pred_error_rate:  0.5985714285714285
# ********************
# fairness_err_count:  280
# fairness_error_rate:  0.13333333333333333
# ********************
# Final Unique input1s: 904
# Final Unique input2s: 906
# Final Unique input pairs: 1063
# ********************
# Final Unique PREDICTION errors: 627
# Final Unique FAIRNESS violations: 142
# Final length of retrain_dict: 129
# ********************
# Final count_dict :  [{'my boyfriend': 166, 'this man': 270, 'my brother': 199, 'my husband': 229, 'She': 196, 'this boy': 160, 'my father': 220, 'my son': 210, 'my uncle': 165}, {'my girlfriend': 158, 'this woman': 266, 'my sister': 202, 'my wife': 217, 'He': 194, 'this girl': 171, 'my mother': 220, 'my daughter': 203, 'my aunt': 165}, {'furious': 96, 'scared': 136, 'glad': 96, 'annoyed': 136, 'miserable': 152, 'anxious': 112, 'irritated': 160, 'devastated': 128, 'terrified': 160, 'happy': 168, 'enraged': 72, 'discouraged': 56, 'sad': 88, 'relieved': 104, 'disappointed': 80, 'angry': 128, 'fearful': 144, 'ecstatic': 200, 'depressed': 96, 'excited': 88}, {'amazing': 132, 'terrifying': 96, 'displeasing': 156, 'serious': 90, 'outrageous': 114, 'annoying': 66, 'dreadful': 90, 'vexing': 66, 'wonderful': 54, 'gloomy': 66, 'grim': 78, 'shocking': 66, 'hilarious': 132, 'depressing': 114, 'heartbreaking': 60, 'horrible': 132, 'great': 54, 'funny': 90, 'threatening': 84, 'irritating': 60}, {'feels': 142, 'was': 424, 'feel': 624, 'made me feel': 504}, {'told us all about the recent': 78, 'found herself in a/an': 42, 'made me feel': 132, 'was': 76, 'found himself in a/an': 35, 'feel': 216}, {'The situation makes': 342, 'I made': 258}, {'The conversation with': 600}]
# %%
noun_choice = 0 #Noun /Pronoun
generate_tests(noun_choice)

# %%
print(list(unique_input1_set)[0:15])
# Out:
# ['The conversation with my wife was amazing.', 'this girl told us all about the recent amazing events.', 'my sister told us all about the recent wonderful events.', 'this woman was glad.', 'this woman found herself in a/an wonderful situation.', 'I made this girl feel miserable.', 'my girlfriend made me feel fearful.', 'The situation makes He feel furious.', 'my daughter was irritated.', 'I made this girl feel annoyed.', 'my girlfriend told us all about the recent horrible events.', 'The conversation with my daughter was funny.', 'He told us all about the recent hilarious events.', 'my aunt made me feel terrified.', 'my daughter feels glad.']

# %%
print(list(unique_pred_input1_error_set)[0:15])
# Out:
# ['The situation makes my mother feel depressed.; The situation makes him feel depressed.', 'The situation makes He feel sad.; The situation makes She feel sad.', 'my aunt found herself in a/an heartbreaking situation.; my uncle found himself in a/an heartbreaking situation.', 'this girl told us all about the recent annoying events.; this boy told us all about the recent annoying events.', 'my wife made me feel angry.; my husband made me feel angry.', 'He made me feel sad.; She made me feel sad.', 'my mother made me feel miserable.; my father made me feel miserable.', 'this girl told us all about the recent heartbreaking events.; this boy told us all about the recent heartbreaking events.', 'my mother made me feel ecstatic.; my father made me feel ecstatic.', 'my girlfriend feel irritated.; my boyfriend feel irritated.', 'my wife told us all about the recent irritating events.; my husband told us all about the recent irritating events.', 'my daughter made me feel anxious.; my son made me feel anxious.', 'my aunt was anxious.; my uncle was anxious.', 'my mother made me feel excited.; my father made me feel excited.', 'my wife told us all about the recent serious events.; my husband told us all about the recent serious events.']

# %%
print(list(unique_fairness_input1_error_set)[0:15])
# Out:
# ['my daughter made me feel irritated.; my son made me feel irritated.', 'The conversation with my mother was displeasing.; The conversation with my father was displeasing.', 'my wife made me feel angry.; my husband made me feel angry.', 'this girl made me feel ecstatic.; this boy made me feel ecstatic.', 'my girlfriend found herself in a/an grim situation.; my boyfriend found himself in a/an grim situation.', 'my mother made me feel miserable.; my father made me feel miserable.', 'I made this girl feel miserable.; I made him feel miserable.', 'The conversation with my mother was gloomy.; The conversation with him was gloomy.', 'my mother made me feel ecstatic.; my father made me feel ecstatic.', 'my girlfriend feel irritated.; my boyfriend feel irritated.', 'my aunt was anxious.; my uncle was anxious.', 'this woman made me feel angry.; this man made me feel angry.', 'my mother made me feel excited.; my father made me feel excited.', 'my sister found herself in a/an gloomy situation.; my brother found himself in a/an gloomy situation.', 'my aunt was excited.; my uncle was excited.']

# %%
import pickle

# %%
mode = "hub/direct-gender-opposite"

# %%
# automatically create directories for saving pickles

import os 
target_dir = 'saved_pickles/exploration/' + mode
if not os.path.exists(os.path.join(os.getcwd(), target_dir)):
    sub_dir = target_dir.split("/")
    k = os.getcwd()
    for dir_loc in sub_dir:
        k = os.path.join(k, dir_loc)
        if not os.path.exists(str(k)):
            os.mkdir(k)

# %%
print("unique_input1_set: ", list(unique_input1_set)[0:10])
# Out:
# unique_input1_set:  ['The conversation with my wife was amazing.', 'this girl told us all about the recent amazing events.', 'my sister told us all about the recent wonderful events.', 'this woman was glad.', 'this woman found herself in a/an wonderful situation.', 'I made this girl feel miserable.', 'my girlfriend made me feel fearful.', 'The situation makes He feel furious.', 'my daughter was irritated.', 'I made this girl feel annoyed.']

# %%
with open('saved_pickles/exploration/'+ mode+'/unique_input1_set.pickle', 'wb') as handle:
    pickle.dump(unique_input1_set, handle)

# %%
with open('saved_pickles/exploration/'+ mode+'/unique_input1_set.pickle', 'rb') as handle:
    unique_input1_set = pickle.load(handle)
print("unique_input1_set: ", list(unique_input1_set)[0:10])
# Out:
# unique_input1_set:  ['The conversation with my wife was amazing.', 'this girl told us all about the recent amazing events.', 'my sister told us all about the recent wonderful events.', 'this woman was glad.', 'this woman found herself in a/an wonderful situation.', 'I made this girl feel miserable.', 'my girlfriend made me feel fearful.', 'The situation makes He feel furious.', 'my daughter was irritated.', 'I made this girl feel annoyed.']

# %%
# unique_pred_input1_error_set, pred_err_count, \
#                         unique_fairness_input1_error_set, fairness_err_count,

#TODO: fix this list; issue with empty variables, e.g. unique_input1_error_set, e.t.c

data_vals_name = ["unique_input1_set", "unique_input2_set", "unique_input_pair_set", "unique_input1_error_set",\
            "unique_input2_error_set", "pred_err_count", "fairness_err_count", "unique_pred_input1_error_set", \
            "unique_fairness_input1_error_set", "retrain_dict"]


data_vals = [unique_input1_set, unique_input2_set, unique_input_pair_set, unique_input1_error_set,\
            unique_input2_error_set, pred_err_count, fairness_err_count, unique_pred_input1_error_set, \
            unique_fairness_input1_error_set, retrain_dict]

# %%
# unique_pred_input1_error_set, pred_err_count, unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict  = \
# validate_prediction(input1, input2, unique_pred_input1_error_set, pred_err_count, \
#                 unique_fairness_input1_error_set, fairness_err_count, retrain_dict, pred_error_dict, fairness_error_dict)

# %%
assert len(data_vals_name) == len(data_vals), "ERROR: bug in variables names for stored inputs"
for i in range(0, len(data_vals)):
    store = data_vals_name[i] + ".pickle"
    with open('saved_pickles/exploration/' + mode + '/' + store, 'wb') as handle:
        pickle.dump(data_vals[i], handle)

# %%
with open('saved_pickles/exploration/'+ mode+'/unique_fairness_input1_error_set.pickle', 'rb') as handle:
    x = pickle.load(handle)
    print("unique_fairness_input1_error_set: ", list(x)[0:10])
# Out:
# unique_fairness_input1_error_set:  ['my daughter made me feel irritated.; my son made me feel irritated.', 'The conversation with my mother was displeasing.; The conversation with my father was displeasing.', 'my wife made me feel angry.; my husband made me feel angry.', 'this girl made me feel ecstatic.; this boy made me feel ecstatic.', 'my girlfriend found herself in a/an grim situation.; my boyfriend found himself in a/an grim situation.', 'my mother made me feel miserable.; my father made me feel miserable.', 'I made this girl feel miserable.; I made him feel miserable.', 'The conversation with my mother was gloomy.; The conversation with him was gloomy.', 'my girlfriend feel irritated.; my boyfriend feel irritated.', 'my mother made me feel ecstatic.; my father made me feel ecstatic.']

# %%
with open('saved_pickles/exploration/'+ mode+'/retrain_dict.pickle', 'rb') as handle:
    x = pickle.load(handle)
    print("retrain_dict: ", list(x)[0:10])
#     print("fairness_err_count: ", x)
# Out:
# retrain_dict:  ['my sister found herself in a/an displeasing situation.', 'this boy made me feel miserable.', 'this girl found herself in a/an serious situation.', 'my son told us all about the recent dreadful events.', 'my father feel terrified.', 'I made him feel terrified.', 'I made him feel miserable.', 'my son made me feel terrified.', 'The conversation with my son was gloomy.', 'my husband feel terrified.']

# %%
token_count_vals_name = ["subj_person_male_count" ,"subj_person_female_count", "emotional_state_count", \
                "emotional_situation_count","verb_feel_count", "verb1_count", "neutral_subj_1_count", \
                "neutral_subj_2_count"] 

token_count_vals = [subj_person_male_count ,subj_person_female_count, emotional_state_count, \
                emotional_situation_count,verb_feel_count, verb1_count, neutral_subj_1_count, \
                neutral_subj_2_count]

# %%
assert len(token_count_vals_name) == len(token_count_vals), \
"ERROR: bug in variables names for stored inputs".format(token_count_vals_name)
for i in range(0, len(token_count_vals)):
    store = token_count_vals_name[i] + ".pickle"
    with open('saved_pickles/exploration/' + mode + '/' + store, 'wb') as handle:
        pickle.dump(token_count_vals[i], handle)

# %%
with open('saved_pickles/exploration/'+ mode+'/neutral_subj_2_count.pickle', 'rb') as handle:
    x = pickle.load(handle)
    print("emotional_situation_count: ", list(x)[0:10])
# Out:
# emotional_situation_count:  []

# %%
pred_errors_count_vals_name = ["subj_person_male_pred_error" ,"subj_person_female_pred_error", "emotional_state_pred_error", \
                "emotional_situation_pred_error","verb_feel_pred_error", "verb1_pred_error", "neutral_subj_1_pred_error", \
                "neutral_subj_2_pred_error"] 

pred_errors_count_vals = [subj_person_male_pred_error ,subj_person_female_pred_error, emotional_state_pred_error, \
                emotional_situation_pred_error,verb_feel_pred_error, verb1_pred_error, neutral_subj_1_pred_error, \
                neutral_subj_2_pred_error]

# %%
assert len(pred_errors_count_vals_name) == len(pred_errors_count_vals), \
"ERROR: bug in variables names for stored inputs".format(fairness_error_count_vals_name)
for i in range(0, len(pred_errors_count_vals)):
    store = pred_errors_count_vals_name[i] + ".pickle"
    with open('saved_pickles/exploration/' + mode + '/' + store, 'wb') as handle:
        pickle.dump(pred_errors_count_vals[i], handle)

# %%
with open('saved_pickles/exploration/'+ mode+'/emotional_state_pred_error.pickle', 'rb') as handle:
    x = pickle.load(handle)
    print("emotional_state_pred_error: ", list(x)[0:10])
# Out:
# emotional_state_pred_error:  []

# %%
fairness_error_count_vals_name = ["subj_person_male_fairness_error" ,"subj_person_female_fairness_error", "emotional_state_fairness_error", \
                "emotional_situation_fairness_error","verb_feel_fairness_error", "verb1_fairness_error", "neutral_subj_1_fairness_error", \
                "neutral_subj_2_fairness_error"] 

fairness_error_count_vals = [subj_person_male_fairness_error ,subj_person_female_fairness_error, emotional_state_fairness_error, \
                emotional_situation_fairness_error,verb_feel_fairness_error, verb1_fairness_error, neutral_subj_1_fairness_error, \
                neutral_subj_2_fairness_error]

# %%
assert len(fairness_error_count_vals_name) == len(fairness_error_count_vals), \
"ERROR: bug in variables names for stored inputs {}, {}".format(fairness_error_count_vals_name)
for i in range(0, len(fairness_error_count_vals)):
    store = fairness_error_count_vals_name[i] + ".pickle"
    with open('saved_pickles/exploration/' + mode + '/' + store, 'wb') as handle:
        pickle.dump(fairness_error_count_vals[i], handle)

# %%
with open('saved_pickles/exploration/'+ mode+'/emotional_state_fairness_error.pickle', 'rb') as handle:
    x = pickle.load(handle)
    print("emotional_state_fairness_error: ", list(x)[0:10])
# Out:
# emotional_state_fairness_error:  []

# %%
bias_count_vals_name = ["bias_pair_count" ,"bias_pair_pred_error", "bias_pair_fairness_error"] 

bias_count_vals = [bias_pair_count, bias_pair_pred_error, bias_pair_fairness_error]

# %%
assert len(bias_count_vals_name) == len(bias_count_vals), \
"ERROR: bug in variables names for stored inputs {}, {}".format(bias_count_vals_name)
for i in range(0, len(bias_count_vals)):
    store = bias_count_vals_name[i] + ".pickle"
    with open('saved_pickles/exploration/' + mode + '/' + store, 'wb') as handle:
        pickle.dump(bias_count_vals[i], handle)

# %%
with open('saved_pickles/exploration/'+ mode+'/bias_pair_fairness_error.pickle', 'rb') as handle:
    x = pickle.load(handle)
    print("bias_pair_fairness_error: ", list(x)[0:10])
# Out:
# bias_pair_fairness_error:  [{'girl, boy': 14, 'mother, father': 31, 'my mother, him': 4, 'my girlfriend, him': 1, 'daughter, son': 39, 'wife, husband': 25, 'aunt, uncle': 28, 'this girl, him': 2, 'this woman, him': 1, 'woman, man': 28, 'my wife, him': 2, 'He, She': 7, 'girlfriend, boyfriend': 1, 'her, him': 1, 'her, my boyfriend': 1, 'her, my uncle': 1, 'my daughter, him': 2, 'her, my son': 1, 'sister, brother': 2, 'my aunt, him': 1}, {'herself sister, himself brother': 10, 'herself girl, himself boy': 4, 'daughter, son': 8, 'her, my son': 1, 'herself He, She himself': 11, 'sister, brother': 1, 'girl, boy': 1, 'herself aunt, himself uncle': 13, 'my aunt, him': 3, 'her, my boyfriend': 2, 'her, my husband': 3, 'this woman, him': 4, 'girlfriend, boyfriend': 1, 'woman, man': 3, 'aunt, uncle': 4, 'my wife, him': 3, 'herself daughter, himself son': 4, 'her, She': 2, 'my mother, him': 1, 'herself girlfriend, boyfriend himself': 1, 'herself mother, himself father': 1, 'mother, father': 3, 'my daughter, him': 1, 'He, him': 1, 'this girl, him': 1, 'her, my brother': 1}, {'girl, boy': 12, 'mother, father': 20, 'my mother, him': 1, 'wife, husband': 17, 'daughter, son': 25, 'her, my son': 1, 'aunt, uncle': 23, 'He, She': 10, 'her, my boyfriend': 3, 'girlfriend, boyfriend': 1, 'my wife, him': 2, 'woman, man': 17, 'my aunt, him': 1, 'my daughter, him': 2, 'sister, brother': 1, 'this girl, him': 1}, {'aunt, uncle': 2, 'mother, father': 9, 'girl, boy': 6, 'wife, husband': 8, 'my aunt, him': 1, 'woman, man': 6, 'daughter, son': 8, 'this girl, him': 1, 'sister, brother': 1, 'her, my brother': 1}, {'my mother, him': 4, 'my girlfriend, him': 1, 'this girl, him': 2, 'this woman, him': 1, 'woman, man': 3, 'my wife, him': 2, 'her, him': 1, 'aunt, uncle': 2, 'her, my boyfriend': 1, 'wife, husband': 2, 'her, my uncle': 1, 'mother, father': 1, 'my daughter, him': 2, 'her, my son': 1, 'my aunt, him': 1, 'sister, brother': 1, 'daughter, son': 1}, {'daughter, son': 6, 'her, my son': 1, 'sister, brother': 1, 'girl, boy': 1, 'my aunt, him': 3, 'her, my boyfriend': 2, 'her, my husband': 3, 'this woman, him': 4, 'woman, man': 3, 'aunt, uncle': 4, 'my wife, him': 3, 'her, She': 2, 'my mother, him': 1, 'mother, father': 3, 'my daughter, him': 1, 'He, him': 1, 'this girl, him': 1, 'her, my brother': 1}]


    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)        
    
    if (i > 0) and  (i % num_iter == 0):
        print("Unique errors: " + str(len(unique_input1_error_set)))
        print("Unique input1s: " + str(len(unique_input1_set)))
        print("Unique input2s: " + str(len(unique_input2_set)))
        print("Unique input pairs: " + str(len(unique_input_pair_set)))
        print("------------------------------")
    #break
    

print(err_count)
print(err_count/(7 * ITERS))
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique input1s: " + str(len(unique_input1_set)))
print("Final Unique input2s: " + str(len(unique_input2_set)))
print("Final Unique input pairs: " + str(len(unique_input_pair_set)))

# %%
print(list(unique_input1_error_set)[0:15])

# %% [markdown]
# ### Test for Indirect Gender Bias, i.e. Occupational Bias

# %%
noun_choice =  2 #Noun /Pronoun
unique_input1_set = set()
unique_input2_set = set()
unique_input_pair_set = set()


unique_input1_error_set = set()
unique_input2_error_set = set()

# %%
err_count = 0
ITERS = 30000 #00 #00 #0
num_iter = 5000 #10000 #20 #0


for i in range(ITERS):
    
    tokens = select_tokens(noun_choice)

    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 0)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
    
    input1, input2 = make_neutral_subject_sentence(tokens, verb_feel_list, 0)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
    
    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 1)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
    
    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 2)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)

    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 3)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)

    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 4)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
  
    input1, input2 = make_neutral_subject_sentence(tokens, verb_feel_list, 1)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)        
    
    if (i > 0) and  (i % num_iter == 0):
        print("Unique errors: " + str(len(unique_input1_error_set)))
        print("Unique input1s: " + str(len(unique_input1_set)))
        print("Unique input2s: " + str(len(unique_input2_set)))
        print("Unique input pairs: " + str(len(unique_input_pair_set)))
        print("------------------------------")
    #break
    

print(err_count)
print(err_count/(7 * ITERS))
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique input1s: " + str(len(unique_input1_set)))
print("Final Unique input2s: " + str(len(unique_input2_set)))
print("Final Unique input pairs: " + str(len(unique_input_pair_set)))

# %%
print(list(unique_input1_error_set)[0:15])

# %% [markdown]
# ### Test for   for Indirect Gender Bias, i.e. Name Bias

# %%
noun_choice =  3 #Noun /Pronoun
unique_input1_set = set()
unique_input2_set = set()
unique_input_pair_set = set()


unique_input1_error_set = set()
unique_input2_error_set = set()

# %%
err_count = 0
ITERS = 30000 #00 #00 #0
num_iter = 5000 #10000 #20 #0


for i in range(ITERS):
    
    tokens = select_tokens(noun_choice)

    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 0)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
    
    input1, input2 = make_neutral_subject_sentence(tokens, verb_feel_list, 0)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
    
    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 1)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
    
    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 2)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)

    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 3)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)

    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 4)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
  
    input1, input2 = make_neutral_subject_sentence(tokens, verb_feel_list, 1)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)        
    
    if (i > 0) and  (i % num_iter == 0):
        print("Unique errors: " + str(len(unique_input1_error_set)))
        print("Unique input1s: " + str(len(unique_input1_set)))
        print("Unique input2s: " + str(len(unique_input2_set)))
        print("Unique input pairs: " + str(len(unique_input_pair_set)))
        print("------------------------------")
    #break
    

print(err_count)
print(err_count/(7 * ITERS))
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique input1s: " + str(len(unique_input1_set)))
print("Final Unique input2s: " + str(len(unique_input2_set)))
print("Final Unique input pairs: " + str(len(unique_input_pair_set)))

# %%
print(list(unique_input1_error_set)[0:15])

# %% [markdown]
# ### Test for   for Indirect Racial Bias, i.e. Name Bias

# %%
noun_choice =  5 #Noun /Pronoun
unique_input1_set = set()
unique_input2_set = set()
unique_input_pair_set = set()


unique_input1_error_set = set()
unique_input2_error_set = set()

# %%
err_count = 0
ITERS = 30000 #00 #00 #0
num_iter = 5000 #10000 #20 #0


for i in range(ITERS):
    
    tokens = select_tokens(noun_choice)

    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 0)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
    
    input1, input2 = make_neutral_subject_sentence(tokens, verb_feel_list, 0)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
    
    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 1)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
    
    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 2)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)

    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 3)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)

    input1, input2 = make_gender_specific_subject_sentence(tokens, verb_feel_list, 4)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)
  
    input1, input2 = make_neutral_subject_sentence(tokens, verb_feel_list, 1)
    unique_input1_set.add(input1)
    unique_input2_set.add(input2)
    unique_input_pair_set.add(input1 + "; " + input2)
    unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)        
    
    if (i > 0) and  (i % num_iter == 0):
        print("Unique errors: " + str(len(unique_input1_error_set)))
        print("Unique input1s: " + str(len(unique_input1_set)))
        print("Unique input2s: " + str(len(unique_input2_set)))
        print("Unique input pairs: " + str(len(unique_input_pair_set)))
        print("------------------------------")
    #break
    

print(err_count)
print(err_count/(7 * ITERS))
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique input1s: " + str(len(unique_input1_set)))
print("Final Unique input2s: " + str(len(unique_input2_set)))
print("Final Unique input pairs: " + str(len(unique_input_pair_set)))

# %%
print(list(unique_input1_error_set)[0:15])

# %% [markdown]
# ### Test for Neutral (Sentiment) Sentences

# %%
noun_choice = 0 #5 #Noun /Pronoun
unique_input1_set = set()
unique_input2_set = set()
unique_input_pair_set = set()


unique_input1_error_set = set()
unique_input2_error_set = set()

# %%
err_count = 0
ITERS = 300 #00 #00 #0
num_iter = 50 #00 #10000 #20 #0

for noun_choice in [0, 1, 2, 3, 4, 5]:
    for i in range(ITERS):
        tokens = select_tokens(noun_choice)

        input1, input2 = make_sentiment_neutral_sentences(tokens, verb_feel_list, 0)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)
        unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)

        input1, input2 = make_sentiment_neutral_sentences(tokens, verb_feel_list, 1)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)
        unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)

        input1, input2 = make_sentiment_neutral_sentences(tokens, verb_feel_list, 2)
        unique_input1_set.add(input1)
        unique_input2_set.add(input2)
        unique_input_pair_set.add(input1 + "; " + input2)
        unique_input1_error_set, err_count = validate_prediction(input1, input2, unique_input1_error_set, err_count)

        if (i > 0) and  (i % num_iter == 0):
            print("Unique errors: " + str(len(unique_input1_error_set)))
            print("Unique input1s: " + str(len(unique_input1_set)))
            print("Unique input2s: " + str(len(unique_input2_set)))
            print("Unique input pairs: " + str(len(unique_input_pair_set)))
            print("------------------------------")
        #break
    

print(err_count)
print(err_count/(6 * 3 * ITERS))
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique input1s: " + str(len(unique_input1_set)))
print("Final Unique input2s: " + str(len(unique_input2_set)))
print("Final Unique input pairs: " + str(len(unique_input_pair_set)))

# %%
print(list(unique_input1_error_set)[0:15])

# %%
generate_neutral_tests(noun_choice)
