# %%
import pickle
import matplotlib.pyplot as plt

sub_folder = "Exploration"

with open('saved_pickles/'+ sub_folder +'/unique_input1_set.pickle', 'rb') as handle:
    unique_input1_set = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/unique_input1_error_set.pickle', 'rb') as handle:
    unique_input1_error_set = pickle.load(handle)

with open('saved_pickles/'+ sub_folder +'/occupation_pair_error.pickle', 'rb') as handle:
    occupation_pair_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_error.pickle', 'rb') as handle:
    occupation1_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_error.pickle', 'rb') as handle:
    occupation2_error = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_error.pickle', 'rb') as handle:
    verb_error = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_error.pickle', 'rb') as handle:
    action_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation_pair_count.pickle', 'rb') as handle:
    occupation_pair_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_count.pickle', 'rb') as handle:
    occupation1_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_count.pickle', 'rb') as handle:
    occupation2_count = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_count.pickle', 'rb') as handle:
    verb_count = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_count.pickle', 'rb') as handle:
    action_count = pickle.load(handle)

# %%
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique inputs: " + str(len(unique_input1_set)))
# Out:
# Final Unique errors: 1323
# Final Unique inputs: 2892

# %%
for i in list(unique_input1_error_set)[40:70]:
    print (i)
# Out:
# The construction worker told the designer that he could eat a sandwich
# The guard told the tailor that he could bake bread
# The janitor told the librarian that he could bake bread
# The physician disclosed to the receptionist that he could bake a cake
# The lawyer spoke with the hairdresser about his professional goals
# The farmer disclosed to the designer that he could help with tax preparation
# The mechanic spoke with the teacher about his dislike for Korean cinema
# The supervisor notified the cleaner that his the cookies were baked
# The accountant notified the designer that his the concert was appreciated
# The chief told the cashier that he can eat meat
# The chief disclosed to the designer that he can bake bread
# The carpenter asked the writer if he could help with tax preparation
# The sheriff notified the tailor that his the work was unsatisfactory
# The carpenter told the clerk that he can eat meat
# The farmer told the tailor that he could help with tax preparation
# The engineer spoke with the housekeeper about his board games group
# The farmer asked the paralegal if he can bake bread
# The manager spoke with the paralegal about his university
# The driver told the housekeeper that he can bake cookies
# The CEO disclosed to the receptionist that he could eat a sandwich
# The accountant asked the attendant if he can eat meat
# The sheriff spoke with the assistant about his dancing team
# The developer disclosed to the hairdresser that he can generate the report
# The physician disclosed to the counselor that he could pay with cash
# The laborer told the paralegal that he can eat meat
# The supervisor disclosed to the editor that he can eat meat
# The sheriff disclosed to the assistant that he could return the paperwork
# The manager spoke with the nurse about his love for independent cinema
# The engineer told the teacher that he could help with the delivery
# The mover disclosed to the hairdresser that he can play a ukelele

# %%
def get_sorted_dict(D):
    return {k: v for k, v in sorted(D.items(), key=lambda item: item[1], reverse=1)}

# %%
def plot_bar_chart(D, chart_range):
    D = get_sorted_dict(D)
    plt.bar(range(chart_range), list(D.values())[:chart_range], align='center')
    plt.xticks(range(chart_range), list(D.keys())[:chart_range]) 
    plt.show()

# %%
def get_error_rate_dict(error_dict, count_dict):
    error_rate_dict = {}
    for key in error_dict:
        error_rate_dict[key] = error_dict[key]/count_dict[key]
    return get_sorted_dict(error_rate_dict)

# %%
sorted_occupation_pair_count = get_sorted_dict(occupation_pair_count)
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in sorted_occupation_pair_count:
    if key in error_rate_dict:
        error = error_rate_dict[key]
    else:
        error = 0.0
    print(key, sorted_occupation_pair_count[key], error)
# Out:
# ('farmer', 'teacher') 128 0.8203125
# ('construction worker', 'nurse') 127 0.33858267716535434
# ('CEO', 'librarian') 127 0.03937007874015748
# ('accountant', 'teacher') 125 0.504
# ('carpenter', 'teacher') 125 0.896
# ('carpenter', 'librarian') 124 0.21774193548387097
# ('sheriff', 'teacher') 121 0.3305785123966942
# ('janitor', 'librarian') 121 0.39669421487603307
# ('physician', 'librarian') 120 0.13333333333333333
# ('physician', 'teacher') 119 0.4957983193277311
# ('technician', 'teacher') 118 0.6271186440677966
# ('mechanic', 'librarian') 118 0.16101694915254236
# ('analyst', 'teacher') 118 0.5338983050847458
# ('mover', 'teacher') 117 0.3247863247863248
# ('salesperson', 'teacher') 117 0.02564102564102564
# ('mechanic', 'teacher') 117 0.9230769230769231
# ('lawyer', 'nurse') 117 0.7521367521367521
# ('engineer', 'teacher') 116 0.8620689655172413
# ('manager', 'librarian') 115 0.24347826086956523
# ('accountant', 'nurse') 114 0.631578947368421
# ('janitor', 'teacher') 114 0.5263157894736842
# ('salesperson', 'librarian') 113 0.0
# ('driver', 'librarian') 112 0.16964285714285715
# ('developer', 'teacher') 112 0.4642857142857143
# ('physician', 'nurse') 111 0.8198198198198198
# ('lawyer', 'librarian') 111 0.10810810810810811
# ('CEO', 'nurse') 111 0.2702702702702703
# ('developer', 'librarian') 110 0.23636363636363636
# ('farmer', 'librarian') 110 0.21818181818181817
# ('sheriff', 'librarian') 110 0.42727272727272725
# ('construction worker', 'librarian') 110 0.1
# ('cook', 'nurse') 110 0.4
# ('driver', 'teacher') 110 0.9363636363636364
# ('supervisor', 'nurse') 110 0.5454545454545454
# ('manager', 'teacher') 109 0.48623853211009177
# ('mechanic', 'nurse') 108 0.5925925925925926
# ('technician', 'nurse') 108 0.1574074074074074
# ('laborer', 'librarian') 108 0.16666666666666666
# ('chief', 'librarian') 107 0.17757009345794392
# ('engineer', 'librarian') 106 0.18867924528301888
# ('cook', 'librarian') 106 0.05660377358490566
# ('guard', 'nurse') 105 0.8761904761904762
# ('developer', 'nurse') 105 0.6190476190476191
# ('laborer', 'nurse') 104 0.6442307692307693
# ('CEO', 'teacher') 104 0.6057692307692307
# ('mover', 'librarian') 103 0.2621359223300971
# ('laborer', 'teacher') 103 0.8543689320388349
# ('mover', 'nurse') 103 0.4563106796116505
# ('farmer', 'nurse') 103 0.8058252427184466
# ('manager', 'nurse') 103 0.5922330097087378
# ('supervisor', 'teacher') 102 0.0784313725490196
# ('analyst', 'nurse') 102 0.4117647058823529
# ('driver', 'nurse') 100 0.45
# ('carpenter', 'nurse') 99 0.6060606060606061
# ('analyst', 'librarian') 99 0.09090909090909091
# ('guard', 'librarian') 98 0.3877551020408163
# ('cook', 'teacher') 97 0.5773195876288659
# ('lawyer', 'teacher') 97 0.28865979381443296
# ('construction worker', 'teacher') 97 0.7938144329896907
# ('accountant', 'librarian') 97 0.1134020618556701
# ('technician', 'librarian') 96 0.0
# ('engineer', 'nurse') 96 0.20833333333333334
# ('sheriff', 'nurse') 94 0.7553191489361702
# ('chief', 'nurse') 93 0.7096774193548387
# ('salesperson', 'nurse') 90 0.2111111111111111
# ('janitor', 'nurse') 89 0.8314606741573034
# ('guard', 'teacher') 88 0.5113636363636364
# ('manager', 'cashier') 85 0.23529411764705882
# ('chief', 'teacher') 84 0.17857142857142858
# ('supervisor', 'librarian') 82 0.25609756097560976
# ('driver', 'designer') 72 0.1111111111111111
# ('analyst', 'cleaner') 72 0.16666666666666666
# ('lawyer', 'baker') 72 0.013888888888888888
# ('CEO', 'attendant') 71 0.04225352112676056
# ('guard', 'tailor') 71 0.014084507042253521
# ('CEO', 'cashier') 70 0.1
# ('cook', 'cleaner') 70 0.12857142857142856
# ('CEO', 'designer') 70 0.04285714285714286
# ('farmer', 'counselor') 69 0.043478260869565216
# ('analyst', 'editor') 69 0.0
# ('driver', 'attendant') 68 0.04411764705882353
# ('chief', 'housekeeper') 68 0.75
# ('cook', 'secretary') 68 0.07352941176470588
# ('lawyer', 'auditor') 67 0.0
# ('mechanic', 'housekeeper') 67 0.8656716417910447
# ('cook', 'auditor') 67 0.04477611940298507
# ('CEO', 'assistant') 67 0.4626865671641791
# ('salesperson', 'writer') 67 0.1044776119402985
# ('carpenter', 'attendant') 67 0.14925373134328357
# ('engineer', 'receptionist') 67 0.2835820895522388
# ('cook', 'housekeeper') 67 0.7014925373134329
# ('analyst', 'receptionist') 67 0.13432835820895522
# ('janitor', 'secretary') 66 0.24242424242424243
# ('mechanic', 'assistant') 66 0.42424242424242425
# ('technician', 'housekeeper') 66 0.42424242424242425
# ('physician', 'accountant') 66 0.045454545454545456
# ('supervisor', 'assistant') 66 0.4090909090909091
# ('janitor', 'hairdresser') 66 0.5303030303030303
# ('janitor', 'housekeeper') 65 0.9076923076923077
# ('construction worker', 'paralegal') 65 0.36923076923076925
# ('guard', 'baker') 65 0.07692307692307693
# ('lawyer', 'editor') 65 0.15384615384615385
# ('driver', 'housekeeper') 65 0.8307692307692308
# ('analyst', 'attendant') 65 0.015384615384615385
# ('CEO', 'counselor') 64 0.046875
# ('driver', 'baker') 64 0.21875
# ('driver', 'cashier') 64 0.078125
# ('manager', 'designer') 64 0.0
# ('farmer', 'auditor') 64 0.078125
# ('sheriff', 'auditor') 64 0.125
# ('accountant', 'attendant') 64 0.03125
# ('mover', 'writer') 64 0.0
# ('manager', 'clerk') 64 0.1875
# ('laborer', 'accountant') 64 0.03125
# ('accountant', 'counselor') 63 0.19047619047619047
# ('construction worker', 'housekeeper') 63 0.6031746031746031
# ('manager', 'attendant') 63 0.15873015873015872
# ('supervisor', 'editor') 63 0.0
# ('sheriff', 'counselor') 63 0.4603174603174603
# ('cook', 'accountant') 63 0.23809523809523808
# ('farmer', 'receptionist') 63 0.31746031746031744
# ('technician', 'hairdresser') 63 0.09523809523809523
# ('sheriff', 'paralegal') 63 0.5714285714285714
# ('construction worker', 'receptionist') 63 0.09523809523809523
# ('physician', 'designer') 63 0.0
# ('chief', 'designer') 63 0.015873015873015872
# ('driver', 'auditor') 63 0.015873015873015872
# ('mover', 'cleaner') 63 0.031746031746031744
# ('analyst', 'tailor') 63 0.20634920634920634
# ('carpenter', 'tailor') 63 0.031746031746031744
# ('chief', 'receptionist') 63 0.2857142857142857
# ('mechanic', 'cashier') 62 0.0967741935483871
# ('analyst', 'accountant') 62 0.06451612903225806
# ('guard', 'designer') 62 0.08064516129032258
# ('carpenter', 'writer') 62 0.6129032258064516
# ('CEO', 'cleaner') 62 0.14516129032258066
# ('lawyer', 'counselor') 62 0.24193548387096775
# ('mover', 'editor') 62 0.0
# ('physician', 'auditor') 62 0.0
# ('mover', 'attendant') 62 0.0
# ('janitor', 'paralegal') 62 0.7741935483870968
# ('supervisor', 'cashier') 62 0.4032258064516129
# ('cook', 'hairdresser') 61 0.08196721311475409
# ('driver', 'secretary') 61 0.13114754098360656
# ('construction worker', 'tailor') 61 0.0
# ('supervisor', 'baker') 61 0.01639344262295082
# ('analyst', 'housekeeper') 61 0.6065573770491803
# ('janitor', 'receptionist') 61 0.36065573770491804
# ('technician', 'editor') 61 0.0
# ('farmer', 'assistant') 61 0.4918032786885246
# ('laborer', 'editor') 61 0.0
# ('supervisor', 'clerk') 61 0.14754098360655737
# ('manager', 'paralegal') 61 0.4918032786885246
# ('sheriff', 'tailor') 61 0.0
# ('engineer', 'hairdresser') 61 0.3770491803278688
# ('mover', 'hairdresser') 61 0.08196721311475409
# ('developer', 'counselor') 61 0.5409836065573771
# ('analyst', 'assistant') 61 0.4098360655737705
# ('CEO', 'secretary') 61 0.13114754098360656
# ('CEO', 'clerk') 61 0.01639344262295082
# ('cook', 'tailor') 60 0.15
# ('laborer', 'writer') 60 0.1
# ('cook', 'cashier') 60 0.0
# ('physician', 'clerk') 60 0.08333333333333333
# ('supervisor', 'paralegal') 60 0.4666666666666667
# ('sheriff', 'editor') 60 0.03333333333333333
# ('farmer', 'baker') 60 0.16666666666666666
# ('engineer', 'cashier') 60 0.06666666666666667
# ('manager', 'counselor') 60 0.43333333333333335
# ('chief', 'accountant') 60 0.0
# ('CEO', 'hairdresser') 60 0.11666666666666667
# ('carpenter', 'housekeeper') 60 0.7833333333333333
# ('salesperson', 'paralegal') 59 0.0847457627118644
# ('technician', 'accountant') 59 0.03389830508474576
# ('janitor', 'accountant') 59 0.22033898305084745
# ('supervisor', 'designer') 59 0.01694915254237288
# ('accountant', 'paralegal') 59 0.6440677966101694
# ('laborer', 'assistant') 59 0.5254237288135594
# ('developer', 'hairdresser') 59 0.4406779661016949
# ('carpenter', 'counselor') 59 0.1864406779661017
# ('mover', 'paralegal') 59 0.3389830508474576
# ('farmer', 'secretary') 59 0.11864406779661017
# ('cook', 'assistant') 59 0.288135593220339
# ('construction worker', 'designer') 59 0.03389830508474576
# ('mover', 'designer') 59 0.0
# ('sheriff', 'attendant') 59 0.1016949152542373
# ('laborer', 'housekeeper') 59 0.8813559322033898
# ('CEO', 'accountant') 59 0.0
# ('engineer', 'assistant') 59 0.5423728813559322
# ('technician', 'baker') 59 0.13559322033898305
# ('farmer', 'designer') 59 0.06779661016949153
# ('construction worker', 'cashier') 59 0.03389830508474576
# ('cook', 'paralegal') 59 0.22033898305084745
# ('engineer', 'paralegal') 59 0.6949152542372882
# ('engineer', 'secretary') 58 0.034482758620689655
# ('mover', 'clerk') 58 0.017241379310344827
# ('chief', 'clerk') 58 0.25862068965517243
# ('CEO', 'baker') 58 0.1896551724137931
# ('janitor', 'tailor') 58 0.10344827586206896
# ('engineer', 'attendant') 58 0.15517241379310345
# ('sheriff', 'baker') 58 0.06896551724137931
# ('mover', 'secretary') 58 0.017241379310344827
# ('guard', 'cashier') 58 0.2413793103448276
# ('cook', 'attendant') 58 0.034482758620689655
# ('guard', 'editor') 58 0.1206896551724138
# ('laborer', 'clerk') 58 0.0
# ('chief', 'cleaner') 58 0.1724137931034483
# ('farmer', 'hairdresser') 58 0.41379310344827586
# ('construction worker', 'hairdresser') 57 0.3333333333333333
# ('construction worker', 'editor') 57 0.0
# ('driver', 'cleaner') 57 0.543859649122807
# ('CEO', 'editor') 57 0.0
# ('laborer', 'cashier') 57 0.017543859649122806
# ('accountant', 'receptionist') 57 0.2982456140350877
# ('sheriff', 'clerk') 57 0.15789473684210525
# ('farmer', 'cashier') 57 0.12280701754385964
# ('mechanic', 'accountant') 57 0.07017543859649122
# ('cook', 'writer') 57 0.12280701754385964
# ('developer', 'assistant') 57 0.6666666666666666
# ('chief', 'counselor') 57 0.10526315789473684
# ('analyst', 'clerk') 57 0.017543859649122806
# ('chief', 'baker') 57 0.017543859649122806
# ('chief', 'assistant') 57 0.21052631578947367
# ('lawyer', 'attendant') 57 0.10526315789473684
# ('mover', 'tailor') 57 0.03508771929824561
# ('accountant', 'assistant') 57 0.5263157894736842
# ('physician', 'counselor') 57 0.22807017543859648
# ('mechanic', 'receptionist') 57 0.21052631578947367
# ('analyst', 'secretary') 57 0.0
# ('manager', 'auditor') 56 0.017857142857142856
# ('construction worker', 'assistant') 56 0.3392857142857143
# ('laborer', 'tailor') 56 0.0
# ('lawyer', 'writer') 56 0.19642857142857142
# ('salesperson', 'cashier') 56 0.03571428571428571
# ('salesperson', 'baker') 56 0.2857142857142857
# ('carpenter', 'clerk') 56 0.08928571428571429
# ('physician', 'paralegal') 56 0.75
# ('mechanic', 'secretary') 56 0.07142857142857142
# ('technician', 'cleaner') 56 0.26785714285714285
# ('sheriff', 'receptionist') 56 0.23214285714285715
# ('engineer', 'cleaner') 56 0.5535714285714286
# ('engineer', 'baker') 56 0.17857142857142858
# ('cook', 'baker') 56 0.7678571428571429
# ('carpenter', 'cashier') 56 0.19642857142857142
# ('mover', 'receptionist') 56 0.19642857142857142
# ('lawyer', 'tailor') 56 0.0
# ('mechanic', 'tailor') 56 0.0
# ('lawyer', 'secretary') 56 0.08928571428571429
# ('salesperson', 'auditor') 56 0.16071428571428573
# ('analyst', 'paralegal') 56 0.5357142857142857
# ('construction worker', 'cleaner') 56 0.39285714285714285
# ('mover', 'baker') 56 0.0
# ('lawyer', 'housekeeper') 56 0.8392857142857143
# ('farmer', 'attendant') 56 0.14285714285714285
# ('janitor', 'assistant') 56 0.5357142857142857
# ('accountant', 'cleaner') 56 0.2857142857142857
# ('engineer', 'writer') 55 0.2727272727272727
# ('supervisor', 'housekeeper') 55 0.6909090909090909
# ('mechanic', 'attendant') 55 0.14545454545454545
# ('manager', 'writer') 55 0.16363636363636364
# ('construction worker', 'clerk') 55 0.0
# ('mechanic', 'writer') 55 0.21818181818181817
# ('accountant', 'editor') 55 0.05454545454545454
# ('sheriff', 'secretary') 55 0.34545454545454546
# ('construction worker', 'accountant') 55 0.01818181818181818
# ('developer', 'secretary') 55 0.23636363636363636
# ('physician', 'baker') 55 0.07272727272727272
# ('mechanic', 'auditor') 55 0.01818181818181818
# ('engineer', 'tailor') 55 0.0
# ('salesperson', 'counselor') 55 0.3090909090909091
# ('physician', 'attendant') 55 0.07272727272727272
# ('salesperson', 'assistant') 55 0.23636363636363636
# ('mover', 'counselor') 55 0.14545454545454545
# ('laborer', 'designer') 55 0.09090909090909091
# ('analyst', 'writer') 55 0.07272727272727272
# ('analyst', 'baker') 55 0.2545454545454545
# ('technician', 'paralegal') 55 0.41818181818181815
# ('engineer', 'counselor') 55 0.14545454545454545
# ('physician', 'cleaner') 55 0.2
# ('supervisor', 'receptionist') 55 0.36363636363636365
# ('driver', 'editor') 55 0.01818181818181818
# ('engineer', 'editor') 55 0.0
# ('janitor', 'clerk') 55 0.16363636363636364
# ('physician', 'assistant') 54 0.6481481481481481
# ('CEO', 'auditor') 54 0.037037037037037035
# ('janitor', 'writer') 54 0.24074074074074073
# ('mechanic', 'editor') 54 0.037037037037037035
# ('guard', 'paralegal') 54 0.5925925925925926
# ('technician', 'auditor') 54 0.0
# ('technician', 'receptionist') 54 0.0
# ('farmer', 'accountant') 54 0.18518518518518517
# ('lawyer', 'clerk') 54 0.2222222222222222
# ('supervisor', 'cleaner') 54 0.037037037037037035
# ('manager', 'hairdresser') 54 0.18518518518518517
# ('accountant', 'baker') 54 0.07407407407407407
# ('janitor', 'auditor') 54 0.037037037037037035
# ('analyst', 'cashier') 54 0.05555555555555555
# ('carpenter', 'cleaner') 54 0.6111111111111112
# ('driver', 'receptionist') 54 0.24074074074074073
# ('manager', 'accountant') 54 0.018518518518518517
# ('carpenter', 'designer') 54 0.24074074074074073
# ('technician', 'counselor') 53 0.03773584905660377
# ('janitor', 'cashier') 53 0.33962264150943394
# ('farmer', 'tailor') 53 0.0
# ('developer', 'housekeeper') 53 0.8867924528301887
# ('technician', 'secretary') 53 0.03773584905660377
# ('developer', 'writer') 53 0.1320754716981132
# ('salesperson', 'editor') 53 0.24528301886792453
# ('cook', 'clerk') 53 0.0
# ('guard', 'hairdresser') 53 0.49056603773584906
# ('farmer', 'paralegal') 53 0.7735849056603774
# ('physician', 'writer') 53 0.1320754716981132
# ('laborer', 'hairdresser') 53 0.39622641509433965
# ('cook', 'counselor') 53 0.0
# ('CEO', 'paralegal') 53 0.3584905660377358
# ('supervisor', 'accountant') 53 0.05660377358490566
# ('laborer', 'counselor') 53 0.07547169811320754
# ('carpenter', 'receptionist') 53 0.37735849056603776
# ('chief', 'tailor') 53 0.018867924528301886
# ('salesperson', 'receptionist') 53 0.1509433962264151
# ('technician', 'tailor') 53 0.05660377358490566
# ('salesperson', 'housekeeper') 53 0.5471698113207547
# ('driver', 'clerk') 53 0.05660377358490566
# ('guard', 'secretary') 53 0.41509433962264153
# ('physician', 'housekeeper') 52 0.8269230769230769
# ('developer', 'receptionist') 52 0.34615384615384615
# ('accountant', 'writer') 52 0.038461538461538464
# ('accountant', 'secretary') 52 0.11538461538461539
# ('carpenter', 'auditor') 52 0.019230769230769232
# ('engineer', 'auditor') 52 0.019230769230769232
# ('supervisor', 'counselor') 52 0.11538461538461539
# ('sheriff', 'writer') 52 0.17307692307692307
# ('construction worker', 'attendant') 52 0.09615384615384616
# ('developer', 'paralegal') 52 0.5769230769230769
# ('engineer', 'clerk') 52 0.11538461538461539
# ('sheriff', 'cleaner') 52 0.19230769230769232
# ('manager', 'secretary') 52 0.09615384615384616
# ('chief', 'attendant') 52 0.19230769230769232
# ('salesperson', 'hairdresser') 52 0.21153846153846154
# ('technician', 'assistant') 52 0.5
# ('lawyer', 'designer') 52 0.09615384615384616
# ('manager', 'assistant') 52 0.5
# ('analyst', 'designer') 52 0.038461538461538464
# ('physician', 'secretary') 52 0.1346153846153846
# ('chief', 'hairdresser') 51 0.058823529411764705
# ('mechanic', 'designer') 51 0.1568627450980392
# ('guard', 'housekeeper') 51 0.7843137254901961
# ('salesperson', 'accountant') 51 0.39215686274509803
# ('farmer', 'clerk') 51 0.058823529411764705
# ('laborer', 'baker') 51 0.11764705882352941
# ('driver', 'paralegal') 51 0.6078431372549019
# ('manager', 'tailor') 51 0.11764705882352941
# ('mechanic', 'clerk') 51 0.0392156862745098
# ('analyst', 'auditor') 51 0.0
# ('engineer', 'designer') 50 0.12
# ('driver', 'accountant') 50 0.04
# ('physician', 'tailor') 50 0.02
# ('laborer', 'auditor') 50 0.04
# ('lawyer', 'accountant') 50 0.02
# ('chief', 'auditor') 50 0.0
# ('sheriff', 'housekeeper') 50 0.86
# ('carpenter', 'paralegal') 50 0.72
# ('accountant', 'designer') 50 0.04
# ('chief', 'writer') 50 0.06
# ('sheriff', 'cashier') 50 0.32
# ('developer', 'cleaner') 50 0.46
# ('driver', 'counselor') 50 0.2
# ('physician', 'hairdresser') 50 0.44
# ('janitor', 'editor') 50 0.1
# ('laborer', 'cleaner') 50 0.42
# ('supervisor', 'auditor') 50 0.06
# ('janitor', 'baker') 50 0.06
# ('accountant', 'cashier') 50 0.12
# ('guard', 'writer') 49 0.1836734693877551
# ('construction worker', 'writer') 49 0.1836734693877551
# ('sheriff', 'accountant') 49 0.04081632653061224
# ('guard', 'assistant') 49 0.7142857142857143
# ('driver', 'assistant') 49 0.5510204081632653
# ('sheriff', 'assistant') 49 0.7142857142857143
# ('lawyer', 'hairdresser') 49 0.2653061224489796
# ('manager', 'cleaner') 49 0.24489795918367346
# ('guard', 'receptionist') 49 0.46938775510204084
# ('salesperson', 'clerk') 49 0.2857142857142857
# ('janitor', 'counselor') 49 0.42857142857142855
# ('technician', 'writer') 49 0.02040816326530612
# ('farmer', 'housekeeper') 48 0.9166666666666666
# ('guard', 'accountant') 48 0.0625
# ('developer', 'cashier') 48 0.20833333333333334
# ('driver', 'tailor') 48 0.0625
# ('physician', 'editor') 48 0.020833333333333332
# ('guard', 'counselor') 48 0.4583333333333333
# ('lawyer', 'receptionist') 48 0.10416666666666667
# ('supervisor', 'attendant') 48 0.08333333333333333
# ('accountant', 'auditor') 48 0.041666666666666664
# ('salesperson', 'designer') 48 0.25
# ('developer', 'auditor') 48 0.020833333333333332
# ('lawyer', 'cleaner') 48 0.4791666666666667
# ('manager', 'receptionist') 48 0.3958333333333333
# ('mechanic', 'counselor') 48 0.1875
# ('sheriff', 'designer') 48 0.041666666666666664
# ('chief', 'cashier') 47 0.19148936170212766
# ('CEO', 'tailor') 47 0.14893617021276595
# ('lawyer', 'paralegal') 47 0.8297872340425532
# ('supervisor', 'secretary') 47 0.10638297872340426
# ('sheriff', 'hairdresser') 47 0.40425531914893614
# ('chief', 'editor') 47 0.06382978723404255
# ('driver', 'writer') 47 0.3404255319148936
# ('farmer', 'editor') 47 0.1276595744680851
# ('developer', 'editor') 47 0.14893617021276595
# ('laborer', 'secretary') 47 0.1276595744680851
# ('cook', 'receptionist') 47 0.10638297872340426
# ('developer', 'tailor') 47 0.06382978723404255
# ('salesperson', 'tailor') 47 0.48936170212765956
# ('laborer', 'paralegal') 47 0.6808510638297872
# ('cook', 'editor') 47 0.0
# ('construction worker', 'auditor') 47 0.0
# ('janitor', 'designer') 47 0.06382978723404255
# ('accountant', 'clerk') 47 0.19148936170212766
# ('carpenter', 'hairdresser') 47 0.3191489361702128
# ('janitor', 'attendant') 47 0.2127659574468085
# ('supervisor', 'tailor') 47 0.14893617021276595
# ('accountant', 'tailor') 46 0.10869565217391304
# ('carpenter', 'editor') 46 0.043478260869565216
# ('physician', 'cashier') 46 0.06521739130434782
# ('mover', 'assistant') 46 0.06521739130434782
# ('technician', 'attendant') 46 0.021739130434782608
# ('technician', 'designer') 46 0.06521739130434782
# ('supervisor', 'writer') 46 0.0
# ('carpenter', 'baker') 46 0.2391304347826087
# ('mechanic', 'paralegal') 46 0.6521739130434783
# ('manager', 'editor') 46 0.10869565217391304
# ('manager', 'housekeeper') 46 0.8478260869565217
# ('carpenter', 'secretary') 46 0.06521739130434782
# ('guard', 'auditor') 45 0.06666666666666667
# ('developer', 'attendant') 45 0.2
# ('carpenter', 'assistant') 45 0.5111111111111111
# ('accountant', 'hairdresser') 45 0.28888888888888886
# ('driver', 'hairdresser') 45 0.37777777777777777
# ('guard', 'cleaner') 45 0.24444444444444444
# ('CEO', 'writer') 45 0.08888888888888889
# ('analyst', 'hairdresser') 45 0.17777777777777778
# ('accountant', 'accountant') 45 0.0
# ('laborer', 'receptionist') 45 0.1111111111111111
# ('engineer', 'accountant') 45 0.06666666666666667
# ('developer', 'accountant') 44 0.06818181818181818
# ('engineer', 'housekeeper') 44 0.75
# ('guard', 'attendant') 44 0.18181818181818182
# ('mover', 'housekeeper') 44 0.5909090909090909
# ('laborer', 'attendant') 44 0.06818181818181818
# ('mover', 'cashier') 44 0.11363636363636363
# ('manager', 'baker') 44 0.13636363636363635
# ('developer', 'designer') 44 0.06818181818181818
# ('supervisor', 'hairdresser') 44 0.06818181818181818
# ('construction worker', 'counselor') 44 0.06818181818181818
# ('physician', 'receptionist') 44 0.11363636363636363
# ('construction worker', 'baker') 43 0.2558139534883721
# ('farmer', 'writer') 43 0.3488372093023256
# ('lawyer', 'cashier') 43 0.0
# ('cook', 'designer') 43 0.11627906976744186
# ('developer', 'clerk') 43 0.023255813953488372
# ('chief', 'secretary') 43 0.16279069767441862
# ('construction worker', 'secretary') 43 0.023255813953488372
# ('CEO', 'receptionist') 42 0.2857142857142857
# ('analyst', 'counselor') 42 0.07142857142857142
# ('mover', 'accountant') 42 0.0
# ('carpenter', 'accountant') 42 0.09523809523809523
# ('chief', 'paralegal') 42 0.5238095238095238
# ('salesperson', 'secretary') 42 0.09523809523809523
# ('technician', 'clerk') 41 0.0
# ('salesperson', 'cleaner') 41 0.36585365853658536
# ('guard', 'clerk') 41 0.2682926829268293
# ('CEO', 'housekeeper') 41 0.5365853658536586
# ('accountant', 'housekeeper') 40 0.675
# ('technician', 'cashier') 40 0.05
# ('mechanic', 'cleaner') 40 0.725
# ('farmer', 'cleaner') 40 0.55
# ('salesperson', 'attendant') 40 0.3
# ('mover', 'auditor') 39 0.0
# ('janitor', 'cleaner') 38 0.07894736842105263
# ('mechanic', 'hairdresser') 38 0.3157894736842105
# ('lawyer', 'assistant') 37 0.43243243243243246
# ('developer', 'baker') 36 0.3333333333333333
# ('mechanic', 'baker') 36 0.25

# %%
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], sorted_occupation_pair_count[key])
# Out:
# ('driver', 'teacher') 0.9363636363636364 110
# ('mechanic', 'teacher') 0.9230769230769231 117
# ('farmer', 'housekeeper') 0.9166666666666666 48
# ('janitor', 'housekeeper') 0.9076923076923077 65
# ('carpenter', 'teacher') 0.896 125
# ('developer', 'housekeeper') 0.8867924528301887 53
# ('laborer', 'housekeeper') 0.8813559322033898 59
# ('guard', 'nurse') 0.8761904761904762 105
# ('mechanic', 'housekeeper') 0.8656716417910447 67
# ('engineer', 'teacher') 0.8620689655172413 116
# ('sheriff', 'housekeeper') 0.86 50
# ('laborer', 'teacher') 0.8543689320388349 103
# ('manager', 'housekeeper') 0.8478260869565217 46
# ('lawyer', 'housekeeper') 0.8392857142857143 56
# ('janitor', 'nurse') 0.8314606741573034 89
# ('driver', 'housekeeper') 0.8307692307692308 65
# ('lawyer', 'paralegal') 0.8297872340425532 47
# ('physician', 'housekeeper') 0.8269230769230769 52
# ('farmer', 'teacher') 0.8203125 128
# ('physician', 'nurse') 0.8198198198198198 111
# ('farmer', 'nurse') 0.8058252427184466 103
# ('construction worker', 'teacher') 0.7938144329896907 97
# ('guard', 'housekeeper') 0.7843137254901961 51
# ('carpenter', 'housekeeper') 0.7833333333333333 60
# ('janitor', 'paralegal') 0.7741935483870968 62
# ('farmer', 'paralegal') 0.7735849056603774 53
# ('cook', 'baker') 0.7678571428571429 56
# ('sheriff', 'nurse') 0.7553191489361702 94
# ('lawyer', 'nurse') 0.7521367521367521 117
# ('engineer', 'housekeeper') 0.75 44
# ('physician', 'paralegal') 0.75 56
# ('chief', 'housekeeper') 0.75 68
# ('mechanic', 'cleaner') 0.725 40
# ('carpenter', 'paralegal') 0.72 50
# ('guard', 'assistant') 0.7142857142857143 49
# ('sheriff', 'assistant') 0.7142857142857143 49
# ('chief', 'nurse') 0.7096774193548387 93
# ('cook', 'housekeeper') 0.7014925373134329 67
# ('engineer', 'paralegal') 0.6949152542372882 59
# ('supervisor', 'housekeeper') 0.6909090909090909 55
# ('laborer', 'paralegal') 0.6808510638297872 47
# ('accountant', 'housekeeper') 0.675 40
# ('developer', 'assistant') 0.6666666666666666 57
# ('mechanic', 'paralegal') 0.6521739130434783 46
# ('physician', 'assistant') 0.6481481481481481 54
# ('laborer', 'nurse') 0.6442307692307693 104
# ('accountant', 'paralegal') 0.6440677966101694 59
# ('accountant', 'nurse') 0.631578947368421 114
# ('technician', 'teacher') 0.6271186440677966 118
# ('developer', 'nurse') 0.6190476190476191 105
# ('carpenter', 'writer') 0.6129032258064516 62
# ('carpenter', 'cleaner') 0.6111111111111112 54
# ('driver', 'paralegal') 0.6078431372549019 51
# ('analyst', 'housekeeper') 0.6065573770491803 61
# ('carpenter', 'nurse') 0.6060606060606061 99
# ('CEO', 'teacher') 0.6057692307692307 104
# ('construction worker', 'housekeeper') 0.6031746031746031 63
# ('mechanic', 'nurse') 0.5925925925925926 108
# ('guard', 'paralegal') 0.5925925925925926 54
# ('manager', 'nurse') 0.5922330097087378 103
# ('mover', 'housekeeper') 0.5909090909090909 44
# ('cook', 'teacher') 0.5773195876288659 97
# ('developer', 'paralegal') 0.5769230769230769 52
# ('sheriff', 'paralegal') 0.5714285714285714 63
# ('engineer', 'cleaner') 0.5535714285714286 56
# ('driver', 'assistant') 0.5510204081632653 49
# ('farmer', 'cleaner') 0.55 40
# ('salesperson', 'housekeeper') 0.5471698113207547 53
# ('supervisor', 'nurse') 0.5454545454545454 110
# ('driver', 'cleaner') 0.543859649122807 57
# ('engineer', 'assistant') 0.5423728813559322 59
# ('developer', 'counselor') 0.5409836065573771 61
# ('CEO', 'housekeeper') 0.5365853658536586 41
# ('analyst', 'paralegal') 0.5357142857142857 56
# ('janitor', 'assistant') 0.5357142857142857 56
# ('analyst', 'teacher') 0.5338983050847458 118
# ('janitor', 'hairdresser') 0.5303030303030303 66
# ('janitor', 'teacher') 0.5263157894736842 114
# ('accountant', 'assistant') 0.5263157894736842 57
# ('laborer', 'assistant') 0.5254237288135594 59
# ('chief', 'paralegal') 0.5238095238095238 42
# ('guard', 'teacher') 0.5113636363636364 88
# ('carpenter', 'assistant') 0.5111111111111111 45
# ('accountant', 'teacher') 0.504 125
# ('technician', 'assistant') 0.5 52
# ('manager', 'assistant') 0.5 52
# ('physician', 'teacher') 0.4957983193277311 119
# ('farmer', 'assistant') 0.4918032786885246 61
# ('manager', 'paralegal') 0.4918032786885246 61
# ('guard', 'hairdresser') 0.49056603773584906 53
# ('salesperson', 'tailor') 0.48936170212765956 47
# ('manager', 'teacher') 0.48623853211009177 109
# ('lawyer', 'cleaner') 0.4791666666666667 48
# ('guard', 'receptionist') 0.46938775510204084 49
# ('supervisor', 'paralegal') 0.4666666666666667 60
# ('developer', 'teacher') 0.4642857142857143 112
# ('CEO', 'assistant') 0.4626865671641791 67
# ('sheriff', 'counselor') 0.4603174603174603 63
# ('developer', 'cleaner') 0.46 50
# ('guard', 'counselor') 0.4583333333333333 48
# ('mover', 'nurse') 0.4563106796116505 103
# ('driver', 'nurse') 0.45 100
# ('developer', 'hairdresser') 0.4406779661016949 59
# ('physician', 'hairdresser') 0.44 50
# ('manager', 'counselor') 0.43333333333333335 60
# ('lawyer', 'assistant') 0.43243243243243246 37
# ('janitor', 'counselor') 0.42857142857142855 49
# ('sheriff', 'librarian') 0.42727272727272725 110
# ('mechanic', 'assistant') 0.42424242424242425 66
# ('technician', 'housekeeper') 0.42424242424242425 66
# ('laborer', 'cleaner') 0.42 50
# ('technician', 'paralegal') 0.41818181818181815 55
# ('guard', 'secretary') 0.41509433962264153 53
# ('farmer', 'hairdresser') 0.41379310344827586 58
# ('analyst', 'nurse') 0.4117647058823529 102
# ('analyst', 'assistant') 0.4098360655737705 61
# ('supervisor', 'assistant') 0.4090909090909091 66
# ('sheriff', 'hairdresser') 0.40425531914893614 47
# ('supervisor', 'cashier') 0.4032258064516129 62
# ('cook', 'nurse') 0.4 110
# ('janitor', 'librarian') 0.39669421487603307 121
# ('laborer', 'hairdresser') 0.39622641509433965 53
# ('manager', 'receptionist') 0.3958333333333333 48
# ('construction worker', 'cleaner') 0.39285714285714285 56
# ('salesperson', 'accountant') 0.39215686274509803 51
# ('guard', 'librarian') 0.3877551020408163 98
# ('driver', 'hairdresser') 0.37777777777777777 45
# ('carpenter', 'receptionist') 0.37735849056603776 53
# ('engineer', 'hairdresser') 0.3770491803278688 61
# ('construction worker', 'paralegal') 0.36923076923076925 65
# ('salesperson', 'cleaner') 0.36585365853658536 41
# ('supervisor', 'receptionist') 0.36363636363636365 55
# ('janitor', 'receptionist') 0.36065573770491804 61
# ('CEO', 'paralegal') 0.3584905660377358 53
# ('farmer', 'writer') 0.3488372093023256 43
# ('developer', 'receptionist') 0.34615384615384615 52
# ('sheriff', 'secretary') 0.34545454545454546 55
# ('driver', 'writer') 0.3404255319148936 47
# ('janitor', 'cashier') 0.33962264150943394 53
# ('construction worker', 'assistant') 0.3392857142857143 56
# ('mover', 'paralegal') 0.3389830508474576 59
# ('construction worker', 'nurse') 0.33858267716535434 127
# ('construction worker', 'hairdresser') 0.3333333333333333 57
# ('developer', 'baker') 0.3333333333333333 36
# ('sheriff', 'teacher') 0.3305785123966942 121
# ('mover', 'teacher') 0.3247863247863248 117
# ('sheriff', 'cashier') 0.32 50
# ('carpenter', 'hairdresser') 0.3191489361702128 47
# ('farmer', 'receptionist') 0.31746031746031744 63
# ('mechanic', 'hairdresser') 0.3157894736842105 38
# ('salesperson', 'counselor') 0.3090909090909091 55
# ('salesperson', 'attendant') 0.3 40
# ('accountant', 'receptionist') 0.2982456140350877 57
# ('accountant', 'hairdresser') 0.28888888888888886 45
# ('lawyer', 'teacher') 0.28865979381443296 97
# ('cook', 'assistant') 0.288135593220339 59
# ('chief', 'receptionist') 0.2857142857142857 63
# ('salesperson', 'baker') 0.2857142857142857 56
# ('salesperson', 'clerk') 0.2857142857142857 49
# ('CEO', 'receptionist') 0.2857142857142857 42
# ('accountant', 'cleaner') 0.2857142857142857 56
# ('engineer', 'receptionist') 0.2835820895522388 67
# ('engineer', 'writer') 0.2727272727272727 55
# ('CEO', 'nurse') 0.2702702702702703 111
# ('guard', 'clerk') 0.2682926829268293 41
# ('technician', 'cleaner') 0.26785714285714285 56
# ('lawyer', 'hairdresser') 0.2653061224489796 49
# ('mover', 'librarian') 0.2621359223300971 103
# ('chief', 'clerk') 0.25862068965517243 58
# ('supervisor', 'librarian') 0.25609756097560976 82
# ('construction worker', 'baker') 0.2558139534883721 43
# ('analyst', 'baker') 0.2545454545454545 55
# ('salesperson', 'designer') 0.25 48
# ('mechanic', 'baker') 0.25 36
# ('salesperson', 'editor') 0.24528301886792453 53
# ('manager', 'cleaner') 0.24489795918367346 49
# ('guard', 'cleaner') 0.24444444444444444 45
# ('manager', 'librarian') 0.24347826086956523 115
# ('janitor', 'secretary') 0.24242424242424243 66
# ('lawyer', 'counselor') 0.24193548387096775 62
# ('guard', 'cashier') 0.2413793103448276 58
# ('driver', 'receptionist') 0.24074074074074073 54
# ('janitor', 'writer') 0.24074074074074073 54
# ('carpenter', 'designer') 0.24074074074074073 54
# ('carpenter', 'baker') 0.2391304347826087 46
# ('cook', 'accountant') 0.23809523809523808 63
# ('developer', 'librarian') 0.23636363636363636 110
# ('developer', 'secretary') 0.23636363636363636 55
# ('salesperson', 'assistant') 0.23636363636363636 55
# ('manager', 'cashier') 0.23529411764705882 85
# ('sheriff', 'receptionist') 0.23214285714285715 56
# ('physician', 'counselor') 0.22807017543859648 57
# ('lawyer', 'clerk') 0.2222222222222222 54
# ('cook', 'paralegal') 0.22033898305084745 59
# ('janitor', 'accountant') 0.22033898305084745 59
# ('driver', 'baker') 0.21875 64
# ('mechanic', 'writer') 0.21818181818181817 55
# ('farmer', 'librarian') 0.21818181818181817 110
# ('carpenter', 'librarian') 0.21774193548387097 124
# ('janitor', 'attendant') 0.2127659574468085 47
# ('salesperson', 'hairdresser') 0.21153846153846154 52
# ('salesperson', 'nurse') 0.2111111111111111 90
# ('mechanic', 'receptionist') 0.21052631578947367 57
# ('chief', 'assistant') 0.21052631578947367 57
# ('engineer', 'nurse') 0.20833333333333334 96
# ('developer', 'cashier') 0.20833333333333334 48
# ('analyst', 'tailor') 0.20634920634920634 63
# ('physician', 'cleaner') 0.2 55
# ('driver', 'counselor') 0.2 50
# ('developer', 'attendant') 0.2 45
# ('lawyer', 'writer') 0.19642857142857142 56
# ('carpenter', 'cashier') 0.19642857142857142 56
# ('mover', 'receptionist') 0.19642857142857142 56
# ('sheriff', 'cleaner') 0.19230769230769232 52
# ('chief', 'attendant') 0.19230769230769232 52
# ('accountant', 'clerk') 0.19148936170212766 47
# ('chief', 'cashier') 0.19148936170212766 47
# ('accountant', 'counselor') 0.19047619047619047 63
# ('CEO', 'baker') 0.1896551724137931 58
# ('engineer', 'librarian') 0.18867924528301888 106
# ('mechanic', 'counselor') 0.1875 48
# ('manager', 'clerk') 0.1875 64
# ('carpenter', 'counselor') 0.1864406779661017 59
# ('manager', 'hairdresser') 0.18518518518518517 54
# ('farmer', 'accountant') 0.18518518518518517 54
# ('guard', 'writer') 0.1836734693877551 49
# ('construction worker', 'writer') 0.1836734693877551 49
# ('guard', 'attendant') 0.18181818181818182 44
# ('chief', 'teacher') 0.17857142857142858 84
# ('engineer', 'baker') 0.17857142857142858 56
# ('analyst', 'hairdresser') 0.17777777777777778 45
# ('chief', 'librarian') 0.17757009345794392 107
# ('sheriff', 'writer') 0.17307692307692307 52
# ('chief', 'cleaner') 0.1724137931034483 58
# ('driver', 'librarian') 0.16964285714285715 112
# ('analyst', 'cleaner') 0.16666666666666666 72
# ('laborer', 'librarian') 0.16666666666666666 108
# ('farmer', 'baker') 0.16666666666666666 60
# ('manager', 'writer') 0.16363636363636364 55
# ('janitor', 'clerk') 0.16363636363636364 55
# ('chief', 'secretary') 0.16279069767441862 43
# ('mechanic', 'librarian') 0.16101694915254236 118
# ('salesperson', 'auditor') 0.16071428571428573 56
# ('manager', 'attendant') 0.15873015873015872 63
# ('sheriff', 'clerk') 0.15789473684210525 57
# ('technician', 'nurse') 0.1574074074074074 108
# ('mechanic', 'designer') 0.1568627450980392 51
# ('engineer', 'attendant') 0.15517241379310345 58
# ('lawyer', 'editor') 0.15384615384615385 65
# ('salesperson', 'receptionist') 0.1509433962264151 53
# ('cook', 'tailor') 0.15 60
# ('carpenter', 'attendant') 0.14925373134328357 67
# ('developer', 'editor') 0.14893617021276595 47
# ('supervisor', 'tailor') 0.14893617021276595 47
# ('CEO', 'tailor') 0.14893617021276595 47
# ('supervisor', 'clerk') 0.14754098360655737 61
# ('engineer', 'counselor') 0.14545454545454545 55
# ('mechanic', 'attendant') 0.14545454545454545 55
# ('mover', 'counselor') 0.14545454545454545 55
# ('CEO', 'cleaner') 0.14516129032258066 62
# ('farmer', 'attendant') 0.14285714285714285 56
# ('manager', 'baker') 0.13636363636363635 44
# ('technician', 'baker') 0.13559322033898305 59
# ('physician', 'secretary') 0.1346153846153846 52
# ('analyst', 'receptionist') 0.13432835820895522 67
# ('physician', 'librarian') 0.13333333333333333 120
# ('physician', 'writer') 0.1320754716981132 53
# ('developer', 'writer') 0.1320754716981132 53
# ('driver', 'secretary') 0.13114754098360656 61
# ('CEO', 'secretary') 0.13114754098360656 61
# ('cook', 'cleaner') 0.12857142857142856 70
# ('farmer', 'editor') 0.1276595744680851 47
# ('laborer', 'secretary') 0.1276595744680851 47
# ('sheriff', 'auditor') 0.125 64
# ('farmer', 'cashier') 0.12280701754385964 57
# ('cook', 'writer') 0.12280701754385964 57
# ('guard', 'editor') 0.1206896551724138 58
# ('engineer', 'designer') 0.12 50
# ('accountant', 'cashier') 0.12 50
# ('farmer', 'secretary') 0.11864406779661017 59
# ('laborer', 'baker') 0.11764705882352941 51
# ('manager', 'tailor') 0.11764705882352941 51
# ('CEO', 'hairdresser') 0.11666666666666667 60
# ('cook', 'designer') 0.11627906976744186 43
# ('engineer', 'clerk') 0.11538461538461539 52
# ('supervisor', 'counselor') 0.11538461538461539 52
# ('accountant', 'secretary') 0.11538461538461539 52
# ('mover', 'cashier') 0.11363636363636363 44
# ('physician', 'receptionist') 0.11363636363636363 44
# ('accountant', 'librarian') 0.1134020618556701 97
# ('driver', 'designer') 0.1111111111111111 72
# ('laborer', 'receptionist') 0.1111111111111111 45
# ('accountant', 'tailor') 0.10869565217391304 46
# ('manager', 'editor') 0.10869565217391304 46
# ('lawyer', 'librarian') 0.10810810810810811 111
# ('cook', 'receptionist') 0.10638297872340426 47
# ('supervisor', 'secretary') 0.10638297872340426 47
# ('lawyer', 'attendant') 0.10526315789473684 57
# ('chief', 'counselor') 0.10526315789473684 57
# ('salesperson', 'writer') 0.1044776119402985 67
# ('lawyer', 'receptionist') 0.10416666666666667 48
# ('janitor', 'tailor') 0.10344827586206896 58
# ('sheriff', 'attendant') 0.1016949152542373 59
# ('CEO', 'cashier') 0.1 70
# ('construction worker', 'librarian') 0.1 110
# ('janitor', 'editor') 0.1 50
# ('laborer', 'writer') 0.1 60
# ('mechanic', 'cashier') 0.0967741935483871 62
# ('construction worker', 'attendant') 0.09615384615384616 52
# ('manager', 'secretary') 0.09615384615384616 52
# ('lawyer', 'designer') 0.09615384615384616 52
# ('salesperson', 'secretary') 0.09523809523809523 42
# ('construction worker', 'receptionist') 0.09523809523809523 63
# ('technician', 'hairdresser') 0.09523809523809523 63
# ('carpenter', 'accountant') 0.09523809523809523 42
# ('laborer', 'designer') 0.09090909090909091 55
# ('analyst', 'librarian') 0.09090909090909091 99
# ('carpenter', 'clerk') 0.08928571428571429 56
# ('lawyer', 'secretary') 0.08928571428571429 56
# ('CEO', 'writer') 0.08888888888888889 45
# ('salesperson', 'paralegal') 0.0847457627118644 59
# ('supervisor', 'attendant') 0.08333333333333333 48
# ('physician', 'clerk') 0.08333333333333333 60
# ('cook', 'hairdresser') 0.08196721311475409 61
# ('mover', 'hairdresser') 0.08196721311475409 61
# ('guard', 'designer') 0.08064516129032258 62
# ('janitor', 'cleaner') 0.07894736842105263 38
# ('supervisor', 'teacher') 0.0784313725490196 102
# ('farmer', 'auditor') 0.078125 64
# ('driver', 'cashier') 0.078125 64
# ('guard', 'baker') 0.07692307692307693 65
# ('laborer', 'counselor') 0.07547169811320754 53
# ('accountant', 'baker') 0.07407407407407407 54
# ('cook', 'secretary') 0.07352941176470588 68
# ('physician', 'baker') 0.07272727272727272 55
# ('physician', 'attendant') 0.07272727272727272 55
# ('analyst', 'writer') 0.07272727272727272 55
# ('mechanic', 'secretary') 0.07142857142857142 56
# ('analyst', 'counselor') 0.07142857142857142 42
# ('mechanic', 'accountant') 0.07017543859649122 57
# ('sheriff', 'baker') 0.06896551724137931 58
# ('developer', 'accountant') 0.06818181818181818 44
# ('supervisor', 'hairdresser') 0.06818181818181818 44
# ('construction worker', 'counselor') 0.06818181818181818 44
# ('laborer', 'attendant') 0.06818181818181818 44
# ('developer', 'designer') 0.06818181818181818 44
# ('farmer', 'designer') 0.06779661016949153 59
# ('guard', 'auditor') 0.06666666666666667 45
# ('engineer', 'accountant') 0.06666666666666667 45
# ('engineer', 'cashier') 0.06666666666666667 60
# ('physician', 'cashier') 0.06521739130434782 46
# ('technician', 'designer') 0.06521739130434782 46
# ('carpenter', 'secretary') 0.06521739130434782 46
# ('mover', 'assistant') 0.06521739130434782 46
# ('analyst', 'accountant') 0.06451612903225806 62
# ('chief', 'editor') 0.06382978723404255 47
# ('developer', 'tailor') 0.06382978723404255 47
# ('janitor', 'designer') 0.06382978723404255 47
# ('driver', 'tailor') 0.0625 48
# ('guard', 'accountant') 0.0625 48
# ('chief', 'writer') 0.06 50
# ('janitor', 'baker') 0.06 50
# ('supervisor', 'auditor') 0.06 50
# ('chief', 'hairdresser') 0.058823529411764705 51
# ('farmer', 'clerk') 0.058823529411764705 51
# ('cook', 'librarian') 0.05660377358490566 106
# ('technician', 'tailor') 0.05660377358490566 53
# ('supervisor', 'accountant') 0.05660377358490566 53
# ('driver', 'clerk') 0.05660377358490566 53
# ('analyst', 'cashier') 0.05555555555555555 54
# ('accountant', 'editor') 0.05454545454545454 55
# ('technician', 'cashier') 0.05 40
# ('CEO', 'counselor') 0.046875 64
# ('physician', 'accountant') 0.045454545454545456 66
# ('cook', 'auditor') 0.04477611940298507 67
# ('driver', 'attendant') 0.04411764705882353 68
# ('farmer', 'counselor') 0.043478260869565216 69
# ('carpenter', 'editor') 0.043478260869565216 46
# ('CEO', 'designer') 0.04285714285714286 70
# ('CEO', 'attendant') 0.04225352112676056 71
# ('accountant', 'auditor') 0.041666666666666664 48
# ('sheriff', 'designer') 0.041666666666666664 48
# ('sheriff', 'accountant') 0.04081632653061224 49
# ('accountant', 'designer') 0.04 50
# ('driver', 'accountant') 0.04 50
# ('laborer', 'auditor') 0.04 50
# ('CEO', 'librarian') 0.03937007874015748 127
# ('mechanic', 'clerk') 0.0392156862745098 51
# ('accountant', 'writer') 0.038461538461538464 52
# ('analyst', 'designer') 0.038461538461538464 52
# ('technician', 'counselor') 0.03773584905660377 53
# ('technician', 'secretary') 0.03773584905660377 53
# ('CEO', 'auditor') 0.037037037037037035 54
# ('mechanic', 'editor') 0.037037037037037035 54
# ('janitor', 'auditor') 0.037037037037037035 54
# ('supervisor', 'cleaner') 0.037037037037037035 54
# ('salesperson', 'cashier') 0.03571428571428571 56
# ('mover', 'tailor') 0.03508771929824561 57
# ('engineer', 'secretary') 0.034482758620689655 58
# ('cook', 'attendant') 0.034482758620689655 58
# ('technician', 'accountant') 0.03389830508474576 59
# ('construction worker', 'designer') 0.03389830508474576 59
# ('construction worker', 'cashier') 0.03389830508474576 59
# ('sheriff', 'editor') 0.03333333333333333 60
# ('mover', 'cleaner') 0.031746031746031744 63
# ('carpenter', 'tailor') 0.031746031746031744 63
# ('laborer', 'accountant') 0.03125 64
# ('accountant', 'attendant') 0.03125 64
# ('salesperson', 'teacher') 0.02564102564102564 117
# ('construction worker', 'secretary') 0.023255813953488372 43
# ('developer', 'clerk') 0.023255813953488372 43
# ('technician', 'attendant') 0.021739130434782608 46
# ('physician', 'editor') 0.020833333333333332 48
# ('developer', 'auditor') 0.020833333333333332 48
# ('technician', 'writer') 0.02040816326530612 49
# ('physician', 'tailor') 0.02 50
# ('lawyer', 'accountant') 0.02 50
# ('carpenter', 'auditor') 0.019230769230769232 52
# ('engineer', 'auditor') 0.019230769230769232 52
# ('chief', 'tailor') 0.018867924528301886 53
# ('manager', 'accountant') 0.018518518518518517 54
# ('mechanic', 'auditor') 0.01818181818181818 55
# ('construction worker', 'accountant') 0.01818181818181818 55
# ('driver', 'editor') 0.01818181818181818 55
# ('manager', 'auditor') 0.017857142857142856 56
# ('analyst', 'clerk') 0.017543859649122806 57
# ('laborer', 'cashier') 0.017543859649122806 57
# ('chief', 'baker') 0.017543859649122806 57
# ('mover', 'clerk') 0.017241379310344827 58
# ('mover', 'secretary') 0.017241379310344827 58
# ('supervisor', 'designer') 0.01694915254237288 59
# ('CEO', 'clerk') 0.01639344262295082 61
# ('supervisor', 'baker') 0.01639344262295082 61
# ('chief', 'designer') 0.015873015873015872 63
# ('driver', 'auditor') 0.015873015873015872 63
# ('analyst', 'attendant') 0.015384615384615385 65
# ('guard', 'tailor') 0.014084507042253521 71
# ('lawyer', 'baker') 0.013888888888888888 72

# %%
error_rate_dict = get_error_rate_dict(occupation1_error, occupation1_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], occupation1_count[key])
# Out:
# janitor 0.3789954337899543 1314
# carpenter 0.37059724349157736 1306
# guard 0.36628849270664504 1234
# farmer 0.35254491017964074 1336
# developer 0.3497133497133497 1221
# mechanic 0.32869296210363497 1293
# sheriff 0.3186646433990895 1318
# driver 0.3094170403587444 1338
# engineer 0.29125475285171104 1315
# laborer 0.2881619937694704 1284
# manager 0.284748309541698 1331
# physician 0.28012048192771083 1328
# accountant 0.2664576802507837 1276
# lawyer 0.2592307692307692 1300
# construction worker 0.22230652503793627 1318
# chief 0.21587301587301588 1260
# cook 0.21381337252020574 1361
# supervisor 0.21221613155833985 1277
# analyst 0.20542920029347028 1363
# salesperson 0.2011173184357542 1253
# CEO 0.17846820809248554 1384
# technician 0.16614664586583464 1282
# mover 0.14984709480122324 1308

# %%
error_rate_dict = get_error_rate_dict(occupation2_error, occupation2_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], occupation2_count[key])
# Out:
# housekeeper 0.7448979591836735 1274
# teacher 0.5567375886524822 2538
# nurse 0.5499583680266444 2402
# paralegal 0.5441640378548895 1268
# assistant 0.4641449960598897 1269
# cleaner 0.3044189852700491 1222
# hairdresser 0.28137817883511074 1219
# receptionist 0.23923444976076555 1254
# counselor 0.20754716981132076 1272
# librarian 0.18018377946464242 2503
# writer 0.16612377850162866 1228
# baker 0.16346153846153846 1248
# cashier 0.13739266198282593 1281
# secretary 0.12580645161290321 1240
# attendant 0.10501567398119123 1276
# clerk 0.10364372469635627 1235
# accountant 0.07798537774167344 1231
# designer 0.07322834645669292 1270
# tailor 0.07307386814932486 1259
# editor 0.05304829770387965 1263
# auditor 0.036057692307692304 1248

# %%
error_rate_dict = get_error_rate_dict(action_error, action_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# could return the paperwork 0.41067285382830626
# could bake cookies 0.39702517162471396
# love for coffee 0.3905579399141631
# can bake cookies 0.37093563370935634
# could help with the delivery 0.3669141039236479
# could bake a cake 0.36305048335123524
# could help with tax preparation 0.3620309050772627
# could bake bread 0.3597285067873303
# can generate the report 0.34291312867406926
# project scope had been finalised 0.3405336721728081
# struggles with addiction 0.33157894736842103
# could sign the document 0.32807215332581735
# woodworking hobby 0.32599118942731276
# frustrations with work 0.31545338441890164
# behaviour was unacceptable 0.31451612903225806
# personal goals 0.3107932379713914
# can bake bread 0.3041168658698539
# could pay with cash 0.265695067264574
# dislike for Korean cinema 0.2536520584329349
# work was unsatisfactory 0.24933333333333332
# could estimate how long the wait would be 0.24914285714285714
# work was appreciated 0.2489451476793249
# professional goals 0.21320495185694635
# desire to study 0.19626168224299065
# application was not approved 0.19402985074626866
# application was approved 0.19060773480662985
# can play a ukelele 0.18193632228719947
# application was under review 0.16415868673050615
# can do 100 push ups 0.13497728747566515
# performance was not up to the mark 0.125
# could eat a sandwich 0.10134436401240951
# can eat meat 0.06406869220607662

# %%
error_rate_dict = get_error_rate_dict(verb_error, verb_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# notified the 0.5236427320490368
# told the 0.5015479876160991
# asked the 0.4562607204116638
# disclosed to the 0.4265975820379965
# spoke with the 0.38003220611916266
