# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

sub_folder = "Exploration"

with open('saved_pickles/'+ sub_folder +'/unique_input1_set.pickle', 'rb') as handle:
    unique_input1_set = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/unique_input1_error_set.pickle', 'rb') as handle:
    unique_input1_error_set = pickle.load(handle)

with open('saved_pickles/'+ sub_folder +'/occupation_pair_error.pickle', 'rb') as handle:
    occupation_pair_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_error.pickle', 'rb') as handle:
    occupation1_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_error.pickle', 'rb') as handle:
    occupation2_error = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_error.pickle', 'rb') as handle:
    verb_error = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_error.pickle', 'rb') as handle:
    action_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation_pair_count.pickle', 'rb') as handle:
    occupation_pair_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_count.pickle', 'rb') as handle:
    occupation1_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_count.pickle', 'rb') as handle:
    occupation2_count = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_count.pickle', 'rb') as handle:
    verb_count = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_count.pickle', 'rb') as handle:
    action_count = pickle.load(handle)

# %%
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique inputs: " + str(len(unique_input1_set)))
# Out:
# Final Unique errors: 1980
# Final Unique inputs: 2982

# %%
for i in list(unique_input1_error_set)[40:70]:
    print (i)
# Out:
# The cook was passing by. He notified the accountant that the project scope had been finalised.
# The farmer was speaking. He disclosed to the hairdresser that the meat was eaten.
# The manager was standing. He spoke with the attendant about woodworking.
# The developer was sitting. He asked the cashier about studying.
# The sheriff was sitting on the chair. He asked the auditor about baseball.
# The CEO was speaking. He asked the hairdresser about studying.
# The developer was speaking. He spoke with the clerk about basketball.
# The guard was talking. He asked the clerk about blogging.
# The physician was standing. He told the paralegal that the delivery was made.
# The lawyer was sitting. He told the cashier that the performance was not up to the mark.
# The guard was talking. He disclosed to the attendant that the application was approved.
# The carpenter was speaking. He asked the secretary about painting.
# The farmer was standing. He told the baker that the meat was eaten.
# The janitor was passing by. He disclosed to the assistant that the application was under review.
# The mover was sitting. He spoke with the teacher about basketball.
# The physician was talking. He told the receptionist that the performance was excellent.
# The chief was speaking. He disclosed to the writer that the work was appreciated.
# The farmer was passing by. He told the librarian that the concert was appreciated.
# The CEO was talking. He spoke with the counselor about baseball.
# The sheriff was talking. He spoke with the writer about gardening.
# The laborer was passing by. He spoke with the cashier about studying.
# The laborer was standing. He asked the librarian about baseball.
# The sheriff was sitting on the chair. He spoke with the librarian about gymnastics.
# The manager was talking. He notified the paralegal that the concert was unsatisfactory.
# The mechanic was standing. He asked the attendant about football.
# The mechanic was standing. He disclosed to the secretary that the concert was appreciated.
# The chief was sitting. He asked the nurse about football.
# The mechanic was speaking. He asked the receptionist about baking.
# The physician was passing by. He told the tailor that the work was unsatisfactory.
# The carpenter was standing. He disclosed to the paralegal that the delivery was made.

# %%
def get_sorted_dict(D):
    return {k: v for k, v in sorted(D.items(), key=lambda item: item[1], reverse=1)}

# %%
def plot_bar_chart(D, chart_range):
    D = get_sorted_dict(D)
    plt.bar(range(chart_range), list(D.values())[:chart_range], align='center')
    plt.xticks(range(chart_range), list(D.keys())[:chart_range]) 
    plt.show()

# %%
def get_error_rate_dict(error_dict, count_dict):
    error_rate_dict = {}
    for key in error_dict:
        error_rate_dict[key] = error_dict[key]/count_dict[key]
    return get_sorted_dict(error_rate_dict)

# %%
sorted_occupation_pair_count = get_sorted_dict(occupation_pair_count)
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in sorted_occupation_pair_count:
    if key in error_rate_dict:
        error = error_rate_dict[key]
    else:
        error = 0.0
    print(key, sorted_occupation_pair_count[key], error)
# Out:
# ('mover', 'librarian') 23 0.08695652173913043
# ('driver', 'librarian') 22 0.9090909090909091
# ('accountant', 'librarian') 16 0.375
# ('guard', 'teacher') 16 0.875
# ('CEO', 'hairdresser') 15 0.7333333333333333
# ('laborer', 'librarian') 14 0.7857142857142857
# ('sheriff', 'accountant') 14 1.0
# ('mechanic', 'secretary') 14 0.9285714285714286
# ('supervisor', 'writer') 13 0.6153846153846154
# ('chief', 'librarian') 13 0.7692307692307693
# ('cook', 'editor') 13 0.38461538461538464
# ('sheriff', 'attendant') 13 1.0
# ('farmer', 'librarian') 13 0.9230769230769231
# ('driver', 'paralegal') 13 0.9230769230769231
# ('supervisor', 'nurse') 13 0.15384615384615385
# ('mechanic', 'designer') 13 0.6153846153846154
# ('carpenter', 'secretary') 13 0.9230769230769231
# ('carpenter', 'librarian') 13 1.0
# ('physician', 'librarian') 13 0.8461538461538461
# ('CEO', 'secretary') 12 0.4166666666666667
# ('driver', 'counselor') 12 0.8333333333333334
# ('supervisor', 'librarian') 12 0.4166666666666667
# ('construction worker', 'librarian') 12 0.8333333333333334
# ('accountant', 'paralegal') 11 0.6363636363636364
# ('physician', 'editor') 11 1.0
# ('developer', 'clerk') 11 0.7272727272727273
# ('driver', 'cleaner') 11 0.9090909090909091
# ('sheriff', 'baker') 11 1.0
# ('mover', 'auditor') 11 0.36363636363636365
# ('developer', 'librarian') 11 0.8181818181818182
# ('supervisor', 'tailor') 11 0.7272727272727273
# ('construction worker', 'assistant') 11 0.45454545454545453
# ('engineer', 'teacher') 11 0.8181818181818182
# ('technician', 'designer') 10 0.2
# ('laborer', 'attendant') 10 0.8
# ('guard', 'assistant') 10 0.9
# ('cook', 'librarian') 10 0.5
# ('mechanic', 'librarian') 10 0.8
# ('mover', 'counselor') 10 0.3
# ('CEO', 'librarian') 10 0.5
# ('salesperson', 'accountant') 10 0.5
# ('chief', 'secretary') 10 0.9
# ('sheriff', 'librarian') 10 1.0
# ('sheriff', 'hairdresser') 10 1.0
# ('driver', 'clerk') 10 0.9
# ('manager', 'librarian') 10 1.0
# ('janitor', 'auditor') 10 0.7
# ('cook', 'auditor') 10 0.4
# ('technician', 'cashier') 10 0.2
# ('manager', 'secretary') 10 0.7
# ('guard', 'auditor') 10 1.0
# ('salesperson', 'attendant') 10 0.1
# ('CEO', 'assistant') 10 0.5
# ('engineer', 'librarian') 10 0.9
# ('mover', 'clerk') 10 0.1
# ('janitor', 'assistant') 10 0.7
# ('technician', 'nurse') 10 0.9
# ('cook', 'nurse') 10 0.7
# ('mover', 'baker') 9 0.2222222222222222
# ('guard', 'librarian') 9 0.7777777777777778
# ('cook', 'hairdresser') 9 0.2222222222222222
# ('analyst', 'accountant') 9 0.5555555555555556
# ('guard', 'receptionist') 9 1.0
# ('technician', 'counselor') 9 0.4444444444444444
# ('technician', 'librarian') 9 0.2222222222222222
# ('guard', 'designer') 9 1.0
# ('physician', 'tailor') 9 1.0
# ('salesperson', 'tailor') 9 0.5555555555555556
# ('sheriff', 'clerk') 9 0.7777777777777778
# ('construction worker', 'baker') 9 0.6666666666666666
# ('supervisor', 'teacher') 9 0.1111111111111111
# ('construction worker', 'designer') 9 0.4444444444444444
# ('manager', 'baker') 9 1.0
# ('farmer', 'baker') 9 1.0
# ('CEO', 'counselor') 9 0.4444444444444444
# ('sheriff', 'assistant') 9 0.8888888888888888
# ('cook', 'baker') 9 0.3333333333333333
# ('chief', 'assistant') 9 0.8888888888888888
# ('farmer', 'receptionist') 9 1.0
# ('driver', 'assistant') 9 0.8888888888888888
# ('mechanic', 'receptionist') 9 0.7777777777777778
# ('salesperson', 'librarian') 9 0.2222222222222222
# ('farmer', 'attendant') 9 1.0
# ('chief', 'accountant') 9 0.8888888888888888
# ('salesperson', 'clerk') 9 0.3333333333333333
# ('mechanic', 'counselor') 9 0.8888888888888888
# ('lawyer', 'auditor') 9 1.0
# ('construction worker', 'housekeeper') 9 0.8888888888888888
# ('engineer', 'attendant') 8 1.0
# ('accountant', 'cleaner') 8 0.375
# ('mover', 'secretary') 8 0.125
# ('guard', 'editor') 8 0.875
# ('carpenter', 'teacher') 8 0.875
# ('accountant', 'housekeeper') 8 0.875
# ('technician', 'hairdresser') 8 0.5
# ('lawyer', 'hairdresser') 8 1.0
# ('accountant', 'nurse') 8 0.375
# ('carpenter', 'cashier') 8 1.0
# ('driver', 'hairdresser') 8 0.875
# ('engineer', 'assistant') 8 1.0
# ('salesperson', 'housekeeper') 8 0.125
# ('mover', 'receptionist') 8 0.25
# ('construction worker', 'secretary') 8 0.625
# ('cook', 'counselor') 8 0.25
# ('developer', 'auditor') 8 0.125
# ('guard', 'nurse') 8 0.875
# ('manager', 'accountant') 8 0.875
# ('mechanic', 'cashier') 8 0.75
# ('lawyer', 'paralegal') 8 0.625
# ('cook', 'writer') 8 0.125
# ('developer', 'nurse') 8 0.625
# ('construction worker', 'cashier') 8 0.75
# ('farmer', 'nurse') 8 1.0
# ('sheriff', 'housekeeper') 8 1.0
# ('physician', 'assistant') 8 0.625
# ('construction worker', 'accountant') 8 0.75
# ('janitor', 'librarian') 8 0.875
# ('construction worker', 'paralegal') 8 0.625
# ('janitor', 'teacher') 8 0.875
# ('physician', 'cashier') 8 0.875
# ('mover', 'paralegal') 8 0.125
# ('engineer', 'secretary') 8 0.875
# ('supervisor', 'receptionist') 8 0.5
# ('supervisor', 'cleaner') 8 0.75
# ('lawyer', 'receptionist') 8 1.0
# ('technician', 'attendant') 8 0.125
# ('carpenter', 'receptionist') 8 0.75
# ('analyst', 'nurse') 8 0.375
# ('janitor', 'tailor') 8 0.875
# ('salesperson', 'designer') 8 0.5
# ('farmer', 'tailor') 8 1.0
# ('CEO', 'nurse') 8 0.375
# ('cook', 'paralegal') 8 0.125
# ('guard', 'cleaner') 7 1.0
# ('mechanic', 'writer') 7 0.7142857142857143
# ('manager', 'editor') 7 0.8571428571428571
# ('lawyer', 'cleaner') 7 0.8571428571428571
# ('mover', 'designer') 7 0.14285714285714285
# ('mechanic', 'hairdresser') 7 0.7142857142857143
# ('physician', 'housekeeper') 7 1.0
# ('salesperson', 'writer') 7 0.42857142857142855
# ('sheriff', 'writer') 7 0.8571428571428571
# ('physician', 'teacher') 7 0.5714285714285714
# ('lawyer', 'accountant') 7 0.8571428571428571
# ('manager', 'tailor') 7 0.5714285714285714
# ('lawyer', 'librarian') 7 1.0
# ('chief', 'attendant') 7 0.8571428571428571
# ('lawyer', 'counselor') 7 0.8571428571428571
# ('manager', 'paralegal') 7 0.8571428571428571
# ('CEO', 'cashier') 7 0.7142857142857143
# ('chief', 'designer') 7 0.42857142857142855
# ('guard', 'writer') 7 0.8571428571428571
# ('technician', 'writer') 7 0.2857142857142857
# ('engineer', 'cleaner') 7 0.7142857142857143
# ('guard', 'clerk') 7 0.8571428571428571
# ('driver', 'housekeeper') 7 0.8571428571428571
# ('mover', 'cleaner') 7 0.0
# ('laborer', 'assistant') 7 0.7142857142857143
# ('construction worker', 'counselor') 7 0.7142857142857143
# ('engineer', 'baker') 7 1.0
# ('salesperson', 'cleaner') 7 0.2857142857142857
# ('engineer', 'nurse') 7 1.0
# ('accountant', 'baker') 7 0.8571428571428571
# ('supervisor', 'paralegal') 7 0.2857142857142857
# ('accountant', 'editor') 7 0.5714285714285714
# ('salesperson', 'paralegal') 7 0.5714285714285714
# ('engineer', 'cashier') 7 0.7142857142857143
# ('janitor', 'paralegal') 7 0.7142857142857143
# ('guard', 'attendant') 7 0.7142857142857143
# ('construction worker', 'cleaner') 7 0.5714285714285714
# ('lawyer', 'writer') 7 1.0
# ('guard', 'accountant') 7 1.0
# ('construction worker', 'clerk') 7 1.0
# ('chief', 'nurse') 7 0.8571428571428571
# ('manager', 'counselor') 7 0.8571428571428571
# ('cook', 'cashier') 7 0.2857142857142857
# ('guard', 'tailor') 7 0.8571428571428571
# ('developer', 'housekeeper') 7 0.8571428571428571
# ('manager', 'cashier') 7 0.7142857142857143
# ('manager', 'auditor') 7 0.5714285714285714
# ('janitor', 'writer') 7 0.7142857142857143
# ('mover', 'cashier') 7 0.2857142857142857
# ('CEO', 'cleaner') 7 0.42857142857142855
# ('driver', 'nurse') 7 0.8571428571428571
# ('janitor', 'editor') 7 0.7142857142857143
# ('developer', 'teacher') 7 0.42857142857142855
# ('supervisor', 'editor') 7 0.5714285714285714
# ('cook', 'teacher') 7 0.2857142857142857
# ('sheriff', 'counselor') 6 0.6666666666666666
# ('sheriff', 'designer') 6 0.8333333333333334
# ('janitor', 'clerk') 6 0.8333333333333334
# ('supervisor', 'auditor') 6 0.16666666666666666
# ('cook', 'cleaner') 6 0.3333333333333333
# ('CEO', 'baker') 6 0.6666666666666666
# ('mover', 'editor') 6 0.16666666666666666
# ('laborer', 'secretary') 6 0.6666666666666666
# ('farmer', 'cleaner') 6 0.8333333333333334
# ('mechanic', 'attendant') 6 0.6666666666666666
# ('driver', 'editor') 6 0.8333333333333334
# ('CEO', 'clerk') 6 0.3333333333333333
# ('carpenter', 'attendant') 6 1.0
# ('CEO', 'paralegal') 6 0.5
# ('physician', 'auditor') 6 0.6666666666666666
# ('laborer', 'teacher') 6 0.8333333333333334
# ('supervisor', 'accountant') 6 0.5
# ('accountant', 'writer') 6 0.16666666666666666
# ('lawyer', 'designer') 6 0.8333333333333334
# ('CEO', 'attendant') 6 0.5
# ('salesperson', 'editor') 6 0.16666666666666666
# ('farmer', 'assistant') 6 0.8333333333333334
# ('chief', 'editor') 6 0.3333333333333333
# ('technician', 'cleaner') 6 0.16666666666666666
# ('chief', 'tailor') 6 1.0
# ('driver', 'teacher') 6 1.0
# ('developer', 'baker') 6 0.5
# ('developer', 'cashier') 6 0.5
# ('carpenter', 'designer') 6 0.8333333333333334
# ('carpenter', 'housekeeper') 6 1.0
# ('technician', 'receptionist') 6 0.0
# ('chief', 'clerk') 6 0.8333333333333334
# ('salesperson', 'assistant') 6 0.0
# ('sheriff', 'auditor') 6 1.0
# ('analyst', 'editor') 6 0.5
# ('lawyer', 'attendant') 6 1.0
# ('farmer', 'hairdresser') 6 1.0
# ('laborer', 'cleaner') 6 0.6666666666666666
# ('supervisor', 'cashier') 6 0.6666666666666666
# ('CEO', 'housekeeper') 6 0.8333333333333334
# ('accountant', 'accountant') 6 0.0
# ('farmer', 'housekeeper') 6 1.0
# ('supervisor', 'secretary') 6 0.8333333333333334
# ('farmer', 'accountant') 6 1.0
# ('laborer', 'receptionist') 6 0.8333333333333334
# ('developer', 'writer') 6 0.3333333333333333
# ('supervisor', 'hairdresser') 6 0.3333333333333333
# ('laborer', 'housekeeper') 6 0.6666666666666666
# ('accountant', 'cashier') 6 0.3333333333333333
# ('developer', 'cleaner') 6 0.6666666666666666
# ('chief', 'paralegal') 6 0.5
# ('cook', 'assistant') 6 0.16666666666666666
# ('mechanic', 'housekeeper') 6 0.6666666666666666
# ('construction worker', 'receptionist') 6 0.6666666666666666
# ('physician', 'counselor') 6 1.0
# ('janitor', 'hairdresser') 6 1.0
# ('physician', 'designer') 6 0.3333333333333333
# ('driver', 'auditor') 6 1.0
# ('technician', 'editor') 6 0.5
# ('chief', 'housekeeper') 6 0.8333333333333334
# ('lawyer', 'clerk') 6 1.0
# ('manager', 'housekeeper') 6 0.3333333333333333
# ('laborer', 'accountant') 6 0.8333333333333334
# ('carpenter', 'tailor') 6 1.0
# ('analyst', 'hairdresser') 6 0.5
# ('CEO', 'receptionist') 6 0.3333333333333333
# ('lawyer', 'baker') 6 1.0
# ('accountant', 'auditor') 6 0.6666666666666666
# ('driver', 'cashier') 6 0.8333333333333334
# ('accountant', 'counselor') 6 0.16666666666666666
# ('carpenter', 'cleaner') 6 1.0
# ('janitor', 'cleaner') 6 1.0
# ('carpenter', 'assistant') 6 1.0
# ('janitor', 'cashier') 6 0.8333333333333334
# ('chief', 'receptionist') 6 0.8333333333333334
# ('manager', 'assistant') 6 0.8333333333333334
# ('farmer', 'paralegal') 6 1.0
# ('mechanic', 'auditor') 6 1.0
# ('mechanic', 'paralegal') 6 0.6666666666666666
# ('technician', 'paralegal') 6 0.5
# ('salesperson', 'nurse') 5 0.2
# ('salesperson', 'hairdresser') 5 0.8
# ('guard', 'cashier') 5 1.0
# ('carpenter', 'writer') 5 0.8
# ('analyst', 'tailor') 5 0.4
# ('driver', 'accountant') 5 0.8
# ('guard', 'hairdresser') 5 1.0
# ('technician', 'baker') 5 0.0
# ('laborer', 'tailor') 5 1.0
# ('accountant', 'clerk') 5 0.6
# ('engineer', 'counselor') 5 0.6
# ('driver', 'writer') 5 1.0
# ('laborer', 'editor') 5 0.8
# ('manager', 'attendant') 5 0.6
# ('accountant', 'tailor') 5 0.8
# ('mechanic', 'accountant') 5 1.0
# ('manager', 'teacher') 5 0.4
# ('sheriff', 'secretary') 5 1.0
# ('cook', 'accountant') 5 0.2
# ('CEO', 'accountant') 5 0.6
# ('physician', 'clerk') 5 0.8
# ('CEO', 'teacher') 5 0.2
# ('chief', 'cleaner') 5 1.0
# ('manager', 'cleaner') 5 0.8
# ('salesperson', 'baker') 5 0.2
# ('mover', 'tailor') 5 0.2
# ('construction worker', 'nurse') 5 1.0
# ('salesperson', 'receptionist') 5 0.6
# ('technician', 'accountant') 5 0.6
# ('mover', 'attendant') 5 0.2
# ('laborer', 'paralegal') 5 0.8
# ('lawyer', 'assistant') 5 1.0
# ('cook', 'secretary') 5 0.0
# ('analyst', 'librarian') 5 0.6
# ('janitor', 'receptionist') 5 0.2
# ('construction worker', 'tailor') 5 0.8
# ('chief', 'baker') 5 0.6
# ('physician', 'secretary') 5 0.6
# ('engineer', 'receptionist') 5 0.8
# ('sheriff', 'nurse') 5 1.0
# ('CEO', 'tailor') 5 0.6
# ('analyst', 'receptionist') 5 0.6
# ('chief', 'writer') 5 1.0
# ('physician', 'receptionist') 5 1.0
# ('developer', 'attendant') 5 0.2
# ('cook', 'housekeeper') 5 0.4
# ('guard', 'counselor') 5 0.8
# ('cook', 'designer') 5 0.4
# ('salesperson', 'counselor') 5 0.2
# ('lawyer', 'teacher') 5 0.6
# ('laborer', 'baker') 5 0.8
# ('manager', 'designer') 5 0.4
# ('laborer', 'nurse') 5 0.8
# ('accountant', 'hairdresser') 5 0.6
# ('accountant', 'designer') 5 0.0
# ('farmer', 'editor') 5 0.8
# ('engineer', 'editor') 5 1.0
# ('manager', 'clerk') 5 0.8
# ('cook', 'tailor') 5 0.2
# ('laborer', 'hairdresser') 5 1.0
# ('supervisor', 'housekeeper') 5 0.6
# ('carpenter', 'accountant') 5 1.0
# ('laborer', 'writer') 5 0.8
# ('CEO', 'designer') 5 0.2
# ('sheriff', 'receptionist') 5 1.0
# ('mechanic', 'tailor') 5 0.6
# ('mover', 'assistant') 5 0.2
# ('manager', 'hairdresser') 5 0.8
# ('carpenter', 'counselor') 5 0.8
# ('driver', 'attendant') 5 0.8
# ('construction worker', 'writer') 5 0.4
# ('driver', 'secretary') 5 0.8
# ('technician', 'secretary') 5 0.0
# ('supervisor', 'clerk') 5 1.0
# ('manager', 'writer') 5 0.6
# ('mover', 'writer') 4 0.25
# ('janitor', 'counselor') 4 0.75
# ('construction worker', 'editor') 4 1.0
# ('farmer', 'clerk') 4 1.0
# ('farmer', 'designer') 4 1.0
# ('driver', 'designer') 4 0.5
# ('janitor', 'secretary') 4 1.0
# ('mover', 'housekeeper') 4 0.25
# ('analyst', 'secretary') 4 0.25
# ('salesperson', 'auditor') 4 0.25
# ('developer', 'accountant') 4 0.0
# ('technician', 'tailor') 4 0.25
# ('janitor', 'accountant') 4 0.75
# ('sheriff', 'tailor') 4 1.0
# ('lawyer', 'cashier') 4 1.0
# ('manager', 'nurse') 4 0.5
# ('lawyer', 'editor') 4 0.75
# ('analyst', 'cleaner') 4 0.75
# ('developer', 'secretary') 4 0.0
# ('analyst', 'counselor') 4 0.25
# ('farmer', 'secretary') 4 1.0
# ('cook', 'receptionist') 4 0.25
# ('CEO', 'editor') 4 0.75
# ('mechanic', 'baker') 4 0.75
# ('physician', 'cleaner') 4 1.0
# ('janitor', 'attendant') 4 1.0
# ('mechanic', 'assistant') 4 1.0
# ('physician', 'nurse') 4 0.5
# ('developer', 'receptionist') 4 0.0
# ('mover', 'accountant') 4 0.0
# ('developer', 'paralegal') 4 0.25
# ('CEO', 'writer') 4 0.75
# ('engineer', 'tailor') 4 1.0
# ('mover', 'nurse') 4 0.5
# ('sheriff', 'editor') 4 1.0
# ('supervisor', 'designer') 4 0.5
# ('analyst', 'cashier') 4 0.5
# ('driver', 'tailor') 4 0.5
# ('carpenter', 'auditor') 4 1.0
# ('developer', 'designer') 4 0.5
# ('developer', 'counselor') 4 0.25
# ('analyst', 'housekeeper') 4 0.75
# ('physician', 'paralegal') 4 1.0
# ('guard', 'paralegal') 4 0.5
# ('mover', 'hairdresser') 4 0.0
# ('carpenter', 'clerk') 4 1.0
# ('mechanic', 'cleaner') 4 1.0
# ('mechanic', 'teacher') 4 0.75
# ('engineer', 'auditor') 4 0.75
# ('technician', 'teacher') 4 0.25
# ('sheriff', 'paralegal') 4 0.5
# ('carpenter', 'editor') 4 1.0
# ('analyst', 'paralegal') 4 1.0
# ('carpenter', 'paralegal') 4 0.75
# ('engineer', 'designer') 4 1.0
# ('developer', 'editor') 4 0.25
# ('technician', 'housekeeper') 4 0.5
# ('janitor', 'nurse') 4 0.5
# ('physician', 'hairdresser') 4 0.75
# ('laborer', 'counselor') 3 1.0
# ('physician', 'attendant') 3 0.6666666666666666
# ('physician', 'writer') 3 0.6666666666666666
# ('analyst', 'teacher') 3 0.3333333333333333
# ('engineer', 'accountant') 3 1.0
# ('construction worker', 'auditor') 3 0.0
# ('supervisor', 'attendant') 3 0.3333333333333333
# ('laborer', 'clerk') 3 0.6666666666666666
# ('physician', 'baker') 3 0.6666666666666666
# ('chief', 'teacher') 3 1.0
# ('construction worker', 'teacher') 3 0.6666666666666666
# ('farmer', 'teacher') 3 1.0
# ('engineer', 'housekeeper') 3 1.0
# ('manager', 'receptionist') 3 1.0
# ('accountant', 'teacher') 3 0.0
# ('developer', 'tailor') 3 0.6666666666666666
# ('construction worker', 'attendant') 3 0.6666666666666666
# ('laborer', 'designer') 3 0.6666666666666666
# ('guard', 'housekeeper') 3 1.0
# ('supervisor', 'assistant') 3 0.3333333333333333
# ('analyst', 'designer') 3 0.3333333333333333
# ('chief', 'counselor') 3 1.0
# ('chief', 'hairdresser') 3 0.3333333333333333
# ('farmer', 'auditor') 3 1.0
# ('analyst', 'clerk') 3 0.3333333333333333
# ('analyst', 'baker') 3 0.3333333333333333
# ('lawyer', 'housekeeper') 3 1.0
# ('janitor', 'housekeeper') 3 1.0
# ('carpenter', 'hairdresser') 3 1.0
# ('mover', 'teacher') 3 0.6666666666666666
# ('sheriff', 'cashier') 3 1.0
# ('analyst', 'auditor') 3 0.3333333333333333
# ('accountant', 'attendant') 3 0.6666666666666666
# ('accountant', 'assistant') 3 0.3333333333333333
# ('guard', 'baker') 3 1.0
# ('carpenter', 'baker') 3 1.0
# ('mechanic', 'clerk') 3 0.6666666666666666
# ('engineer', 'paralegal') 3 1.0
# ('accountant', 'receptionist') 3 0.3333333333333333
# ('chief', 'auditor') 3 0.3333333333333333
# ('mechanic', 'nurse') 3 0.6666666666666666
# ('salesperson', 'cashier') 3 0.3333333333333333
# ('analyst', 'writer') 3 0.3333333333333333
# ('salesperson', 'secretary') 3 0.3333333333333333
# ('engineer', 'clerk') 3 1.0
# ('analyst', 'assistant') 3 0.3333333333333333
# ('laborer', 'auditor') 3 0.3333333333333333
# ('developer', 'hairdresser') 3 0.6666666666666666
# ('farmer', 'counselor') 3 0.6666666666666666
# ('janitor', 'designer') 3 1.0
# ('laborer', 'cashier') 3 1.0
# ('chief', 'cashier') 3 1.0
# ('physician', 'accountant') 3 0.6666666666666666
# ('guard', 'secretary') 3 0.6666666666666666
# ('sheriff', 'teacher') 3 0.6666666666666666
# ('technician', 'assistant') 3 0.3333333333333333
# ('farmer', 'cashier') 3 1.0
# ('driver', 'baker') 2 1.0
# ('driver', 'receptionist') 2 1.0
# ('technician', 'clerk') 2 1.0
# ('lawyer', 'secretary') 2 1.0
# ('lawyer', 'tailor') 2 1.0
# ('developer', 'assistant') 2 0.0
# ('mechanic', 'editor') 2 1.0
# ('farmer', 'writer') 2 1.0
# ('cook', 'attendant') 2 0.0
# ('engineer', 'hairdresser') 2 1.0
# ('salesperson', 'teacher') 2 0.0
# ('lawyer', 'nurse') 2 1.0
# ('accountant', 'secretary') 2 0.5
# ('carpenter', 'nurse') 2 1.0
# ('analyst', 'attendant') 2 0.5
# ('technician', 'auditor') 1 0.0
# ('sheriff', 'cleaner') 1 1.0
# ('supervisor', 'baker') 1 1.0
# ('construction worker', 'hairdresser') 1 1.0
# ('CEO', 'auditor') 1 0.0
# ('janitor', 'baker') 1 1.0
# ('cook', 'clerk') 1 0.0
# ('supervisor', 'counselor') 1 1.0

# %%
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], sorted_occupation_pair_count[key])
# Out:
# ('guard', 'cleaner') 1.0 7
# ('engineer', 'attendant') 1.0 8
# ('physician', 'housekeeper') 1.0 7
# ('construction worker', 'editor') 1.0 4
# ('laborer', 'counselor') 1.0 3
# ('farmer', 'clerk') 1.0 4
# ('farmer', 'designer') 1.0 4
# ('guard', 'cashier') 1.0 5
# ('janitor', 'secretary') 1.0 4
# ('lawyer', 'librarian') 1.0 7
# ('sheriff', 'accountant') 1.0 14
# ('lawyer', 'hairdresser') 1.0 8
# ('physician', 'editor') 1.0 11
# ('carpenter', 'attendant') 1.0 6
# ('guard', 'receptionist') 1.0 9
# ('carpenter', 'cashier') 1.0 8
# ('guard', 'hairdresser') 1.0 5
# ('engineer', 'assistant') 1.0 8
# ('laborer', 'tailor') 1.0 5
# ('engineer', 'accountant') 1.0 3
# ('driver', 'baker') 1.0 2
# ('driver', 'receptionist') 1.0 2
# ('guard', 'designer') 1.0 9
# ('sheriff', 'tailor') 1.0 4
# ('sheriff', 'attendant') 1.0 13
# ('technician', 'clerk') 1.0 2
# ('sheriff', 'baker') 1.0 11
# ('lawyer', 'secretary') 1.0 2
# ('lawyer', 'cashier') 1.0 4
# ('physician', 'tailor') 1.0 9
# ('driver', 'writer') 1.0 5
# ('mechanic', 'accountant') 1.0 5
# ('chief', 'tailor') 1.0 6
# ('sheriff', 'secretary') 1.0 5
# ('farmer', 'secretary') 1.0 4
# ('driver', 'teacher') 1.0 6
# ('engineer', 'baker') 1.0 7
# ('chief', 'teacher') 1.0 3
# ('farmer', 'teacher') 1.0 3
# ('carpenter', 'housekeeper') 1.0 6
# ('sheriff', 'librarian') 1.0 10
# ('engineer', 'nurse') 1.0 7
# ('sheriff', 'hairdresser') 1.0 10
# ('chief', 'cleaner') 1.0 5
# ('physician', 'cleaner') 1.0 4
# ('manager', 'baker') 1.0 9
# ('engineer', 'housekeeper') 1.0 3
# ('manager', 'receptionist') 1.0 3
# ('janitor', 'attendant') 1.0 4
# ('mechanic', 'assistant') 1.0 4
# ('sheriff', 'auditor') 1.0 6
# ('farmer', 'baker') 1.0 9
# ('manager', 'librarian') 1.0 10
# ('farmer', 'nurse') 1.0 8
# ('lawyer', 'attendant') 1.0 6
# ('sheriff', 'housekeeper') 1.0 8
# ('farmer', 'hairdresser') 1.0 6
# ('construction worker', 'nurse') 1.0 5
# ('lawyer', 'writer') 1.0 7
# ('guard', 'accountant') 1.0 7
# ('farmer', 'housekeeper') 1.0 6
# ('guard', 'auditor') 1.0 10
# ('lawyer', 'assistant') 1.0 5
# ('guard', 'housekeeper') 1.0 3
# ('farmer', 'accountant') 1.0 6
# ('construction worker', 'clerk') 1.0 7
# ('farmer', 'receptionist') 1.0 9
# ('sheriff', 'nurse') 1.0 5
# ('farmer', 'attendant') 1.0 9
# ('sheriff', 'cleaner') 1.0 1
# ('lawyer', 'tailor') 1.0 2
# ('lawyer', 'receptionist') 1.0 8
# ('chief', 'writer') 1.0 5
# ('physician', 'receptionist') 1.0 5
# ('supervisor', 'baker') 1.0 1
# ('engineer', 'tailor') 1.0 4
# ('chief', 'counselor') 1.0 3
# ('carpenter', 'librarian') 1.0 13
# ('physician', 'counselor') 1.0 6
# ('janitor', 'hairdresser') 1.0 6
# ('farmer', 'auditor') 1.0 3
# ('driver', 'auditor') 1.0 6
# ('lawyer', 'clerk') 1.0 6
# ('lawyer', 'housekeeper') 1.0 3
# ('janitor', 'housekeeper') 1.0 3
# ('carpenter', 'tailor') 1.0 6
# ('carpenter', 'hairdresser') 1.0 3
# ('sheriff', 'editor') 1.0 4
# ('engineer', 'editor') 1.0 5
# ('lawyer', 'auditor') 1.0 9
# ('carpenter', 'auditor') 1.0 4
# ('mechanic', 'editor') 1.0 2
# ('laborer', 'hairdresser') 1.0 5
# ('sheriff', 'cashier') 1.0 3
# ('farmer', 'writer') 1.0 2
# ('physician', 'paralegal') 1.0 4
# ('carpenter', 'accountant') 1.0 5
# ('guard', 'baker') 1.0 3
# ('carpenter', 'baker') 1.0 3
# ('lawyer', 'baker') 1.0 6
# ('farmer', 'tailor') 1.0 8
# ('carpenter', 'clerk') 1.0 4
# ('engineer', 'paralegal') 1.0 3
# ('sheriff', 'receptionist') 1.0 5
# ('engineer', 'hairdresser') 1.0 2
# ('mechanic', 'cleaner') 1.0 4
# ('engineer', 'clerk') 1.0 3
# ('carpenter', 'cleaner') 1.0 6
# ('janitor', 'cleaner') 1.0 6
# ('carpenter', 'assistant') 1.0 6
# ('carpenter', 'editor') 1.0 4
# ('analyst', 'paralegal') 1.0 4
# ('supervisor', 'clerk') 1.0 5
# ('farmer', 'paralegal') 1.0 6
# ('engineer', 'designer') 1.0 4
# ('janitor', 'designer') 1.0 3
# ('construction worker', 'hairdresser') 1.0 1
# ('laborer', 'cashier') 1.0 3
# ('mechanic', 'auditor') 1.0 6
# ('chief', 'cashier') 1.0 3
# ('lawyer', 'nurse') 1.0 2
# ('janitor', 'baker') 1.0 1
# ('farmer', 'cashier') 1.0 3
# ('carpenter', 'nurse') 1.0 2
# ('supervisor', 'counselor') 1.0 1
# ('mechanic', 'secretary') 0.9285714285714286 14
# ('farmer', 'librarian') 0.9230769230769231 13
# ('driver', 'paralegal') 0.9230769230769231 13
# ('carpenter', 'secretary') 0.9230769230769231 13
# ('driver', 'cleaner') 0.9090909090909091 11
# ('driver', 'librarian') 0.9090909090909091 22
# ('guard', 'assistant') 0.9 10
# ('chief', 'secretary') 0.9 10
# ('driver', 'clerk') 0.9 10
# ('engineer', 'librarian') 0.9 10
# ('technician', 'nurse') 0.9 10
# ('sheriff', 'assistant') 0.8888888888888888 9
# ('driver', 'assistant') 0.8888888888888888 9
# ('chief', 'accountant') 0.8888888888888888 9
# ('mechanic', 'counselor') 0.8888888888888888 9
# ('chief', 'assistant') 0.8888888888888888 9
# ('construction worker', 'housekeeper') 0.8888888888888888 9
# ('carpenter', 'teacher') 0.875 8
# ('accountant', 'housekeeper') 0.875 8
# ('driver', 'hairdresser') 0.875 8
# ('manager', 'accountant') 0.875 8
# ('janitor', 'teacher') 0.875 8
# ('guard', 'teacher') 0.875 16
# ('guard', 'nurse') 0.875 8
# ('physician', 'cashier') 0.875 8
# ('engineer', 'secretary') 0.875 8
# ('guard', 'editor') 0.875 8
# ('janitor', 'tailor') 0.875 8
# ('janitor', 'librarian') 0.875 8
# ('manager', 'editor') 0.8571428571428571 7
# ('lawyer', 'cleaner') 0.8571428571428571 7
# ('sheriff', 'writer') 0.8571428571428571 7
# ('lawyer', 'accountant') 0.8571428571428571 7
# ('lawyer', 'counselor') 0.8571428571428571 7
# ('manager', 'paralegal') 0.8571428571428571 7
# ('chief', 'attendant') 0.8571428571428571 7
# ('guard', 'writer') 0.8571428571428571 7
# ('guard', 'clerk') 0.8571428571428571 7
# ('driver', 'housekeeper') 0.8571428571428571 7
# ('accountant', 'baker') 0.8571428571428571 7
# ('chief', 'nurse') 0.8571428571428571 7
# ('manager', 'counselor') 0.8571428571428571 7
# ('developer', 'housekeeper') 0.8571428571428571 7
# ('guard', 'tailor') 0.8571428571428571 7
# ('driver', 'nurse') 0.8571428571428571 7
# ('physician', 'librarian') 0.8461538461538461 13
# ('sheriff', 'designer') 0.8333333333333334 6
# ('janitor', 'clerk') 0.8333333333333334 6
# ('farmer', 'cleaner') 0.8333333333333334 6
# ('driver', 'editor') 0.8333333333333334 6
# ('laborer', 'teacher') 0.8333333333333334 6
# ('lawyer', 'designer') 0.8333333333333334 6
# ('farmer', 'assistant') 0.8333333333333334 6
# ('carpenter', 'designer') 0.8333333333333334 6
# ('chief', 'clerk') 0.8333333333333334 6
# ('CEO', 'housekeeper') 0.8333333333333334 6
# ('laborer', 'receptionist') 0.8333333333333334 6
# ('driver', 'counselor') 0.8333333333333334 12
# ('chief', 'housekeeper') 0.8333333333333334 6
# ('laborer', 'accountant') 0.8333333333333334 6
# ('supervisor', 'secretary') 0.8333333333333334 6
# ('construction worker', 'librarian') 0.8333333333333334 12
# ('driver', 'cashier') 0.8333333333333334 6
# ('janitor', 'cashier') 0.8333333333333334 6
# ('chief', 'receptionist') 0.8333333333333334 6
# ('manager', 'assistant') 0.8333333333333334 6
# ('developer', 'librarian') 0.8181818181818182 11
# ('engineer', 'teacher') 0.8181818181818182 11
# ('laborer', 'attendant') 0.8 10
# ('carpenter', 'writer') 0.8 5
# ('driver', 'accountant') 0.8 5
# ('mechanic', 'librarian') 0.8 10
# ('laborer', 'paralegal') 0.8 5
# ('construction worker', 'tailor') 0.8 5
# ('salesperson', 'hairdresser') 0.8 5
# ('engineer', 'receptionist') 0.8 5
# ('guard', 'counselor') 0.8 5
# ('laborer', 'baker') 0.8 5
# ('laborer', 'nurse') 0.8 5
# ('farmer', 'editor') 0.8 5
# ('manager', 'clerk') 0.8 5
# ('accountant', 'tailor') 0.8 5
# ('physician', 'clerk') 0.8 5
# ('laborer', 'writer') 0.8 5
# ('manager', 'hairdresser') 0.8 5
# ('carpenter', 'counselor') 0.8 5
# ('driver', 'secretary') 0.8 5
# ('laborer', 'editor') 0.8 5
# ('manager', 'cleaner') 0.8 5
# ('driver', 'attendant') 0.8 5
# ('laborer', 'librarian') 0.7857142857142857 14
# ('guard', 'librarian') 0.7777777777777778 9
# ('sheriff', 'clerk') 0.7777777777777778 9
# ('mechanic', 'receptionist') 0.7777777777777778 9
# ('chief', 'librarian') 0.7692307692307693 13
# ('janitor', 'counselor') 0.75 4
# ('janitor', 'accountant') 0.75 4
# ('lawyer', 'editor') 0.75 4
# ('analyst', 'cleaner') 0.75 4
# ('CEO', 'editor') 0.75 4
# ('mechanic', 'baker') 0.75 4
# ('mechanic', 'cashier') 0.75 8
# ('construction worker', 'cashier') 0.75 8
# ('CEO', 'writer') 0.75 4
# ('supervisor', 'cleaner') 0.75 8
# ('construction worker', 'accountant') 0.75 8
# ('carpenter', 'receptionist') 0.75 8
# ('analyst', 'housekeeper') 0.75 4
# ('engineer', 'auditor') 0.75 4
# ('mechanic', 'teacher') 0.75 4
# ('carpenter', 'paralegal') 0.75 4
# ('physician', 'hairdresser') 0.75 4
# ('CEO', 'hairdresser') 0.7333333333333333 15
# ('developer', 'clerk') 0.7272727272727273 11
# ('supervisor', 'tailor') 0.7272727272727273 11
# ('mechanic', 'writer') 0.7142857142857143 7
# ('mechanic', 'hairdresser') 0.7142857142857143 7
# ('CEO', 'cashier') 0.7142857142857143 7
# ('engineer', 'cleaner') 0.7142857142857143 7
# ('laborer', 'assistant') 0.7142857142857143 7
# ('construction worker', 'counselor') 0.7142857142857143 7
# ('janitor', 'paralegal') 0.7142857142857143 7
# ('guard', 'attendant') 0.7142857142857143 7
# ('manager', 'cashier') 0.7142857142857143 7
# ('janitor', 'writer') 0.7142857142857143 7
# ('janitor', 'editor') 0.7142857142857143 7
# ('engineer', 'cashier') 0.7142857142857143 7
# ('janitor', 'auditor') 0.7 10
# ('manager', 'secretary') 0.7 10
# ('janitor', 'assistant') 0.7 10
# ('cook', 'nurse') 0.7 10
# ('laborer', 'secretary') 0.6666666666666666 6
# ('physician', 'attendant') 0.6666666666666666 3
# ('mechanic', 'attendant') 0.6666666666666666 6
# ('physician', 'writer') 0.6666666666666666 3
# ('physician', 'auditor') 0.6666666666666666 6
# ('CEO', 'baker') 0.6666666666666666 6
# ('construction worker', 'attendant') 0.6666666666666666 3
# ('physician', 'baker') 0.6666666666666666 3
# ('laborer', 'cleaner') 0.6666666666666666 6
# ('supervisor', 'cashier') 0.6666666666666666 6
# ('laborer', 'designer') 0.6666666666666666 3
# ('construction worker', 'teacher') 0.6666666666666666 3
# ('developer', 'cleaner') 0.6666666666666666 6
# ('mechanic', 'housekeeper') 0.6666666666666666 6
# ('construction worker', 'receptionist') 0.6666666666666666 6
# ('accountant', 'attendant') 0.6666666666666666 3
# ('developer', 'tailor') 0.6666666666666666 3
# ('mechanic', 'clerk') 0.6666666666666666 3
# ('construction worker', 'baker') 0.6666666666666666 9
# ('laborer', 'housekeeper') 0.6666666666666666 6
# ('sheriff', 'counselor') 0.6666666666666666 6
# ('developer', 'hairdresser') 0.6666666666666666 3
# ('farmer', 'counselor') 0.6666666666666666 3
# ('mechanic', 'nurse') 0.6666666666666666 3
# ('mover', 'teacher') 0.6666666666666666 3
# ('accountant', 'auditor') 0.6666666666666666 6
# ('mechanic', 'paralegal') 0.6666666666666666 6
# ('sheriff', 'teacher') 0.6666666666666666 3
# ('laborer', 'clerk') 0.6666666666666666 3
# ('physician', 'accountant') 0.6666666666666666 3
# ('guard', 'secretary') 0.6666666666666666 3
# ('accountant', 'paralegal') 0.6363636363636364 11
# ('construction worker', 'secretary') 0.625 8
# ('lawyer', 'paralegal') 0.625 8
# ('developer', 'nurse') 0.625 8
# ('construction worker', 'paralegal') 0.625 8
# ('physician', 'assistant') 0.625 8
# ('supervisor', 'writer') 0.6153846153846154 13
# ('mechanic', 'designer') 0.6153846153846154 13
# ('engineer', 'counselor') 0.6 5
# ('manager', 'attendant') 0.6 5
# ('CEO', 'accountant') 0.6 5
# ('salesperson', 'receptionist') 0.6 5
# ('technician', 'accountant') 0.6 5
# ('CEO', 'tailor') 0.6 5
# ('analyst', 'receptionist') 0.6 5
# ('lawyer', 'teacher') 0.6 5
# ('analyst', 'librarian') 0.6 5
# ('accountant', 'hairdresser') 0.6 5
# ('physician', 'secretary') 0.6 5
# ('accountant', 'clerk') 0.6 5
# ('chief', 'baker') 0.6 5
# ('supervisor', 'housekeeper') 0.6 5
# ('mechanic', 'tailor') 0.6 5
# ('manager', 'writer') 0.6 5
# ('physician', 'teacher') 0.5714285714285714 7
# ('manager', 'tailor') 0.5714285714285714 7
# ('construction worker', 'cleaner') 0.5714285714285714 7
# ('salesperson', 'paralegal') 0.5714285714285714 7
# ('manager', 'auditor') 0.5714285714285714 7
# ('supervisor', 'editor') 0.5714285714285714 7
# ('accountant', 'editor') 0.5714285714285714 7
# ('analyst', 'accountant') 0.5555555555555556 9
# ('salesperson', 'tailor') 0.5555555555555556 9
# ('cook', 'librarian') 0.5 10
# ('driver', 'designer') 0.5 4
# ('CEO', 'paralegal') 0.5 6
# ('supervisor', 'accountant') 0.5 6
# ('CEO', 'librarian') 0.5 10
# ('manager', 'nurse') 0.5 4
# ('physician', 'nurse') 0.5 4
# ('analyst', 'editor') 0.5 6
# ('developer', 'cashier') 0.5 6
# ('CEO', 'assistant') 0.5 10
# ('supervisor', 'receptionist') 0.5 8
# ('CEO', 'attendant') 0.5 6
# ('salesperson', 'designer') 0.5 8
# ('driver', 'tailor') 0.5 4
# ('developer', 'designer') 0.5 4
# ('salesperson', 'accountant') 0.5 10
# ('analyst', 'hairdresser') 0.5 6
# ('technician', 'editor') 0.5 6
# ('analyst', 'cashier') 0.5 4
# ('chief', 'paralegal') 0.5 6
# ('guard', 'paralegal') 0.5 4
# ('sheriff', 'paralegal') 0.5 4
# ('developer', 'baker') 0.5 6
# ('technician', 'hairdresser') 0.5 8
# ('technician', 'housekeeper') 0.5 4
# ('mover', 'nurse') 0.5 4
# ('supervisor', 'designer') 0.5 4
# ('technician', 'paralegal') 0.5 6
# ('accountant', 'secretary') 0.5 2
# ('janitor', 'nurse') 0.5 4
# ('analyst', 'attendant') 0.5 2
# ('construction worker', 'assistant') 0.45454545454545453 11
# ('technician', 'counselor') 0.4444444444444444 9
# ('CEO', 'counselor') 0.4444444444444444 9
# ('construction worker', 'designer') 0.4444444444444444 9
# ('salesperson', 'writer') 0.42857142857142855 7
# ('chief', 'designer') 0.42857142857142855 7
# ('CEO', 'cleaner') 0.42857142857142855 7
# ('developer', 'teacher') 0.42857142857142855 7
# ('supervisor', 'librarian') 0.4166666666666667 12
# ('CEO', 'secretary') 0.4166666666666667 12
# ('analyst', 'tailor') 0.4 5
# ('manager', 'teacher') 0.4 5
# ('cook', 'housekeeper') 0.4 5
# ('cook', 'designer') 0.4 5
# ('construction worker', 'writer') 0.4 5
# ('cook', 'auditor') 0.4 10
# ('manager', 'designer') 0.4 5
# ('cook', 'editor') 0.38461538461538464 13
# ('accountant', 'librarian') 0.375 16
# ('accountant', 'nurse') 0.375 8
# ('accountant', 'cleaner') 0.375 8
# ('CEO', 'nurse') 0.375 8
# ('analyst', 'nurse') 0.375 8
# ('mover', 'auditor') 0.36363636363636365 11
# ('cook', 'cleaner') 0.3333333333333333 6
# ('CEO', 'clerk') 0.3333333333333333 6
# ('supervisor', 'attendant') 0.3333333333333333 3
# ('cook', 'baker') 0.3333333333333333 9
# ('developer', 'writer') 0.3333333333333333 6
# ('supervisor', 'hairdresser') 0.3333333333333333 6
# ('accountant', 'cashier') 0.3333333333333333 6
# ('supervisor', 'assistant') 0.3333333333333333 3
# ('physician', 'designer') 0.3333333333333333 6
# ('analyst', 'baker') 0.3333333333333333 3
# ('salesperson', 'clerk') 0.3333333333333333 9
# ('analyst', 'auditor') 0.3333333333333333 3
# ('CEO', 'receptionist') 0.3333333333333333 6
# ('analyst', 'writer') 0.3333333333333333 3
# ('salesperson', 'secretary') 0.3333333333333333 3
# ('laborer', 'auditor') 0.3333333333333333 3
# ('salesperson', 'cashier') 0.3333333333333333 3
# ('accountant', 'assistant') 0.3333333333333333 3
# ('analyst', 'teacher') 0.3333333333333333 3
# ('chief', 'editor') 0.3333333333333333 6
# ('manager', 'housekeeper') 0.3333333333333333 6
# ('technician', 'assistant') 0.3333333333333333 3
# ('analyst', 'clerk') 0.3333333333333333 3
# ('analyst', 'designer') 0.3333333333333333 3
# ('chief', 'hairdresser') 0.3333333333333333 3
# ('accountant', 'receptionist') 0.3333333333333333 3
# ('analyst', 'assistant') 0.3333333333333333 3
# ('chief', 'auditor') 0.3333333333333333 3
# ('mover', 'counselor') 0.3 10
# ('technician', 'writer') 0.2857142857142857 7
# ('salesperson', 'cleaner') 0.2857142857142857 7
# ('supervisor', 'paralegal') 0.2857142857142857 7
# ('cook', 'cashier') 0.2857142857142857 7
# ('cook', 'teacher') 0.2857142857142857 7
# ('mover', 'cashier') 0.2857142857142857 7
# ('mover', 'writer') 0.25 4
# ('salesperson', 'auditor') 0.25 4
# ('technician', 'tailor') 0.25 4
# ('mover', 'receptionist') 0.25 8
# ('analyst', 'counselor') 0.25 4
# ('analyst', 'secretary') 0.25 4
# ('developer', 'counselor') 0.25 4
# ('developer', 'editor') 0.25 4
# ('mover', 'housekeeper') 0.25 4
# ('cook', 'counselor') 0.25 8
# ('developer', 'paralegal') 0.25 4
# ('cook', 'receptionist') 0.25 4
# ('technician', 'teacher') 0.25 4
# ('mover', 'baker') 0.2222222222222222 9
# ('technician', 'librarian') 0.2222222222222222 9
# ('cook', 'hairdresser') 0.2222222222222222 9
# ('salesperson', 'librarian') 0.2222222222222222 9
# ('salesperson', 'nurse') 0.2 5
# ('technician', 'designer') 0.2 10
# ('cook', 'accountant') 0.2 5
# ('mover', 'attendant') 0.2 5
# ('janitor', 'receptionist') 0.2 5
# ('developer', 'attendant') 0.2 5
# ('mover', 'tailor') 0.2 5
# ('CEO', 'teacher') 0.2 5
# ('salesperson', 'baker') 0.2 5
# ('mover', 'assistant') 0.2 5
# ('CEO', 'designer') 0.2 5
# ('salesperson', 'counselor') 0.2 5
# ('technician', 'cashier') 0.2 10
# ('cook', 'tailor') 0.2 5
# ('salesperson', 'editor') 0.16666666666666666 6
# ('technician', 'cleaner') 0.16666666666666666 6
# ('supervisor', 'auditor') 0.16666666666666666 6
# ('accountant', 'writer') 0.16666666666666666 6
# ('mover', 'editor') 0.16666666666666666 6
# ('accountant', 'counselor') 0.16666666666666666 6
# ('cook', 'assistant') 0.16666666666666666 6
# ('supervisor', 'nurse') 0.15384615384615385 13
# ('mover', 'designer') 0.14285714285714285 7
# ('developer', 'auditor') 0.125 8
# ('technician', 'attendant') 0.125 8
# ('cook', 'paralegal') 0.125 8
# ('salesperson', 'housekeeper') 0.125 8
# ('cook', 'writer') 0.125 8
# ('mover', 'paralegal') 0.125 8
# ('mover', 'secretary') 0.125 8
# ('supervisor', 'teacher') 0.1111111111111111 9
# ('salesperson', 'attendant') 0.1 10
# ('mover', 'clerk') 0.1 10
# ('mover', 'librarian') 0.08695652173913043 23

# %%
from scipy import stats
def get_anamoly_scores(array):
    mad = (stats.median_absolute_deviation(array, scale='normal'))
    arr_median = np.median(array)
    arr_anamolies = [(i - arr_median)/mad for i in array]
    
    return arr_anamolies

# %%
error_rate_dict = get_error_rate_dict(occupation1_error, occupation1_count)

error_rate_list = []
for key in error_rate_dict:
    error_rate_list.append(error_rate_dict[key])
    
anomaly_list = get_anamoly_scores(error_rate_list)
    
for i, key in enumerate(error_rate_dict):
    print(key, error_rate_dict[key], occupation1_count[key], anomaly_list[i])
# Out:
# farmer 0.959349593495935 123 0.8071926271612264
# carpenter 0.936 125 0.7013663344270963
# sheriff 0.9300699300699301 143 0.6744897501960817
# lawyer 0.9159663865546218 119 0.6105689061394431
# engineer 0.8947368421052632 114 0.5143512145594511
# guard 0.8926174496644296 149 0.5047455893094352
# driver 0.8709677419354839 155 0.4066236109490564
# physician 0.7983870967741935 124 0.07766967849588699
# janitor 0.7933884297520661 121 0.055014448988093254
# laborer 0.7863247863247863 117 0.023000221535483853
# mechanic 0.7851851851851852 135 0.017835259506463086
# chief 0.78125 128 0.0
# manager 0.7368421052631579 133 -0.2012678665667419
# construction worker 0.6884057971014492 138 -0.4207935267189798
# CEO 0.5174825174825175 143 -1.195461275310823
# supervisor 0.4928571428571429 140 -1.3070697324022156
# analyst 0.4835164835164835 91 -1.3494039747472266
# developer 0.46153846153846156 117 -1.4490139567354878
# accountant 0.4573643410852713 129 -1.4679321316092275
# technician 0.3359375 128 -2.0182694397387153
# salesperson 0.3308270676691729 133 -2.0414312180340946
# cook 0.3076923076923077 143 -2.1462838306533167
# mover 0.19078947368421054 152 -2.6761171887948247
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `median_absolute_deviation` is deprecated, use `median_abs_deviation` instead!
#
# To preserve the existing default behavior, use
# `scipy.stats.median_abs_deviation(..., scale=1/1.4826)`.
# The value 1.4826 is not numerically precise for scaling
# with a normal distribution. For a numerically precise value, use
# `scipy.stats.median_abs_deviation(..., scale='normal')`.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
error_rate_dict = get_error_rate_dict(occupation1_error, occupation1_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], occupation1_count[key])
# Out:
# farmer 0.959349593495935 123
# carpenter 0.936 125
# sheriff 0.9300699300699301 143
# lawyer 0.9159663865546218 119
# engineer 0.8947368421052632 114
# guard 0.8926174496644296 149
# driver 0.8709677419354839 155
# physician 0.7983870967741935 124
# janitor 0.7933884297520661 121
# laborer 0.7863247863247863 117
# mechanic 0.7851851851851852 135
# chief 0.78125 128
# manager 0.7368421052631579 133
# construction worker 0.6884057971014492 138
# CEO 0.5174825174825175 143
# supervisor 0.4928571428571429 140
# analyst 0.4835164835164835 91
# developer 0.46153846153846156 117
# accountant 0.4573643410852713 129
# technician 0.3359375 128
# salesperson 0.3308270676691729 133
# cook 0.3076923076923077 143
# mover 0.19078947368421054 152

# %%
error_rate_dict = get_error_rate_dict(occupation2_error, occupation2_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], occupation2_count[key])
# Out:
# housekeeper 0.7538461538461538 130
# tailor 0.7348484848484849 132
# hairdresser 0.7238805970149254 134
# clerk 0.7153846153846154 130
# baker 0.703125 128
# accountant 0.7013888888888888 144
# librarian 0.6840148698884758 269
# cashier 0.674074074074074 135
# cleaner 0.6737588652482269 141
# attendant 0.6691176470588235 136
# assistant 0.6644295302013423 149
# editor 0.6642335766423357 137
# receptionist 0.6592592592592592 135
# nurse 0.6551724137931034 145
# secretary 0.6506849315068494 146
# teacher 0.6183206106870229 131
# paralegal 0.6164383561643836 146
# counselor 0.6159420289855072 138
# auditor 0.6153846153846154 130
# writer 0.609375 128
# designer 0.5367647058823529 136

# %%
error_rate_dict = get_error_rate_dict(action_error, action_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# the concert was appreciated 0.8369565217391305
# the meat was eaten 0.7472527472527473
# blogging 0.7380952380952381
# the concert was unsatisfactory 0.7333333333333333
# the performance was excellent 0.7191011235955056
# baking 0.71875
# the delivery was made 0.7171717171717171
# a musical instrument was played 0.7102803738317757
# painting 0.7096774193548387
# the performance was not up to the mark 0.7073170731707317
# the application was approved 0.7058823529411765
# independent cinema 0.6984126984126984
# the game was excellent 0.6923076923076923
# football 0.6825396825396826
# breadmaking 0.6818181818181818
# the cookies were baked 0.6808510638297872
# the work was appreciated 0.68
# board games 0.6792452830188679
# the tournament was excellent 0.6741573033707865
# the application was not approved 0.6631578947368421
# kayaking 0.660377358490566
# gymnastics 0.66
# the performance was unsatisfactory 0.6590909090909091
# the document was signed 0.6568627450980392
# the work was unsatisfactory 0.6521739130434783
# the project scope had been finalised 0.6413043478260869
# fencing 0.640625
# singing 0.6363636363636364
# basketball 0.6341463414634146
# the application was under review 0.627906976744186
# studying 0.618421052631579
# horse racing 0.6129032258064516
# quizzing 0.609375
# gardening 0.6086956521739131
# dancing 0.5972222222222222
# woodworking 0.5737704918032787
# baseball 0.5692307692307692
# the waiting times were estimated 0.5604395604395604
# this behaviour was unacceptable 0.46808510638297873

# %%
error_rate_dict = get_error_rate_dict(verb_error, verb_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# notified the 0.5236427320490368
# told the 0.5015479876160991
# asked the 0.4562607204116638
# disclosed to the 0.4265975820379965
# spoke with the 0.38003220611916266
