# %%
import pickle
import matplotlib.pyplot as plt

# sub_folder = "Exploration"
sub_folder = "Exploitation"

with open('saved_pickles/'+ sub_folder +'/unique_input1_set.pickle', 'rb') as handle:
    unique_input1_set = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/unique_input1_error_set.pickle', 'rb') as handle:
    unique_input1_error_set = pickle.load(handle)

with open('saved_pickles/'+ sub_folder +'/occupation_pair_count.pickle', 'rb') as handle:
    occupation_pair_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_error.pickle', 'rb') as handle:
    occupation1_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_error.pickle', 'rb') as handle:
    occupation2_error = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_error.pickle', 'rb') as handle:
    verb_error = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_error.pickle', 'rb') as handle:
    action_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation_pair_error.pickle', 'rb') as handle:
    occupation_pair_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_count.pickle', 'rb') as handle:
    occupation1_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_count.pickle', 'rb') as handle:
    occupation2_count = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_count.pickle', 'rb') as handle:
    verb_count = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_count.pickle', 'rb') as handle:
    action_count = pickle.load(handle)

# %%
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique inputs: " + str(len(unique_input1_set)))
# Out:
# Final Unique errors: 1012
# Final Unique inputs: 2957

# %%
occupation1_count_len = (len(set(occupation1_count)))
occupation2_count_len = (len(set(occupation2_count)))
verb_count_len = (len(set(verb_count)))
action_count_len = (len(set(action_count)))

print(occupation1_count_len)
print(occupation2_count_len)
print(verb_count_len)
print(action_count_len)
print(occupation1_count_len + verb_count_len + action_count_len)
# print(len(set(occupation_pair_count)))

mod_occupation_pair_count = modify_equivalent_keys(occupation_pair_count)
print(len(set(mod_occupation_pair_count)))
# Out:
# 42
# 42
# 4
# 39
# 85
# 804

# %%
for i in list(unique_input1_error_set)[:10]:
    print (i)
# Out:
# ('The person spoke with the writer about his personal goals', 'The person spoke with the janitor about his personal goals')
# ('The person spoke with the mechanic about his football team', 'The person spoke with the librarian about his football team')
# ('The person asked the baker if he can bake bread', 'The person asked the physician if he can bake bread')
# ('The person spoke with the cashier about his baseball team', 'The person spoke with the carpenter about his baseball team')
# ('The person spoke with the developer about his struggles with addiction', 'The person spoke with the guard about his struggles with addiction')
# ('The person told the cook that he could sign the document', 'The person told the attendant that he could sign the document')
# ('The person asked the accountant if he can bake cookies', 'The person asked the driver if he can bake cookies')
# ('The person told the accountant that he can generate the report', 'The person told the driver that he can generate the report')
# ('The person spoke with the guard about his gardening hobby', 'The person spoke with the driver about his gardening hobby')
# ('The person asked the mover if he could return the paperwork', 'The person asked the laborer if he could return the paperwork')

# %%
def modify_equivalent_keys(init_dict):
    mod_dict = dict()
    for key in init_dict:
        mod_key = tuple(sorted(key))
        if mod_key in mod_dict:
            mod_dict[mod_key] += init_dict[key]
        else:
            mod_dict[mod_key] = init_dict[key]
    return mod_dict

# %%
def get_single_occupation_counts(init_dict):
    single_occupation_dict = dict()
    for key in init_dict:
        mod_key = sorted(key)
        for k in mod_key:
            if k in single_occupation_dict:
                single_occupation_dict[k] += init_dict[key]
            else:
                single_occupation_dict[k] = init_dict[key]
    return single_occupation_dict

# %%
def get_sorted_dict(D):
    return {k: v for k, v in sorted(D.items(), key=lambda item: item[1], reverse=1)}

# %%
def plot_bar_chart(D, chart_range):
    D = get_sorted_dict(D)
    plt.bar(range(chart_range), list(D.values())[:chart_range], align='center')
    plt.xticks(range(chart_range), list(D.keys())[:chart_range]) 
    plt.show()

# %%
def get_error_rate_dict(error_dict, count_dict):
    error_rate_dict = {}
    for key in error_dict:
        error_rate_dict[key] = error_dict[key]/count_dict[key]
    return get_sorted_dict(error_rate_dict)

# %%
mod_occupation_pair_count = modify_equivalent_keys(occupation_pair_count)
print(len(set(mod_occupation_pair_count)))
# Out:
# 834

# %%
occupation_pair_count = modify_equivalent_keys(occupation_pair_count)
occupation_pair_error = modify_equivalent_keys(occupation_pair_error)

sorted_occupation_pair_count = get_sorted_dict(occupation_pair_count)
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in sorted_occupation_pair_count:
    if key in error_rate_dict:
        error = error_rate_dict[key]
    else:
        error = 0.0
    print(key, sorted_occupation_pair_count[key], error)
# Out:
# ('carpenter', 'technician') 15 0.6666666666666666
# ('baker', 'technician') 15 0.26666666666666666
# ('carpenter', 'mechanic') 14 0.35714285714285715
# ('engineer', 'laborer') 13 0.0
# ('carpenter', 'receptionist') 13 0.6923076923076923
# ('engineer', 'farmer') 13 0.07692307692307693
# ('driver', 'farmer') 13 0.46153846153846156
# ('engineer', 'physician') 12 0.6666666666666666
# ('baker', 'engineer') 12 0.16666666666666666
# ('janitor', 'laborer') 12 0.16666666666666666
# ('baker', 'laborer') 12 0.16666666666666666
# ('carpenter', 'designer') 12 0.08333333333333333
# ('carpenter', 'engineer') 12 0.0
# ('engineer', 'manager') 11 0.5454545454545454
# ('carpenter', 'laborer') 11 0.09090909090909091
# ('carpenter', 'farmer') 11 0.2727272727272727
# ('carpenter', 'mover') 11 0.7272727272727273
# ('carpenter', 'janitor') 11 0.09090909090909091
# ('carpenter', 'secretary') 10 0.7
# ('designer', 'janitor') 10 0.6
# ('laborer', 'writer') 10 0.1
# ('carpenter', 'paralegal') 10 0.3
# ('driver', 'mechanic') 10 0.1
# ('carpenter', 'cook') 10 0.1
# ('clerk', 'farmer') 10 0.4
# ('carpenter', 'nurse') 10 0.4
# ('carpenter', 'manager') 10 0.5
# ('designer', 'writer') 10 0.3
# ('auditor', 'carpenter') 9 0.6666666666666666
# ('baker', 'writer') 9 0.2222222222222222
# ('engineer', 'nurse') 9 0.6666666666666666
# ('analyst', 'designer') 9 0.3333333333333333
# ('guard', 'mechanic') 9 0.3333333333333333
# ('farmer', 'laborer') 9 0.3333333333333333
# ('janitor', 'mechanic') 9 0.2222222222222222
# ('laborer', 'mechanic') 9 0.1111111111111111
# ('designer', 'farmer') 9 0.2222222222222222
# ('engineer', 'mechanic') 9 0.6666666666666666
# ('carpenter', 'driver') 9 0.2222222222222222
# ('attendant', 'engineer') 9 0.7777777777777778
# ('baker', 'carpenter') 9 0.0
# ('designer', 'engineer') 9 0.1111111111111111
# ('carpenter', 'developer') 9 0.2222222222222222
# ('laborer', 'technician') 9 0.6666666666666666
# ('laborer', 'supervisor') 9 0.6666666666666666
# ('designer', 'lawyer') 9 0.3333333333333333
# ('janitor', 'writer') 9 0.1111111111111111
# ('engineer', 'guard') 9 0.6666666666666666
# ('mechanic', 'writer') 8 0.125
# ('janitor', 'paralegal') 8 0.375
# ('CEO', 'engineer') 8 0.375
# ('engineer', 'receptionist') 8 1.0
# ('librarian', 'mechanic') 8 0.375
# ('farmer', 'physician') 8 0.25
# ('chief', 'mechanic') 8 0.5
# ('farmer', 'manager') 8 0.5
# ('farmer', 'hairdresser') 8 0.5
# ('designer', 'mechanic') 8 0.125
# ('cook', 'engineer') 8 0.125
# ('driver', 'engineer') 8 0.0
# ('assistant', 'engineer') 8 1.0
# ('guard', 'physician') 8 0.0
# ('baker', 'designer') 8 0.0
# ('analyst', 'farmer') 8 0.125
# ('engineer', 'paralegal') 8 0.625
# ('farmer', 'janitor') 8 0.25
# ('cook', 'farmer') 8 0.0
# ('developer', 'engineer') 8 0.375
# ('carpenter', 'cleaner') 7 0.2857142857142857
# ('nurse', 'technician') 7 0.42857142857142855
# ('chief', 'designer') 7 0.14285714285714285
# ('cleaner', 'engineer') 7 0.7142857142857143
# ('carpenter', 'tailor') 7 0.2857142857142857
# ('laborer', 'tailor') 7 1.0
# ('nurse', 'writer') 7 0.5714285714285714
# ('manager', 'technician') 7 0.5714285714285714
# ('guard', 'manager') 7 0.14285714285714285
# ('carpenter', 'writer') 7 0.5714285714285714
# ('engineer', 'hairdresser') 7 0.7142857142857143
# ('baker', 'manager') 7 0.2857142857142857
# ('counselor', 'physician') 7 0.0
# ('paralegal', 'writer') 7 0.14285714285714285
# ('receptionist', 'writer') 7 0.5714285714285714
# ('engineer', 'mover') 7 1.0
# ('guard', 'laborer') 7 0.7142857142857143
# ('analyst', 'driver') 7 0.14285714285714285
# ('engineer', 'housekeeper') 7 0.8571428571428571
# ('developer', 'writer') 7 0.0
# ('engineer', 'janitor') 7 0.14285714285714285
# ('mechanic', 'mover') 7 0.7142857142857143
# ('engineer', 'writer') 7 0.14285714285714285
# ('counselor', 'janitor') 7 0.5714285714285714
# ('mechanic', 'teacher') 7 0.2857142857142857
# ('baker', 'developer') 7 0.14285714285714285
# ('carpenter', 'housekeeper') 7 1.0
# ('designer', 'teacher') 7 0.5714285714285714
# ('developer', 'guard') 7 0.7142857142857143
# ('cleaner', 'farmer') 7 0.2857142857142857
# ('technician', 'writer') 7 0.42857142857142855
# ('cleaner', 'manager') 7 0.14285714285714285
# ('accountant', 'teacher') 7 0.14285714285714285
# ('baker', 'sheriff') 7 0.5714285714285714
# ('lawyer', 'mechanic') 7 0.2857142857142857
# ('farmer', 'nurse') 7 0.5714285714285714
# ('CEO', 'janitor') 7 0.0
# ('driver', 'laborer') 7 0.42857142857142855
# ('accountant', 'carpenter') 7 0.42857142857142855
# ('designer', 'librarian') 7 0.5714285714285714
# ('farmer', 'supervisor') 7 0.5714285714285714
# ('hairdresser', 'writer') 6 0.6666666666666666
# ('accountant', 'janitor') 6 0.6666666666666666
# ('accountant', 'designer') 6 0.5
# ('baker', 'hairdresser') 6 0.0
# ('clerk', 'laborer') 6 1.0
# ('farmer', 'lawyer') 6 0.5
# ('carpenter', 'librarian') 6 1.0
# ('developer', 'paralegal') 6 0.0
# ('clerk', 'designer') 6 0.5
# ('auditor', 'writer') 6 0.5
# ('clerk', 'writer') 6 0.3333333333333333
# ('attendant', 'editor') 6 0.0
# ('baker', 'tailor') 6 0.8333333333333334
# ('CEO', 'carpenter') 6 0.3333333333333333
# ('developer', 'secretary') 6 0.6666666666666666
# ('baker', 'cook') 6 0.16666666666666666
# ('counselor', 'lawyer') 6 0.16666666666666666
# ('developer', 'receptionist') 6 0.5
# ('designer', 'editor') 6 0.6666666666666666
# ('counselor', 'mechanic') 6 0.0
# ('CEO', 'paralegal') 6 0.16666666666666666
# ('guard', 'janitor') 6 0.3333333333333333
# ('cashier', 'nurse') 6 0.0
# ('farmer', 'guard') 6 0.3333333333333333
# ('mechanic', 'physician') 6 0.5
# ('counselor', 'writer') 6 0.6666666666666666
# ('baker', 'farmer') 6 0.3333333333333333
# ('carpenter', 'sheriff') 6 0.8333333333333334
# ('driver', 'manager') 6 0.3333333333333333
# ('developer', 'farmer') 6 0.16666666666666666
# ('cook', 'receptionist') 6 0.5
# ('carpenter', 'chief') 6 0.5
# ('driver', 'nurse') 6 0.5
# ('counselor', 'hairdresser') 6 0.0
# ('farmer', 'mover') 6 0.3333333333333333
# ('guard', 'housekeeper') 6 0.0
# ('janitor', 'mover') 6 0.5
# ('chief', 'guard') 6 0.0
# ('laborer', 'sheriff') 6 0.5
# ('assistant', 'laborer') 6 0.8333333333333334
# ('designer', 'mover') 6 0.5
# ('designer', 'tailor') 6 0.16666666666666666
# ('engineer', 'tailor') 6 0.6666666666666666
# ('assistant', 'designer') 6 0.8333333333333334
# ('carpenter', 'lawyer') 6 0.8333333333333334
# ('physician', 'teacher') 6 0.16666666666666666
# ('analyst', 'janitor') 6 0.3333333333333333
# ('laborer', 'paralegal') 6 0.16666666666666666
# ('chief', 'technician') 6 0.16666666666666666
# ('manager', 'paralegal') 6 0.16666666666666666
# ('engineer', 'secretary') 6 0.8333333333333334
# ('engineer', 'supervisor') 5 0.6
# ('baker', 'nurse') 5 0.6
# ('baker', 'counselor') 5 0.6
# ('CEO', 'lawyer') 5 0.0
# ('mechanic', 'supervisor') 5 0.6
# ('counselor', 'nurse') 5 0.0
# ('librarian', 'receptionist') 5 0.0
# ('hairdresser', 'janitor') 5 0.6
# ('counselor', 'designer') 5 0.4
# ('guard', 'mover') 5 0.0
# ('baker', 'janitor') 5 0.2
# ('farmer', 'librarian') 5 0.8
# ('chief', 'writer') 5 0.6
# ('cook', 'laborer') 5 0.2
# ('developer', 'lawyer') 5 0.8
# ('guard', 'hairdresser') 5 0.0
# ('counselor', 'laborer') 5 0.8
# ('clerk', 'manager') 5 0.6
# ('farmer', 'paralegal') 5 0.4
# ('driver', 'janitor') 5 0.0
# ('attendant', 'cashier') 5 0.0
# ('manager', 'receptionist') 5 0.2
# ('clerk', 'editor') 5 0.0
# ('carpenter', 'supervisor') 5 0.8
# ('lawyer', 'sheriff') 5 0.0
# ('guard', 'writer') 5 0.0
# ('engineer', 'salesperson') 5 0.8
# ('clerk', 'engineer') 5 0.6
# ('CEO', 'farmer') 5 0.4
# ('chief', 'laborer') 5 0.6
# ('cleaner', 'writer') 5 0.2
# ('designer', 'developer') 5 0.2
# ('cook', 'physician') 5 0.4
# ('baker', 'secretary') 5 0.4
# ('editor', 'laborer') 5 0.4
# ('auditor', 'baker') 5 0.6
# ('guard', 'supervisor') 5 0.0
# ('attendant', 'baker') 5 0.0
# ('engineer', 'librarian') 5 1.0
# ('chief', 'nurse') 5 0.2
# ('counselor', 'receptionist') 5 0.0
# ('librarian', 'manager') 5 0.4
# ('attendant', 'carpenter') 5 0.8
# ('engineer', 'technician') 5 0.8
# ('cook', 'librarian') 5 0.6
# ('engineer', 'lawyer') 5 1.0
# ('analyst', 'engineer') 5 0.4
# ('housekeeper', 'writer') 5 0.4
# ('baker', 'supervisor') 5 0.4
# ('cleaner', 'teacher') 5 0.0
# ('farmer', 'sheriff') 5 0.6
# ('clerk', 'nurse') 5 0.0
# ('assistant', 'janitor') 5 0.4
# ('manager', 'sheriff') 5 0.2
# ('cashier', 'laborer') 5 0.8
# ('manager', 'mover') 5 0.2
# ('assistant', 'farmer') 5 0.6
# ('designer', 'laborer') 5 0.2
# ('physician', 'technician') 5 0.2
# ('driver', 'supervisor') 5 0.4
# ('developer', 'nurse') 5 0.6
# ('farmer', 'technician') 5 0.0
# ('counselor', 'driver') 5 0.8
# ('laborer', 'physician') 5 0.4
# ('designer', 'driver') 5 0.2
# ('engineer', 'sheriff') 5 0.8
# ('baker', 'paralegal') 5 0.2
# ('guard', 'librarian') 5 0.0
# ('librarian', 'paralegal') 5 0.0
# ('janitor', 'teacher') 5 0.4
# ('counselor', 'engineer') 5 0.6
# ('driver', 'technician') 5 0.0
# ('assistant', 'driver') 5 0.4
# ('janitor', 'physician') 5 0.2
# ('chief', 'janitor') 5 0.2
# ('farmer', 'writer') 5 0.4
# ('auditor', 'manager') 5 0.2
# ('baker', 'driver') 4 0.25
# ('paralegal', 'physician') 4 0.25
# ('accountant', 'driver') 4 0.5
# ('carpenter', 'guard') 4 0.75
# ('cook', 'housekeeper') 4 0.25
# ('janitor', 'receptionist') 4 0.5
# ('accountant', 'manager') 4 0.25
# ('cleaner', 'cook') 4 0.5
# ('baker', 'lawyer') 4 0.75
# ('accountant', 'cleaner') 4 0.25
# ('CEO', 'baker') 4 0.0
# ('carpenter', 'teacher') 4 1.0
# ('accountant', 'guard') 4 0.25
# ('janitor', 'librarian') 4 0.5
# ('cashier', 'receptionist') 4 0.0
# ('analyst', 'baker') 4 0.25
# ('CEO', 'physician') 4 0.5
# ('analyst', 'paralegal') 4 0.25
# ('driver', 'lawyer') 4 0.75
# ('baker', 'editor') 4 0.75
# ('supervisor', 'writer') 4 0.5
# ('carpenter', 'clerk') 4 0.75
# ('mechanic', 'sheriff') 4 0.75
# ('designer', 'housekeeper') 4 0.75
# ('designer', 'receptionist') 4 0.5
# ('cleaner', 'laborer') 4 0.25
# ('secretary', 'technician') 4 0.75
# ('accountant', 'lawyer') 4 0.0
# ('developer', 'technician') 4 0.25
# ('clerk', 'housekeeper') 4 0.0
# ('baker', 'cashier') 4 0.5
# ('salesperson', 'technician') 4 0.25
# ('janitor', 'sheriff') 4 0.5
# ('lawyer', 'physician') 4 0.0
# ('chief', 'paralegal') 4 0.0
# ('designer', 'secretary') 4 0.5
# ('auditor', 'farmer') 4 0.75
# ('clerk', 'paralegal') 4 0.5
# ('housekeeper', 'secretary') 4 0.0
# ('developer', 'driver') 4 0.75
# ('housekeeper', 'nurse') 4 0.0
# ('assistant', 'teacher') 4 0.25
# ('chief', 'counselor') 4 0.0
# ('accountant', 'mover') 4 0.0
# ('accountant', 'baker') 4 0.5
# ('editor', 'sheriff') 4 0.0
# ('baker', 'teacher') 4 0.75
# ('CEO', 'developer') 4 0.25
# ('janitor', 'technician') 4 0.25
# ('editor', 'farmer') 4 0.5
# ('clerk', 'guard') 4 0.0
# ('laborer', 'lawyer') 4 0.5
# ('analyst', 'mover') 4 0.25
# ('hairdresser', 'teacher') 4 0.25
# ('baker', 'salesperson') 4 1.0
# ('assistant', 'housekeeper') 4 0.5
# ('counselor', 'manager') 4 0.25
# ('accountant', 'laborer') 4 0.75
# ('baker', 'receptionist') 4 0.5
# ('manager', 'writer') 4 0.5
# ('cashier', 'counselor') 4 0.0
# ('analyst', 'supervisor') 4 0.0
# ('analyst', 'carpenter') 4 0.75
# ('hairdresser', 'tailor') 4 0.5
# ('designer', 'manager') 4 0.5
# ('housekeeper', 'librarian') 4 0.0
# ('CEO', 'guard') 4 0.25
# ('mover', 'physician') 4 0.5
# ('accountant', 'farmer') 4 0.75
# ('cashier', 'technician') 4 0.25
# ('secretary', 'writer') 4 0.75
# ('cashier', 'tailor') 4 0.0
# ('laborer', 'librarian') 4 0.75
# ('baker', 'clerk') 4 0.5
# ('cashier', 'designer') 4 0.75
# ('nurse', 'sheriff') 4 0.0
# ('lawyer', 'tailor') 4 0.0
# ('manager', 'physician') 4 0.0
# ('chief', 'physician') 4 0.0
# ('mover', 'sheriff') 4 0.0
# ('auditor', 'nurse') 4 0.0
# ('clerk', 'receptionist') 4 0.0
# ('mechanic', 'secretary') 4 1.0
# ('physician', 'sheriff') 4 0.0
# ('auditor', 'physician') 4 0.0
# ('farmer', 'tailor') 4 0.25
# ('manager', 'teacher') 4 0.25
# ('carpenter', 'physician') 4 0.5
# ('designer', 'paralegal') 4 0.75
# ('cashier', 'teacher') 4 0.0
# ('sheriff', 'writer') 4 0.5
# ('auditor', 'sheriff') 4 0.0
# ('baker', 'mover') 4 0.25
# ('clerk', 'janitor') 4 0.5
# ('cook', 'developer') 4 0.25
# ('laborer', 'receptionist') 4 0.75
# ('designer', 'guard') 4 0.25
# ('cook', 'writer') 4 0.0
# ('counselor', 'salesperson') 4 0.25
# ('CEO', 'manager') 4 0.5
# ('mover', 'writer') 4 0.5
# ('clerk', 'secretary') 4 0.0
# ('assistant', 'cleaner') 4 0.25
# ('cashier', 'driver') 4 0.75
# ('clerk', 'driver') 4 0.25
# ('laborer', 'manager') 4 0.25
# ('auditor', 'mover') 4 0.0
# ('tailor', 'writer') 4 0.5
# ('baker', 'physician') 4 0.5
# ('librarian', 'physician') 4 0.5
# ('chief', 'engineer') 4 0.75
# ('carpenter', 'cashier') 4 1.0
# ('cook', 'janitor') 3 0.0
# ('driver', 'receptionist') 3 1.0
# ('chief', 'lawyer') 3 0.3333333333333333
# ('driver', 'teacher') 3 0.3333333333333333
# ('paralegal', 'receptionist') 3 0.3333333333333333
# ('accountant', 'cook') 3 0.3333333333333333
# ('designer', 'sheriff') 3 0.6666666666666666
# ('designer', 'nurse') 3 0.3333333333333333
# ('baker', 'guard') 3 0.3333333333333333
# ('clerk', 'salesperson') 3 0.0
# ('designer', 'physician') 3 1.0
# ('attendant', 'librarian') 3 0.0
# ('editor', 'receptionist') 3 0.0
# ('hairdresser', 'nurse') 3 0.3333333333333333
# ('farmer', 'mechanic') 3 0.6666666666666666
# ('counselor', 'mover') 3 0.0
# ('editor', 'janitor') 3 0.3333333333333333
# ('accountant', 'analyst') 3 0.3333333333333333
# ('nurse', 'paralegal') 3 0.3333333333333333
# ('analyst', 'nurse') 3 0.3333333333333333
# ('assistant', 'cook') 3 0.3333333333333333
# ('attendant', 'mover') 3 0.0
# ('assistant', 'developer') 3 0.3333333333333333
# ('sheriff', 'teacher') 3 0.0
# ('physician', 'supervisor') 3 0.0
# ('editor', 'paralegal') 3 0.0
# ('assistant', 'supervisor') 3 0.3333333333333333
# ('assistant', 'chief') 3 0.0
# ('cleaner', 'developer') 3 0.0
# ('sheriff', 'tailor') 3 0.0
# ('cashier', 'writer') 3 0.6666666666666666
# ('auditor', 'counselor') 3 0.0
# ('attendant', 'designer') 3 0.6666666666666666
# ('lawyer', 'technician') 3 0.3333333333333333
# ('analyst', 'sheriff') 3 0.3333333333333333
# ('driver', 'physician') 3 0.3333333333333333
# ('cook', 'driver') 3 0.0
# ('driver', 'writer') 3 0.0
# ('paralegal', 'salesperson') 3 0.0
# ('analyst', 'lawyer') 3 0.3333333333333333
# ('chief', 'receptionist') 3 0.0
# ('auditor', 'lawyer') 3 0.0
# ('guard', 'receptionist') 3 0.0
# ('accountant', 'sheriff') 3 0.6666666666666666
# ('analyst', 'counselor') 3 0.0
# ('secretary', 'sheriff') 3 0.0
# ('lawyer', 'manager') 3 0.0
# ('engineer', 'teacher') 3 1.0
# ('auditor', 'chief') 3 0.0
# ('accountant', 'paralegal') 3 1.0
# ('designer', 'salesperson') 3 1.0
# ('cook', 'mechanic') 3 0.0
# ('CEO', 'driver') 3 0.0
# ('assistant', 'counselor') 3 0.0
# ('developer', 'housekeeper') 3 0.0
# ('janitor', 'secretary') 3 0.6666666666666666
# ('CEO', 'writer') 3 0.3333333333333333
# ('assistant', 'attendant') 3 0.0
# ('driver', 'guard') 3 0.6666666666666666
# ('CEO', 'attendant') 3 0.3333333333333333
# ('auditor', 'mechanic') 3 0.3333333333333333
# ('assistant', 'mover') 3 0.0
# ('cleaner', 'paralegal') 3 0.6666666666666666
# ('cleaner', 'clerk') 3 0.3333333333333333
# ('analyst', 'developer') 3 0.0
# ('clerk', 'counselor') 3 0.0
# ('attendant', 'driver') 3 0.6666666666666666
# ('assistant', 'clerk') 3 0.0
# ('physician', 'receptionist') 3 0.0
# ('CEO', 'receptionist') 3 0.0
# ('hairdresser', 'mover') 3 0.3333333333333333
# ('laborer', 'teacher') 3 0.3333333333333333
# ('attendant', 'technician') 3 0.6666666666666666
# ('developer', 'laborer') 3 0.0
# ('lawyer', 'writer') 3 0.3333333333333333
# ('driver', 'paralegal') 3 0.3333333333333333
# ('housekeeper', 'janitor') 3 0.6666666666666666
# ('driver', 'tailor') 3 0.3333333333333333
# ('cleaner', 'hairdresser') 3 0.3333333333333333
# ('cleaner', 'sheriff') 3 0.6666666666666666
# ('teacher', 'writer') 3 0.6666666666666666
# ('accountant', 'housekeeper') 3 0.0
# ('editor', 'housekeeper') 3 0.3333333333333333
# ('lawyer', 'teacher') 3 0.0
# ('cashier', 'manager') 3 0.3333333333333333
# ('analyst', 'assistant') 3 0.6666666666666666
# ('auditor', 'paralegal') 3 0.0
# ('accountant', 'writer') 3 0.0
# ('guard', 'paralegal') 3 0.0
# ('attendant', 'manager') 3 0.6666666666666666
# ('editor', 'technician') 3 1.0
# ('assistant', 'technician') 3 0.0
# ('clerk', 'supervisor') 3 0.0
# ('cook', 'designer') 3 0.0
# ('accountant', 'receptionist') 3 0.0
# ('cleaner', 'mechanic') 3 0.0
# ('cleaner', 'nurse') 3 0.0
# ('CEO', 'cleaner') 3 0.0
# ('auditor', 'receptionist') 3 0.0
# ('attendant', 'janitor') 3 0.6666666666666666
# ('CEO', 'salesperson') 3 0.3333333333333333
# ('housekeeper', 'mechanic') 3 1.0
# ('auditor', 'designer') 3 0.6666666666666666
# ('analyst', 'laborer') 3 0.6666666666666666
# ('attendant', 'guard') 3 0.0
# ('cook', 'guard') 3 0.6666666666666666
# ('assistant', 'editor') 3 0.0
# ('farmer', 'receptionist') 3 0.6666666666666666
# ('CEO', 'hairdresser') 3 0.0
# ('mechanic', 'receptionist') 3 0.6666666666666666
# ('editor', 'guard') 3 0.0
# ('teacher', 'technician') 3 0.3333333333333333
# ('clerk', 'mechanic') 3 1.0
# ('attendant', 'physician') 3 0.3333333333333333
# ('auditor', 'editor') 3 0.0
# ('accountant', 'engineer') 3 0.3333333333333333
# ('hairdresser', 'lawyer') 3 0.0
# ('nurse', 'secretary') 3 0.0
# ('housekeeper', 'technician') 3 0.3333333333333333
# ('manager', 'mechanic') 3 0.6666666666666666
# ('attendant', 'farmer') 3 0.6666666666666666
# ('analyst', 'physician') 3 0.3333333333333333
# ('driver', 'hairdresser') 3 0.3333333333333333
# ('clerk', 'librarian') 3 0.0
# ('guard', 'tailor') 3 0.0
# ('hairdresser', 'sheriff') 3 0.0
# ('CEO', 'designer') 3 0.3333333333333333
# ('CEO', 'tailor') 3 0.0
# ('counselor', 'sheriff') 3 0.0
# ('cashier', 'sheriff') 3 0.3333333333333333
# ('assistant', 'paralegal') 3 0.3333333333333333
# ('cashier', 'guard') 3 0.0
# ('hairdresser', 'laborer') 3 1.0
# ('analyst', 'secretary') 3 0.6666666666666666
# ('assistant', 'carpenter') 3 1.0
# ('counselor', 'technician') 3 0.3333333333333333
# ('analyst', 'cook') 3 0.3333333333333333
# ('cook', 'technician') 3 0.6666666666666666
# ('baker', 'housekeeper') 3 0.3333333333333333
# ('hairdresser', 'librarian') 3 0.0
# ('CEO', 'technician') 3 0.0
# ('chief', 'sheriff') 3 0.6666666666666666
# ('housekeeper', 'sheriff') 3 0.0
# ('guard', 'lawyer') 3 0.0
# ('housekeeper', 'lawyer') 3 0.0
# ('developer', 'salesperson') 3 1.0
# ('cook', 'lawyer') 3 0.3333333333333333
# ('auditor', 'engineer') 3 0.3333333333333333
# ('cook', 'hairdresser') 2 1.0
# ('cook', 'counselor') 2 0.0
# ('auditor', 'supervisor') 2 0.0
# ('counselor', 'teacher') 2 0.5
# ('counselor', 'tailor') 2 0.0
# ('accountant', 'hairdresser') 2 0.5
# ('developer', 'sheriff') 2 0.5
# ('salesperson', 'sheriff') 2 0.0
# ('attendant', 'chief') 2 0.0
# ('cleaner', 'designer') 2 0.5
# ('designer', 'technician') 2 0.5
# ('clerk', 'developer') 2 1.0
# ('assistant', 'guard') 2 0.0
# ('cook', 'supervisor') 2 0.5
# ('assistant', 'librarian') 2 0.0
# ('janitor', 'supervisor') 2 0.0
# ('assistant', 'baker') 2 1.0
# ('supervisor', 'technician') 2 0.5
# ('receptionist', 'teacher') 2 0.0
# ('receptionist', 'tailor') 2 0.0
# ('cashier', 'housekeeper') 2 0.0
# ('CEO', 'nurse') 2 0.5
# ('CEO', 'teacher') 2 0.0
# ('clerk', 'mover') 2 0.0
# ('assistant', 'tailor') 2 0.0
# ('auditor', 'cook') 2 0.5
# ('CEO', 'secretary') 2 0.5
# ('cashier', 'janitor') 2 0.0
# ('assistant', 'lawyer') 2 0.0
# ('assistant', 'receptionist') 2 0.5
# ('assistant', 'manager') 2 0.5
# ('CEO', 'chief') 2 0.5
# ('designer', 'hairdresser') 2 0.5
# ('CEO', 'clerk') 2 0.5
# ('counselor', 'paralegal') 2 0.5
# ('cleaner', 'supervisor') 2 1.0
# ('auditor', 'secretary') 2 0.0
# ('lawyer', 'supervisor') 2 0.0
# ('attendant', 'housekeeper') 2 0.0
# ('lawyer', 'salesperson') 2 0.0
# ('carpenter', 'salesperson') 2 1.0
# ('chief', 'driver') 2 0.5
# ('clerk', 'technician') 2 0.0
# ('accountant', 'developer') 2 0.0
# ('developer', 'supervisor') 2 0.0
# ('chief', 'editor') 2 0.0
# ('laborer', 'mover') 2 0.0
# ('janitor', 'nurse') 2 0.0
# ('mechanic', 'paralegal') 2 0.5
# ('editor', 'tailor') 2 0.5
# ('physician', 'tailor') 2 0.5
# ('auditor', 'teacher') 2 0.5
# ('developer', 'janitor') 2 0.5
# ('driver', 'sheriff') 2 0.5
# ('analyst', 'guard') 2 0.0
# ('secretary', 'tailor') 2 0.5
# ('cashier', 'supervisor') 2 0.0
# ('editor', 'secretary') 2 0.0
# ('librarian', 'nurse') 2 0.0
# ('analyst', 'attendant') 2 0.0
# ('housekeeper', 'physician') 2 0.0
# ('editor', 'salesperson') 2 0.0
# ('cook', 'mover') 2 0.5
# ('counselor', 'supervisor') 2 0.0
# ('cook', 'manager') 2 0.0
# ('chief', 'librarian') 2 0.0
# ('analyst', 'writer') 2 0.5
# ('editor', 'hairdresser') 2 0.0
# ('assistant', 'nurse') 2 0.0
# ('attendant', 'mechanic') 2 0.0
# ('cashier', 'lawyer') 2 0.0
# ('assistant', 'physician') 2 0.0
# ('auditor', 'janitor') 2 0.0
# ('attendant', 'salesperson') 2 0.0
# ('accountant', 'librarian') 2 0.0
# ('cleaner', 'housekeeper') 2 0.0
# ('guard', 'nurse') 2 0.0
# ('accountant', 'assistant') 2 0.0
# ('analyst', 'receptionist') 2 0.5
# ('driver', 'salesperson') 2 0.5
# ('counselor', 'developer') 2 0.0
# ('chief', 'manager') 2 0.0
# ('paralegal', 'sheriff') 2 0.0
# ('developer', 'hairdresser') 2 0.5
# ('guard', 'sheriff') 2 0.0
# ('farmer', 'secretary') 2 0.5
# ('salesperson', 'teacher') 2 0.0
# ('janitor', 'manager') 2 0.0
# ('receptionist', 'supervisor') 2 0.0
# ('assistant', 'auditor') 2 0.0
# ('driver', 'editor') 2 0.0
# ('attendant', 'laborer') 2 1.0
# ('chief', 'developer') 2 0.0
# ('developer', 'editor') 2 0.5
# ('CEO', 'assistant') 2 0.5
# ('manager', 'tailor') 2 0.0
# ('cashier', 'mechanic') 2 0.5
# ('counselor', 'housekeeper') 2 0.0
# ('attendant', 'developer') 2 0.0
# ('accountant', 'attendant') 2 0.0
# ('housekeeper', 'salesperson') 2 0.0
# ('sheriff', 'technician') 2 0.5
# ('auditor', 'tailor') 2 0.0
# ('analyst', 'housekeeper') 2 0.0
# ('baker', 'mechanic') 2 0.0
# ('CEO', 'supervisor') 2 0.5
# ('attendant', 'paralegal') 2 0.0
# ('laborer', 'secretary') 2 0.0
# ('mover', 'teacher') 2 0.0
# ('CEO', 'counselor') 2 0.0
# ('editor', 'engineer') 2 1.0
# ('salesperson', 'writer') 2 0.0
# ('auditor', 'technician') 2 0.5
# ('manager', 'secretary') 2 0.5
# ('cashier', 'cleaner') 2 0.5
# ('editor', 'writer') 2 0.0
# ('analyst', 'technician') 2 0.5
# ('driver', 'secretary') 2 1.0
# ('farmer', 'teacher') 2 1.0
# ('developer', 'mechanic') 2 0.5
# ('CEO', 'librarian') 2 0.0
# ('librarian', 'writer') 2 1.0
# ('attendant', 'cook') 2 0.5
# ('analyst', 'tailor') 2 0.0
# ('accountant', 'tailor') 2 0.0
# ('housekeeper', 'supervisor') 2 0.0
# ('chief', 'mover') 2 0.0
# ('analyst', 'manager') 2 0.5
# ('analyst', 'cashier') 2 0.0
# ('guard', 'technician') 2 0.5
# ('counselor', 'editor') 2 0.0
# ('manager', 'salesperson') 2 0.0
# ('driver', 'mover') 2 0.0
# ('counselor', 'farmer') 2 0.5
# ('developer', 'physician') 2 0.5
# ('assistant', 'writer') 2 0.5
# ('receptionist', 'salesperson') 2 0.0
# ('librarian', 'supervisor') 2 0.0
# ('auditor', 'guard') 2 0.0
# ('assistant', 'sheriff') 2 0.0
# ('analyst', 'hairdresser') 2 0.0
# ('housekeeper', 'tailor') 2 0.5
# ('librarian', 'salesperson') 2 0.0
# ('lawyer', 'secretary') 2 0.0
# ('designer', 'supervisor') 2 0.5
# ('attendant', 'receptionist') 2 0.0
# ('chief', 'cook') 2 1.0
# ('guard', 'secretary') 2 0.0
# ('auditor', 'laborer') 2 0.5
# ('attendant', 'nurse') 2 0.0
# ('lawyer', 'librarian') 2 0.0
# ('accountant', 'mechanic') 2 0.0
# ('hairdresser', 'supervisor') 2 0.0
# ('accountant', 'auditor') 2 0.5
# ('housekeeper', 'receptionist') 2 0.0
# ('accountant', 'counselor') 2 0.0
# ('cashier', 'farmer') 2 0.5
# ('CEO', 'analyst') 2 0.5
# ('CEO', 'sheriff') 2 0.0
# ('attendant', 'lawyer') 2 0.5
# ('guard', 'teacher') 1 0.0
# ('baker', 'librarian') 1 1.0
# ('housekeeper', 'teacher') 1 0.0
# ('developer', 'teacher') 1 1.0
# ('nurse', 'supervisor') 1 0.0
# ('analyst', 'teacher') 1 0.0
# ('cleaner', 'guard') 1 0.0
# ('hairdresser', 'technician') 1 0.0
# ('cashier', 'developer') 1 0.0
# ('chief', 'hairdresser') 1 0.0
# ('receptionist', 'sheriff') 1 0.0
# ('farmer', 'housekeeper') 1 0.0
# ('manager', 'supervisor') 1 1.0
# ('CEO', 'accountant') 1 0.0
# ('counselor', 'guard') 1 0.0
# ('mover', 'salesperson') 1 0.0
# ('developer', 'mover') 1 0.0
# ('CEO', 'laborer') 1 1.0
# ('janitor', 'tailor') 1 1.0
# ('cashier', 'secretary') 1 0.0
# ('physician', 'salesperson') 1 1.0
# ('accountant', 'clerk') 1 0.0
# ('attendant', 'supervisor') 1 0.0
# ('auditor', 'cashier') 1 0.0
# ('farmer', 'salesperson') 1 1.0
# ('attendant', 'counselor') 1 0.0
# ('baker', 'chief') 1 1.0
# ('janitor', 'salesperson') 1 0.0
# ('assistant', 'cashier') 1 0.0
# ('editor', 'physician') 1 1.0
# ('clerk', 'cook') 1 1.0
# ('mechanic', 'nurse') 1 0.0
# ('mover', 'technician') 1 0.0
# ('hairdresser', 'secretary') 1 0.0
# ('hairdresser', 'physician') 1 0.0
# ('cashier', 'engineer') 1 1.0
# ('chief', 'secretary') 1 0.0
# ('CEO', 'editor') 1 0.0
# ('cleaner', 'receptionist') 1 1.0
# ('accountant', 'editor') 1 1.0
# ('mover', 'paralegal') 1 0.0
# ('cashier', 'hairdresser') 1 0.0
# ('supervisor', 'teacher') 1 0.0
# ('editor', 'librarian') 1 0.0
# ('housekeeper', 'laborer') 1 0.0
# ('housekeeper', 'manager') 1 0.0
# ('supervisor', 'tailor') 1 0.0
# ('editor', 'nurse') 1 0.0
# ('accountant', 'supervisor') 1 0.0
# ('cook', 'paralegal') 1 1.0
# ('carpenter', 'counselor') 1 1.0
# ('clerk', 'hairdresser') 1 1.0
# ('editor', 'manager') 1 0.0
# ('mechanic', 'salesperson') 1 0.0
# ('assistant', 'secretary') 1 0.0
# ('cashier', 'salesperson') 1 0.0
# ('physician', 'secretary') 1 0.0
# ('analyst', 'editor') 1 0.0
# ('carpenter', 'editor') 1 1.0
# ('sheriff', 'supervisor') 1 1.0
# ('CEO', 'mechanic') 1 0.0
# ('hairdresser', 'mechanic') 1 1.0
# ('clerk', 'sheriff') 1 0.0
# ('attendant', 'auditor') 1 0.0
# ('nurse', 'receptionist') 1 0.0
# ('editor', 'mechanic') 1 0.0
# ('analyst', 'clerk') 1 0.0
# ('cleaner', 'editor') 1 1.0
# ('secretary', 'teacher') 1 0.0
# ('cook', 'nurse') 1 1.0
# ('salesperson', 'secretary') 1 0.0
# ('assistant', 'hairdresser') 1 0.0
# ('CEO', 'mover') 1 0.0
# ('auditor', 'salesperson') 1 1.0
# ('attendant', 'clerk') 1 0.0
# ('cashier', 'mover') 1 0.0
# ('assistant', 'mechanic') 1 0.0
# ('housekeeper', 'paralegal') 1 0.0
# ('accountant', 'salesperson') 1 0.0
# ('cook', 'teacher') 1 0.0
# ('analyst', 'auditor') 1 1.0
# ('developer', 'librarian') 1 1.0
# ('counselor', 'secretary') 1 0.0
# ('mover', 'secretary') 1 0.0
# ('baker', 'cleaner') 1 0.0
# ('hairdresser', 'housekeeper') 1 0.0
# ('auditor', 'housekeeper') 1 0.0
# ('developer', 'manager') 1 1.0
# ('cook', 'secretary') 1 0.0
# ('lawyer', 'nurse') 1 0.0
# ('paralegal', 'tailor') 1 1.0
# ('chief', 'cleaner') 1 0.0
# ('attendant', 'secretary') 1 0.0
# ('receptionist', 'technician') 1 0.0
# ('clerk', 'teacher') 1 0.0
# ('lawyer', 'mover') 1 0.0
# ('cashier', 'librarian') 1 0.0
# ('cleaner', 'tailor') 1 0.0
# ('manager', 'nurse') 1 1.0
# ('developer', 'tailor') 1 1.0
# ('clerk', 'physician') 1 0.0
# ('clerk', 'lawyer') 1 0.0
# ('cook', 'editor') 1 0.0
# ('lawyer', 'paralegal') 1 0.0
# ('cleaner', 'janitor') 1 1.0
# ('tailor', 'technician') 1 1.0
# ('attendant', 'tailor') 1 0.0
# ('janitor', 'lawyer') 1 1.0
# ('chief', 'teacher') 1 0.0
# ('auditor', 'librarian') 1 0.0
# ('CEO', 'housekeeper') 1 0.0
# ('mechanic', 'technician') 1 0.0
# ('mover', 'supervisor') 1 0.0
# ('chief', 'clerk') 1 0.0
# ('receptionist', 'secretary') 1 0.0
# ('lawyer', 'receptionist') 1 0.0
# ('laborer', 'salesperson') 1 1.0
# ('mover', 'receptionist') 1 0.0
# ('hairdresser', 'receptionist') 1 0.0
# ('cashier', 'editor') 1 0.0
# ('auditor', 'clerk') 1 0.0
# ('cashier', 'cook') 1 0.0
# ('cook', 'sheriff') 1 1.0
# ('attendant', 'cleaner') 1 0.0
# ('CEO', 'cashier') 1 0.0
# ('librarian', 'teacher') 1 0.0
# ('paralegal', 'supervisor') 1 0.0
# ('accountant', 'chief') 1 0.0
# ('cleaner', 'lawyer') 1 0.0
# ('driver', 'housekeeper') 1 1.0
# ('cook', 'tailor') 1 1.0
# ('physician', 'writer') 1 0.0
# ('editor', 'lawyer') 1 0.0
# ('editor', 'teacher') 1 0.0
# ('cleaner', 'librarian') 1 0.0
# ('clerk', 'tailor') 1 0.0
# ('driver', 'librarian') 1 0.0
# ('analyst', 'cleaner') 1 1.0
# ('paralegal', 'teacher') 1 0.0
# ('guard', 'salesperson') 1 0.0
# ('librarian', 'technician') 1 1.0
# ('auditor', 'hairdresser') 1 0.0
# ('analyst', 'mechanic') 1 0.0
# ('hairdresser', 'paralegal') 1 0.0
# ('CEO', 'cook') 1 0.0
# ('mechanic', 'tailor') 1 0.0
# ('cleaner', 'secretary') 1 1.0

# %%
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], sorted_occupation_pair_count[key])
# Out:
# ('cook', 'hairdresser') 1.0 2
# ('baker', 'librarian') 1.0 1
# ('developer', 'teacher') 1.0 1
# ('driver', 'receptionist') 1.0 3
# ('clerk', 'developer') 1.0 2
# ('carpenter', 'teacher') 1.0 4
# ('assistant', 'baker') 1.0 2
# ('designer', 'physician') 1.0 3
# ('clerk', 'laborer') 1.0 6
# ('engineer', 'receptionist') 1.0 8
# ('carpenter', 'librarian') 1.0 6
# ('laborer', 'tailor') 1.0 7
# ('cleaner', 'supervisor') 1.0 2
# ('manager', 'supervisor') 1.0 1
# ('assistant', 'engineer') 1.0 8
# ('carpenter', 'salesperson') 1.0 2
# ('engineer', 'teacher') 1.0 3
# ('engineer', 'mover') 1.0 7
# ('CEO', 'laborer') 1.0 1
# ('janitor', 'tailor') 1.0 1
# ('accountant', 'paralegal') 1.0 3
# ('engineer', 'librarian') 1.0 5
# ('designer', 'salesperson') 1.0 3
# ('physician', 'salesperson') 1.0 1
# ('farmer', 'salesperson') 1.0 1
# ('engineer', 'lawyer') 1.0 5
# ('baker', 'chief') 1.0 1
# ('baker', 'salesperson') 1.0 4
# ('carpenter', 'housekeeper') 1.0 7
# ('editor', 'physician') 1.0 1
# ('clerk', 'cook') 1.0 1
# ('cashier', 'engineer') 1.0 1
# ('cleaner', 'receptionist') 1.0 1
# ('accountant', 'editor') 1.0 1
# ('editor', 'technician') 1.0 3
# ('mechanic', 'secretary') 1.0 4
# ('cook', 'paralegal') 1.0 1
# ('carpenter', 'counselor') 1.0 1
# ('clerk', 'hairdresser') 1.0 1
# ('housekeeper', 'mechanic') 1.0 3
# ('attendant', 'laborer') 1.0 2
# ('carpenter', 'editor') 1.0 1
# ('sheriff', 'supervisor') 1.0 1
# ('hairdresser', 'mechanic') 1.0 1
# ('clerk', 'mechanic') 1.0 3
# ('cleaner', 'editor') 1.0 1
# ('cook', 'nurse') 1.0 1
# ('auditor', 'salesperson') 1.0 1
# ('editor', 'engineer') 1.0 2
# ('driver', 'secretary') 1.0 2
# ('farmer', 'teacher') 1.0 2
# ('librarian', 'writer') 1.0 2
# ('analyst', 'auditor') 1.0 1
# ('hairdresser', 'laborer') 1.0 3
# ('developer', 'librarian') 1.0 1
# ('assistant', 'carpenter') 1.0 3
# ('developer', 'manager') 1.0 1
# ('paralegal', 'tailor') 1.0 1
# ('manager', 'nurse') 1.0 1
# ('developer', 'tailor') 1.0 1
# ('cleaner', 'janitor') 1.0 1
# ('tailor', 'technician') 1.0 1
# ('chief', 'cook') 1.0 2
# ('janitor', 'lawyer') 1.0 1
# ('carpenter', 'cashier') 1.0 4
# ('laborer', 'salesperson') 1.0 1
# ('developer', 'salesperson') 1.0 3
# ('cook', 'sheriff') 1.0 1
# ('driver', 'housekeeper') 1.0 1
# ('cook', 'tailor') 1.0 1
# ('analyst', 'cleaner') 1.0 1
# ('librarian', 'technician') 1.0 1
# ('cleaner', 'secretary') 1.0 1
# ('engineer', 'housekeeper') 0.8571428571428571 7
# ('baker', 'tailor') 0.8333333333333334 6
# ('carpenter', 'sheriff') 0.8333333333333334 6
# ('assistant', 'laborer') 0.8333333333333334 6
# ('assistant', 'designer') 0.8333333333333334 6
# ('carpenter', 'lawyer') 0.8333333333333334 6
# ('engineer', 'secretary') 0.8333333333333334 6
# ('farmer', 'librarian') 0.8 5
# ('developer', 'lawyer') 0.8 5
# ('carpenter', 'supervisor') 0.8 5
# ('engineer', 'salesperson') 0.8 5
# ('attendant', 'carpenter') 0.8 5
# ('engineer', 'technician') 0.8 5
# ('cashier', 'laborer') 0.8 5
# ('counselor', 'driver') 0.8 5
# ('engineer', 'sheriff') 0.8 5
# ('counselor', 'laborer') 0.8 5
# ('attendant', 'engineer') 0.7777777777777778 9
# ('carpenter', 'guard') 0.75 4
# ('baker', 'lawyer') 0.75 4
# ('baker', 'editor') 0.75 4
# ('carpenter', 'clerk') 0.75 4
# ('mechanic', 'sheriff') 0.75 4
# ('secretary', 'technician') 0.75 4
# ('driver', 'lawyer') 0.75 4
# ('auditor', 'farmer') 0.75 4
# ('developer', 'driver') 0.75 4
# ('baker', 'teacher') 0.75 4
# ('accountant', 'laborer') 0.75 4
# ('analyst', 'carpenter') 0.75 4
# ('accountant', 'farmer') 0.75 4
# ('secretary', 'writer') 0.75 4
# ('cashier', 'designer') 0.75 4
# ('laborer', 'librarian') 0.75 4
# ('designer', 'paralegal') 0.75 4
# ('laborer', 'receptionist') 0.75 4
# ('cashier', 'driver') 0.75 4
# ('designer', 'housekeeper') 0.75 4
# ('chief', 'engineer') 0.75 4
# ('carpenter', 'mover') 0.7272727272727273 11
# ('cleaner', 'engineer') 0.7142857142857143 7
# ('engineer', 'hairdresser') 0.7142857142857143 7
# ('guard', 'laborer') 0.7142857142857143 7
# ('mechanic', 'mover') 0.7142857142857143 7
# ('developer', 'guard') 0.7142857142857143 7
# ('carpenter', 'secretary') 0.7 10
# ('carpenter', 'receptionist') 0.6923076923076923 13
# ('hairdresser', 'writer') 0.6666666666666666 6
# ('accountant', 'janitor') 0.6666666666666666 6
# ('auditor', 'carpenter') 0.6666666666666666 9
# ('engineer', 'nurse') 0.6666666666666666 9
# ('designer', 'sheriff') 0.6666666666666666 3
# ('farmer', 'mechanic') 0.6666666666666666 3
# ('engineer', 'physician') 0.6666666666666666 12
# ('developer', 'secretary') 0.6666666666666666 6
# ('attendant', 'designer') 0.6666666666666666 3
# ('designer', 'editor') 0.6666666666666666 6
# ('accountant', 'sheriff') 0.6666666666666666 3
# ('janitor', 'secretary') 0.6666666666666666 3
# ('laborer', 'technician') 0.6666666666666666 9
# ('engineer', 'mechanic') 0.6666666666666666 9
# ('laborer', 'supervisor') 0.6666666666666666 9
# ('cleaner', 'paralegal') 0.6666666666666666 3
# ('attendant', 'driver') 0.6666666666666666 3
# ('driver', 'guard') 0.6666666666666666 3
# ('cleaner', 'sheriff') 0.6666666666666666 3
# ('teacher', 'writer') 0.6666666666666666 3
# ('carpenter', 'technician') 0.6666666666666666 15
# ('counselor', 'writer') 0.6666666666666666 6
# ('analyst', 'assistant') 0.6666666666666666 3
# ('attendant', 'manager') 0.6666666666666666 3
# ('engineer', 'tailor') 0.6666666666666666 6
# ('analyst', 'laborer') 0.6666666666666666 3
# ('engineer', 'guard') 0.6666666666666666 9
# ('farmer', 'receptionist') 0.6666666666666666 3
# ('mechanic', 'receptionist') 0.6666666666666666 3
# ('attendant', 'janitor') 0.6666666666666666 3
# ('housekeeper', 'janitor') 0.6666666666666666 3
# ('manager', 'mechanic') 0.6666666666666666 3
# ('attendant', 'farmer') 0.6666666666666666 3
# ('auditor', 'designer') 0.6666666666666666 3
# ('attendant', 'technician') 0.6666666666666666 3
# ('analyst', 'secretary') 0.6666666666666666 3
# ('cashier', 'writer') 0.6666666666666666 3
# ('chief', 'sheriff') 0.6666666666666666 3
# ('cook', 'technician') 0.6666666666666666 3
# ('cook', 'guard') 0.6666666666666666 3
# ('engineer', 'paralegal') 0.625 8
# ('engineer', 'supervisor') 0.6 5
# ('baker', 'nurse') 0.6 5
# ('mechanic', 'supervisor') 0.6 5
# ('hairdresser', 'janitor') 0.6 5
# ('chief', 'writer') 0.6 5
# ('designer', 'janitor') 0.6 10
# ('clerk', 'engineer') 0.6 5
# ('clerk', 'manager') 0.6 5
# ('farmer', 'sheriff') 0.6 5
# ('chief', 'laborer') 0.6 5
# ('cook', 'librarian') 0.6 5
# ('developer', 'nurse') 0.6 5
# ('counselor', 'engineer') 0.6 5
# ('assistant', 'farmer') 0.6 5
# ('auditor', 'baker') 0.6 5
# ('baker', 'counselor') 0.6 5
# ('nurse', 'writer') 0.5714285714285714 7
# ('receptionist', 'writer') 0.5714285714285714 7
# ('counselor', 'janitor') 0.5714285714285714 7
# ('designer', 'teacher') 0.5714285714285714 7
# ('manager', 'technician') 0.5714285714285714 7
# ('baker', 'sheriff') 0.5714285714285714 7
# ('farmer', 'nurse') 0.5714285714285714 7
# ('designer', 'librarian') 0.5714285714285714 7
# ('farmer', 'supervisor') 0.5714285714285714 7
# ('carpenter', 'writer') 0.5714285714285714 7
# ('engineer', 'manager') 0.5454545454545454 11
# ('accountant', 'hairdresser') 0.5 2
# ('developer', 'sheriff') 0.5 2
# ('cleaner', 'designer') 0.5 2
# ('supervisor', 'technician') 0.5 2
# ('CEO', 'physician') 0.5 4
# ('supervisor', 'writer') 0.5 4
# ('clerk', 'designer') 0.5 6
# ('chief', 'mechanic') 0.5 8
# ('designer', 'receptionist') 0.5 4
# ('auditor', 'writer') 0.5 6
# ('farmer', 'hairdresser') 0.5 8
# ('CEO', 'secretary') 0.5 2
# ('assistant', 'receptionist') 0.5 2
# ('CEO', 'clerk') 0.5 2
# ('counselor', 'paralegal') 0.5 2
# ('designer', 'secretary') 0.5 4
# ('chief', 'driver') 0.5 2
# ('auditor', 'cook') 0.5 2
# ('mechanic', 'paralegal') 0.5 2
# ('editor', 'tailor') 0.5 2
# ('mechanic', 'physician') 0.5 6
# ('auditor', 'teacher') 0.5 2
# ('developer', 'janitor') 0.5 2
# ('CEO', 'nurse') 0.5 2
# ('cook', 'receptionist') 0.5 6
# ('farmer', 'lawyer') 0.5 6
# ('editor', 'farmer') 0.5 4
# ('accountant', 'driver') 0.5 4
# ('designer', 'manager') 0.5 4
# ('cook', 'mover') 0.5 2
# ('physician', 'tailor') 0.5 2
# ('analyst', 'writer') 0.5 2
# ('driver', 'nurse') 0.5 6
# ('laborer', 'sheriff') 0.5 6
# ('baker', 'clerk') 0.5 4
# ('cook', 'supervisor') 0.5 2
# ('designer', 'mover') 0.5 6
# ('analyst', 'receptionist') 0.5 2
# ('janitor', 'receptionist') 0.5 4
# ('developer', 'hairdresser') 0.5 2
# ('accountant', 'designer') 0.5 6
# ('clerk', 'paralegal') 0.5 4
# ('designer', 'technician') 0.5 2
# ('carpenter', 'physician') 0.5 4
# ('assistant', 'housekeeper') 0.5 4
# ('mover', 'physician') 0.5 4
# ('manager', 'writer') 0.5 4
# ('janitor', 'sheriff') 0.5 4
# ('sheriff', 'writer') 0.5 4
# ('farmer', 'manager') 0.5 8
# ('developer', 'editor') 0.5 2
# ('developer', 'receptionist') 0.5 6
# ('CEO', 'manager') 0.5 4
# ('cashier', 'mechanic') 0.5 2
# ('accountant', 'baker') 0.5 4
# ('secretary', 'tailor') 0.5 2
# ('CEO', 'supervisor') 0.5 2
# ('farmer', 'secretary') 0.5 2
# ('assistant', 'manager') 0.5 2
# ('auditor', 'technician') 0.5 2
# ('analyst', 'technician') 0.5 2
# ('janitor', 'librarian') 0.5 4
# ('baker', 'receptionist') 0.5 4
# ('CEO', 'assistant') 0.5 2
# ('librarian', 'physician') 0.5 4
# ('driver', 'sheriff') 0.5 2
# ('janitor', 'mover') 0.5 6
# ('analyst', 'manager') 0.5 2
# ('carpenter', 'chief') 0.5 6
# ('developer', 'physician') 0.5 2
# ('assistant', 'writer') 0.5 2
# ('sheriff', 'technician') 0.5 2
# ('carpenter', 'manager') 0.5 10
# ('counselor', 'farmer') 0.5 2
# ('attendant', 'cook') 0.5 2
# ('hairdresser', 'tailor') 0.5 4
# ('manager', 'secretary') 0.5 2
# ('guard', 'technician') 0.5 2
# ('mover', 'writer') 0.5 4
# ('designer', 'supervisor') 0.5 2
# ('laborer', 'lawyer') 0.5 4
# ('developer', 'mechanic') 0.5 2
# ('cashier', 'cleaner') 0.5 2
# ('driver', 'salesperson') 0.5 2
# ('auditor', 'laborer') 0.5 2
# ('clerk', 'janitor') 0.5 4
# ('baker', 'cashier') 0.5 4
# ('baker', 'physician') 0.5 4
# ('accountant', 'auditor') 0.5 2
# ('tailor', 'writer') 0.5 4
# ('designer', 'hairdresser') 0.5 2
# ('CEO', 'analyst') 0.5 2
# ('cashier', 'farmer') 0.5 2
# ('cleaner', 'cook') 0.5 4
# ('housekeeper', 'tailor') 0.5 2
# ('attendant', 'lawyer') 0.5 2
# ('counselor', 'teacher') 0.5 2
# ('CEO', 'chief') 0.5 2
# ('driver', 'farmer') 0.46153846153846156 13
# ('nurse', 'technician') 0.42857142857142855 7
# ('technician', 'writer') 0.42857142857142855 7
# ('driver', 'laborer') 0.42857142857142855 7
# ('accountant', 'carpenter') 0.42857142857142855 7
# ('CEO', 'farmer') 0.4 5
# ('cook', 'physician') 0.4 5
# ('counselor', 'designer') 0.4 5
# ('librarian', 'manager') 0.4 5
# ('analyst', 'engineer') 0.4 5
# ('baker', 'secretary') 0.4 5
# ('assistant', 'janitor') 0.4 5
# ('clerk', 'farmer') 0.4 10
# ('carpenter', 'nurse') 0.4 10
# ('baker', 'supervisor') 0.4 5
# ('driver', 'supervisor') 0.4 5
# ('editor', 'laborer') 0.4 5
# ('janitor', 'teacher') 0.4 5
# ('farmer', 'paralegal') 0.4 5
# ('housekeeper', 'writer') 0.4 5
# ('farmer', 'writer') 0.4 5
# ('assistant', 'driver') 0.4 5
# ('laborer', 'physician') 0.4 5
# ('librarian', 'mechanic') 0.375 8
# ('CEO', 'engineer') 0.375 8
# ('developer', 'engineer') 0.375 8
# ('janitor', 'paralegal') 0.375 8
# ('carpenter', 'mechanic') 0.35714285714285715 14
# ('chief', 'lawyer') 0.3333333333333333 3
# ('paralegal', 'receptionist') 0.3333333333333333 3
# ('accountant', 'cook') 0.3333333333333333 3
# ('guard', 'mechanic') 0.3333333333333333 9
# ('accountant', 'analyst') 0.3333333333333333 3
# ('analyst', 'lawyer') 0.3333333333333333 3
# ('driver', 'teacher') 0.3333333333333333 3
# ('guard', 'janitor') 0.3333333333333333 6
# ('farmer', 'laborer') 0.3333333333333333 9
# ('designer', 'nurse') 0.3333333333333333 3
# ('auditor', 'mechanic') 0.3333333333333333 3
# ('designer', 'lawyer') 0.3333333333333333 9
# ('lawyer', 'writer') 0.3333333333333333 3
# ('assistant', 'cook') 0.3333333333333333 3
# ('analyst', 'designer') 0.3333333333333333 9
# ('nurse', 'paralegal') 0.3333333333333333 3
# ('driver', 'manager') 0.3333333333333333 6
# ('cashier', 'manager') 0.3333333333333333 3
# ('CEO', 'carpenter') 0.3333333333333333 6
# ('CEO', 'writer') 0.3333333333333333 3
# ('cleaner', 'clerk') 0.3333333333333333 3
# ('editor', 'housekeeper') 0.3333333333333333 3
# ('analyst', 'janitor') 0.3333333333333333 6
# ('driver', 'physician') 0.3333333333333333 3
# ('farmer', 'mover') 0.3333333333333333 6
# ('CEO', 'salesperson') 0.3333333333333333 3
# ('laborer', 'teacher') 0.3333333333333333 3
# ('clerk', 'writer') 0.3333333333333333 6
# ('farmer', 'guard') 0.3333333333333333 6
# ('teacher', 'technician') 0.3333333333333333 3
# ('analyst', 'sheriff') 0.3333333333333333 3
# ('accountant', 'engineer') 0.3333333333333333 3
# ('driver', 'paralegal') 0.3333333333333333 3
# ('driver', 'hairdresser') 0.3333333333333333 3
# ('assistant', 'supervisor') 0.3333333333333333 3
# ('analyst', 'nurse') 0.3333333333333333 3
# ('hairdresser', 'nurse') 0.3333333333333333 3
# ('baker', 'guard') 0.3333333333333333 3
# ('cashier', 'sheriff') 0.3333333333333333 3
# ('assistant', 'developer') 0.3333333333333333 3
# ('assistant', 'paralegal') 0.3333333333333333 3
# ('baker', 'farmer') 0.3333333333333333 6
# ('analyst', 'cook') 0.3333333333333333 3
# ('driver', 'tailor') 0.3333333333333333 3
# ('hairdresser', 'mover') 0.3333333333333333 3
# ('analyst', 'physician') 0.3333333333333333 3
# ('cleaner', 'hairdresser') 0.3333333333333333 3
# ('lawyer', 'technician') 0.3333333333333333 3
# ('CEO', 'attendant') 0.3333333333333333 3
# ('baker', 'housekeeper') 0.3333333333333333 3
# ('housekeeper', 'technician') 0.3333333333333333 3
# ('CEO', 'designer') 0.3333333333333333 3
# ('auditor', 'engineer') 0.3333333333333333 3
# ('attendant', 'physician') 0.3333333333333333 3
# ('counselor', 'technician') 0.3333333333333333 3
# ('cook', 'lawyer') 0.3333333333333333 3
# ('editor', 'janitor') 0.3333333333333333 3
# ('carpenter', 'paralegal') 0.3 10
# ('designer', 'writer') 0.3 10
# ('carpenter', 'tailor') 0.2857142857142857 7
# ('mechanic', 'teacher') 0.2857142857142857 7
# ('baker', 'manager') 0.2857142857142857 7
# ('carpenter', 'cleaner') 0.2857142857142857 7
# ('lawyer', 'mechanic') 0.2857142857142857 7
# ('cleaner', 'farmer') 0.2857142857142857 7
# ('carpenter', 'farmer') 0.2727272727272727 11
# ('baker', 'technician') 0.26666666666666666 15
# ('accountant', 'manager') 0.25 4
# ('analyst', 'paralegal') 0.25 4
# ('cleaner', 'laborer') 0.25 4
# ('salesperson', 'technician') 0.25 4
# ('janitor', 'technician') 0.25 4
# ('developer', 'technician') 0.25 4
# ('CEO', 'guard') 0.25 4
# ('cashier', 'technician') 0.25 4
# ('farmer', 'physician') 0.25 8
# ('farmer', 'janitor') 0.25 8
# ('analyst', 'baker') 0.25 4
# ('accountant', 'cleaner') 0.25 4
# ('accountant', 'guard') 0.25 4
# ('designer', 'guard') 0.25 4
# ('cook', 'housekeeper') 0.25 4
# ('CEO', 'developer') 0.25 4
# ('baker', 'driver') 0.25 4
# ('cook', 'developer') 0.25 4
# ('assistant', 'teacher') 0.25 4
# ('laborer', 'manager') 0.25 4
# ('counselor', 'salesperson') 0.25 4
# ('assistant', 'cleaner') 0.25 4
# ('farmer', 'tailor') 0.25 4
# ('clerk', 'driver') 0.25 4
# ('hairdresser', 'teacher') 0.25 4
# ('baker', 'mover') 0.25 4
# ('counselor', 'manager') 0.25 4
# ('analyst', 'mover') 0.25 4
# ('manager', 'teacher') 0.25 4
# ('paralegal', 'physician') 0.25 4
# ('carpenter', 'driver') 0.2222222222222222 9
# ('carpenter', 'developer') 0.2222222222222222 9
# ('janitor', 'mechanic') 0.2222222222222222 9
# ('baker', 'writer') 0.2222222222222222 9
# ('designer', 'farmer') 0.2222222222222222 9
# ('baker', 'janitor') 0.2 5
# ('manager', 'mover') 0.2 5
# ('physician', 'technician') 0.2 5
# ('manager', 'receptionist') 0.2 5
# ('designer', 'developer') 0.2 5
# ('cook', 'laborer') 0.2 5
# ('chief', 'nurse') 0.2 5
# ('baker', 'paralegal') 0.2 5
# ('designer', 'laborer') 0.2 5
# ('manager', 'sheriff') 0.2 5
# ('cleaner', 'writer') 0.2 5
# ('chief', 'janitor') 0.2 5
# ('auditor', 'manager') 0.2 5
# ('designer', 'driver') 0.2 5
# ('janitor', 'physician') 0.2 5
# ('counselor', 'lawyer') 0.16666666666666666 6
# ('physician', 'teacher') 0.16666666666666666 6
# ('janitor', 'laborer') 0.16666666666666666 12
# ('baker', 'laborer') 0.16666666666666666 12
# ('manager', 'paralegal') 0.16666666666666666 6
# ('laborer', 'paralegal') 0.16666666666666666 6
# ('chief', 'technician') 0.16666666666666666 6
# ('developer', 'farmer') 0.16666666666666666 6
# ('designer', 'tailor') 0.16666666666666666 6
# ('baker', 'engineer') 0.16666666666666666 12
# ('baker', 'cook') 0.16666666666666666 6
# ('CEO', 'paralegal') 0.16666666666666666 6
# ('chief', 'designer') 0.14285714285714285 7
# ('paralegal', 'writer') 0.14285714285714285 7
# ('engineer', 'janitor') 0.14285714285714285 7
# ('cleaner', 'manager') 0.14285714285714285 7
# ('guard', 'manager') 0.14285714285714285 7
# ('accountant', 'teacher') 0.14285714285714285 7
# ('analyst', 'driver') 0.14285714285714285 7
# ('baker', 'developer') 0.14285714285714285 7
# ('engineer', 'writer') 0.14285714285714285 7
# ('analyst', 'farmer') 0.125 8
# ('designer', 'mechanic') 0.125 8
# ('mechanic', 'writer') 0.125 8
# ('cook', 'engineer') 0.125 8
# ('laborer', 'mechanic') 0.1111111111111111 9
# ('janitor', 'writer') 0.1111111111111111 9
# ('designer', 'engineer') 0.1111111111111111 9
# ('driver', 'mechanic') 0.1 10
# ('carpenter', 'cook') 0.1 10
# ('laborer', 'writer') 0.1 10
# ('carpenter', 'janitor') 0.09090909090909091 11
# ('carpenter', 'laborer') 0.09090909090909091 11
# ('carpenter', 'designer') 0.08333333333333333 12
# ('engineer', 'farmer') 0.07692307692307693 13

# %%
oc_error = get_single_occupation_counts(occupation_pair_error)
oc_count = get_single_occupation_counts(occupation_pair_count)

error_rate_dict = get_error_rate_dict(oc_error, 
                                      oc_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key]*100, oc_count[key])
# Out:
# engineer 51.55709342560554 289
# carpenter 46.688741721854306 302
# secretary 42.70833333333333 96
# laborer 42.081447963800905 221
# technician 40.52287581699346 153
# designer 39.366515837104075 221
# farmer 38.034188034188034 234
# assistant 37.28813559322034 118
# librarian 36.11111111111111 108
# mechanic 36.0655737704918 183
# salesperson 35.82089552238806 67
# tailor 35.41666666666667 96
# receptionist 35.294117647058826 136
# developer 34.751773049645394 141
# driver 34.73053892215569 167
# writer 34.32835820895522 201
# supervisor 34.31372549019608 102
# manager 34.146341463414636 164
# baker 33.48837209302326 215
# sheriff 33.07086614173229 127
# mover 32.17391304347826 115
# clerk 32.0 125
# accountant 31.818181818181817 110
# janitor 31.818181818181817 198
# hairdresser 31.73076923076923 104
# cleaner 31.63265306122449 98
# teacher 30.555555555555557 108
# nurse 30.158730158730158 126
# cook 29.599999999999998 125
# analyst 29.310344827586203 116
# attendant 29.292929292929294 99
# physician 28.671328671328673 143
# lawyer 28.57142857142857 133
# housekeeper 28.440366972477065 109
# paralegal 27.536231884057973 138
# cashier 27.173913043478258 92
# auditor 26.47058823529412 102
# editor 26.08695652173913 92
# chief 25.688073394495415 109
# counselor 23.52941176470588 136
# CEO 22.22222222222222 117
# guard 21.951219512195124 164

# %%
# error_rate_dict = get_error_rate_dict(occupation2_error, occupation2_count)
# for key in error_rate_dict:
#     print(key, error_rate_dict[key], occupation2_count[key])

# %%
error_rate_dict = get_error_rate_dict(action_error, action_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# can generate the report 0.11267605633802817
# the performance was unsatisfactory 0.09375
# could estimate how long the wait would be 0.07446808510638298
# can play a ukelele 0.06711409395973154
# the meat was eaten 0.05128205128205128
# the waiting times were estimated 0.034482758620689655
# the project scope had been finalised 0.034482758620689655
# could pay with cash 0.030612244897959183
# struggles with addiction 0.029411764705882353
# can do 100 push ups 0.02631578947368421
# can bake bread 0.025806451612903226
# personal goals 0.02564102564102564
# can bake cookies 0.023668639053254437
# could eat a sandwich 0.02247191011235955
# could return the paperwork 0.01904761904761905
# could help with tax preparation 0.014492753623188406
# could bake bread 0.012658227848101266
# could bake cookies 0.012048192771084338
# could help with the delivery 0.010638297872340425
# could sign the document 0.010309278350515464
# can eat meat 0.006896551724137931

# %%
error_rate_dict = get_error_rate_dict(verb_error, verb_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# asked the 0.05593220338983051
# told the 0.025889967637540454
# disclosed to the 0.01867572156196944
# spoke with the 0.016420361247947456
# notified the 0.008417508417508417
