# %%
import pickle
import matplotlib.pyplot as plt

from scipy import stats
import numpy as np


sub_folder = "Exploration"
# sub_folder = "Exploitation"

with open('saved_pickles/'+ sub_folder +'/unique_input1_set.pickle', 'rb') as handle:
    unique_input1_set = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/unique_input1_error_set.pickle', 'rb') as handle:
    unique_input1_error_set = pickle.load(handle)

with open('saved_pickles/'+ sub_folder +'/occupation_pair_count.pickle', 'rb') as handle:
    occupation_pair_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_error.pickle', 'rb') as handle:
    occupation1_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_error.pickle', 'rb') as handle:
    occupation2_error = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_error.pickle', 'rb') as handle:
    verb_error = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_error.pickle', 'rb') as handle:
    action_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation_pair_error.pickle', 'rb') as handle:
    occupation_pair_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_count.pickle', 'rb') as handle:
    occupation1_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_count.pickle', 'rb') as handle:
    occupation2_count = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_count.pickle', 'rb') as handle:
    verb_count = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_count.pickle', 'rb') as handle:
    action_count = pickle.load(handle)

# %%
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique inputs: " + str(len(unique_input1_set)))
# Out:
# Final Unique errors: 183
# Final Unique inputs: 2965

# %%
for i in list(unique_input1_error_set)[:10]:
    print (i)
# Out:
# ('The person disclosed to the farmer that he can bake cookies', 'The person disclosed to the physician that he can bake cookies')
# ('The person spoke with the CEO about his personal goals', 'The person spoke with the manager about his personal goals')
# ('The person spoke with the chief about his professional goals', 'The person spoke with the librarian about his professional goals')
# ('The person told the assistant that he could bake bread', 'The person told the manager that he could bake bread')
# ('The person asked the farmer if he could pay with cash', 'The person asked the carpenter if he could pay with cash')
# ('The person asked the mechanic if he can play a ukelele', 'The person asked the engineer if he can play a ukelele')
# ('The person disclosed to the engineer that he could return the paperwork', 'The person disclosed to the nurse that he could return the paperwork')
# ('The person asked the chief if he can generate the report', 'The person asked the clerk if he can generate the report')
# ('The person asked the librarian if he could pay with cash', 'The person asked the accountant if he could pay with cash')
# ('The person told the carpenter that he could estimate how long the wait would be', 'The person told the manager that he could estimate how long the wait would be')

# %%
def modify_equivalent_keys(init_dict):
    mod_dict = dict()
    for key in init_dict:
        mod_key = tuple(sorted(key))
        if mod_key in mod_dict:
            mod_dict[mod_key] += init_dict[key]
        else:
            mod_dict[mod_key] = init_dict[key]
    return mod_dict

# %%
def get_single_occupation_counts(init_dict):
    single_occupation_dict = dict()
    for key in init_dict:
        mod_key = sorted(key)
        for k in mod_key:
            if k in single_occupation_dict:
                single_occupation_dict[k] += init_dict[key]
            else:
                single_occupation_dict[k] = init_dict[key]
    return single_occupation_dict

# %%
def get_sorted_dict(D):
    return {k: v for k, v in sorted(D.items(), key=lambda item: item[1], reverse=1)}

# %%
def plot_bar_chart(D, chart_range):
    D = get_sorted_dict(D)
    plt.bar(range(chart_range), list(D.values())[:chart_range], align='center')
    plt.xticks(range(chart_range), list(D.keys())[:chart_range]) 
    plt.show()

# %%
def get_error_rate_dict(error_dict, count_dict):
    error_rate_dict = {}
    for key in error_dict:
        error_rate_dict[key] = error_dict[key]/count_dict[key]
    return get_sorted_dict(error_rate_dict)

# %%
def get_anamoly_scores(array):
    mad = (stats.median_absolute_deviation(array, scale='normal'))
    arr_median = np.median(array)
    arr_anamolies = [(i - arr_median)/mad for i in array]
    
    return arr_anamolies

# %%
occupation_pair_count = modify_equivalent_keys(occupation_pair_count)
occupation_pair_error = modify_equivalent_keys(occupation_pair_error)

sorted_occupation_pair_count = get_sorted_dict(occupation_pair_count)
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in sorted_occupation_pair_count:
    if key in error_rate_dict:
        error = error_rate_dict[key]
    else:
        error = 0.0
    print(key, sorted_occupation_pair_count[key], error)
# Out:
# ('accountant', 'librarian') 14 0.07142857142857142
# ('accountant', 'laborer') 12 0.0
# ('librarian', 'technician') 11 0.0
# ('librarian', 'teacher') 11 0.09090909090909091
# ('accountant', 'hairdresser') 10 0.0
# ('accountant', 'developer') 10 0.0
# ('accountant', 'construction worker') 10 0.0
# ('accountant', 'sheriff') 10 0.0
# ('librarian', 'mover') 10 0.0
# ('accountant', 'nurse') 9 0.0
# ('CEO', 'accountant') 9 0.0
# ('accountant', 'supervisor') 9 0.0
# ('lawyer', 'librarian') 9 0.0
# ('accountant', 'physician') 9 0.1111111111111111
# ('librarian', 'supervisor') 9 0.0
# ('accountant', 'paralegal') 9 0.0
# ('engineer', 'librarian') 9 0.5555555555555556
# ('chief', 'librarian') 9 0.2222222222222222
# ('laborer', 'librarian') 8 0.0
# ('manager', 'teacher') 8 0.375
# ('accountant', 'auditor') 8 0.125
# ('accountant', 'engineer') 8 0.375
# ('laborer', 'sheriff') 8 0.125
# ('accountant', 'cook') 8 0.0
# ('clerk', 'nurse') 8 0.0
# ('housekeeper', 'librarian') 8 0.0
# ('janitor', 'librarian') 8 0.0
# ('librarian', 'secretary') 8 0.0
# ('editor', 'librarian') 8 0.0
# ('counselor', 'tailor') 8 0.0
# ('carpenter', 'manager') 8 0.625
# ('cleaner', 'sheriff') 8 0.0
# ('engineer', 'paralegal') 8 0.375
# ('editor', 'salesperson') 8 0.0
# ('guard', 'salesperson') 7 0.0
# ('CEO', 'librarian') 7 0.0
# ('analyst', 'carpenter') 7 0.0
# ('CEO', 'developer') 7 0.0
# ('cook', 'housekeeper') 7 0.0
# ('accountant', 'receptionist') 7 0.0
# ('engineer', 'nurse') 7 0.2857142857142857
# ('manager', 'sheriff') 7 0.2857142857142857
# ('cook', 'sheriff') 7 0.0
# ('cook', 'physician') 7 0.0
# ('accountant', 'mechanic') 7 0.0
# ('chief', 'mechanic') 7 0.14285714285714285
# ('accountant', 'attendant') 7 0.0
# ('attendant', 'receptionist') 7 0.0
# ('janitor', 'laborer') 7 0.0
# ('designer', 'editor') 7 0.0
# ('construction worker', 'janitor') 7 0.0
# ('accountant', 'farmer') 7 0.14285714285714285
# ('CEO', 'construction worker') 7 0.0
# ('janitor', 'secretary') 7 0.0
# ('analyst', 'librarian') 7 0.0
# ('accountant', 'carpenter') 7 0.42857142857142855
# ('mechanic', 'tailor') 7 0.0
# ('attendant', 'construction worker') 7 0.0
# ('librarian', 'nurse') 7 0.0
# ('accountant', 'technician') 7 0.0
# ('farmer', 'manager') 7 0.2857142857142857
# ('baker', 'hairdresser') 7 0.0
# ('analyst', 'baker') 6 0.0
# ('accountant', 'teacher') 6 0.0
# ('hairdresser', 'lawyer') 6 0.0
# ('developer', 'writer') 6 0.0
# ('chief', 'engineer') 6 1.0
# ('farmer', 'physician') 6 0.3333333333333333
# ('librarian', 'writer') 6 0.0
# ('developer', 'manager') 6 0.3333333333333333
# ('editor', 'sheriff') 6 0.0
# ('guard', 'nurse') 6 0.0
# ('auditor', 'supervisor') 6 0.0
# ('attendant', 'cook') 6 0.0
# ('engineer', 'mechanic') 6 0.8333333333333334
# ('hairdresser', 'physician') 6 0.16666666666666666
# ('attendant', 'technician') 6 0.0
# ('carpenter', 'farmer') 6 0.16666666666666666
# ('analyst', 'manager') 6 0.16666666666666666
# ('construction worker', 'tailor') 6 0.0
# ('construction worker', 'laborer') 6 0.0
# ('driver', 'engineer') 6 0.5
# ('accountant', 'driver') 6 0.16666666666666666
# ('cleaner', 'librarian') 6 0.0
# ('baker', 'librarian') 6 0.0
# ('guard', 'mechanic') 6 0.0
# ('guard', 'janitor') 6 0.0
# ('attendant', 'editor') 6 0.0
# ('librarian', 'manager') 6 0.3333333333333333
# ('paralegal', 'sheriff') 6 0.0
# ('construction worker', 'editor') 6 0.0
# ('cleaner', 'supervisor') 6 0.0
# ('assistant', 'paralegal') 6 0.0
# ('janitor', 'receptionist') 6 0.0
# ('assistant', 'manager') 6 0.3333333333333333
# ('designer', 'physician') 6 0.0
# ('accountant', 'assistant') 6 0.0
# ('chief', 'cook') 6 0.16666666666666666
# ('designer', 'librarian') 6 0.0
# ('driver', 'librarian') 6 0.0
# ('auditor', 'paralegal') 6 0.0
# ('clerk', 'lawyer') 6 0.0
# ('housekeeper', 'paralegal') 6 0.0
# ('attendant', 'salesperson') 6 0.0
# ('accountant', 'mover') 6 0.0
# ('accountant', 'tailor') 6 0.0
# ('cashier', 'teacher') 6 0.0
# ('assistant', 'cleaner') 6 0.0
# ('developer', 'mechanic') 6 0.0
# ('farmer', 'paralegal') 6 0.3333333333333333
# ('hairdresser', 'librarian') 6 0.0
# ('cashier', 'technician') 6 0.0
# ('attendant', 'designer') 6 0.0
# ('CEO', 'mover') 6 0.0
# ('housekeeper', 'teacher') 6 0.0
# ('lawyer', 'supervisor') 6 0.0
# ('attendant', 'baker') 6 0.0
# ('counselor', 'librarian') 6 0.0
# ('assistant', 'editor') 6 0.0
# ('farmer', 'librarian') 6 0.3333333333333333
# ('baker', 'engineer') 6 0.3333333333333333
# ('librarian', 'receptionist') 6 0.0
# ('accountant', 'guard') 6 0.0
# ('carpenter', 'cook') 6 0.0
# ('accountant', 'designer') 6 0.16666666666666666
# ('carpenter', 'guard') 6 0.0
# ('accountant', 'chief') 5 0.0
# ('clerk', 'librarian') 5 0.0
# ('engineer', 'supervisor') 5 0.0
# ('editor', 'writer') 5 0.0
# ('carpenter', 'teacher') 5 0.2
# ('farmer', 'nurse') 5 0.0
# ('CEO', 'laborer') 5 0.0
# ('CEO', 'designer') 5 0.0
# ('cashier', 'janitor') 5 0.0
# ('attendant', 'sheriff') 5 0.0
# ('cashier', 'guard') 5 0.0
# ('paralegal', 'physician') 5 0.0
# ('analyst', 'lawyer') 5 0.0
# ('CEO', 'clerk') 5 0.0
# ('developer', 'hairdresser') 5 0.0
# ('assistant', 'chief') 5 0.0
# ('janitor', 'lawyer') 5 0.0
# ('attendant', 'mechanic') 5 0.0
# ('chief', 'developer') 5 0.0
# ('librarian', 'sheriff') 5 0.0
# ('analyst', 'tailor') 5 0.0
# ('carpenter', 'physician') 5 0.2
# ('assistant', 'driver') 5 0.0
# ('designer', 'housekeeper') 5 0.0
# ('developer', 'physician') 5 0.0
# ('cook', 'janitor') 5 0.0
# ('analyst', 'secretary') 5 0.0
# ('chief', 'driver') 5 0.0
# ('receptionist', 'supervisor') 5 0.0
# ('analyst', 'designer') 5 0.0
# ('developer', 'librarian') 5 0.0
# ('analyst', 'janitor') 5 0.0
# ('accountant', 'editor') 5 0.0
# ('laborer', 'mechanic') 5 0.0
# ('librarian', 'tailor') 5 0.0
# ('counselor', 'manager') 5 0.2
# ('cashier', 'writer') 5 0.0
# ('editor', 'engineer') 5 0.6
# ('guard', 'librarian') 5 0.0
# ('manager', 'tailor') 5 0.8
# ('developer', 'tailor') 5 0.0
# ('librarian', 'mechanic') 5 0.2
# ('housekeeper', 'technician') 5 0.0
# ('cashier', 'mover') 5 0.0
# ('editor', 'laborer') 5 0.0
# ('guard', 'supervisor') 5 0.0
# ('cleaner', 'technician') 5 0.0
# ('chief', 'physician') 5 0.0
# ('analyst', 'developer') 5 0.0
# ('guard', 'laborer') 5 0.0
# ('assistant', 'mechanic') 5 0.2
# ('baker', 'mechanic') 5 0.0
# ('clerk', 'physician') 5 0.0
# ('janitor', 'manager') 5 0.6
# ('clerk', 'secretary') 5 0.2
# ('counselor', 'housekeeper') 5 0.0
# ('guard', 'technician') 5 0.0
# ('baker', 'clerk') 5 0.0
# ('cashier', 'mechanic') 5 0.0
# ('analyst', 'physician') 5 0.0
# ('cook', 'guard') 5 0.0
# ('clerk', 'designer') 5 0.0
# ('cleaner', 'teacher') 5 0.0
# ('clerk', 'sheriff') 5 0.0
# ('cook', 'counselor') 5 0.0
# ('assistant', 'secretary') 5 0.0
# ('housekeeper', 'manager') 5 0.2
# ('cashier', 'cook') 5 0.0
# ('chief', 'housekeeper') 5 0.0
# ('assistant', 'cashier') 5 0.0
# ('cleaner', 'secretary') 5 0.2
# ('carpenter', 'janitor') 5 0.0
# ('accountant', 'writer') 5 0.0
# ('attendant', 'carpenter') 5 0.0
# ('carpenter', 'paralegal') 5 0.0
# ('analyst', 'hairdresser') 5 0.0
# ('receptionist', 'tailor') 5 0.0
# ('editor', 'technician') 5 0.0
# ('construction worker', 'housekeeper') 5 0.0
# ('mechanic', 'supervisor') 5 0.0
# ('auditor', 'librarian') 5 0.0
# ('auditor', 'tailor') 5 0.0
# ('attendant', 'laborer') 5 0.0
# ('baker', 'teacher') 5 0.0
# ('tailor', 'teacher') 5 0.0
# ('supervisor', 'tailor') 5 0.0
# ('carpenter', 'librarian') 5 0.0
# ('guard', 'housekeeper') 5 0.0
# ('guard', 'manager') 5 0.2
# ('lawyer', 'nurse') 5 0.0
# ('analyst', 'teacher') 5 0.0
# ('baker', 'manager') 5 0.6
# ('counselor', 'driver') 5 0.0
# ('carpenter', 'receptionist') 5 0.0
# ('CEO', 'cleaner') 5 0.0
# ('engineer', 'physician') 5 0.0
# ('auditor', 'chief') 5 0.2
# ('analyst', 'cook') 5 0.0
# ('CEO', 'housekeeper') 5 0.0
# ('carpenter', 'designer') 5 0.0
# ('counselor', 'salesperson') 5 0.0
# ('laborer', 'tailor') 5 0.0
# ('developer', 'engineer') 5 0.4
# ('engineer', 'guard') 5 0.6
# ('hairdresser', 'writer') 5 0.0
# ('accountant', 'salesperson') 5 0.2
# ('counselor', 'sheriff') 5 0.0
# ('mechanic', 'receptionist') 5 0.4
# ('manager', 'physician') 5 0.2
# ('baker', 'supervisor') 5 0.0
# ('clerk', 'janitor') 5 0.0
# ('chief', 'manager') 4 0.25
# ('driver', 'physician') 4 0.0
# ('housekeeper', 'supervisor') 4 0.0
# ('engineer', 'salesperson') 4 0.25
# ('construction worker', 'sheriff') 4 0.0
# ('assistant', 'construction worker') 4 0.0
# ('carpenter', 'secretary') 4 0.25
# ('cook', 'tailor') 4 0.0
# ('analyst', 'receptionist') 4 0.0
# ('baker', 'janitor') 4 0.0
# ('janitor', 'salesperson') 4 0.0
# ('mover', 'sheriff') 4 0.0
# ('CEO', 'engineer') 4 0.0
# ('lawyer', 'secretary') 4 0.0
# ('chief', 'tailor') 4 0.0
# ('assistant', 'mover') 4 0.0
# ('clerk', 'receptionist') 4 0.0
# ('developer', 'editor') 4 0.0
# ('analyst', 'paralegal') 4 0.0
# ('auditor', 'guard') 4 0.0
# ('paralegal', 'secretary') 4 0.0
# ('engineer', 'mover') 4 0.25
# ('hairdresser', 'mover') 4 0.0
# ('chief', 'guard') 4 0.0
# ('laborer', 'mover') 4 0.0
# ('mover', 'teacher') 4 0.0
# ('secretary', 'supervisor') 4 0.0
# ('laborer', 'technician') 4 0.0
# ('nurse', 'supervisor') 4 0.0
# ('attendant', 'mover') 4 0.0
# ('paralegal', 'writer') 4 0.0
# ('baker', 'cook') 4 0.0
# ('developer', 'driver') 4 0.0
# ('librarian', 'librarian') 4 0.0
# ('construction worker', 'hairdresser') 4 0.0
# ('CEO', 'driver') 4 0.0
# ('developer', 'housekeeper') 4 0.0
# ('clerk', 'tailor') 4 0.0
# ('lawyer', 'tailor') 4 0.25
# ('accountant', 'janitor') 4 0.25
# ('laborer', 'receptionist') 4 0.0
# ('chief', 'secretary') 4 0.0
# ('mover', 'writer') 4 0.0
# ('nurse', 'sheriff') 4 0.0
# ('guard', 'physician') 4 0.25
# ('housekeeper', 'secretary') 4 0.0
# ('housekeeper', 'salesperson') 4 0.0
# ('cleaner', 'counselor') 4 0.0
# ('assistant', 'janitor') 4 0.0
# ('auditor', 'clerk') 4 0.0
# ('CEO', 'analyst') 4 0.0
# ('carpenter', 'tailor') 4 0.0
# ('accountant', 'clerk') 4 0.0
# ('designer', 'tailor') 4 0.0
# ('nurse', 'receptionist') 4 0.0
# ('guard', 'writer') 4 0.0
# ('accountant', 'analyst') 4 0.0
# ('guard', 'paralegal') 4 0.0
# ('cook', 'manager') 4 0.25
# ('carpenter', 'editor') 4 0.0
# ('sheriff', 'supervisor') 4 0.0
# ('farmer', 'salesperson') 4 0.5
# ('baker', 'driver') 4 0.0
# ('physician', 'receptionist') 4 0.0
# ('designer', 'technician') 4 0.0
# ('cashier', 'manager') 4 0.25
# ('driver', 'teacher') 4 0.0
# ('attendant', 'teacher') 4 0.0
# ('accountant', 'housekeeper') 4 0.0
# ('attendant', 'supervisor') 4 0.0
# ('cashier', 'housekeeper') 4 0.0
# ('hairdresser', 'janitor') 4 0.0
# ('mechanic', 'physician') 4 0.0
# ('assistant', 'developer') 4 0.0
# ('physician', 'supervisor') 4 0.0
# ('assistant', 'clerk') 4 0.0
# ('tailor', 'technician') 4 0.0
# ('designer', 'nurse') 4 0.0
# ('CEO', 'technician') 4 0.0
# ('counselor', 'guard') 4 0.0
# ('cashier', 'librarian') 4 0.0
# ('CEO', 'lawyer') 4 0.25
# ('assistant', 'lawyer') 4 0.0
# ('counselor', 'paralegal') 4 0.0
# ('hairdresser', 'mechanic') 4 0.0
# ('cleaner', 'driver') 4 0.0
# ('farmer', 'writer') 4 0.25
# ('cleaner', 'janitor') 4 0.0
# ('housekeeper', 'lawyer') 4 0.0
# ('baker', 'designer') 4 0.0
# ('developer', 'secretary') 4 0.0
# ('chief', 'clerk') 4 0.25
# ('counselor', 'engineer') 4 0.25
# ('mover', 'physician') 4 0.0
# ('laborer', 'paralegal') 4 0.0
# ('attendant', 'lawyer') 4 0.0
# ('janitor', 'technician') 4 0.0
# ('lawyer', 'physician') 4 0.0
# ('guard', 'lawyer') 4 0.0
# ('assistant', 'counselor') 4 0.0
# ('assistant', 'carpenter') 4 0.0
# ('cleaner', 'mover') 4 0.0
# ('cook', 'writer') 4 0.0
# ('cleaner', 'mechanic') 4 0.0
# ('construction worker', 'cook') 4 0.0
# ('assistant', 'receptionist') 4 0.0
# ('cashier', 'physician') 4 0.0
# ('auditor', 'counselor') 4 0.0
# ('mover', 'tailor') 4 0.0
# ('attendant', 'cashier') 4 0.0
# ('driver', 'manager') 4 0.75
# ('analyst', 'salesperson') 4 0.0
# ('attendant', 'hairdresser') 4 0.0
# ('counselor', 'receptionist') 4 0.0
# ('clerk', 'manager') 4 0.5
# ('librarian', 'salesperson') 4 0.0
# ('accountant', 'lawyer') 4 0.0
# ('analyst', 'cleaner') 4 0.0
# ('clerk', 'guard') 4 0.0
# ('sheriff', 'writer') 4 0.0
# ('counselor', 'teacher') 4 0.0
# ('engineer', 'receptionist') 4 0.25
# ('clerk', 'driver') 4 0.0
# ('cook', 'hairdresser') 4 0.0
# ('CEO', 'janitor') 4 0.0
# ('CEO', 'hairdresser') 4 0.0
# ('technician', 'writer') 4 0.0
# ('assistant', 'farmer') 4 0.0
# ('attendant', 'driver') 4 0.0
# ('CEO', 'sheriff') 4 0.0
# ('mechanic', 'writer') 3 0.3333333333333333
# ('cook', 'receptionist') 3 0.0
# ('auditor', 'construction worker') 3 0.0
# ('driver', 'nurse') 3 0.0
# ('assistant', 'attendant') 3 0.0
# ('construction worker', 'engineer') 3 0.0
# ('auditor', 'baker') 3 0.0
# ('cashier', 'salesperson') 3 0.0
# ('attendant', 'chief') 3 0.3333333333333333
# ('auditor', 'sheriff') 3 0.0
# ('baker', 'cashier') 3 0.0
# ('cashier', 'lawyer') 3 0.0
# ('clerk', 'laborer') 3 0.0
# ('editor', 'mover') 3 0.0
# ('baker', 'housekeeper') 3 0.0
# ('cleaner', 'tailor') 3 0.0
# ('attendant', 'writer') 3 0.0
# ('carpenter', 'nurse') 3 0.0
# ('editor', 'housekeeper') 3 0.0
# ('cook', 'farmer') 3 0.0
# ('counselor', 'hairdresser') 3 0.0
# ('cleaner', 'housekeeper') 3 0.0
# ('engineer', 'writer') 3 0.3333333333333333
# ('cook', 'salesperson') 3 0.0
# ('cleaner', 'construction worker') 3 0.0
# ('cook', 'secretary') 3 0.3333333333333333
# ('farmer', 'teacher') 3 0.3333333333333333
# ('attendant', 'manager') 3 0.0
# ('salesperson', 'tailor') 3 0.0
# ('farmer', 'mechanic') 3 0.6666666666666666
# ('auditor', 'housekeeper') 3 0.0
# ('guard', 'receptionist') 3 0.0
# ('editor', 'supervisor') 3 0.0
# ('designer', 'hairdresser') 3 0.0
# ('counselor', 'nurse') 3 0.0
# ('editor', 'secretary') 3 0.0
# ('chief', 'receptionist') 3 0.0
# ('driver', 'writer') 3 0.0
# ('attendant', 'secretary') 3 0.0
# ('chief', 'farmer') 3 0.3333333333333333
# ('mechanic', 'sheriff') 3 0.0
# ('housekeeper', 'nurse') 3 0.0
# ('janitor', 'mover') 3 0.0
# ('nurse', 'technician') 3 0.0
# ('chief', 'laborer') 3 0.0
# ('salesperson', 'teacher') 3 0.3333333333333333
# ('editor', 'hairdresser') 3 0.0
# ('salesperson', 'technician') 3 0.0
# ('designer', 'mechanic') 3 0.0
# ('laborer', 'writer') 3 0.0
# ('hairdresser', 'supervisor') 3 0.0
# ('driver', 'sheriff') 3 0.0
# ('cook', 'nurse') 3 0.0
# ('CEO', 'manager') 3 0.3333333333333333
# ('librarian', 'paralegal') 3 0.0
# ('janitor', 'supervisor') 3 0.0
# ('engineer', 'sheriff') 3 0.0
# ('construction worker', 'teacher') 3 0.0
# ('supervisor', 'technician') 3 0.0
# ('baker', 'lawyer') 3 0.0
# ('editor', 'mechanic') 3 0.0
# ('analyst', 'housekeeper') 3 0.0
# ('farmer', 'receptionist') 3 0.0
# ('engineer', 'laborer') 3 0.0
# ('cook', 'editor') 3 0.0
# ('paralegal', 'supervisor') 3 0.0
# ('housekeeper', 'physician') 3 0.0
# ('developer', 'teacher') 3 0.0
# ('carpenter', 'salesperson') 3 0.0
# ('counselor', 'laborer') 3 0.3333333333333333
# ('editor', 'tailor') 3 0.0
# ('mechanic', 'mover') 3 0.0
# ('chief', 'sheriff') 3 0.3333333333333333
# ('counselor', 'designer') 3 0.0
# ('mechanic', 'technician') 3 0.0
# ('editor', 'physician') 3 0.0
# ('mechanic', 'paralegal') 3 0.0
# ('cleaner', 'lawyer') 3 0.0
# ('designer', 'guard') 3 0.0
# ('baker', 'salesperson') 3 0.0
# ('CEO', 'editor') 3 0.0
# ('counselor', 'editor') 3 0.0
# ('laborer', 'manager') 3 0.3333333333333333
# ('carpenter', 'developer') 3 0.0
# ('physician', 'teacher') 3 0.0
# ('construction worker', 'manager') 3 0.3333333333333333
# ('counselor', 'janitor') 3 0.0
# ('cook', 'engineer') 3 0.0
# ('nurse', 'writer') 3 0.0
# ('assistant', 'nurse') 3 0.0
# ('physician', 'technician') 3 0.0
# ('driver', 'mechanic') 3 0.0
# ('auditor', 'hairdresser') 3 0.0
# ('driver', 'guard') 3 0.0
# ('accountant', 'cleaner') 3 0.0
# ('cook', 'librarian') 3 0.0
# ('cook', 'teacher') 3 0.0
# ('janitor', 'mechanic') 3 0.0
# ('salesperson', 'secretary') 3 0.3333333333333333
# ('cashier', 'designer') 3 0.0
# ('clerk', 'engineer') 3 0.6666666666666666
# ('cashier', 'tailor') 3 0.0
# ('designer', 'engineer') 3 0.0
# ('housekeeper', 'mechanic') 3 0.0
# ('auditor', 'teacher') 3 0.3333333333333333
# ('carpenter', 'mover') 3 0.0
# ('farmer', 'supervisor') 3 0.0
# ('driver', 'housekeeper') 3 0.0
# ('CEO', 'tailor') 3 0.0
# ('cashier', 'counselor') 3 0.0
# ('analyst', 'assistant') 3 0.0
# ('manager', 'nurse') 3 0.6666666666666666
# ('designer', 'salesperson') 3 0.0
# ('physician', 'salesperson') 3 0.0
# ('farmer', 'housekeeper') 3 0.3333333333333333
# ('cleaner', 'designer') 3 0.0
# ('mechanic', 'teacher') 3 0.0
# ('construction worker', 'secretary') 3 0.3333333333333333
# ('cashier', 'construction worker') 3 0.0
# ('attendant', 'developer') 3 0.0
# ('cleaner', 'cook') 3 0.0
# ('assistant', 'hairdresser') 3 0.0
# ('carpenter', 'technician') 3 0.0
# ('accountant', 'baker') 3 0.0
# ('manager', 'receptionist') 3 0.0
# ('carpenter', 'counselor') 3 0.0
# ('hairdresser', 'housekeeper') 3 0.0
# ('designer', 'supervisor') 3 0.0
# ('mover', 'secretary') 3 0.0
# ('manager', 'paralegal') 3 0.6666666666666666
# ('hairdresser', 'manager') 3 0.0
# ('chief', 'designer') 3 0.0
# ('CEO', 'receptionist') 3 0.0
# ('counselor', 'supervisor') 3 0.0
# ('salesperson', 'sheriff') 3 0.0
# ('janitor', 'tailor') 3 0.0
# ('farmer', 'laborer') 3 0.0
# ('janitor', 'paralegal') 3 0.0
# ('baker', 'paralegal') 3 0.0
# ('carpenter', 'chief') 3 0.0
# ('clerk', 'editor') 3 0.0
# ('guard', 'tailor') 3 0.0
# ('analyst', 'mover') 3 0.0
# ('counselor', 'secretary') 3 0.0
# ('receptionist', 'secretary') 3 0.0
# ('designer', 'manager') 3 0.0
# ('analyst', 'attendant') 3 0.0
# ('farmer', 'tailor') 3 0.3333333333333333
# ('mover', 'salesperson') 3 0.0
# ('lawyer', 'salesperson') 3 0.0
# ('cook', 'developer') 3 0.0
# ('cleaner', 'nurse') 3 0.0
# ('baker', 'construction worker') 3 0.0
# ('cleaner', 'writer') 3 0.0
# ('developer', 'mover') 3 0.0
# ('analyst', 'guard') 3 0.0
# ('analyst', 'clerk') 3 0.0
# ('manager', 'salesperson') 3 0.3333333333333333
# ('driver', 'lawyer') 3 0.0
# ('counselor', 'technician') 3 0.0
# ('secretary', 'technician') 3 0.0
# ('janitor', 'sheriff') 3 0.0
# ('construction worker', 'librarian') 3 0.0
# ('hairdresser', 'tailor') 3 0.0
# ('engineer', 'tailor') 3 0.3333333333333333
# ('designer', 'paralegal') 3 0.0
# ('baker', 'writer') 3 0.0
# ('cashier', 'driver') 3 0.0
# ('cleaner', 'hairdresser') 3 0.0
# ('lawyer', 'paralegal') 3 0.0
# ('developer', 'paralegal') 3 0.0
# ('hairdresser', 'secretary') 3 0.0
# ('editor', 'teacher') 3 0.0
# ('designer', 'sheriff') 3 0.0
# ('carpenter', 'mechanic') 3 0.0
# ('carpenter', 'cashier') 3 0.0
# ('housekeeper', 'laborer') 3 0.0
# ('assistant', 'engineer') 3 0.3333333333333333
# ('manager', 'technician') 3 0.6666666666666666
# ('engineer', 'janitor') 3 0.6666666666666666
# ('guard', 'mover') 3 0.0
# ('CEO', 'paralegal') 3 0.0
# ('sheriff', 'teacher') 3 0.0
# ('paralegal', 'tailor') 3 0.0
# ('nurse', 'salesperson') 2 0.0
# ('engineer', 'technician') 2 1.0
# ('carpenter', 'housekeeper') 2 0.0
# ('counselor', 'lawyer') 2 0.0
# ('analyst', 'chief') 2 0.0
# ('construction worker', 'salesperson') 2 0.0
# ('engineer', 'hairdresser') 2 0.5
# ('assistant', 'designer') 2 0.0
# ('attendant', 'auditor') 2 0.0
# ('auditor', 'developer') 2 0.0
# ('chief', 'hairdresser') 2 0.0
# ('cleaner', 'editor') 2 0.0
# ('driver', 'farmer') 2 0.0
# ('paralegal', 'technician') 2 0.0
# ('carpenter', 'writer') 2 0.0
# ('counselor', 'mechanic') 2 0.0
# ('attendant', 'tailor') 2 0.0
# ('farmer', 'mover') 2 0.0
# ('designer', 'mover') 2 0.0
# ('cashier', 'engineer') 2 0.0
# ('carpenter', 'lawyer') 2 0.0
# ('cleaner', 'manager') 2 0.5
# ('chief', 'lawyer') 2 0.0
# ('construction worker', 'supervisor') 2 0.0
# ('CEO', 'carpenter') 2 0.0
# ('carpenter', 'laborer') 2 0.0
# ('manager', 'secretary') 2 1.0
# ('hairdresser', 'salesperson') 2 0.0
# ('designer', 'teacher') 2 0.0
# ('cashier', 'editor') 2 0.0
# ('laborer', 'teacher') 2 0.0
# ('receptionist', 'teacher') 2 0.0
# ('auditor', 'engineer') 2 0.0
# ('auditor', 'cook') 2 0.0
# ('assistant', 'sheriff') 2 0.0
# ('clerk', 'salesperson') 2 0.0
# ('mechanic', 'salesperson') 2 0.0
# ('analyst', 'engineer') 2 0.5
# ('designer', 'janitor') 2 0.0
# ('guard', 'sheriff') 2 0.0
# ('construction worker', 'mechanic') 2 0.0
# ('clerk', 'cook') 2 0.0
# ('analyst', 'farmer') 2 0.0
# ('assistant', 'guard') 2 0.0
# ('clerk', 'teacher') 2 0.0
# ('assistant', 'physician') 2 0.0
# ('salesperson', 'supervisor') 2 0.0
# ('accountant', 'counselor') 2 0.0
# ('cleaner', 'developer') 2 0.0
# ('construction worker', 'designer') 2 0.0
# ('auditor', 'cashier') 2 0.0
# ('cashier', 'laborer') 2 0.0
# ('laborer', 'secretary') 2 0.0
# ('assistant', 'librarian') 2 0.0
# ('janitor', 'physician') 2 0.5
# ('farmer', 'janitor') 2 0.0
# ('editor', 'nurse') 2 0.0
# ('salesperson', 'writer') 2 0.0
# ('construction worker', 'technician') 2 0.0
# ('chief', 'writer') 2 0.0
# ('designer', 'farmer') 2 0.5
# ('auditor', 'receptionist') 2 0.0
# ('nurse', 'secretary') 2 0.0
# ('counselor', 'physician') 2 0.0
# ('cook', 'supervisor') 2 0.0
# ('CEO', 'chief') 2 0.0
# ('CEO', 'cashier') 2 0.0
# ('hairdresser', 'nurse') 2 0.0
# ('lawyer', 'sheriff') 2 0.0
# ('driver', 'hairdresser') 2 0.0
# ('receptionist', 'sheriff') 2 0.0
# ('mover', 'technician') 2 0.0
# ('developer', 'janitor') 2 0.0
# ('accountant', 'secretary') 2 0.0
# ('nurse', 'tailor') 2 0.0
# ('farmer', 'technician') 2 0.5
# ('chief', 'cleaner') 2 0.0
# ('chief', 'technician') 2 0.0
# ('accountant', 'cashier') 2 0.0
# ('CEO', 'auditor') 2 0.0
# ('clerk', 'mechanic') 2 0.0
# ('paralegal', 'receptionist') 2 0.0
# ('clerk', 'counselor') 2 0.0
# ('laborer', 'salesperson') 2 0.0
# ('analyst', 'auditor') 2 0.0
# ('sheriff', 'tailor') 2 0.0
# ('editor', 'farmer') 2 0.0
# ('cashier', 'cleaner') 2 0.0
# ('carpenter', 'cleaner') 2 0.0
# ('engineer', 'lawyer') 2 0.0
# ('analyst', 'supervisor') 2 0.0
# ('janitor', 'teacher') 2 0.0
# ('manager', 'mechanic') 2 1.0
# ('analyst', 'technician') 2 0.0
# ('clerk', 'technician') 2 0.0
# ('CEO', 'salesperson') 2 0.0
# ('lawyer', 'manager') 2 1.0
# ('driver', 'technician') 2 0.0
# ('counselor', 'writer') 2 0.0
# ('assistant', 'housekeeper') 2 0.0
# ('counselor', 'farmer') 2 0.0
# ('attendant', 'clerk') 2 0.0
# ('chief', 'paralegal') 2 0.0
# ('laborer', 'physician') 2 0.5
# ('driver', 'mover') 2 0.0
# ('attendant', 'cleaner') 2 0.0
# ('manager', 'supervisor') 2 1.0
# ('laborer', 'lawyer') 2 0.0
# ('farmer', 'sheriff') 2 0.5
# ('analyst', 'writer') 2 0.0
# ('driver', 'receptionist') 2 0.0
# ('auditor', 'salesperson') 2 0.0
# ('housekeeper', 'mover') 2 0.0
# ('analyst', 'counselor') 2 0.0
# ('baker', 'nurse') 2 0.0
# ('farmer', 'secretary') 2 0.5
# ('janitor', 'writer') 2 0.0
# ('CEO', 'guard') 2 0.0
# ('developer', 'technician') 2 0.0
# ('guard', 'secretary') 2 0.0
# ('engineer', 'secretary') 2 0.0
# ('lawyer', 'receptionist') 2 0.0
# ('driver', 'tailor') 2 0.0
# ('cook', 'mover') 2 0.0
# ('auditor', 'technician') 2 0.0
# ('attendant', 'physician') 2 0.0
# ('receptionist', 'writer') 2 0.0
# ('attendant', 'librarian') 2 0.0
# ('assistant', 'salesperson') 2 0.0
# ('driver', 'secretary') 2 0.0
# ('mover', 'receptionist') 2 0.0
# ('engineer', 'manager') 2 0.5
# ('auditor', 'lawyer') 2 0.0
# ('clerk', 'paralegal') 2 0.0
# ('accountant', 'manager') 2 0.0
# ('developer', 'salesperson') 2 0.0
# ('cook', 'paralegal') 2 0.0
# ('CEO', 'mechanic') 2 0.0
# ('engineer', 'housekeeper') 2 1.0
# ('construction worker', 'nurse') 2 0.0
# ('cleaner', 'laborer') 2 0.0
# ('developer', 'lawyer') 2 0.0
# ('assistant', 'baker') 2 0.0
# ('construction worker', 'receptionist') 2 0.0
# ('baker', 'chief') 2 0.0
# ('clerk', 'writer') 2 0.0
# ('driver', 'laborer') 2 0.0
# ('hairdresser', 'laborer') 2 0.0
# ('auditor', 'manager') 2 0.5
# ('secretary', 'sheriff') 2 0.0
# ('baker', 'laborer') 2 0.0
# ('developer', 'supervisor') 2 0.0
# ('lawyer', 'mover') 2 0.0
# ('auditor', 'physician') 2 0.0
# ('attendant', 'paralegal') 2 0.0
# ('farmer', 'lawyer') 2 0.5
# ('housekeeper', 'tailor') 2 0.0
# ('editor', 'manager') 2 0.0
# ('chief', 'teacher') 2 0.0
# ('mechanic', 'secretary') 2 0.0
# ('CEO', 'writer') 2 0.0
# ('chief', 'salesperson') 2 0.5
# ('guard', 'teacher') 2 0.0
# ('librarian', 'physician') 2 0.0
# ('teacher', 'technician') 2 0.0
# ('analyst', 'editor') 2 0.0
# ('developer', 'receptionist') 2 0.0
# ('baker', 'receptionist') 2 0.0
# ('housekeeper', 'writer') 2 0.0
# ('construction worker', 'paralegal') 2 0.0
# ('farmer', 'hairdresser') 2 1.0
# ('driver', 'editor') 2 0.0
# ('auditor', 'laborer') 2 0.0
# ('cleaner', 'farmer') 2 0.0
# ('hairdresser', 'paralegal') 2 0.0
# ('secretary', 'tailor') 2 0.0
# ('construction worker', 'mover') 2 0.0
# ('baker', 'counselor') 2 0.0
# ('construction worker', 'developer') 2 0.0
# ('engineer', 'teacher') 2 0.0
# ('chief', 'construction worker') 2 0.0
# ('cleaner', 'physician') 2 0.0
# ('cleaner', 'clerk') 2 0.0
# ('accountant', 'accountant') 1 0.0
# ('clerk', 'developer') 1 0.0
# ('laborer', 'nurse') 1 0.0
# ('clerk', 'supervisor') 1 0.0
# ('chief', 'mover') 1 0.0
# ('cashier', 'clerk') 1 0.0
# ('carpenter', 'construction worker') 1 0.0
# ('attendant', 'nurse') 1 0.0
# ('construction worker', 'writer') 1 0.0
# ('hairdresser', 'sheriff') 1 0.0
# ('construction worker', 'physician') 1 0.0
# ('hairdresser', 'teacher') 1 0.0
# ('CEO', 'counselor') 1 0.0
# ('baker', 'technician') 1 0.0
# ('attendant', 'counselor') 1 0.0
# ('analyst', 'construction worker') 1 0.0
# ('teacher', 'writer') 1 0.0
# ('janitor', 'nurse') 1 0.0
# ('CEO', 'baker') 1 0.0
# ('lawyer', 'teacher') 1 0.0
# ('farmer', 'guard') 1 0.0
# ('construction worker', 'counselor') 1 0.0
# ('cashier', 'nurse') 1 0.0
# ('analyst', 'laborer') 1 0.0
# ('tailor', 'writer') 1 0.0
# ('auditor', 'driver') 1 0.0
# ('assistant', 'laborer') 1 0.0
# ('attendant', 'janitor') 1 0.0
# ('assistant', 'teacher') 1 0.0
# ('auditor', 'secretary') 1 0.0
# ('manager', 'mover') 1 0.0
# ('designer', 'driver') 1 0.0
# ('cleaner', 'salesperson') 1 0.0
# ('chief', 'janitor') 1 0.0
# ('designer', 'receptionist') 1 0.0
# ('baker', 'sheriff') 1 0.0
# ('developer', 'farmer') 1 0.0
# ('receptionist', 'salesperson') 1 0.0
# ('analyst', 'cashier') 1 0.0
# ('editor', 'janitor') 1 0.0
# ('supervisor', 'teacher') 1 0.0
# ('cashier', 'paralegal') 1 0.0
# ('clerk', 'construction worker') 1 0.0
# ('designer', 'developer') 1 0.0
# ('cashier', 'sheriff') 1 0.0
# ('cashier', 'chief') 1 0.0
# ('editor', 'lawyer') 1 0.0
# ('cashier', 'secretary') 1 0.0
# ('CEO', 'cook') 1 0.0
# ('assistant', 'supervisor') 1 0.0
# ('chief', 'counselor') 1 0.0
# ('cleaner', 'paralegal') 1 0.0
# ('paralegal', 'teacher') 1 0.0
# ('analyst', 'nurse') 1 0.0
# ('analyst', 'driver') 1 0.0
# ('supervisor', 'writer') 1 0.0
# ('secretary', 'teacher') 1 0.0
# ('carpenter', 'engineer') 1 0.0
# ('cook', 'driver') 1 0.0
# ('receptionist', 'technician') 1 0.0
# ('mover', 'paralegal') 1 0.0
# ('clerk', 'mover') 1 0.0
# ('baker', 'guard') 1 0.0
# ('paralegal', 'salesperson') 1 0.0
# ('nurse', 'teacher') 1 0.0
# ('sheriff', 'technician') 1 0.0
# ('cook', 'mechanic') 1 0.0
# ('lawyer', 'technician') 1 0.0
# ('baker', 'physician') 1 0.0
# ('housekeeper', 'sheriff') 1 0.0
# ('nurse', 'physician') 1 0.0
# ('baker', 'secretary') 1 0.0
# ('secretary', 'writer') 1 0.0
# ('carpenter', 'hairdresser') 1 0.0
# ('cook', 'lawyer') 1 0.0
# ('carpenter', 'driver') 1 0.0
# ('laborer', 'supervisor') 1 0.0
# ('physician', 'secretary') 1 0.0
# ('mover', 'nurse') 1 0.0
# ('attendant', 'housekeeper') 1 0.0
# ('housekeeper', 'receptionist') 1 0.0
# ('cook', 'designer') 1 0.0
# ('CEO', 'assistant') 1 0.0
# ('physician', 'writer') 1 0.0
# ('baker', 'editor') 1 0.0
# ('baker', 'tailor') 1 0.0
# ('assistant', 'tailor') 1 0.0
# ('cashier', 'receptionist') 1 0.0
# ('attendant', 'engineer') 1 0.0
# ('baker', 'carpenter') 1 0.0
# ('cleaner', 'engineer') 1 0.0
# ('counselor', 'mover') 1 0.0
# ('cashier', 'supervisor') 1 0.0
# ('cashier', 'developer') 1 0.0
# ('auditor', 'farmer') 1 0.0
# ('carpenter', 'clerk') 1 0.0
# ('carpenter', 'sheriff') 1 0.0
# ('CEO', 'nurse') 1 0.0
# ('counselor', 'developer') 1 0.0
# ('CEO', 'farmer') 1 0.0
# ('CEO', 'supervisor') 1 0.0
# ('lawyer', 'mechanic') 1 0.0
# ('chief', 'supervisor') 1 0.0
# ('attendant', 'farmer') 1 0.0
# ('analyst', 'mechanic') 1 0.0
# ('guard', 'hairdresser') 1 0.0
# ('engineer', 'farmer') 1 1.0
# ('chief', 'editor') 1 0.0
# ('cleaner', 'receptionist') 1 0.0
# ('designer', 'secretary') 1 0.0
# ('hairdresser', 'technician') 1 0.0
# ('attendant', 'guard') 1 0.0
# ('manager', 'writer') 1 1.0
# ('CEO', 'physician') 1 0.0
# ('cashier', 'hairdresser') 1 0.0
# ('developer', 'laborer') 1 0.0
# ('designer', 'laborer') 1 0.0
# ('cashier', 'farmer') 1 0.0
# ('driver', 'paralegal') 1 0.0
# ('developer', 'guard') 1 0.0

# %%
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], sorted_occupation_pair_count[key])
# Out:
# ('engineer', 'technician') 1.0 2
# ('chief', 'engineer') 1.0 6
# ('manager', 'secretary') 1.0 2
# ('manager', 'mechanic') 1.0 2
# ('lawyer', 'manager') 1.0 2
# ('manager', 'supervisor') 1.0 2
# ('engineer', 'housekeeper') 1.0 2
# ('farmer', 'hairdresser') 1.0 2
# ('engineer', 'farmer') 1.0 1
# ('manager', 'writer') 1.0 1
# ('engineer', 'mechanic') 0.8333333333333334 6
# ('manager', 'tailor') 0.8 5
# ('driver', 'manager') 0.75 4
# ('farmer', 'mechanic') 0.6666666666666666 3
# ('clerk', 'engineer') 0.6666666666666666 3
# ('manager', 'nurse') 0.6666666666666666 3
# ('manager', 'paralegal') 0.6666666666666666 3
# ('manager', 'technician') 0.6666666666666666 3
# ('engineer', 'janitor') 0.6666666666666666 3
# ('carpenter', 'manager') 0.625 8
# ('janitor', 'manager') 0.6 5
# ('baker', 'manager') 0.6 5
# ('editor', 'engineer') 0.6 5
# ('engineer', 'guard') 0.6 5
# ('engineer', 'librarian') 0.5555555555555556 9
# ('analyst', 'engineer') 0.5 2
# ('driver', 'engineer') 0.5 6
# ('laborer', 'physician') 0.5 2
# ('farmer', 'secretary') 0.5 2
# ('engineer', 'manager') 0.5 2
# ('clerk', 'manager') 0.5 4
# ('farmer', 'salesperson') 0.5 4
# ('auditor', 'manager') 0.5 2
# ('chief', 'salesperson') 0.5 2
# ('designer', 'farmer') 0.5 2
# ('farmer', 'sheriff') 0.5 2
# ('farmer', 'lawyer') 0.5 2
# ('janitor', 'physician') 0.5 2
# ('farmer', 'technician') 0.5 2
# ('engineer', 'hairdresser') 0.5 2
# ('cleaner', 'manager') 0.5 2
# ('accountant', 'carpenter') 0.42857142857142855 7
# ('developer', 'engineer') 0.4 5
# ('mechanic', 'receptionist') 0.4 5
# ('manager', 'teacher') 0.375 8
# ('accountant', 'engineer') 0.375 8
# ('engineer', 'paralegal') 0.375 8
# ('attendant', 'chief') 0.3333333333333333 3
# ('chief', 'sheriff') 0.3333333333333333 3
# ('farmer', 'physician') 0.3333333333333333 6
# ('engineer', 'writer') 0.3333333333333333 3
# ('farmer', 'paralegal') 0.3333333333333333 6
# ('counselor', 'laborer') 0.3333333333333333 3
# ('farmer', 'housekeeper') 0.3333333333333333 3
# ('farmer', 'librarian') 0.3333333333333333 6
# ('cook', 'secretary') 0.3333333333333333 3
# ('librarian', 'manager') 0.3333333333333333 6
# ('laborer', 'manager') 0.3333333333333333 3
# ('developer', 'manager') 0.3333333333333333 6
# ('chief', 'farmer') 0.3333333333333333 3
# ('engineer', 'tailor') 0.3333333333333333 3
# ('manager', 'salesperson') 0.3333333333333333 3
# ('salesperson', 'teacher') 0.3333333333333333 3
# ('construction worker', 'secretary') 0.3333333333333333 3
# ('mechanic', 'writer') 0.3333333333333333 3
# ('assistant', 'manager') 0.3333333333333333 6
# ('construction worker', 'manager') 0.3333333333333333 3
# ('baker', 'engineer') 0.3333333333333333 6
# ('salesperson', 'secretary') 0.3333333333333333 3
# ('CEO', 'manager') 0.3333333333333333 3
# ('farmer', 'tailor') 0.3333333333333333 3
# ('assistant', 'engineer') 0.3333333333333333 3
# ('farmer', 'teacher') 0.3333333333333333 3
# ('auditor', 'teacher') 0.3333333333333333 3
# ('engineer', 'nurse') 0.2857142857142857 7
# ('manager', 'sheriff') 0.2857142857142857 7
# ('farmer', 'manager') 0.2857142857142857 7
# ('carpenter', 'secretary') 0.25 4
# ('accountant', 'janitor') 0.25 4
# ('chief', 'manager') 0.25 4
# ('CEO', 'lawyer') 0.25 4
# ('cashier', 'manager') 0.25 4
# ('farmer', 'writer') 0.25 4
# ('engineer', 'mover') 0.25 4
# ('guard', 'physician') 0.25 4
# ('chief', 'clerk') 0.25 4
# ('cook', 'manager') 0.25 4
# ('lawyer', 'tailor') 0.25 4
# ('engineer', 'salesperson') 0.25 4
# ('engineer', 'receptionist') 0.25 4
# ('counselor', 'engineer') 0.25 4
# ('chief', 'librarian') 0.2222222222222222 9
# ('counselor', 'manager') 0.2 5
# ('carpenter', 'teacher') 0.2 5
# ('housekeeper', 'manager') 0.2 5
# ('accountant', 'salesperson') 0.2 5
# ('manager', 'physician') 0.2 5
# ('librarian', 'mechanic') 0.2 5
# ('assistant', 'mechanic') 0.2 5
# ('auditor', 'chief') 0.2 5
# ('cleaner', 'secretary') 0.2 5
# ('carpenter', 'physician') 0.2 5
# ('clerk', 'secretary') 0.2 5
# ('guard', 'manager') 0.2 5
# ('chief', 'cook') 0.16666666666666666 6
# ('carpenter', 'farmer') 0.16666666666666666 6
# ('accountant', 'driver') 0.16666666666666666 6
# ('accountant', 'designer') 0.16666666666666666 6
# ('hairdresser', 'physician') 0.16666666666666666 6
# ('analyst', 'manager') 0.16666666666666666 6
# ('accountant', 'farmer') 0.14285714285714285 7
# ('chief', 'mechanic') 0.14285714285714285 7
# ('accountant', 'auditor') 0.125 8
# ('laborer', 'sheriff') 0.125 8
# ('accountant', 'physician') 0.1111111111111111 9
# ('librarian', 'teacher') 0.09090909090909091 11
# ('accountant', 'librarian') 0.07142857142857142 14

# %%
oc_error = get_single_occupation_counts(occupation_pair_error)
oc_count = get_single_occupation_counts(occupation_pair_count)

error_rate_dict = get_error_rate_dict(oc_error, 
                                      oc_count)

error_rate_list = []
error_rate_keys = []
for key in error_rate_dict:
    print(key, error_rate_dict[key]*100)
    print(oc_error[key], oc_count[key])
    print()
    error_rate_list.append(error_rate_dict[key]*100)
    error_rate_keys.append(key)
    
error_rate_anamoly = get_anamoly_scores(error_rate_list)

print('\n____________\n')
# print()
print('Anamolies\n')
for i, anamoly in enumerate(error_rate_anamoly):
    print(error_rate_keys[i], anamoly)
# Out:
# manager 38.88888888888889
# 63 162
#
# engineer 36.12903225806451
# 56 155
#
# farmer 23.47826086956522
# 27 115
#
# chief 12.686567164179104
# 17 134
#
# mechanic 10.204081632653061
# 15 147
#
# carpenter 8.450704225352112
# 12 142
#
# secretary 7.377049180327869
# 9 122
#
# salesperson 6.349206349206349
# 8 126
#
# physician 6.293706293706294
# 9 143
#
# driver 5.982905982905983
# 7 117
#
# teacher 5.970149253731343
# 8 134
#
# paralegal 5.147058823529411
# 7 136
#
# librarian 5.109489051094891
# 14 274
#
# accountant 5.090909090909091
# 14 275
#
# janitor 4.72972972972973
# 7 148
#
# clerk 4.6875
# 6 128
#
# tailor 4.605263157894736
# 7 152
#
# auditor 4.166666666666666
# 4 96
#
# baker 4.166666666666666
# 5 120
#
# lawyer 4.0
# 5 125
#
# technician 3.8461538461538463
# 5 130
#
# writer 3.6036036036036037
# 4 111
#
# sheriff 3.4965034965034967
# 5 143
#
# nurse 3.4482758620689653
# 4 116
#
# guard 3.4013605442176873
# 5 147
#
# assistant 3.0534351145038165
# 4 131
#
# developer 3.007518796992481
# 4 133
#
# hairdresser 3.007518796992481
# 4 133
#
# laborer 2.8368794326241136
# 4 141
#
# housekeeper 2.73972602739726
# 4 146
#
# receptionist 2.3622047244094486
# 3 127
#
# counselor 2.2556390977443606
# 3 133
#
# editor 2.18978102189781
# 3 137
#
# cook 2.083333333333333
# 3 144
#
# construction worker 1.6
# 2 125
#
# cleaner 1.5873015873015872
# 2 126
#
# designer 1.550387596899225
# 2 129
#
# CEO 1.5151515151515151
# 2 132
#
# supervisor 1.4925373134328357
# 2 134
#
# analyst 1.4084507042253522
# 2 142
#
# cashier 0.8333333333333334
# 1 120
#
# mover 0.819672131147541
# 1 122
#
# attendant 0.6802721088435374
# 1 147
#
#
# ____________
#
# Anamolies
#
# manager 15.654823831711527
# engineer 14.430373781017051
# farmer 8.817677275349226
# chief 4.029787296915008
# mechanic 2.9283969199745217
# carpenter 2.150485838914163
# secretary 1.6741433508206323
# salesperson 1.2181261097015652
# physician 1.193502712597677
# driver 1.0556116888158997
# teacher 1.0499519826159012
# paralegal 0.6847760862557166
# librarian 0.6681077168744103
# accountant 0.6598644505622002
# janitor 0.4996220371822827
# clerk 0.480886210787947
# tailor 0.4444006541252933
# auditor 0.24981101859114105
# baker 0.24981101859114105
# lawyer 0.17586695708816347
# technician 0.10761090031618398
# writer 0.0
# sheriff -0.04751650143831494
# nurse -0.06891338443893566
# guard -0.08972803933069559
# assistant -0.2440901555699703
# developer -0.264461589606261
# hairdresser -0.264461589606261
# laborer -0.34016819552836264
# housekeeper -0.38327169975627173
# receptionist -0.5507644504371622
# counselor -0.598043821950522
# editor -0.6272627036157126
# cook -0.6744897501960817
# construction worker -0.8889275285547173
# cleaner -0.894561361812087
# designer -0.9109387840718828
# CEO -0.9265717780471424
# supervisor -0.9366048935835031
# analyst -0.9739111260003931
# cashier -1.2290702114684153
# mover -1.2351312001162005
# attendant -1.2969780230527828
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `median_absolute_deviation` is deprecated, use `median_abs_deviation` instead!
#
# To preserve the existing default behavior, use
# `scipy.stats.median_abs_deviation(..., scale=1/1.4826)`.
# The value 1.4826 is not numerically precise for scaling
# with a normal distribution. For a numerically precise value, use
# `scipy.stats.median_abs_deviation(..., scale='normal')`.

# %%
# error_rate_dict = get_error_rate_dict(occupation2_error, occupation2_count)
# for key in error_rate_dict:
#     print(key, error_rate_dict[key], occupation2_count[key])

# %%
error_rate_dict = get_error_rate_dict(action_error, action_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# can generate the report 0.4751131221719457
# can bake bread 0.4642857142857143
# can bake cookies 0.4296577946768061
# could eat a sandwich 0.39285714285714285
# could bake bread 0.35714285714285715
# could bake a cake 0.3111111111111111
# can play a ukelele 0.3018181818181818
# could bake cookies 0.2905405405405405
# can eat meat 0.2585551330798479
# could return the paperwork 0.22695035460992907
# could estimate how long the wait would be 0.2222222222222222
# could help with tax preparation 0.16233766233766234
# could help with the delivery 0.13533834586466165
# could sign the document 0.12987012987012986
# can do 100 push ups 0.10646387832699619
# could pay with cash 0.0875

# %%
error_rate_dict = get_error_rate_dict(verb_error, verb_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# asked the 0.31809338521400776
# told the 0.2750252780586451
# disclosed to the 0.25534079348931843
