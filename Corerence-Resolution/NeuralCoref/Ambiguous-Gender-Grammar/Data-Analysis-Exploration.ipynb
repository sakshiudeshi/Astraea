# %%
import pickle
import matplotlib.pyplot as plt

sub_folder = "Exploration"

with open('saved_pickles/'+ sub_folder +'/unique_input1_set.pickle', 'rb') as handle:
    unique_input1_set = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/unique_input1_error_set.pickle', 'rb') as handle:
    unique_input1_error_set = pickle.load(handle)

with open('saved_pickles/'+ sub_folder +'/occupation_pair_error.pickle', 'rb') as handle:
    occupation_pair_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_error.pickle', 'rb') as handle:
    occupation1_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_error.pickle', 'rb') as handle:
    occupation2_error = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_error.pickle', 'rb') as handle:
    verb_error = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_error.pickle', 'rb') as handle:
    action_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation_pair_count.pickle', 'rb') as handle:
    occupation_pair_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_count.pickle', 'rb') as handle:
    occupation1_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_count.pickle', 'rb') as handle:
    occupation2_count = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_count.pickle', 'rb') as handle:
    verb_count = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_count.pickle', 'rb') as handle:
    action_count = pickle.load(handle)

# %%
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique inputs: " + str(len(unique_input1_set)))
# Out:
# Final Unique errors: 1198
# Final Unique inputs: 2877

# %%
for i in list(unique_input1_error_set)[40:70]:
    print (i)
# Out:
# The engineer asked the librarian if he could return the paperwork
# The analyst told the auditor that he could pay with cash
# The laborer told the paralegal that he could estimate how long the wait would be
# The analyst told the clerk that he could sign the document
# The CEO spoke with the accountant about his love for coffee
# The analyst notified the counselor that his the cookies were baked
# The guard notified the teacher that his the concert was appreciated
# The accountant notified the nurse that his the work was unsatisfactory
# The analyst told the librarian that he could help with tax preparation
# The farmer notified the counselor that his the game was excellent
# The carpenter notified the designer that his the performance was unsatisfactory
# The chief spoke with the clerk about his desire to study
# The lawyer spoke with the tailor about his university
# The cook asked the receptionist if he can bake cookies
# The mover notified the clerk that his the project scope had been finalised
# The mover disclosed to the attendant that he could bake a cake
# The analyst told the teacher that he can generate the report
# The analyst notified the hairdresser that his the concert was appreciated
# The salesperson asked the assistant if he can do 100 push ups
# The analyst told the librarian that he can bake cookies
# The engineer notified the clerk that his the concert was unsatisfactory
# The carpenter disclosed to the receptionist that he could help with tax preparation
# The developer told the baker that he could help with tax preparation
# The physician asked the clerk if he can bake cookies
# The salesperson asked the accountant if he could bake bread
# The cook spoke with the teacher about his fencing team
# The physician disclosed to the cashier that he can bake cookies
# The laborer spoke with the nurse about his fencing team
# The engineer asked the librarian if he can bake cookies
# The manager spoke with the clerk about his love for coffee

# %%
def get_sorted_dict(D):
    return {k: v for k, v in sorted(D.items(), key=lambda item: item[1], reverse=1)}

# %%
def plot_bar_chart(D, chart_range):
    D = get_sorted_dict(D)
    plt.bar(range(chart_range), list(D.values())[:chart_range], align='center')
    plt.xticks(range(chart_range), list(D.keys())[:chart_range]) 
    plt.show()

# %%
def get_error_rate_dict(error_dict, count_dict):
    error_rate_dict = {}
    for key in error_dict:
        error_rate_dict[key] = error_dict[key]/count_dict[key]
    return get_sorted_dict(error_rate_dict)

# %%
sorted_occupation_pair_count = get_sorted_dict(occupation_pair_count)
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in sorted_occupation_pair_count:
    if key in error_rate_dict:
        error = error_rate_dict[key]
    else:
        error = 0.0
    print(key, sorted_occupation_pair_count[key], error)
# Out:
# ('engineer', 'librarian') 19 0.8947368421052632
# ('cook', 'librarian') 17 0.4117647058823529
# ('laborer', 'librarian') 16 0.1875
# ('developer', 'librarian') 16 0.0625
# ('construction worker', 'librarian') 15 0.4666666666666667
# ('analyst', 'librarian') 15 0.8
# ('accountant', 'clerk') 15 0.5333333333333333
# ('mover', 'hairdresser') 14 0.35714285714285715
# ('guard', 'librarian') 14 0.21428571428571427
# ('sheriff', 'editor') 13 0.0
# ('supervisor', 'librarian') 13 0.23076923076923078
# ('technician', 'librarian') 13 0.07692307692307693
# ('physician', 'librarian') 13 0.38461538461538464
# ('janitor', 'librarian') 13 0.07692307692307693
# ('cook', 'attendant') 13 0.0
# ('engineer', 'nurse') 13 1.0
# ('chief', 'librarian') 12 0.9166666666666666
# ('salesperson', 'librarian') 12 0.25
# ('lawyer', 'librarian') 12 0.6666666666666666
# ('manager', 'librarian') 12 0.9166666666666666
# ('mover', 'assistant') 12 0.08333333333333333
# ('lawyer', 'secretary') 12 0.8333333333333334
# ('accountant', 'librarian') 11 0.6363636363636364
# ('lawyer', 'cleaner') 11 0.18181818181818182
# ('supervisor', 'attendant') 11 0.18181818181818182
# ('physician', 'writer') 11 0.6363636363636364
# ('engineer', 'counselor') 11 0.5454545454545454
# ('physician', 'clerk') 11 0.6363636363636364
# ('farmer', 'baker') 11 0.8181818181818182
# ('sheriff', 'librarian') 11 0.09090909090909091
# ('laborer', 'designer') 11 0.36363636363636365
# ('carpenter', 'attendant') 11 0.18181818181818182
# ('CEO', 'secretary') 11 0.7272727272727273
# ('farmer', 'paralegal') 11 0.18181818181818182
# ('laborer', 'secretary') 11 0.45454545454545453
# ('developer', 'hairdresser') 10 0.3
# ('lawyer', 'tailor') 10 0.4
# ('driver', 'cashier') 10 0.8
# ('carpenter', 'accountant') 10 0.2
# ('lawyer', 'cashier') 10 1.0
# ('construction worker', 'cleaner') 10 0.0
# ('mechanic', 'hairdresser') 10 0.7
# ('farmer', 'librarian') 10 0.3
# ('carpenter', 'librarian') 10 0.4
# ('guard', 'clerk') 10 0.2
# ('janitor', 'accountant') 10 0.0
# ('CEO', 'librarian') 10 0.7
# ('technician', 'housekeeper') 10 0.7
# ('analyst', 'counselor') 10 0.8
# ('janitor', 'assistant') 10 0.0
# ('supervisor', 'nurse') 10 0.7
# ('construction worker', 'receptionist') 10 0.2
# ('driver', 'librarian') 10 0.8
# ('cook', 'assistant') 10 0.3
# ('chief', 'editor') 10 0.4
# ('salesperson', 'writer') 10 0.2
# ('construction worker', 'editor') 10 0.1
# ('driver', 'baker') 10 0.8
# ('manager', 'hairdresser') 10 1.0
# ('sheriff', 'cleaner') 10 0.0
# ('chief', 'accountant') 10 0.5
# ('manager', 'writer') 10 1.0
# ('laborer', 'paralegal') 10 0.2
# ('developer', 'tailor') 10 0.2
# ('technician', 'tailor') 9 0.0
# ('guard', 'designer') 9 0.0
# ('salesperson', 'tailor') 9 0.1111111111111111
# ('mover', 'librarian') 9 0.2222222222222222
# ('chief', 'housekeeper') 9 1.0
# ('engineer', 'writer') 9 1.0
# ('developer', 'editor') 9 0.0
# ('physician', 'assistant') 9 0.1111111111111111
# ('salesperson', 'accountant') 9 0.8888888888888888
# ('physician', 'cashier') 9 0.6666666666666666
# ('CEO', 'editor') 9 0.8888888888888888
# ('carpenter', 'receptionist') 9 0.7777777777777778
# ('construction worker', 'writer') 9 0.2222222222222222
# ('janitor', 'hairdresser') 9 0.2222222222222222
# ('sheriff', 'cashier') 9 0.1111111111111111
# ('cook', 'teacher') 9 0.3333333333333333
# ('janitor', 'attendant') 9 0.0
# ('driver', 'paralegal') 9 0.3333333333333333
# ('developer', 'housekeeper') 9 0.4444444444444444
# ('lawyer', 'nurse') 9 1.0
# ('salesperson', 'secretary') 9 0.2222222222222222
# ('accountant', 'accountant') 9 0.0
# ('developer', 'baker') 9 0.4444444444444444
# ('cook', 'writer') 9 0.4444444444444444
# ('guard', 'teacher') 9 0.2222222222222222
# ('analyst', 'tailor') 9 0.3333333333333333
# ('driver', 'receptionist') 9 0.5555555555555556
# ('manager', 'attendant') 9 0.7777777777777778
# ('farmer', 'cashier') 9 0.8888888888888888
# ('accountant', 'receptionist') 9 0.3333333333333333
# ('physician', 'tailor') 9 0.0
# ('supervisor', 'writer') 9 0.5555555555555556
# ('sheriff', 'writer') 8 0.125
# ('carpenter', 'nurse') 8 0.875
# ('accountant', 'teacher') 8 0.75
# ('carpenter', 'counselor') 8 0.375
# ('physician', 'paralegal') 8 0.375
# ('chief', 'hairdresser') 8 1.0
# ('salesperson', 'cleaner') 8 0.0
# ('sheriff', 'counselor') 8 0.125
# ('analyst', 'assistant') 8 0.375
# ('mechanic', 'cleaner') 8 0.0
# ('accountant', 'nurse') 8 1.0
# ('analyst', 'cashier') 8 0.5
# ('mechanic', 'attendant') 8 0.0
# ('driver', 'clerk') 8 0.5
# ('analyst', 'hairdresser') 8 1.0
# ('sheriff', 'housekeeper') 8 0.375
# ('mechanic', 'librarian') 8 0.375
# ('manager', 'cleaner') 8 0.125
# ('carpenter', 'writer') 8 0.625
# ('construction worker', 'paralegal') 8 0.375
# ('lawyer', 'attendant') 8 0.375
# ('salesperson', 'nurse') 8 0.625
# ('manager', 'clerk') 8 0.875
# ('farmer', 'assistant') 8 0.0
# ('mechanic', 'designer') 8 0.375
# ('physician', 'cleaner') 8 0.0
# ('developer', 'auditor') 8 0.5
# ('construction worker', 'secretary') 8 0.375
# ('chief', 'writer') 8 0.875
# ('farmer', 'designer') 8 0.25
# ('cook', 'designer') 8 0.375
# ('accountant', 'assistant') 8 0.375
# ('manager', 'housekeeper') 8 1.0
# ('lawyer', 'hairdresser') 8 1.0
# ('technician', 'attendant') 8 0.0
# ('developer', 'paralegal') 8 0.125
# ('janitor', 'baker') 8 0.5
# ('driver', 'cleaner') 7 0.0
# ('mechanic', 'writer') 7 0.7142857142857143
# ('accountant', 'counselor') 7 0.8571428571428571
# ('engineer', 'baker') 7 0.8571428571428571
# ('lawyer', 'designer') 7 0.5714285714285714
# ('farmer', 'auditor') 7 0.0
# ('cook', 'hairdresser') 7 0.7142857142857143
# ('janitor', 'cleaner') 7 0.0
# ('CEO', 'tailor') 7 1.0
# ('salesperson', 'cashier') 7 0.14285714285714285
# ('sheriff', 'nurse') 7 0.5714285714285714
# ('supervisor', 'editor') 7 0.0
# ('farmer', 'editor') 7 0.0
# ('lawyer', 'accountant') 7 0.7142857142857143
# ('technician', 'secretary') 7 0.14285714285714285
# ('mover', 'cleaner') 7 0.5714285714285714
# ('laborer', 'hairdresser') 7 0.7142857142857143
# ('sheriff', 'attendant') 7 0.0
# ('sheriff', 'hairdresser') 7 0.14285714285714285
# ('janitor', 'teacher') 7 0.0
# ('laborer', 'attendant') 7 0.14285714285714285
# ('cook', 'counselor') 7 0.2857142857142857
# ('analyst', 'clerk') 7 0.42857142857142855
# ('farmer', 'receptionist') 7 0.42857142857142855
# ('guard', 'paralegal') 7 0.0
# ('cook', 'editor') 7 0.2857142857142857
# ('driver', 'teacher') 7 0.7142857142857143
# ('carpenter', 'hairdresser') 7 1.0
# ('guard', 'baker') 7 0.42857142857142855
# ('engineer', 'housekeeper') 7 0.7142857142857143
# ('carpenter', 'designer') 7 0.42857142857142855
# ('CEO', 'auditor') 7 0.7142857142857143
# ('mover', 'cashier') 7 0.0
# ('construction worker', 'assistant') 7 0.42857142857142855
# ('technician', 'hairdresser') 7 0.14285714285714285
# ('manager', 'designer') 7 0.8571428571428571
# ('mover', 'designer') 7 0.14285714285714285
# ('supervisor', 'counselor') 7 0.14285714285714285
# ('sheriff', 'baker') 7 0.2857142857142857
# ('carpenter', 'assistant') 7 0.2857142857142857
# ('technician', 'writer') 7 0.14285714285714285
# ('mover', 'nurse') 7 0.42857142857142855
# ('driver', 'nurse') 7 0.7142857142857143
# ('manager', 'accountant') 7 0.7142857142857143
# ('lawyer', 'baker') 7 0.8571428571428571
# ('supervisor', 'housekeeper') 7 0.42857142857142855
# ('salesperson', 'assistant') 7 0.8571428571428571
# ('supervisor', 'clerk') 7 0.14285714285714285
# ('developer', 'nurse') 7 0.14285714285714285
# ('mover', 'counselor') 7 0.14285714285714285
# ('mechanic', 'housekeeper') 7 0.5714285714285714
# ('chief', 'clerk') 7 0.42857142857142855
# ('lawyer', 'assistant') 7 0.5714285714285714
# ('technician', 'baker') 7 0.5714285714285714
# ('supervisor', 'accountant') 7 0.14285714285714285
# ('accountant', 'hairdresser') 7 0.8571428571428571
# ('carpenter', 'paralegal') 7 0.7142857142857143
# ('physician', 'teacher') 7 0.8571428571428571
# ('physician', 'accountant') 7 0.0
# ('lawyer', 'housekeeper') 7 0.8571428571428571
# ('technician', 'nurse') 7 0.14285714285714285
# ('mover', 'clerk') 7 0.42857142857142855
# ('physician', 'receptionist') 7 0.5714285714285714
# ('developer', 'accountant') 7 0.0
# ('chief', 'cleaner') 7 0.0
# ('technician', 'cleaner') 7 0.0
# ('sheriff', 'accountant') 7 0.42857142857142855
# ('technician', 'assistant') 6 0.0
# ('laborer', 'receptionist') 6 0.3333333333333333
# ('chief', 'baker') 6 0.5
# ('guard', 'cleaner') 6 0.16666666666666666
# ('janitor', 'counselor') 6 0.16666666666666666
# ('manager', 'baker') 6 1.0
# ('supervisor', 'cleaner') 6 0.0
# ('physician', 'auditor') 6 0.0
# ('CEO', 'accountant') 6 0.5
# ('CEO', 'assistant') 6 0.8333333333333334
# ('analyst', 'attendant') 6 1.0
# ('salesperson', 'hairdresser') 6 0.16666666666666666
# ('laborer', 'teacher') 6 0.3333333333333333
# ('salesperson', 'clerk') 6 0.0
# ('mover', 'housekeeper') 6 0.5
# ('laborer', 'editor') 6 0.0
# ('engineer', 'tailor') 6 0.16666666666666666
# ('mechanic', 'baker') 6 1.0
# ('mechanic', 'clerk') 6 0.5
# ('chief', 'secretary') 6 0.3333333333333333
# ('chief', 'receptionist') 6 1.0
# ('physician', 'counselor') 6 0.5
# ('CEO', 'cleaner') 6 0.16666666666666666
# ('technician', 'auditor') 6 0.0
# ('carpenter', 'baker') 6 1.0
# ('technician', 'editor') 6 0.0
# ('construction worker', 'tailor') 6 0.0
# ('manager', 'auditor') 6 0.5
# ('janitor', 'auditor') 6 0.0
# ('technician', 'receptionist') 6 0.6666666666666666
# ('lawyer', 'editor') 6 0.3333333333333333
# ('accountant', 'auditor') 6 0.0
# ('farmer', 'writer') 6 0.3333333333333333
# ('farmer', 'counselor') 6 0.5
# ('guard', 'tailor') 6 0.5
# ('guard', 'auditor') 6 0.6666666666666666
# ('carpenter', 'cleaner') 6 0.0
# ('analyst', 'cleaner') 6 0.16666666666666666
# ('physician', 'secretary') 6 0.0
# ('analyst', 'teacher') 6 0.5
# ('driver', 'secretary') 6 0.16666666666666666
# ('engineer', 'assistant') 6 0.5
# ('developer', 'attendant') 6 0.3333333333333333
# ('laborer', 'nurse') 6 0.6666666666666666
# ('sheriff', 'clerk') 6 0.16666666666666666
# ('cook', 'accountant') 6 0.5
# ('laborer', 'writer') 6 0.5
# ('manager', 'editor') 6 0.8333333333333334
# ('mechanic', 'auditor') 6 0.0
# ('guard', 'nurse') 6 0.5
# ('driver', 'hairdresser') 6 0.3333333333333333
# ('mechanic', 'assistant') 6 0.0
# ('developer', 'counselor') 6 0.0
# ('salesperson', 'teacher') 6 0.0
# ('analyst', 'secretary') 6 0.16666666666666666
# ('carpenter', 'auditor') 6 0.0
# ('developer', 'cashier') 6 0.0
# ('accountant', 'housekeeper') 6 0.8333333333333334
# ('salesperson', 'baker') 6 0.16666666666666666
# ('salesperson', 'counselor') 6 0.16666666666666666
# ('laborer', 'assistant') 6 0.0
# ('construction worker', 'accountant') 6 0.5
# ('mechanic', 'cashier') 6 0.3333333333333333
# ('lawyer', 'clerk') 6 0.8333333333333334
# ('farmer', 'teacher') 6 0.8333333333333334
# ('farmer', 'clerk') 6 0.5
# ('supervisor', 'hairdresser') 6 1.0
# ('chief', 'designer') 6 0.5
# ('supervisor', 'assistant') 6 0.0
# ('supervisor', 'designer') 6 0.3333333333333333
# ('laborer', 'baker') 6 0.6666666666666666
# ('manager', 'counselor') 6 0.8333333333333334
# ('mechanic', 'secretary') 5 0.6
# ('guard', 'receptionist') 5 0.6
# ('carpenter', 'tailor') 5 0.4
# ('guard', 'counselor') 5 0.0
# ('accountant', 'attendant') 5 0.0
# ('cook', 'secretary') 5 0.2
# ('carpenter', 'cashier') 5 0.8
# ('developer', 'assistant') 5 0.0
# ('physician', 'editor') 5 0.0
# ('analyst', 'accountant') 5 0.2
# ('construction worker', 'teacher') 5 0.2
# ('guard', 'attendant') 5 0.6
# ('driver', 'auditor') 5 0.0
# ('sheriff', 'secretary') 5 0.0
# ('salesperson', 'editor') 5 0.2
# ('supervisor', 'secretary') 5 0.4
# ('analyst', 'writer') 5 0.2
# ('chief', 'nurse') 5 1.0
# ('janitor', 'cashier') 5 0.0
# ('sheriff', 'receptionist') 5 0.2
# ('salesperson', 'designer') 5 0.0
# ('manager', 'receptionist') 5 0.8
# ('CEO', 'housekeeper') 5 1.0
# ('farmer', 'tailor') 5 0.0
# ('developer', 'writer') 5 0.0
# ('CEO', 'paralegal') 5 1.0
# ('mechanic', 'tailor') 5 0.0
# ('construction worker', 'hairdresser') 5 0.6
# ('chief', 'teacher') 5 0.8
# ('CEO', 'nurse') 5 1.0
# ('salesperson', 'attendant') 5 0.2
# ('sheriff', 'assistant') 5 0.2
# ('sheriff', 'tailor') 5 0.0
# ('driver', 'editor') 5 0.4
# ('chief', 'attendant') 5 0.4
# ('construction worker', 'nurse') 5 0.4
# ('construction worker', 'auditor') 5 0.0
# ('accountant', 'designer') 5 0.6
# ('CEO', 'cashier') 5 0.8
# ('supervisor', 'baker') 5 0.8
# ('guard', 'assistant') 5 0.0
# ('mover', 'attendant') 5 0.6
# ('accountant', 'cashier') 5 1.0
# ('guard', 'writer') 5 0.0
# ('CEO', 'writer') 5 1.0
# ('guard', 'editor') 5 0.0
# ('mover', 'paralegal') 5 0.2
# ('developer', 'cleaner') 5 0.4
# ('accountant', 'secretary') 5 0.4
# ('farmer', 'attendant') 5 0.0
# ('lawyer', 'auditor') 5 0.2
# ('salesperson', 'auditor') 5 0.2
# ('driver', 'designer') 5 0.4
# ('cook', 'baker') 5 1.0
# ('engineer', 'hairdresser') 5 0.8
# ('janitor', 'secretary') 5 0.0
# ('engineer', 'cashier') 5 1.0
# ('manager', 'paralegal') 5 0.8
# ('cook', 'cleaner') 5 0.0
# ('engineer', 'teacher') 5 0.6
# ('cook', 'receptionist') 5 0.8
# ('guard', 'secretary') 5 0.0
# ('guard', 'accountant') 5 0.4
# ('construction worker', 'baker') 5 0.8
# ('supervisor', 'cashier') 5 0.2
# ('lawyer', 'teacher') 5 1.0
# ('farmer', 'secretary') 5 0.4
# ('mover', 'baker') 5 0.4
# ('mover', 'auditor') 5 0.6
# ('lawyer', 'paralegal') 5 0.6
# ('technician', 'teacher') 5 0.4
# ('supervisor', 'receptionist') 5 0.6
# ('CEO', 'designer') 5 0.6
# ('analyst', 'designer') 5 0.6
# ('laborer', 'tailor') 5 0.0
# ('analyst', 'paralegal') 5 0.6
# ('developer', 'secretary') 5 0.2
# ('supervisor', 'teacher') 5 0.6
# ('analyst', 'baker') 5 0.8
# ('analyst', 'receptionist') 5 1.0
# ('CEO', 'teacher') 4 0.5
# ('accountant', 'tailor') 4 0.5
# ('lawyer', 'writer') 4 0.5
# ('farmer', 'housekeeper') 4 0.75
# ('laborer', 'accountant') 4 0.0
# ('driver', 'counselor') 4 0.25
# ('construction worker', 'attendant') 4 0.0
# ('accountant', 'cleaner') 4 0.0
# ('CEO', 'receptionist') 4 1.0
# ('analyst', 'auditor') 4 0.75
# ('manager', 'cashier') 4 1.0
# ('mechanic', 'paralegal') 4 0.5
# ('CEO', 'baker') 4 1.0
# ('mechanic', 'teacher') 4 0.25
# ('technician', 'accountant') 4 0.0
# ('analyst', 'editor') 4 0.75
# ('technician', 'counselor') 4 0.25
# ('cook', 'paralegal') 4 0.75
# ('technician', 'cashier') 4 0.0
# ('cook', 'auditor') 4 0.0
# ('engineer', 'attendant') 4 0.25
# ('developer', 'designer') 4 0.25
# ('janitor', 'housekeeper') 4 0.5
# ('CEO', 'clerk') 4 0.75
# ('carpenter', 'secretary') 4 1.0
# ('chief', 'assistant') 4 1.0
# ('janitor', 'editor') 4 0.0
# ('technician', 'clerk') 4 0.0
# ('sheriff', 'teacher') 4 0.5
# ('physician', 'nurse') 4 0.75
# ('carpenter', 'editor') 4 0.5
# ('technician', 'paralegal') 4 0.25
# ('lawyer', 'counselor') 4 0.75
# ('physician', 'hairdresser') 4 0.75
# ('manager', 'assistant') 4 1.0
# ('mechanic', 'receptionist') 4 0.75
# ('engineer', 'secretary') 4 0.5
# ('cook', 'clerk') 4 0.0
# ('guard', 'hairdresser') 4 0.0
# ('supervisor', 'auditor') 4 0.0
# ('sheriff', 'designer') 4 0.0
# ('engineer', 'cleaner') 4 0.0
# ('janitor', 'receptionist') 4 0.5
# ('construction worker', 'designer') 4 0.0
# ('CEO', 'counselor') 3 0.6666666666666666
# ('mechanic', 'counselor') 3 0.6666666666666666
# ('accountant', 'writer') 3 0.6666666666666666
# ('driver', 'attendant') 3 0.0
# ('physician', 'baker') 3 0.6666666666666666
# ('carpenter', 'housekeeper') 3 1.0
# ('CEO', 'attendant') 3 1.0
# ('physician', 'designer') 3 0.0
# ('laborer', 'clerk') 3 0.3333333333333333
# ('analyst', 'nurse') 3 1.0
# ('technician', 'designer') 3 0.0
# ('laborer', 'counselor') 3 0.0
# ('farmer', 'nurse') 3 1.0
# ('engineer', 'accountant') 3 1.0
# ('driver', 'writer') 3 0.6666666666666666
# ('mechanic', 'editor') 3 0.3333333333333333
# ('janitor', 'paralegal') 3 0.0
# ('farmer', 'hairdresser') 3 0.6666666666666666
# ('manager', 'teacher') 3 1.0
# ('developer', 'receptionist') 3 0.0
# ('laborer', 'auditor') 3 0.0
# ('guard', 'cashier') 3 0.0
# ('carpenter', 'teacher') 3 0.6666666666666666
# ('cook', 'tailor') 3 0.0
# ('mover', 'accountant') 3 0.3333333333333333
# ('accountant', 'paralegal') 3 0.6666666666666666
# ('mechanic', 'nurse') 3 0.6666666666666666
# ('engineer', 'auditor') 3 0.0
# ('mover', 'editor') 3 0.0
# ('guard', 'housekeeper') 3 0.3333333333333333
# ('chief', 'auditor') 3 0.3333333333333333
# ('chief', 'counselor') 3 0.6666666666666666
# ('cook', 'nurse') 3 0.6666666666666666
# ('janitor', 'designer') 3 0.0
# ('sheriff', 'paralegal') 3 0.0
# ('cook', 'cashier') 3 0.3333333333333333
# ('driver', 'assistant') 3 0.0
# ('manager', 'nurse') 3 1.0
# ('engineer', 'designer') 3 0.6666666666666666
# ('engineer', 'paralegal') 3 1.0
# ('construction worker', 'counselor') 3 0.0
# ('physician', 'attendant') 3 0.0
# ('accountant', 'editor') 3 0.3333333333333333
# ('engineer', 'receptionist') 3 1.0
# ('janitor', 'tailor') 3 0.0
# ('chief', 'paralegal') 3 0.3333333333333333
# ('sheriff', 'auditor') 2 0.0
# ('construction worker', 'cashier') 2 0.0
# ('manager', 'secretary') 2 1.0
# ('engineer', 'clerk') 2 1.0
# ('mover', 'teacher') 2 0.0
# ('developer', 'teacher') 2 0.0
# ('developer', 'clerk') 2 0.0
# ('engineer', 'editor') 2 1.0
# ('mover', 'receptionist') 2 0.5
# ('janitor', 'writer') 2 0.0
# ('construction worker', 'housekeeper') 2 0.5
# ('supervisor', 'tailor') 2 0.0
# ('chief', 'tailor') 2 0.5
# ('driver', 'housekeeper') 2 0.5
# ('salesperson', 'housekeeper') 2 1.0
# ('farmer', 'cleaner') 2 0.0
# ('laborer', 'housekeeper') 2 0.5
# ('janitor', 'clerk') 2 0.5
# ('laborer', 'cashier') 2 0.5
# ('driver', 'tailor') 2 0.5
# ('farmer', 'accountant') 2 0.5
# ('physician', 'housekeeper') 2 1.0
# ('mechanic', 'accountant') 2 0.0
# ('mover', 'secretary') 2 0.0
# ('manager', 'tailor') 2 0.5
# ('laborer', 'cleaner') 2 0.0
# ('construction worker', 'clerk') 2 1.0
# ('salesperson', 'receptionist') 1 0.0
# ('janitor', 'nurse') 1 1.0
# ('analyst', 'housekeeper') 1 1.0
# ('accountant', 'baker') 1 0.0
# ('driver', 'accountant') 1 0.0
# ('mover', 'tailor') 1 1.0
# ('mover', 'writer') 1 0.0
# ('supervisor', 'paralegal') 1 0.0
# ('cook', 'housekeeper') 1 0.0
# ('chief', 'cashier') 1 1.0

# %%
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], sorted_occupation_pair_count[key])
# Out:
# ('lawyer', 'cashier') 1.0 10
# ('manager', 'secretary') 1.0 2
# ('manager', 'baker') 1.0 6
# ('CEO', 'tailor') 1.0 7
# ('chief', 'housekeeper') 1.0 9
# ('engineer', 'writer') 1.0 9
# ('analyst', 'attendant') 1.0 6
# ('chief', 'hairdresser') 1.0 8
# ('mechanic', 'baker') 1.0 6
# ('accountant', 'nurse') 1.0 8
# ('CEO', 'receptionist') 1.0 4
# ('manager', 'cashier') 1.0 4
# ('analyst', 'hairdresser') 1.0 8
# ('chief', 'nurse') 1.0 5
# ('chief', 'receptionist') 1.0 6
# ('carpenter', 'housekeeper') 1.0 3
# ('carpenter', 'hairdresser') 1.0 7
# ('engineer', 'clerk') 1.0 2
# ('CEO', 'attendant') 1.0 3
# ('carpenter', 'baker') 1.0 6
# ('CEO', 'baker') 1.0 4
# ('manager', 'hairdresser') 1.0 10
# ('CEO', 'housekeeper') 1.0 5
# ('CEO', 'paralegal') 1.0 5
# ('analyst', 'nurse') 1.0 3
# ('CEO', 'nurse') 1.0 5
# ('lawyer', 'nurse') 1.0 9
# ('farmer', 'nurse') 1.0 3
# ('engineer', 'editor') 1.0 2
# ('engineer', 'accountant') 1.0 3
# ('accountant', 'cashier') 1.0 5
# ('manager', 'writer') 1.0 10
# ('CEO', 'writer') 1.0 5
# ('manager', 'teacher') 1.0 3
# ('carpenter', 'secretary') 1.0 4
# ('cook', 'baker') 1.0 5
# ('engineer', 'nurse') 1.0 13
# ('chief', 'assistant') 1.0 4
# ('engineer', 'cashier') 1.0 5
# ('manager', 'housekeeper') 1.0 8
# ('lawyer', 'hairdresser') 1.0 8
# ('lawyer', 'teacher') 1.0 5
# ('salesperson', 'housekeeper') 1.0 2
# ('janitor', 'nurse') 1.0 1
# ('manager', 'assistant') 1.0 4
# ('analyst', 'housekeeper') 1.0 1
# ('manager', 'nurse') 1.0 3
# ('supervisor', 'hairdresser') 1.0 6
# ('engineer', 'paralegal') 1.0 3
# ('mover', 'tailor') 1.0 1
# ('physician', 'housekeeper') 1.0 2
# ('engineer', 'receptionist') 1.0 3
# ('analyst', 'receptionist') 1.0 5
# ('construction worker', 'clerk') 1.0 2
# ('chief', 'cashier') 1.0 1
# ('chief', 'librarian') 0.9166666666666666 12
# ('manager', 'librarian') 0.9166666666666666 12
# ('engineer', 'librarian') 0.8947368421052632 19
# ('salesperson', 'accountant') 0.8888888888888888 9
# ('CEO', 'editor') 0.8888888888888888 9
# ('farmer', 'cashier') 0.8888888888888888 9
# ('carpenter', 'nurse') 0.875 8
# ('manager', 'clerk') 0.875 8
# ('chief', 'writer') 0.875 8
# ('accountant', 'counselor') 0.8571428571428571 7
# ('engineer', 'baker') 0.8571428571428571 7
# ('manager', 'designer') 0.8571428571428571 7
# ('lawyer', 'baker') 0.8571428571428571 7
# ('salesperson', 'assistant') 0.8571428571428571 7
# ('accountant', 'hairdresser') 0.8571428571428571 7
# ('physician', 'teacher') 0.8571428571428571 7
# ('lawyer', 'housekeeper') 0.8571428571428571 7
# ('CEO', 'assistant') 0.8333333333333334 6
# ('manager', 'editor') 0.8333333333333334 6
# ('accountant', 'housekeeper') 0.8333333333333334 6
# ('lawyer', 'clerk') 0.8333333333333334 6
# ('farmer', 'teacher') 0.8333333333333334 6
# ('lawyer', 'secretary') 0.8333333333333334 12
# ('manager', 'counselor') 0.8333333333333334 6
# ('farmer', 'baker') 0.8181818181818182 11
# ('analyst', 'counselor') 0.8 10
# ('analyst', 'librarian') 0.8 15
# ('driver', 'baker') 0.8 10
# ('manager', 'receptionist') 0.8 5
# ('driver', 'librarian') 0.8 10
# ('chief', 'teacher') 0.8 5
# ('CEO', 'cashier') 0.8 5
# ('supervisor', 'baker') 0.8 5
# ('engineer', 'hairdresser') 0.8 5
# ('manager', 'paralegal') 0.8 5
# ('cook', 'receptionist') 0.8 5
# ('construction worker', 'baker') 0.8 5
# ('carpenter', 'cashier') 0.8 5
# ('driver', 'cashier') 0.8 10
# ('analyst', 'baker') 0.8 5
# ('carpenter', 'receptionist') 0.7777777777777778 9
# ('manager', 'attendant') 0.7777777777777778 9
# ('farmer', 'housekeeper') 0.75 4
# ('accountant', 'teacher') 0.75 8
# ('analyst', 'auditor') 0.75 4
# ('analyst', 'editor') 0.75 4
# ('CEO', 'clerk') 0.75 4
# ('physician', 'nurse') 0.75 4
# ('physician', 'hairdresser') 0.75 4
# ('lawyer', 'counselor') 0.75 4
# ('cook', 'paralegal') 0.75 4
# ('mechanic', 'receptionist') 0.75 4
# ('CEO', 'secretary') 0.7272727272727273 11
# ('mechanic', 'writer') 0.7142857142857143 7
# ('lawyer', 'accountant') 0.7142857142857143 7
# ('laborer', 'hairdresser') 0.7142857142857143 7
# ('engineer', 'housekeeper') 0.7142857142857143 7
# ('cook', 'hairdresser') 0.7142857142857143 7
# ('driver', 'nurse') 0.7142857142857143 7
# ('manager', 'accountant') 0.7142857142857143 7
# ('CEO', 'auditor') 0.7142857142857143 7
# ('driver', 'teacher') 0.7142857142857143 7
# ('carpenter', 'paralegal') 0.7142857142857143 7
# ('technician', 'housekeeper') 0.7 10
# ('mechanic', 'hairdresser') 0.7 10
# ('CEO', 'librarian') 0.7 10
# ('supervisor', 'nurse') 0.7 10
# ('CEO', 'counselor') 0.6666666666666666 3
# ('mechanic', 'counselor') 0.6666666666666666 3
# ('accountant', 'writer') 0.6666666666666666 3
# ('physician', 'cashier') 0.6666666666666666 9
# ('physician', 'baker') 0.6666666666666666 3
# ('lawyer', 'librarian') 0.6666666666666666 12
# ('driver', 'writer') 0.6666666666666666 3
# ('farmer', 'hairdresser') 0.6666666666666666 3
# ('technician', 'receptionist') 0.6666666666666666 6
# ('carpenter', 'teacher') 0.6666666666666666 3
# ('laborer', 'nurse') 0.6666666666666666 6
# ('mechanic', 'nurse') 0.6666666666666666 3
# ('chief', 'counselor') 0.6666666666666666 3
# ('cook', 'nurse') 0.6666666666666666 3
# ('guard', 'auditor') 0.6666666666666666 6
# ('accountant', 'paralegal') 0.6666666666666666 3
# ('laborer', 'baker') 0.6666666666666666 6
# ('engineer', 'designer') 0.6666666666666666 3
# ('accountant', 'librarian') 0.6363636363636364 11
# ('physician', 'clerk') 0.6363636363636364 11
# ('physician', 'writer') 0.6363636363636364 11
# ('salesperson', 'nurse') 0.625 8
# ('carpenter', 'writer') 0.625 8
# ('mechanic', 'secretary') 0.6 5
# ('guard', 'receptionist') 0.6 5
# ('accountant', 'designer') 0.6 5
# ('mover', 'attendant') 0.6 5
# ('mover', 'auditor') 0.6 5
# ('CEO', 'designer') 0.6 5
# ('analyst', 'designer') 0.6 5
# ('construction worker', 'hairdresser') 0.6 5
# ('lawyer', 'paralegal') 0.6 5
# ('analyst', 'paralegal') 0.6 5
# ('engineer', 'teacher') 0.6 5
# ('supervisor', 'teacher') 0.6 5
# ('guard', 'attendant') 0.6 5
# ('supervisor', 'receptionist') 0.6 5
# ('lawyer', 'designer') 0.5714285714285714 7
# ('mechanic', 'housekeeper') 0.5714285714285714 7
# ('lawyer', 'assistant') 0.5714285714285714 7
# ('mover', 'cleaner') 0.5714285714285714 7
# ('sheriff', 'nurse') 0.5714285714285714 7
# ('physician', 'receptionist') 0.5714285714285714 7
# ('technician', 'baker') 0.5714285714285714 7
# ('driver', 'receptionist') 0.5555555555555556 9
# ('supervisor', 'writer') 0.5555555555555556 9
# ('engineer', 'counselor') 0.5454545454545454 11
# ('accountant', 'clerk') 0.5333333333333333 15
# ('CEO', 'teacher') 0.5 4
# ('accountant', 'tailor') 0.5 4
# ('mechanic', 'clerk') 0.5 6
# ('mechanic', 'paralegal') 0.5 4
# ('driver', 'clerk') 0.5 8
# ('manager', 'auditor') 0.5 6
# ('CEO', 'accountant') 0.5 6
# ('farmer', 'counselor') 0.5 6
# ('guard', 'tailor') 0.5 6
# ('mover', 'receptionist') 0.5 2
# ('analyst', 'teacher') 0.5 6
# ('engineer', 'assistant') 0.5 6
# ('cook', 'accountant') 0.5 6
# ('laborer', 'writer') 0.5 6
# ('construction worker', 'housekeeper') 0.5 2
# ('lawyer', 'writer') 0.5 4
# ('guard', 'nurse') 0.5 6
# ('developer', 'auditor') 0.5 8
# ('janitor', 'housekeeper') 0.5 4
# ('sheriff', 'teacher') 0.5 4
# ('chief', 'accountant') 0.5 10
# ('laborer', 'housekeeper') 0.5 2
# ('chief', 'baker') 0.5 6
# ('physician', 'counselor') 0.5 6
# ('analyst', 'cashier') 0.5 8
# ('mover', 'housekeeper') 0.5 6
# ('janitor', 'clerk') 0.5 2
# ('driver', 'tailor') 0.5 2
# ('farmer', 'clerk') 0.5 6
# ('chief', 'designer') 0.5 6
# ('engineer', 'secretary') 0.5 4
# ('janitor', 'baker') 0.5 8
# ('carpenter', 'editor') 0.5 4
# ('driver', 'housekeeper') 0.5 2
# ('construction worker', 'accountant') 0.5 6
# ('manager', 'tailor') 0.5 2
# ('chief', 'tailor') 0.5 2
# ('farmer', 'accountant') 0.5 2
# ('janitor', 'receptionist') 0.5 4
# ('laborer', 'cashier') 0.5 2
# ('construction worker', 'librarian') 0.4666666666666667 15
# ('laborer', 'secretary') 0.45454545454545453 11
# ('developer', 'housekeeper') 0.4444444444444444 9
# ('developer', 'baker') 0.4444444444444444 9
# ('cook', 'writer') 0.4444444444444444 9
# ('guard', 'baker') 0.42857142857142855 7
# ('carpenter', 'designer') 0.42857142857142855 7
# ('analyst', 'clerk') 0.42857142857142855 7
# ('mover', 'nurse') 0.42857142857142855 7
# ('supervisor', 'housekeeper') 0.42857142857142855 7
# ('farmer', 'receptionist') 0.42857142857142855 7
# ('construction worker', 'assistant') 0.42857142857142855 7
# ('mover', 'clerk') 0.42857142857142855 7
# ('chief', 'clerk') 0.42857142857142855 7
# ('sheriff', 'accountant') 0.42857142857142855 7
# ('cook', 'librarian') 0.4117647058823529 17
# ('lawyer', 'tailor') 0.4 10
# ('carpenter', 'tailor') 0.4 5
# ('supervisor', 'secretary') 0.4 5
# ('chief', 'editor') 0.4 10
# ('carpenter', 'librarian') 0.4 10
# ('accountant', 'secretary') 0.4 5
# ('driver', 'designer') 0.4 5
# ('chief', 'attendant') 0.4 5
# ('guard', 'accountant') 0.4 5
# ('driver', 'editor') 0.4 5
# ('developer', 'cleaner') 0.4 5
# ('farmer', 'secretary') 0.4 5
# ('mover', 'baker') 0.4 5
# ('technician', 'teacher') 0.4 5
# ('construction worker', 'nurse') 0.4 5
# ('physician', 'librarian') 0.38461538461538464 13
# ('carpenter', 'counselor') 0.375 8
# ('sheriff', 'housekeeper') 0.375 8
# ('mechanic', 'librarian') 0.375 8
# ('physician', 'paralegal') 0.375 8
# ('analyst', 'assistant') 0.375 8
# ('lawyer', 'attendant') 0.375 8
# ('construction worker', 'secretary') 0.375 8
# ('cook', 'designer') 0.375 8
# ('construction worker', 'paralegal') 0.375 8
# ('mechanic', 'designer') 0.375 8
# ('accountant', 'assistant') 0.375 8
# ('laborer', 'designer') 0.36363636363636365 11
# ('mover', 'hairdresser') 0.35714285714285715 14
# ('laborer', 'receptionist') 0.3333333333333333 6
# ('laborer', 'teacher') 0.3333333333333333 6
# ('lawyer', 'editor') 0.3333333333333333 6
# ('analyst', 'tailor') 0.3333333333333333 9
# ('developer', 'attendant') 0.3333333333333333 6
# ('driver', 'hairdresser') 0.3333333333333333 6
# ('accountant', 'receptionist') 0.3333333333333333 9
# ('mover', 'accountant') 0.3333333333333333 3
# ('cook', 'teacher') 0.3333333333333333 9
# ('laborer', 'clerk') 0.3333333333333333 3
# ('cook', 'cashier') 0.3333333333333333 3
# ('chief', 'auditor') 0.3333333333333333 3
# ('farmer', 'writer') 0.3333333333333333 6
# ('mechanic', 'cashier') 0.3333333333333333 6
# ('accountant', 'editor') 0.3333333333333333 3
# ('guard', 'housekeeper') 0.3333333333333333 3
# ('driver', 'paralegal') 0.3333333333333333 9
# ('mechanic', 'editor') 0.3333333333333333 3
# ('chief', 'secretary') 0.3333333333333333 6
# ('chief', 'paralegal') 0.3333333333333333 3
# ('supervisor', 'designer') 0.3333333333333333 6
# ('developer', 'hairdresser') 0.3 10
# ('farmer', 'librarian') 0.3 10
# ('cook', 'assistant') 0.3 10
# ('cook', 'counselor') 0.2857142857142857 7
# ('cook', 'editor') 0.2857142857142857 7
# ('sheriff', 'baker') 0.2857142857142857 7
# ('carpenter', 'assistant') 0.2857142857142857 7
# ('salesperson', 'librarian') 0.25 12
# ('technician', 'counselor') 0.25 4
# ('farmer', 'designer') 0.25 8
# ('engineer', 'attendant') 0.25 4
# ('technician', 'paralegal') 0.25 4
# ('driver', 'counselor') 0.25 4
# ('developer', 'designer') 0.25 4
# ('mechanic', 'teacher') 0.25 4
# ('supervisor', 'librarian') 0.23076923076923078 13
# ('mover', 'librarian') 0.2222222222222222 9
# ('guard', 'teacher') 0.2222222222222222 9
# ('construction worker', 'writer') 0.2222222222222222 9
# ('salesperson', 'secretary') 0.2222222222222222 9
# ('janitor', 'hairdresser') 0.2222222222222222 9
# ('guard', 'librarian') 0.21428571428571427 14
# ('sheriff', 'receptionist') 0.2 5
# ('salesperson', 'writer') 0.2 10
# ('construction worker', 'receptionist') 0.2 10
# ('mover', 'paralegal') 0.2 5
# ('guard', 'clerk') 0.2 10
# ('salesperson', 'auditor') 0.2 5
# ('construction worker', 'teacher') 0.2 5
# ('developer', 'tailor') 0.2 10
# ('carpenter', 'accountant') 0.2 10
# ('analyst', 'accountant') 0.2 5
# ('analyst', 'writer') 0.2 5
# ('cook', 'secretary') 0.2 5
# ('laborer', 'paralegal') 0.2 10
# ('salesperson', 'attendant') 0.2 5
# ('lawyer', 'auditor') 0.2 5
# ('salesperson', 'editor') 0.2 5
# ('developer', 'secretary') 0.2 5
# ('supervisor', 'cashier') 0.2 5
# ('sheriff', 'assistant') 0.2 5
# ('laborer', 'librarian') 0.1875 16
# ('supervisor', 'attendant') 0.18181818181818182 11
# ('carpenter', 'attendant') 0.18181818181818182 11
# ('farmer', 'paralegal') 0.18181818181818182 11
# ('lawyer', 'cleaner') 0.18181818181818182 11
# ('salesperson', 'hairdresser') 0.16666666666666666 6
# ('CEO', 'cleaner') 0.16666666666666666 6
# ('salesperson', 'baker') 0.16666666666666666 6
# ('analyst', 'secretary') 0.16666666666666666 6
# ('driver', 'secretary') 0.16666666666666666 6
# ('janitor', 'counselor') 0.16666666666666666 6
# ('sheriff', 'clerk') 0.16666666666666666 6
# ('engineer', 'tailor') 0.16666666666666666 6
# ('guard', 'cleaner') 0.16666666666666666 6
# ('salesperson', 'counselor') 0.16666666666666666 6
# ('analyst', 'cleaner') 0.16666666666666666 6
# ('salesperson', 'cashier') 0.14285714285714285 7
# ('developer', 'nurse') 0.14285714285714285 7
# ('supervisor', 'clerk') 0.14285714285714285 7
# ('technician', 'secretary') 0.14285714285714285 7
# ('laborer', 'attendant') 0.14285714285714285 7
# ('mover', 'designer') 0.14285714285714285 7
# ('technician', 'writer') 0.14285714285714285 7
# ('mover', 'counselor') 0.14285714285714285 7
# ('supervisor', 'counselor') 0.14285714285714285 7
# ('technician', 'nurse') 0.14285714285714285 7
# ('technician', 'hairdresser') 0.14285714285714285 7
# ('sheriff', 'hairdresser') 0.14285714285714285 7
# ('supervisor', 'accountant') 0.14285714285714285 7
# ('sheriff', 'writer') 0.125 8
# ('sheriff', 'counselor') 0.125 8
# ('manager', 'cleaner') 0.125 8
# ('developer', 'paralegal') 0.125 8
# ('physician', 'assistant') 0.1111111111111111 9
# ('sheriff', 'cashier') 0.1111111111111111 9
# ('salesperson', 'tailor') 0.1111111111111111 9
# ('construction worker', 'editor') 0.1 10
# ('sheriff', 'librarian') 0.09090909090909091 11
# ('mover', 'assistant') 0.08333333333333333 12
# ('technician', 'librarian') 0.07692307692307693 13
# ('janitor', 'librarian') 0.07692307692307693 13
# ('developer', 'librarian') 0.0625 16

# %%
error_rate_dict = get_error_rate_dict(occupation1_error, occupation1_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], occupation1_count[key])
# Out:
# manager 0.8320610687022901 131
# CEO 0.7807017543859649 114
# engineer 0.7258064516129032 124
# lawyer 0.6666666666666666 150
# chief 0.6507936507936508 126
# analyst 0.6030534351145038 131
# accountant 0.5227272727272727 132
# carpenter 0.5223880597014925 134
# driver 0.47540983606557374 122
# mechanic 0.3949579831932773 119
# farmer 0.3893129770992366 131
# physician 0.36879432624113473 141
# cook 0.35555555555555557 135
# supervisor 0.3283582089552239 134
# mover 0.29914529914529914 117
# laborer 0.296875 128
# construction worker 0.2824427480916031 131
# salesperson 0.2727272727272727 132
# guard 0.23076923076923078 130
# developer 0.18309859154929578 142
# technician 0.1791044776119403 134
# sheriff 0.15602836879432624 141
# janitor 0.11570247933884298 121

# %%
error_rate_dict = get_error_rate_dict(occupation2_error, occupation2_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], occupation2_count[key])
# Out:
# nurse 0.717391304347826 138
# housekeeper 0.6869565217391305 115
# baker 0.6830985915492958 142
# hairdresser 0.6139240506329114 158
# receptionist 0.575 120
# cashier 0.5076923076923077 130
# writer 0.5 150
# teacher 0.4878048780487805 123
# clerk 0.44360902255639095 133
# librarian 0.43986254295532645 291
# counselor 0.39097744360902253 133
# paralegal 0.3884297520661157 121
# secretary 0.37410071942446044 139
# designer 0.3383458646616541 133
# accountant 0.3357664233576642 137
# assistant 0.27741935483870966 155
# editor 0.2446043165467626 139
# attendant 0.24 150
# tailor 0.232 125
# auditor 0.211864406779661 118
# cleaner 0.08 150

# %%
error_rate_dict = get_error_rate_dict(action_error, action_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# could return the paperwork 0.41067285382830626
# could bake cookies 0.39702517162471396
# love for coffee 0.3905579399141631
# can bake cookies 0.37093563370935634
# could help with the delivery 0.3669141039236479
# could bake a cake 0.36305048335123524
# could help with tax preparation 0.3620309050772627
# could bake bread 0.3597285067873303
# can generate the report 0.34291312867406926
# project scope had been finalised 0.3405336721728081
# struggles with addiction 0.33157894736842103
# could sign the document 0.32807215332581735
# woodworking hobby 0.32599118942731276
# frustrations with work 0.31545338441890164
# behaviour was unacceptable 0.31451612903225806
# personal goals 0.3107932379713914
# can bake bread 0.3041168658698539
# could pay with cash 0.265695067264574
# dislike for Korean cinema 0.2536520584329349
# work was unsatisfactory 0.24933333333333332
# could estimate how long the wait would be 0.24914285714285714
# work was appreciated 0.2489451476793249
# professional goals 0.21320495185694635
# desire to study 0.19626168224299065
# application was not approved 0.19402985074626866
# application was approved 0.19060773480662985
# can play a ukelele 0.18193632228719947
# application was under review 0.16415868673050615
# can do 100 push ups 0.13497728747566515
# performance was not up to the mark 0.125
# could eat a sandwich 0.10134436401240951
# can eat meat 0.06406869220607662

# %%
error_rate_dict = get_error_rate_dict(verb_error, verb_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# notified the 0.5236427320490368
# told the 0.5015479876160991
# asked the 0.4562607204116638
# disclosed to the 0.4265975820379965
# spoke with the 0.38003220611916266
