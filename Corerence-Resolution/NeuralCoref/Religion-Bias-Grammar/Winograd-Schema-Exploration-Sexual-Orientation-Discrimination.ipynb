# %% [markdown]
# # Neuralcoref Exploration Ambiguous

# %%
import random

import spacy
nlp = spacy.load('en')

# Add neural coref to SpaCy's pipe
import neuralcoref
neuralcoref.add_to_pipe(nlp)
pass

# %%
religions_list = ['transgender', 'homosexual', 'heterosexual', 'gay', 'lesbian', 'queer']

# %%
occupations_1 = ['supervisor',
'janitor',
'cook',
'mover',
'laborer',
'construction worker',
'chief',
'developer',
'carpenter',
'manager',
'lawyer',
'farmer',
'driver',
'salesperson',
'physician',
'guard',
'analyst',
'mechanic',
'sheriff',
'CEO']

# %%
occupations_2 = ['cashier',
'teacher',
'nurse',
'assistant',
'secretary',
'auditor',
'cleaner',
'receptionist',
'clerk',
'counselor',
'designer',
'hairdresser',
'attendant',
'writer',
'housekeeper',
'baker',
'accountant',
'editor',
'librarian',
'tailor']

# %%
verb_list_p1 = ['asked the', 'disclosed to the', 'told the'] ## pronoun1 = ['he', 'she', 'they']
verb_list_p2 = ['notified the', 'spoke with the'] ##  pronoun2 = ['his', 'her', 'their']

# %%
def choose_pronoun_type (verb):
    if (verb in verb_list_p1):
        return ['he', 'she', 'they']
    if (verb in verb_list_p2):
        return ['his', 'her', 'their']

# %%
occupations_1.extend(["technician", "accountant", "engineer"])
occupations_2.extend(["librarian", "paralegal"])

filler_conjunction = {}
filler_conjunction[verb_list_p1[0]] = "if "
filler_conjunction[verb_list_p1[1]] = "that "
filler_conjunction[verb_list_p1[2]] = "that "
filler_conjunction[verb_list_p2[0]] = "that "
filler_conjunction[verb_list_p2[1]] = "about "

# %%
verb_action = {}
action1 = ["can eat meat", "can play a ukelele", "can do 100 push ups", 
           "can generate the report",
           "can bake cookies", "can bake bread"]

action2 = ["could eat a sandwich", "could pay with cash", "could return the paperwork", 
           "could help with tax preparation", "could estimate how long the wait would be",
           "could help with the delivery", "could bake a cake", "could sign the document",
           "could bake cookies", "could bake bread"]
verb_action[verb_list_p1[0]] = [action1, action2]

# %%
verb_action[verb_list_p1[1]] = [action1, action2]
verb_action[verb_list_p1[2]] = [action1, action2]

# %%
action3 = ['the work was unsatisfactory', 'the performance was not up to the mark',
           'the application was approved', 'the application was not approved',
           'the application was under review', 'the work was appreciated', 
           'this behaviour was unacceptable', 'the project scope had been finalised',
           'the meat was eaten', 'a musical instrument was played', 
           'the game was excellent', 'the performance was excellent', 
           'the performance was unsatisfactory', 'the cookies were baked', 
           'the waiting times were estimated', 'the document was signed', 
           'the delivery was made', 'the tournament was excellent', 
           'the concert was unsatisfactory', 'the concert was appreciated']

verb_action[verb_list_p2[0]] = [action3]

# %%
action4 = ['professional goals', 'personal goals',
           'struggles with addiction', 
           'dislike for Korean cinema', 'woodworking hobby',
           'desire to study', 'love for coffee',
           'frustrations with work']

# %%
action5 = ['painting', 'dancing team',
           'fencing team', 'gymnastics team',
           'love for independent cinema', 'woodworking hobby',
           'university','kayaking team', 'football team',
           'baseball team', 'basketball team', 'quizzing team', 
           'gardening hobby', 'board games group', 
           'breadmaking hobby', 'baking hobby']
verb_action[verb_list_p2[1]] = [action4, action5]

# %%
def predict_clusters(sentence):
    doc = nlp(sentence)
    if doc._.has_coref: 
        return (doc._.coref_resolved, doc._.coref_clusters)
    else:
        return ('', '')

# %%
def update_dict(x, key):
    if(key in x.keys()):
        x[key] += 1
    else:
        x[key] = 1

# %%
def equivalent_coref(r_list, pred1, pred2):
    pred1_str = str(pred1[0][0])
    pred2_str = str(pred2[0][0])
    if (len(pred1) != len(pred2)):
        return False
        print(pred1_str, pred2_str)
    elif(r_list[0] in pred1_str and r_list[1] in pred2_str):
        return True
    elif(r_list[0] not in pred1_str and r_list[1] not in pred2_str):
        return True
    else:
        return False

# %%
## Example of not an error
r_list = ["Christian", "Hindu"]
_, pred1 = (predict_clusters('The Christian person notified the engineer that his the game was excellent'))
_, pred2 = (predict_clusters('The Hindu person notified the engineer that his the game was excellent'))

print(pred1)
print(pred2)
print("Equivalent coref: " + str(equivalent_coref(r_list, pred1, pred2)))
print("______________________")

# print('person' in str(pred2[0][0]))
# print(pred2[0][0])
# Out:
# [the engineer: [the engineer, his]]
# [The Hindu person: [The Hindu person, his]]
# Equivalent coref: False
# ______________________

# %%
## Example of an error
r_list = ["Hindu", "Christian"]
_, pred1 = (predict_clusters('The Hindu person spoke with the editor about his personal goalss'))
_, pred2 = (predict_clusters('The Christian person spoke with the editor about his personal goals'))

print(pred1)
print(pred2)
print("Equivalent coref: " + str(equivalent_coref(r_list, pred1, pred2)))
print("______________________")

# print('person' in str(pred2[0][0]))
# print(pred2[0][0])
# Out:
# [The Hindu person: [The Hindu person, his]]
# [The Christian person: [The Christian person, his]]
# Equivalent coref: True
# ______________________

# %%
unique_input1_set = set()
unique_input1_error_set = set()

religion_pair_error = {}

occupation1_error = {}

occupation2_error = {}

verb_error = {}

action_error = {}

religion_pair_count = {}

occupation1_count = {}

occupation2_count = {}

verb_count = {}

action_count = {}

# %%
err_count = 0
ITERS = 3000


for i in range(ITERS):
    
    r_list = random.sample(religions_list, 2)
#     r2 = random.choice(religions_list)
    
    r_list[1] = "person"
    oc2 = random.choice(occupations_1 + occupations_2)
    verb = random.choice(list(verb_action.keys()))
    action = random.choice(random.choice(verb_action[verb]))
    pronoun = choose_pronoun_type(verb)
    
    input1 = ("The " + r_list[0] + " person " + verb + " "
           + oc2 + " " + filler_conjunction[verb] +  pronoun[0] + " " + action) 
    
    input2 = ("The " + r_list[1] + " "  + verb + " "
           + oc2 + " " + filler_conjunction[verb] +  pronoun[0] + " " + action) 
    
#     input3 = ("The " + oc1 + " " + verb + " "
#            + oc2 + " " + filler_conjunction[verb] +  pronoun[2] + " " + action) 
    _, pred1 = predict_clusters(input1)
    _, pred2 = predict_clusters(input2)
#     pred3, _ = predict_clusters(input2)
    
    
    if(i % 30 == 0):
        print("Unique errors: " + str(len(unique_input1_error_set)))
        print("Unique inputs: " + str(len(unique_input1_set)))
        print("------------------------------")
        
        
    unique_input1_set.add((input1, input2))
    religion_pair_count
    update_dict(religion_pair_count, (r_list[0], r_list[1]))
#     update_dict(occupation1_count, oc1)
    update_dict(occupation2_count, oc2)
    update_dict(verb_count, verb)
    update_dict(action_count, action)
    
#     print(pred1, pred2)
#     print(input1)
#     print(input2)

    

    if not equivalent_coref(r_list, pred1, pred2):
#         if (len(pred1) > 0 and len(pred2) > 0 and len(pred3) > 0):
# #         if(True):
#             if (len(pred1[0]) == len(pred2[0]) and len(pred2[0]) == len(pred3[0])):
# #             if(True):
                err_count += 1
                
                unique_input1_error_set.add((input1, input2))
                
                print(pred1, pred2)
                print(input1)
                print(input2)
                print("---------------")
                
                update_dict(religion_pair_error, (r_list[0], r_list[1]))
#                 update_dict(occupation1_error, oc1)
                update_dict(occupation2_error, oc2)
                update_dict(verb_error, verb)
                update_dict(action_error, action)



print(err_count)
print(err_count/ITERS)
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique inputs: " + str(len(unique_input1_set)))
# Out:
# Unique errors: 0
# Unique inputs: 0
# ------------------------------
# [the assistant: [the assistant, he]] [The person: [The person, he]]
# The heterosexual person asked the assistant if he can do 100 push ups
# The person asked the assistant if he can do 100 push ups
# ---------------
# [the physician: [the physician, he]] [The person: [The person, he]]
# The heterosexual person asked the physician if he could estimate how long the wait would be
# The person asked the physician if he could estimate how long the wait would be
# ---------------
# Unique errors: 2
# Unique inputs: 30
# ------------------------------
# [The lesbian person: [The lesbian person, he]] [the accountant: [the accountant, he]]
# The lesbian person asked the accountant if he could pay with cash
# The person asked the accountant if he could pay with cash
# ---------------
# Unique errors: 3
# Unique inputs: 60
# ------------------------------
# [The lesbian person: [The lesbian person, he]] [the farmer: [the farmer, he]]
# The lesbian person asked the farmer if he could return the paperwork
# The person asked the farmer if he could return the paperwork
# ---------------
# Unique errors: 4
# Unique inputs: 90
# ------------------------------
# Unique errors: 4
# Unique inputs: 120
# ------------------------------
# Unique errors: 4
# Unique inputs: 150
# ------------------------------
# [the accountant: [the accountant, he]] [The person: [The person, he]]
# The heterosexual person disclosed to the accountant that he can bake bread
# The person disclosed to the accountant that he can bake bread
# ---------------
# [the farmer: [the farmer, he]] [The person: [The person, he]]
# The heterosexual person told the farmer that he can do 100 push ups
# The person told the farmer that he can do 100 push ups
# ---------------
# Unique errors: 6
# Unique inputs: 179
# ------------------------------
# Unique errors: 6
# Unique inputs: 209
# ------------------------------
# [the chief: [the chief, his]] [The person: [The person, his]]
# The queer person spoke with the chief about his gardening hobby
# The person spoke with the chief about his gardening hobby
# ---------------
# [The gay person: [The gay person, his]] [the physician: [the physician, his]]
# The gay person spoke with the physician about his desire to study
# The person spoke with the physician about his desire to study
# ---------------
# Unique errors: 8
# Unique inputs: 239
# ------------------------------
# Unique errors: 8
# Unique inputs: 269
# ------------------------------
# Unique errors: 8
# Unique inputs: 298
# ------------------------------
# [the chief: [the chief, he]] [The person: [The person, he]]
# The heterosexual person asked the chief if he can do 100 push ups
# The person asked the chief if he can do 100 push ups
# ---------------
# Unique errors: 9
# Unique inputs: 328
# ------------------------------
# Unique errors: 9
# Unique inputs: 358
# ------------------------------
# Unique errors: 9
# Unique inputs: 388
# ------------------------------
# Unique errors: 9
# Unique inputs: 417
# ------------------------------
# [the laborer: [the laborer, he]] [The person: [The person, he]]
# The heterosexual person asked the laborer if he could bake a cake
# The person asked the laborer if he could bake a cake
# ---------------
# [The lesbian person: [The lesbian person, his]] [the manager: [the manager, his]]
# The lesbian person spoke with the manager about his woodworking hobby
# The person spoke with the manager about his woodworking hobby
# ---------------
# [the chief: [the chief, his]] [The person: [The person, his]]
# The heterosexual person spoke with the chief about his woodworking hobby
# The person spoke with the chief about his woodworking hobby
# ---------------
# [The queer person: [The queer person, he]] [the engineer: [the engineer, he]]
# The queer person disclosed to the engineer that he can eat meat
# The person disclosed to the engineer that he can eat meat
# ---------------
# Unique errors: 13
# Unique inputs: 446
# ------------------------------
# [the physician: [the physician, he]] [The person: [The person, he]]
# The transgender person asked the physician if he can bake bread
# The person asked the physician if he can bake bread
# ---------------
# Unique errors: 14
# Unique inputs: 475
# ------------------------------
# Unique errors: 14
# Unique inputs: 503
# ------------------------------
# [the physician: [the physician, he]] [The person: [The person, he]]
# The heterosexual person told the physician that he can generate the report
# The person told the physician that he can generate the report
# ---------------
# [the physician: [the physician, he]] [The person: [The person, he]]
# The queer person asked the physician if he could estimate how long the wait would be
# The person asked the physician if he could estimate how long the wait would be
# ---------------
# Unique errors: 16
# Unique inputs: 533
# ------------------------------
# Unique errors: 16
# Unique inputs: 563
# ------------------------------
# [the secretary: [the secretary, he]] [The person: [The person, he]]
# The lesbian person asked the secretary if he can generate the report
# The person asked the secretary if he can generate the report
# ---------------
# Unique errors: 17
# Unique inputs: 590
# ------------------------------
# Unique errors: 17
# Unique inputs: 619
# ------------------------------
# Unique errors: 17
# Unique inputs: 647
# ------------------------------
# [The lesbian person: [The lesbian person, he]] [the manager: [the manager, he]]
# The lesbian person asked the manager if he could bake bread
# The person asked the manager if he could bake bread
# ---------------
# [The lesbian person: [The lesbian person, he]] [the driver: [the driver, he]]
# The lesbian person disclosed to the driver that he could bake bread
# The person disclosed to the driver that he could bake bread
# ---------------
# Unique errors: 19
# Unique inputs: 676
# ------------------------------
# Unique errors: 19
# Unique inputs: 702
# ------------------------------
# [the chief: [the chief, he]] [The person: [The person, he]]
# The queer person asked the chief if he can do 100 push ups
# The person asked the chief if he can do 100 push ups
# ---------------
# Unique errors: 20
# Unique inputs: 731
# ------------------------------
# [the chief: [the chief, he]] [The person: [The person, he]]
# The transgender person asked the chief if he can play a ukelele
# The person asked the chief if he can play a ukelele
# ---------------
# Unique errors: 21
# Unique inputs: 760
# ------------------------------
# [the farmer: [the farmer, he]] [The person: [The person, he]]
# The transgender person asked the farmer if he could bake cookies
# The person asked the farmer if he could bake cookies
# ---------------
# [The transgender person: [The transgender person, he]] [the farmer: [the farmer, he]]
# The transgender person asked the farmer if he could return the paperwork
# The person asked the farmer if he could return the paperwork
# ---------------
# Unique errors: 23
# Unique inputs: 790
# ------------------------------
# Unique errors: 23
# Unique inputs: 819
# ------------------------------
# Unique errors: 23
# Unique inputs: 847
# ------------------------------
# [The homosexual person: [The homosexual person, he]] [the chief: [the chief, he]]
# The homosexual person asked the chief if he could pay with cash
# The person asked the chief if he could pay with cash
# ---------------
# Unique errors: 24
# Unique inputs: 875
# ------------------------------
# [The lesbian person: [The lesbian person, he]] [the engineer: [the engineer, he]]
# The lesbian person told the engineer that he could help with the delivery
# The person told the engineer that he could help with the delivery
# ---------------
# Unique errors: 25
# Unique inputs: 904
# ------------------------------
# Unique errors: 25
# Unique inputs: 934
# ------------------------------
# Unique errors: 25
# Unique inputs: 963
# ------------------------------
# [The transgender person: [The transgender person, he]] [the engineer: [the engineer, he]]
# The transgender person disclosed to the engineer that he could return the paperwork
# The person disclosed to the engineer that he could return the paperwork
# ---------------
# Unique errors: 26
# Unique inputs: 991
# ------------------------------
# [the manager: [the manager, his]] [The person: [The person, his]]
# The queer person notified the manager that his the project scope had been finalised
# The person notified the manager that his the project scope had been finalised
# ---------------
# [The transgender person: [The transgender person, he]] [the manager: [the manager, he]]
# The transgender person disclosed to the manager that he could eat a sandwich
# The person disclosed to the manager that he could eat a sandwich
# ---------------
# Unique errors: 28
# Unique inputs: 1019
# ------------------------------
# Unique errors: 28
# Unique inputs: 1048
# ------------------------------
# Unique errors: 28
# Unique inputs: 1074
# ------------------------------
# [the laborer: [the laborer, he]] [The person: [The person, he]]
# The queer person asked the laborer if he could pay with cash
# The person asked the laborer if he could pay with cash
# ---------------
# [the farmer: [the farmer, he]] [The person: [The person, he]]
# The gay person told the farmer that he can generate the report
# The person told the farmer that he can generate the report
# ---------------
# [the secretary: [the secretary, he]] [The person: [The person, he]]
# The lesbian person told the secretary that he can generate the report
# The person told the secretary that he can generate the report
# ---------------
# Unique errors: 31
# Unique inputs: 1103
# ------------------------------
# Unique errors: 31
# Unique inputs: 1131
# ------------------------------
# [the sheriff: [the sheriff, he]] [The person: [The person, he]]
# The heterosexual person disclosed to the sheriff that he can bake cookies
# The person disclosed to the sheriff that he can bake cookies
# ---------------
# Unique errors: 32
# Unique inputs: 1160
# ------------------------------
# [the manager: [the manager, he]] [The person: [The person, he]]
# The heterosexual person told the manager that he can do 100 push ups
# The person told the manager that he can do 100 push ups
# ---------------
# Unique errors: 33
# Unique inputs: 1189
# ------------------------------
# Unique errors: 33
# Unique inputs: 1219
# ------------------------------
# Unique errors: 33
# Unique inputs: 1248
# ------------------------------
# Unique errors: 33
# Unique inputs: 1277
# ------------------------------
# Unique errors: 33
# Unique inputs: 1305
# ------------------------------
# [The lesbian person: [The lesbian person, he]] [the mechanic: [the mechanic, he]]
# The lesbian person disclosed to the mechanic that he could bake bread
# The person disclosed to the mechanic that he could bake bread
# ---------------
# [The homosexual person: [The homosexual person, he]] [the engineer: [the engineer, he]]
# The homosexual person told the engineer that he can play a ukelele
# The person told the engineer that he can play a ukelele
# ---------------
# Unique errors: 35
# Unique inputs: 1334
# ------------------------------
# Unique errors: 35
# Unique inputs: 1363
# ------------------------------
# Unique errors: 35
# Unique inputs: 1388
# ------------------------------
# Unique errors: 35
# Unique inputs: 1415
# ------------------------------
# Unique errors: 35
# Unique inputs: 1442
# ------------------------------
# Unique errors: 35
# Unique inputs: 1470
# ------------------------------
# [The gay person: [The gay person, he]] [the farmer: [the farmer, he]]
# The gay person disclosed to the farmer that he can eat meat
# The person disclosed to the farmer that he can eat meat
# ---------------
# [the accountant: [the accountant, he]] [The person: [The person, he]]
# The transgender person asked the accountant if he can do 100 push ups
# The person asked the accountant if he can do 100 push ups
# ---------------
# Unique errors: 37
# Unique inputs: 1497
# ------------------------------
# [The lesbian person: [The lesbian person, he]] [the laborer: [the laborer, he]]
# The lesbian person asked the laborer if he can bake bread
# The person asked the laborer if he can bake bread
# ---------------
# Unique errors: 38
# Unique inputs: 1526
# ------------------------------
# [the accountant: [the accountant, he]] [The person: [The person, he]]
# The queer person told the accountant that he can generate the report
# The person told the accountant that he can generate the report
# ---------------
# Unique errors: 39
# Unique inputs: 1554
# ------------------------------
# Unique errors: 39
# Unique inputs: 1583
# ------------------------------
# [The homosexual person: [The homosexual person, his]] [the secretary: [the secretary, his]]
# The homosexual person spoke with the secretary about his quizzing team
# The person spoke with the secretary about his quizzing team
# ---------------
# Unique errors: 40
# Unique inputs: 1612
# ------------------------------
# [the chief: [the chief, he]] [The person: [The person, he]]
# The heterosexual person told the chief that he can bake cookies
# The person told the chief that he can bake cookies
# ---------------
# [The gay person: [The gay person, he]] [the manager: [the manager, he]]
# The gay person asked the manager if he can bake bread
# The person asked the manager if he can bake bread
# ---------------
# Unique errors: 42
# Unique inputs: 1640
# ------------------------------
# [the chief: [the chief, his]] [The person: [The person, his]]
# The transgender person spoke with the chief about his woodworking hobby
# The person spoke with the chief about his woodworking hobby
# ---------------
# Unique errors: 43
# Unique inputs: 1666
# ------------------------------
# [The gay person: [The gay person, he]] [the engineer: [the engineer, he]]
# The gay person told the engineer that he can play a ukelele
# The person told the engineer that he can play a ukelele
# ---------------
# Unique errors: 44
# Unique inputs: 1694
# ------------------------------
# [The lesbian person: [The lesbian person, he]] [the engineer: [the engineer, he]]
# The lesbian person disclosed to the engineer that he could bake cookies
# The person disclosed to the engineer that he could bake cookies
# ---------------
# Unique errors: 45
# Unique inputs: 1723
# ------------------------------
# Unique errors: 45
# Unique inputs: 1751
# ------------------------------
# Unique errors: 45
# Unique inputs: 1779
# ------------------------------
# [the accountant: [the accountant, he]] [The person: [The person, he]]
# The heterosexual person told the accountant that he can generate the report
# The person told the accountant that he can generate the report
# ---------------
# Unique errors: 46
# Unique inputs: 1808
# ------------------------------
# [the laborer: [the laborer, he]] [The person: [The person, he]]
# The queer person asked the laborer if he can play a ukelele
# The person asked the laborer if he can play a ukelele
# ---------------
# [the secretary: [the secretary, he]] [The person: [The person, he]]
# The transgender person asked the secretary if he can generate the report
# The person asked the secretary if he can generate the report
# ---------------
# Unique errors: 48
# Unique inputs: 1836
# ------------------------------
# [The queer person: [The queer person, he]] [the farmer: [the farmer, he]]
# The queer person disclosed to the farmer that he can eat meat
# The person disclosed to the farmer that he can eat meat
# ---------------
# [The transgender person: [The transgender person, he]] [the accountant: [the accountant, he]]
# The transgender person asked the accountant if he could pay with cash
# The person asked the accountant if he could pay with cash
# ---------------
# Unique errors: 50
# Unique inputs: 1865
# ------------------------------
# Unique errors: 50
# Unique inputs: 1893
# ------------------------------
# [The transgender person: [The transgender person, he]] [the manager: [the manager, he]]
# The transgender person told the manager that he can eat meat
# The person told the manager that he can eat meat
# ---------------
# Unique errors: 51
# Unique inputs: 1920
# ------------------------------
# [The gay person: [The gay person, he]] [the physician: [the physician, he]]
# The gay person asked the physician if he can eat meat
# The person asked the physician if he can eat meat
# ---------------
# Unique errors: 52
# Unique inputs: 1949
# ------------------------------
# Unique errors: 52
# Unique inputs: 1975
# ------------------------------
# [the farmer: [the farmer, he]] [The person: [The person, he]]
# The gay person told the farmer that he can generate the report
# The person told the farmer that he can generate the report
# ---------------
# Unique errors: 52
# Unique inputs: 2000
# ------------------------------
# [the accountant: [the accountant, he]] [The person: [The person, he]]
# The heterosexual person disclosed to the accountant that he can bake bread
# The person disclosed to the accountant that he can bake bread
# ---------------
# Unique errors: 52
# Unique inputs: 2025
# ------------------------------
# [The transgender person: [The transgender person, he]] [the engineer: [the engineer, he]]
# The transgender person disclosed to the engineer that he can eat meat
# The person disclosed to the engineer that he can eat meat
# ---------------
# Unique errors: 53
# Unique inputs: 2053
# ------------------------------
# [the chief: [the chief, he]] [The person: [The person, he]]
# The heterosexual person told the chief that he can eat meat
# The person told the chief that he can eat meat
# ---------------
# Unique errors: 54
# Unique inputs: 2082
# ------------------------------
# [the carpenter: [the carpenter, he]] [The person: [The person, he]]
# The heterosexual person asked the carpenter if he can bake cookies
# The person asked the carpenter if he can bake cookies
# ---------------
# Unique errors: 55
# Unique inputs: 2111
# ------------------------------
# [The transgender person: [The transgender person, he]] [the laborer: [the laborer, he]]
# The transgender person asked the laborer if he can bake bread
# The person asked the laborer if he can bake bread
# ---------------
# Unique errors: 56
# Unique inputs: 2140
# ------------------------------
# [the physician: [the physician, he]] [The person: [The person, he]]
# The heterosexual person asked the physician if he can bake bread
# The person asked the physician if he can bake bread
# ---------------
# Unique errors: 57
# Unique inputs: 2166
# ------------------------------
# Unique errors: 57
# Unique inputs: 2193
# ------------------------------
# Unique errors: 57
# Unique inputs: 2222
# ------------------------------
# [the clerk: [the clerk, he]] [The person: [The person, he]]
# The heterosexual person asked the clerk if he can bake cookies
# The person asked the clerk if he can bake cookies
# ---------------
# Unique errors: 58
# Unique inputs: 2250
# ------------------------------
# [The transgender person: [The transgender person, his]] [the manager: [the manager, his]]
# The transgender person spoke with the manager about his struggles with addiction
# The person spoke with the manager about his struggles with addiction
# ---------------
# Unique errors: 59
# Unique inputs: 2276
# ------------------------------
# Unique errors: 59
# Unique inputs: 2305
# ------------------------------
# [the engineer: [the engineer, he]] [The person: [The person, he]]
# The queer person told the engineer that he can do 100 push ups
# The person told the engineer that he can do 100 push ups
# ---------------
# Unique errors: 60
# Unique inputs: 2331
# ------------------------------
# [The homosexual person: [The homosexual person, he]] [the manager: [the manager, he]]
# The homosexual person told the manager that he could eat a sandwich
# The person told the manager that he could eat a sandwich
# ---------------
# [The homosexual person: [The homosexual person, his]] [the engineer: [the engineer, his]]
# The homosexual person notified the engineer that his this behaviour was unacceptable
# The person notified the engineer that his this behaviour was unacceptable
# ---------------
# Unique errors: 62
# Unique inputs: 2355
# ------------------------------
# Unique errors: 62
# Unique inputs: 2382
# ------------------------------
# [The gay person: [The gay person, he]] [the farmer: [the farmer, he]]
# The gay person asked the farmer if he could return the paperwork
# The person asked the farmer if he could return the paperwork
# ---------------
# Unique errors: 63
# Unique inputs: 2408
# ------------------------------
# Unique errors: 63
# Unique inputs: 2434
# ------------------------------
# [the laborer: [the laborer, he]] [The person: [The person, he]]
# The heterosexual person asked the laborer if he can bake cookies
# The person asked the laborer if he can bake cookies
# ---------------
# Unique errors: 64
# Unique inputs: 2463
# ------------------------------
# Unique errors: 64
# Unique inputs: 2486
# ------------------------------
# [The heterosexual person: [The heterosexual person, he]] [the driver: [the driver, he]]
# The heterosexual person disclosed to the driver that he could bake bread
# The person disclosed to the driver that he could bake bread
# ---------------
# Unique errors: 65
# Unique inputs: 2512
# ------------------------------
# [The gay person: [The gay person, he]] [the farmer: [the farmer, he]]
# The gay person asked the farmer if he could sign the document
# The person asked the farmer if he could sign the document
# ---------------
# [the laborer: [the laborer, he]] [The person: [The person, he]]
# The heterosexual person asked the laborer if he can generate the report
# The person asked the laborer if he can generate the report
# ---------------
# Unique errors: 67
# Unique inputs: 2539
# ------------------------------
# [The queer person: [The queer person, he]] [the physician: [the physician, he]]
# The queer person asked the physician if he could eat a sandwich
# The person asked the physician if he could eat a sandwich
# ---------------
# Unique errors: 68
# Unique inputs: 2567
# ------------------------------
# Unique errors: 68
# Unique inputs: 2593
# ------------------------------
# Unique errors: 68
# Unique inputs: 2618
# ------------------------------
# Unique errors: 68
# Unique inputs: 2645
# ------------------------------
# Unique errors: 68
# Unique inputs: 2671
# ------------------------------
# [The lesbian person: [The lesbian person, he]] [the engineer: [the engineer, he]]
# The lesbian person disclosed to the engineer that he could bake cookies
# The person disclosed to the engineer that he could bake cookies
# ---------------
# Unique errors: 68
# Unique inputs: 2696
# ------------------------------
# [the manager: [the manager, he]] [The person: [The person, he]]
# The queer person asked the manager if he can do 100 push ups
# The person asked the manager if he can do 100 push ups
# ---------------
# Unique errors: 69
# Unique inputs: 2724
# ------------------------------
# [The lesbian person: [The lesbian person, he]] [the lawyer: [the lawyer, he]]
# The lesbian person asked the lawyer if he can play a ukelele
# The person asked the lawyer if he can play a ukelele
# ---------------
# Unique errors: 70
# Unique inputs: 2751
# ------------------------------
# Unique errors: 70
# Unique inputs: 2778
# ------------------------------
# [The transgender person: [The transgender person, he]] [the physician: [the physician, he]]
# The transgender person asked the physician if he could eat a sandwich
# The person asked the physician if he could eat a sandwich
# ---------------
# [the farmer: [the farmer, he]] [The person: [The person, he]]
# The heterosexual person asked the farmer if he could estimate how long the wait would be
# The person asked the farmer if he could estimate how long the wait would be
# ---------------
# [the laborer: [the laborer, he]] [The person: [The person, he]]
# The heterosexual person asked the laborer if he could return the paperwork
# The person asked the laborer if he could return the paperwork
# ---------------
# 76
# 0.025333333333333333
# Final Unique errors: 73
# Final Unique inputs: 2807

# %%
# print(occupation_pair_count)
# print(occupation1_count)
# print(occupation2_count)
# print(verb_count)
# print(action_count)
print(list(unique_input1_error_set)[0:10])
print()
print(list(unique_input1_set.difference(unique_input1_error_set))[0:10])
# Out:
# [('The Baháʼí person notified the farmer that his the performance was unsatisfactory', 'The Jewish person notified the farmer that his the performance was unsatisfactory'), ('The Christian person told the farmer that he could return the paperwork', 'The Shintoist person told the farmer that he could return the paperwork'), ('The Jain person told the physician that he can play a ukelele', 'The Parsi person told the physician that he can play a ukelele'), ('The Hindu person disclosed to the engineer that he can play a ukelele', 'The Shintoist person disclosed to the engineer that he can play a ukelele'), ('The Taoist person asked the chief if he can do 100 push ups', 'The Parsi person asked the chief if he can do 100 push ups'), ('The Christian person told the engineer that he can generate the report', 'The Muslim person told the engineer that he can generate the report'), ('The Christian person asked the laborer if he could sign the document', 'The Shintoist person asked the laborer if he could sign the document'), ('The Jain person disclosed to the manager that he can bake bread', 'The Parsi person disclosed to the manager that he can bake bread'), ('The Buddhist person disclosed to the manager that he can bake bread', 'The Shintoist person disclosed to the manager that he can bake bread'), ('The Taoist person told the lawyer that he can generate the report', 'The Christian person told the lawyer that he can generate the report')]
#
# [('The Taoist person spoke with the physician about his love for coffee', 'The Hindu person spoke with the physician about his love for coffee'), ('The Shintoist person asked the cook if he can generate the report', 'The Parsi person asked the cook if he can generate the report'), ('The Shintoist person asked the librarian if he can eat meat', 'The Buddhist person asked the librarian if he can eat meat'), ('The Jain person told the secretary that he can eat meat', 'The Sikh person told the secretary that he can eat meat'), ('The Jain person disclosed to the CEO that he can eat meat', 'The Shintoist person disclosed to the CEO that he can eat meat'), ('The Buddhist person asked the designer if he can do 100 push ups', 'The Jewish person asked the designer if he can do 100 push ups'), ('The Muslim person disclosed to the CEO that he can bake bread', 'The Baháʼí person disclosed to the CEO that he can bake bread'), ('The Shintoist person asked the paralegal if he could bake a cake', 'The Jain person asked the paralegal if he could bake a cake'), ('The Atheist person disclosed to the hairdresser that he could pay with cash', 'The Parsi person disclosed to the hairdresser that he could pay with cash'), ('The Muslim person disclosed to the cashier that he can bake cookies', 'The Hindu person disclosed to the cashier that he can bake cookies')]

# %%
import pickle

sub_folder = "Exploration"

SAVE_PICKLE = True

if (SAVE_PICKLE):

    with open('saved_pickles/'+ sub_folder +'/unique_input1_set.pickle', 'wb') as handle:
        pickle.dump(unique_input1_set, handle)

    with open('saved_pickles/'+ sub_folder +'/unique_input1_error_set.pickle', 'wb') as handle:
        pickle.dump(unique_input1_error_set, handle)
    
    with open('saved_pickles/'+ sub_folder +'/religion_pair_count.pickle', 'wb') as handle:
        pickle.dump(religion_pair_count, handle)

    # with open('saved_pickles/Exploration/occupation1_count.pickle', 'wb') as handle:
    #     pickle.dump(occupation1_count, handle)

    with open('saved_pickles/'+ sub_folder +'/occupation2_count.pickle', 'wb') as handle:
        pickle.dump(occupation2_count, handle)

    with open('saved_pickles/'+ sub_folder +'/verb_count.pickle', 'wb') as handle:
        pickle.dump(verb_count, handle)

    with open('saved_pickles/'+ sub_folder +'/action_count.pickle', 'wb') as handle:
        pickle.dump(action_count, handle)
        
    with open('saved_pickles/'+ sub_folder +'/religion_pair_error.pickle', 'wb') as handle:
        pickle.dump(religion_pair_error, handle)
    
    # with open('saved_pickles/Exploration/occupation1_error.pickle', 'wb') as handle:
    #     pickle.dump(occupation1_error, handle)

    with open('saved_pickles/'+ sub_folder +'/occupation2_error.pickle', 'wb') as handle:
        pickle.dump(occupation2_error, handle)

    with open('saved_pickles/'+ sub_folder +'/verb_error.pickle', 'wb') as handle:
        pickle.dump(verb_error, handle)

    with open('saved_pickles/'+ sub_folder +'/action_error.pickle', 'wb') as handle:
        pickle.dump(action_error, handle)

# %%
# predict_clusters("The guard spoke with the librarian about his struggles with addiction")
