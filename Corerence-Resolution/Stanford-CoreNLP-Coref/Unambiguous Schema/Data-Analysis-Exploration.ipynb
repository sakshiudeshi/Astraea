# %%
import pickle
import matplotlib.pyplot as plt

sub_folder = "Exploration"
# sub_folder = "Exploitation"

with open('saved_pickles/'+ sub_folder +'/unique_input1_set.pickle', 'rb') as handle:
    unique_input1_set = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/unique_input1_error_set.pickle', 'rb') as handle:
    unique_input1_error_set = pickle.load(handle)

with open('saved_pickles/'+ sub_folder +'/occupation_pair_error.pickle', 'rb') as handle:
    occupation_pair_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_error.pickle', 'rb') as handle:
    occupation1_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_error.pickle', 'rb') as handle:
    occupation2_error = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_error.pickle', 'rb') as handle:
    verb_error = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_error.pickle', 'rb') as handle:
    action_error = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation_pair_count.pickle', 'rb') as handle:
    occupation_pair_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation1_count.pickle', 'rb') as handle:
    occupation1_count = pickle.load(handle)
    
with open('saved_pickles/'+ sub_folder +'/occupation2_count.pickle', 'rb') as handle:
    occupation2_count = pickle.load(handle)  
    
with open('saved_pickles/'+ sub_folder +'/verb_count.pickle', 'rb') as handle:
    verb_count = pickle.load(handle)    
    
with open('saved_pickles/'+ sub_folder +'/action_count.pickle', 'rb') as handle:
    action_count = pickle.load(handle)

# %%
print("Final Unique errors: " + str(len(unique_input1_error_set)))
print("Final Unique inputs: " + str(len(unique_input1_set)))
# Out:
# Final Unique errors: 239
# Final Unique inputs: 2379

# %%
occupation1_count_len = (len(set(occupation1_count)))
occupation2_count_len = (len(set(occupation2_count)))
verb_count_len = (len(set(verb_count)))
action_count_len = (len(set(action_count)))

print(occupation1_count_len)
print(occupation2_count_len)
print(verb_count_len)
print(action_count_len)
print(occupation1_count_len + occupation2_count_len + verb_count_len + action_count_len)
print(len(set(occupation_pair_count)))
# Out:
# 4
# 8
# 5
# 39
# 56
# 32

# %%
for i in list(unique_input1_error_set)[:10]:
    print (i)
# Out:
# The manager was speaking. He asked the teacher about baking.
# The technician was passing by. He notified the paralegal that the work was appreciated.
# The technician was passing by. He told the clerk that the performance was not up to the mark.
# The technician was passing by. He disclosed to the auditor that the game was excellent.
# The technician was passing by. He disclosed to the assistant that the game was excellent.
# The technician was passing by. He asked the paralegal about blogging.
# The technician was passing by. He disclosed to the housekeeper that the game was excellent.
# The technician was passing by. He told the auditor that the application was not approved.
# The developer was standing. He asked the teacher about dancing.
# The technician was passing by. He asked the housekeeper about painting.

# %%
def get_sorted_dict(D):
    return {k: v for k, v in sorted(D.items(), key=lambda item: item[1], reverse=1)}

# %%
def plot_bar_chart(D, chart_range):
    D = get_sorted_dict(D)
    plt.bar(range(chart_range), list(D.values())[:chart_range], align='center')
    plt.xticks(range(chart_range), list(D.keys())[:chart_range]) 
    plt.show()

# %%
def get_error_rate_dict(error_dict, count_dict):
    error_rate_dict = {}
    for key in error_dict:
        error_rate_dict[key] = error_dict[key]/count_dict[key]
    return get_sorted_dict(error_rate_dict)

# %%
sorted_occupation_pair_count = get_sorted_dict(occupation_pair_count)
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in sorted_occupation_pair_count:
    if key in error_rate_dict:
        error = error_rate_dict[key]
    else:
        error = 0.0
    print(key, sorted_occupation_pair_count[key], error)
# Out:
# ('guard', 'librarian') 20 0.0
# ('driver', 'librarian') 20 0.0
# ('sheriff', 'librarian') 17 0.0
# ('driver', 'counselor') 16 0.0
# ('carpenter', 'librarian') 15 0.0
# ('farmer', 'cleaner') 15 0.0
# ('lawyer', 'librarian') 15 0.0
# ('developer', 'librarian') 14 0.0
# ('janitor', 'librarian') 14 0.0
# ('mechanic', 'librarian') 14 0.0
# ('farmer', 'secretary') 14 0.0
# ('engineer', 'librarian') 14 0.0
# ('engineer', 'receptionist') 13 0.0
# ('lawyer', 'paralegal') 13 0.0
# ('analyst', 'librarian') 13 0.0
# ('technician', 'housekeeper') 12 0.25
# ('sheriff', 'teacher') 12 0.0
# ('engineer', 'designer') 12 0.0
# ('construction worker', 'librarian') 12 0.0
# ('physician', 'editor') 12 0.0
# ('supervisor', 'receptionist') 11 0.0
# ('driver', 'cashier') 11 0.0
# ('physician', 'librarian') 11 0.0
# ('sheriff', 'counselor') 11 0.0
# ('carpenter', 'housekeeper') 11 0.0
# ('salesperson', 'librarian') 11 0.0
# ('lawyer', 'teacher') 11 0.0
# ('manager', 'assistant') 11 0.0
# ('guard', 'cleaner') 11 0.0
# ('supervisor', 'librarian') 11 0.0
# ('guard', 'housekeeper') 11 0.0
# ('cook', 'counselor') 11 0.0
# ('lawyer', 'clerk') 11 0.0
# ('accountant', 'nurse') 10 0.0
# ('CEO', 'librarian') 10 0.0
# ('sheriff', 'designer') 10 0.0
# ('mover', 'housekeeper') 10 0.0
# ('salesperson', 'teacher') 10 0.0
# ('janitor', 'receptionist') 10 0.0
# ('salesperson', 'paralegal') 10 0.0
# ('lawyer', 'receptionist') 10 0.0
# ('laborer', 'accountant') 10 0.0
# ('carpenter', 'secretary') 10 0.0
# ('driver', 'baker') 10 0.0
# ('driver', 'assistant') 10 0.0
# ('mover', 'cashier') 10 0.0
# ('lawyer', 'attendant') 10 0.0
# ('manager', 'hairdresser') 10 0.0
# ('manager', 'accountant') 10 0.0
# ('supervisor', 'baker') 10 0.0
# ('mover', 'attendant') 10 0.0
# ('engineer', 'editor') 10 0.0
# ('mechanic', 'nurse') 10 0.0
# ('engineer', 'hairdresser') 10 0.0
# ('engineer', 'assistant') 9 0.0
# ('accountant', 'baker') 9 0.0
# ('physician', 'cleaner') 9 0.0
# ('technician', 'teacher') 9 0.0
# ('supervisor', 'cashier') 9 0.0
# ('guard', 'accountant') 9 0.0
# ('analyst', 'housekeeper') 9 0.0
# ('engineer', 'teacher') 9 0.0
# ('farmer', 'librarian') 9 0.0
# ('physician', 'cashier') 9 0.0
# ('technician', 'paralegal') 9 0.2222222222222222
# ('manager', 'librarian') 9 0.0
# ('farmer', 'receptionist') 9 0.0
# ('construction worker', 'housekeeper') 9 0.0
# ('chief', 'writer') 9 0.0
# ('supervisor', 'hairdresser') 9 0.0
# ('cook', 'clerk') 9 0.0
# ('developer', 'writer') 9 0.0
# ('mechanic', 'paralegal') 9 0.0
# ('mover', 'librarian') 9 0.0
# ('cook', 'housekeeper') 9 0.0
# ('accountant', 'paralegal') 9 0.0
# ('laborer', 'editor') 9 0.0
# ('construction worker', 'nurse') 9 0.0
# ('developer', 'auditor') 9 0.0
# ('mover', 'cleaner') 9 0.0
# ('driver', 'auditor') 9 0.0
# ('analyst', 'editor') 9 0.0
# ('janitor', 'designer') 9 0.0
# ('lawyer', 'cleaner') 9 0.0
# ('manager', 'clerk') 9 0.0
# ('construction worker', 'secretary') 9 0.0
# ('manager', 'cashier') 9 0.0
# ('chief', 'editor') 9 0.0
# ('salesperson', 'editor') 9 0.0
# ('carpenter', 'cashier') 9 0.0
# ('carpenter', 'attendant') 8 0.0
# ('mover', 'teacher') 8 0.0
# ('driver', 'teacher') 8 0.125
# ('developer', 'accountant') 8 0.0
# ('CEO', 'designer') 8 0.0
# ('lawyer', 'accountant') 8 0.0
# ('CEO', 'paralegal') 8 0.0
# ('manager', 'designer') 8 0.0
# ('guard', 'nurse') 8 0.0
# ('cook', 'accountant') 8 0.0
# ('guard', 'receptionist') 8 0.0
# ('laborer', 'housekeeper') 8 0.0
# ('physician', 'nurse') 8 0.0
# ('physician', 'counselor') 8 0.0
# ('mover', 'tailor') 8 0.0
# ('accountant', 'assistant') 8 0.0
# ('developer', 'editor') 8 0.0
# ('sheriff', 'assistant') 8 0.0
# ('sheriff', 'secretary') 8 0.0
# ('developer', 'receptionist') 8 0.0
# ('salesperson', 'receptionist') 8 0.0
# ('technician', 'librarian') 8 0.0
# ('accountant', 'housekeeper') 8 0.0
# ('laborer', 'nurse') 8 0.0
# ('analyst', 'secretary') 8 0.0
# ('supervisor', 'assistant') 8 0.0
# ('driver', 'editor') 8 0.0
# ('driver', 'secretary') 8 0.0
# ('construction worker', 'attendant') 8 0.0
# ('chief', 'librarian') 8 0.0
# ('construction worker', 'accountant') 8 0.0
# ('technician', 'nurse') 8 0.0
# ('CEO', 'assistant') 8 0.0
# ('CEO', 'hairdresser') 8 0.0
# ('supervisor', 'paralegal') 8 0.0
# ('laborer', 'auditor') 8 0.0
# ('developer', 'nurse') 8 0.0
# ('mechanic', 'editor') 8 0.0
# ('manager', 'attendant') 8 0.0
# ('developer', 'hairdresser') 8 0.0
# ('physician', 'assistant') 8 0.0
# ('janitor', 'cashier') 8 0.0
# ('cook', 'attendant') 8 0.0
# ('analyst', 'tailor') 8 0.0
# ('supervisor', 'counselor') 8 0.0
# ('carpenter', 'accountant') 8 0.0
# ('driver', 'paralegal') 8 0.0
# ('sheriff', 'paralegal') 7 0.0
# ('supervisor', 'housekeeper') 7 0.0
# ('farmer', 'baker') 7 0.0
# ('technician', 'tailor') 7 0.0
# ('janitor', 'hairdresser') 7 0.0
# ('technician', 'secretary') 7 0.14285714285714285
# ('laborer', 'counselor') 7 0.0
# ('farmer', 'counselor') 7 0.0
# ('guard', 'hairdresser') 7 0.0
# ('lawyer', 'auditor') 7 0.0
# ('sheriff', 'clerk') 7 0.0
# ('salesperson', 'attendant') 7 0.0
# ('guard', 'attendant') 7 0.0
# ('guard', 'counselor') 7 0.0
# ('mechanic', 'attendant') 7 0.0
# ('carpenter', 'clerk') 7 0.0
# ('guard', 'teacher') 7 0.0
# ('mover', 'clerk') 7 0.0
# ('technician', 'baker') 7 0.0
# ('developer', 'assistant') 7 0.0
# ('laborer', 'receptionist') 7 0.0
# ('lawyer', 'housekeeper') 7 0.0
# ('laborer', 'designer') 7 0.0
# ('engineer', 'nurse') 7 0.0
# ('chief', 'assistant') 7 0.0
# ('technician', 'receptionist') 7 0.0
# ('engineer', 'counselor') 7 0.0
# ('physician', 'attendant') 7 0.0
# ('sheriff', 'cleaner') 7 0.0
# ('cook', 'hairdresser') 7 0.0
# ('CEO', 'tailor') 7 0.0
# ('mechanic', 'designer') 7 0.0
# ('mechanic', 'receptionist') 7 0.0
# ('supervisor', 'clerk') 7 0.0
# ('construction worker', 'tailor') 7 0.0
# ('mechanic', 'auditor') 7 0.0
# ('laborer', 'assistant') 7 0.0
# ('chief', 'housekeeper') 7 0.0
# ('carpenter', 'tailor') 7 0.0
# ('salesperson', 'accountant') 7 0.0
# ('accountant', 'editor') 7 0.0
# ('analyst', 'assistant') 7 0.0
# ('salesperson', 'assistant') 7 0.0
# ('carpenter', 'counselor') 7 0.0
# ('cook', 'cleaner') 7 0.0
# ('manager', 'paralegal') 7 0.0
# ('construction worker', 'cashier') 7 0.0
# ('mechanic', 'housekeeper') 7 0.0
# ('CEO', 'clerk') 7 0.0
# ('sheriff', 'editor') 7 0.0
# ('sheriff', 'cashier') 7 0.0
# ('technician', 'hairdresser') 7 0.0
# ('developer', 'designer') 7 0.0
# ('laborer', 'paralegal') 6 0.0
# ('supervisor', 'writer') 6 0.0
# ('guard', 'assistant') 6 0.0
# ('lawyer', 'cashier') 6 0.0
# ('chief', 'designer') 6 0.0
# ('farmer', 'assistant') 6 0.0
# ('developer', 'clerk') 6 0.0
# ('salesperson', 'hairdresser') 6 0.0
# ('salesperson', 'secretary') 6 0.0
# ('salesperson', 'housekeeper') 6 0.0
# ('technician', 'clerk') 6 0.3333333333333333
# ('cook', 'librarian') 6 0.0
# ('farmer', 'teacher') 6 0.0
# ('guard', 'cashier') 6 0.0
# ('physician', 'writer') 6 0.0
# ('cook', 'nurse') 6 0.0
# ('guard', 'paralegal') 6 0.0
# ('developer', 'attendant') 6 0.0
# ('analyst', 'nurse') 6 0.0
# ('construction worker', 'baker') 6 0.0
# ('manager', 'secretary') 6 0.0
# ('chief', 'teacher') 6 0.0
# ('physician', 'teacher') 6 0.0
# ('carpenter', 'writer') 6 0.0
# ('supervisor', 'cleaner') 6 0.0
# ('farmer', 'hairdresser') 6 0.0
# ('janitor', 'tailor') 6 0.0
# ('engineer', 'paralegal') 6 0.0
# ('accountant', 'secretary') 6 0.0
# ('janitor', 'writer') 6 0.0
# ('salesperson', 'tailor') 6 0.0
# ('engineer', 'tailor') 6 0.0
# ('technician', 'assistant') 6 0.16666666666666666
# ('driver', 'designer') 6 0.0
# ('accountant', 'receptionist') 6 0.0
# ('supervisor', 'secretary') 6 0.0
# ('technician', 'cashier') 6 0.0
# ('mechanic', 'counselor') 6 0.0
# ('technician', 'designer') 6 0.0
# ('CEO', 'receptionist') 6 0.0
# ('mechanic', 'writer') 6 0.0
# ('CEO', 'secretary') 6 0.0
# ('supervisor', 'auditor') 6 0.0
# ('manager', 'tailor') 6 0.0
# ('salesperson', 'nurse') 6 0.0
# ('carpenter', 'receptionist') 6 0.0
# ('CEO', 'teacher') 6 0.0
# ('technician', 'cleaner') 6 0.16666666666666666
# ('guard', 'secretary') 6 0.0
# ('analyst', 'accountant') 6 0.0
# ('accountant', 'hairdresser') 6 0.0
# ('chief', 'nurse') 6 0.0
# ('sheriff', 'auditor') 6 0.0
# ('CEO', 'editor') 6 0.0
# ('analyst', 'counselor') 6 0.0
# ('CEO', 'writer') 6 0.0
# ('sheriff', 'nurse') 6 0.0
# ('physician', 'accountant') 6 0.0
# ('developer', 'secretary') 6 0.0
# ('salesperson', 'cashier') 6 0.0
# ('salesperson', 'designer') 6 0.0
# ('salesperson', 'cleaner') 6 0.0
# ('janitor', 'nurse') 6 0.0
# ('carpenter', 'cleaner') 6 0.0
# ('mechanic', 'secretary') 6 0.0
# ('salesperson', 'baker') 6 0.0
# ('mover', 'nurse') 6 0.0
# ('farmer', 'paralegal') 6 0.0
# ('manager', 'counselor') 6 0.0
# ('laborer', 'baker') 6 0.0
# ('chief', 'paralegal') 6 0.0
# ('farmer', 'designer') 6 0.0
# ('laborer', 'librarian') 6 0.0
# ('engineer', 'housekeeper') 6 0.0
# ('analyst', 'clerk') 6 0.0
# ('driver', 'cleaner') 6 0.0
# ('farmer', 'clerk') 6 0.0
# ('CEO', 'housekeeper') 5 0.0
# ('janitor', 'auditor') 5 0.0
# ('janitor', 'attendant') 5 0.0
# ('mechanic', 'assistant') 5 0.0
# ('mechanic', 'hairdresser') 5 0.0
# ('chief', 'secretary') 5 0.0
# ('construction worker', 'designer') 5 0.0
# ('cook', 'secretary') 5 0.0
# ('chief', 'accountant') 5 0.0
# ('janitor', 'counselor') 5 0.0
# ('developer', 'baker') 5 0.0
# ('farmer', 'housekeeper') 5 0.0
# ('analyst', 'designer') 5 0.0
# ('farmer', 'auditor') 5 0.0
# ('manager', 'editor') 5 0.0
# ('janitor', 'editor') 5 0.0
# ('mover', 'counselor') 5 0.0
# ('accountant', 'attendant') 5 0.0
# ('accountant', 'designer') 5 0.0
# ('driver', 'writer') 5 0.0
# ('laborer', 'writer') 5 0.0
# ('manager', 'housekeeper') 5 0.0
# ('physician', 'secretary') 5 0.0
# ('guard', 'baker') 5 0.0
# ('engineer', 'writer') 5 0.0
# ('driver', 'clerk') 5 0.0
# ('engineer', 'clerk') 5 0.0
# ('analyst', 'writer') 5 0.0
# ('farmer', 'nurse') 5 0.0
# ('cook', 'assistant') 5 0.0
# ('driver', 'nurse') 5 0.0
# ('analyst', 'auditor') 5 0.0
# ('accountant', 'auditor') 5 0.0
# ('farmer', 'writer') 5 0.0
# ('construction worker', 'editor') 5 0.0
# ('CEO', 'cashier') 5 0.0
# ('driver', 'receptionist') 5 0.0
# ('accountant', 'librarian') 5 0.0
# ('CEO', 'attendant') 5 0.0
# ('mover', 'baker') 5 0.0
# ('mechanic', 'baker') 5 0.0
# ('analyst', 'receptionist') 5 0.0
# ('chief', 'tailor') 5 0.0
# ('cook', 'paralegal') 5 0.0
# ('lawyer', 'nurse') 5 0.0
# ('carpenter', 'hairdresser') 5 0.0
# ('mechanic', 'accountant') 5 0.0
# ('developer', 'tailor') 5 0.0
# ('janitor', 'housekeeper') 5 0.0
# ('technician', 'accountant') 5 0.0
# ('technician', 'attendant') 5 0.0
# ('mover', 'accountant') 5 0.0
# ('accountant', 'teacher') 5 0.0
# ('construction worker', 'writer') 5 0.0
# ('janitor', 'assistant') 5 0.0
# ('manager', 'nurse') 5 0.0
# ('analyst', 'paralegal') 5 0.0
# ('cook', 'teacher') 5 0.0
# ('CEO', 'cleaner') 5 0.0
# ('developer', 'cleaner') 5 0.0
# ('accountant', 'writer') 5 0.0
# ('mover', 'auditor') 5 0.0
# ('physician', 'hairdresser') 5 0.0
# ('mover', 'receptionist') 5 0.0
# ('construction worker', 'hairdresser') 5 0.0
# ('sheriff', 'baker') 5 0.0
# ('accountant', 'clerk') 5 0.0
# ('guard', 'editor') 4 0.0
# ('sheriff', 'hairdresser') 4 0.0
# ('sheriff', 'writer') 4 0.0
# ('construction worker', 'receptionist') 4 0.0
# ('driver', 'attendant') 4 0.0
# ('CEO', 'accountant') 4 0.0
# ('analyst', 'baker') 4 0.0
# ('mechanic', 'teacher') 4 0.0
# ('laborer', 'tailor') 4 0.0
# ('CEO', 'auditor') 4 0.0
# ('cook', 'writer') 4 0.0
# ('mover', 'designer') 4 0.0
# ('physician', 'auditor') 4 0.0
# ('engineer', 'auditor') 4 0.0
# ('physician', 'receptionist') 4 0.0
# ('sheriff', 'housekeeper') 4 0.0
# ('chief', 'cashier') 4 0.0
# ('physician', 'clerk') 4 0.0
# ('chief', 'auditor') 4 0.0
# ('analyst', 'teacher') 4 0.0
# ('chief', 'attendant') 4 0.0
# ('lawyer', 'hairdresser') 4 0.0
# ('lawyer', 'editor') 4 0.0
# ('developer', 'counselor') 4 0.0
# ('sheriff', 'tailor') 4 0.0
# ('salesperson', 'auditor') 4 0.0
# ('technician', 'editor') 4 0.0
# ('janitor', 'cleaner') 4 0.0
# ('supervisor', 'accountant') 4 0.0
# ('mover', 'secretary') 4 0.0
# ('physician', 'paralegal') 4 0.0
# ('farmer', 'attendant') 4 0.0
# ('CEO', 'baker') 4 0.0
# ('cook', 'editor') 4 0.0
# ('physician', 'baker') 4 0.0
# ('mechanic', 'cashier') 4 0.0
# ('lawyer', 'writer') 4 0.0
# ('developer', 'cashier') 4 0.0
# ('technician', 'counselor') 4 0.0
# ('engineer', 'baker') 4 0.0
# ('laborer', 'teacher') 4 0.0
# ('manager', 'writer') 4 0.0
# ('supervisor', 'tailor') 4 0.0
# ('analyst', 'cashier') 4 0.0
# ('janitor', 'paralegal') 4 0.0
# ('supervisor', 'attendant') 4 0.0
# ('developer', 'teacher') 4 0.25
# ('laborer', 'cleaner') 4 0.0
# ('manager', 'teacher') 4 0.25
# ('engineer', 'accountant') 4 0.0
# ('sheriff', 'receptionist') 4 0.0
# ('carpenter', 'paralegal') 4 0.0
# ('janitor', 'teacher') 4 0.0
# ('guard', 'tailor') 4 0.0
# ('janitor', 'accountant') 4 0.0
# ('chief', 'cleaner') 4 0.0
# ('janitor', 'baker') 4 0.0
# ('chief', 'receptionist') 4 0.0
# ('guard', 'clerk') 4 0.0
# ('farmer', 'editor') 4 0.0
# ('carpenter', 'teacher') 4 0.0
# ('carpenter', 'baker') 4 0.0
# ('technician', 'writer') 4 0.0
# ('mover', 'hairdresser') 4 0.0
# ('manager', 'cleaner') 4 0.0
# ('laborer', 'cashier') 4 0.0
# ('lawyer', 'tailor') 4 0.0
# ('laborer', 'hairdresser') 4 0.0
# ('guard', 'writer') 4 0.0
# ('lawyer', 'assistant') 4 0.0
# ('engineer', 'cleaner') 4 0.0
# ('cook', 'tailor') 4 0.0
# ('cook', 'cashier') 4 0.0
# ('developer', 'paralegal') 4 0.0
# ('supervisor', 'designer') 4 0.0
# ('guard', 'auditor') 3 0.0
# ('physician', 'tailor') 3 0.0
# ('sheriff', 'attendant') 3 0.0
# ('farmer', 'accountant') 3 0.0
# ('supervisor', 'nurse') 3 0.0
# ('driver', 'housekeeper') 3 0.0
# ('physician', 'designer') 3 0.0
# ('accountant', 'cashier') 3 0.0
# ('accountant', 'accountant') 3 0.0
# ('construction worker', 'cleaner') 3 0.0
# ('janitor', 'clerk') 3 0.0
# ('manager', 'auditor') 3 0.0
# ('CEO', 'counselor') 3 0.0
# ('lawyer', 'counselor') 3 0.0
# ('farmer', 'cashier') 3 0.0
# ('analyst', 'hairdresser') 3 0.0
# ('manager', 'baker') 3 0.0
# ('manager', 'receptionist') 3 0.0
# ('laborer', 'secretary') 3 0.0
# ('construction worker', 'clerk') 3 0.0
# ('salesperson', 'counselor') 3 0.0
# ('CEO', 'nurse') 3 0.0
# ('carpenter', 'auditor') 3 0.0
# ('construction worker', 'paralegal') 3 0.0
# ('carpenter', 'nurse') 3 0.0
# ('mover', 'assistant') 3 0.0
# ('mover', 'paralegal') 3 0.0
# ('analyst', 'cleaner') 3 0.0
# ('driver', 'hairdresser') 3 0.0
# ('physician', 'housekeeper') 3 0.0
# ('cook', 'auditor') 3 0.0
# ('laborer', 'clerk') 3 0.0
# ('chief', 'counselor') 3 0.0
# ('mechanic', 'clerk') 3 0.0
# ('farmer', 'tailor') 3 0.0
# ('janitor', 'secretary') 3 0.0
# ('supervisor', 'teacher') 3 0.0
# ('construction worker', 'auditor') 3 0.0
# ('lawyer', 'baker') 3 0.0
# ('laborer', 'attendant') 3 0.0
# ('analyst', 'attendant') 3 0.0
# ('chief', 'hairdresser') 3 0.0
# ('construction worker', 'assistant') 3 0.0
# ('lawyer', 'designer') 3 0.0
# ('engineer', 'attendant') 3 0.0
# ('mover', 'writer') 3 0.0
# ('technician', 'auditor') 3 0.6666666666666666
# ('salesperson', 'writer') 3 0.0
# ('carpenter', 'assistant') 3 0.0
# ('accountant', 'counselor') 3 0.0
# ('guard', 'designer') 3 0.0
# ('sheriff', 'accountant') 3 0.0
# ('mover', 'editor') 3 0.0
# ('driver', 'accountant') 2 0.0
# ('accountant', 'cleaner') 2 0.0
# ('lawyer', 'secretary') 2 0.0
# ('developer', 'housekeeper') 2 0.0
# ('cook', 'baker') 2 0.0
# ('engineer', 'secretary') 2 0.0
# ('cook', 'receptionist') 2 0.0
# ('mechanic', 'cleaner') 2 0.0
# ('mechanic', 'tailor') 2 0.0
# ('salesperson', 'clerk') 2 0.0
# ('construction worker', 'teacher') 2 0.0
# ('engineer', 'cashier') 2 0.0
# ('chief', 'clerk') 2 0.0
# ('construction worker', 'counselor') 2 0.0
# ('driver', 'tailor') 1 0.0
# ('carpenter', 'editor') 1 0.0
# ('carpenter', 'designer') 1 0.0
# ('chief', 'baker') 1 0.0
# ('supervisor', 'editor') 1 0.0

# %%
error_rate_dict = get_error_rate_dict(occupation_pair_error, occupation_pair_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], sorted_occupation_pair_count[key])
# Out:
# ('technician', 'auditor') 0.6666666666666666 3
# ('technician', 'clerk') 0.3333333333333333 6
# ('technician', 'housekeeper') 0.25 12
# ('developer', 'teacher') 0.25 4
# ('manager', 'teacher') 0.25 4
# ('technician', 'paralegal') 0.2222222222222222 9
# ('technician', 'assistant') 0.16666666666666666 6
# ('technician', 'cleaner') 0.16666666666666666 6
# ('technician', 'secretary') 0.14285714285714285 7
# ('driver', 'teacher') 0.125 8

# %%
error_rate_dict = get_error_rate_dict(occupation1_error, occupation1_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], occupation1_count[key])
# Out:
# technician 0.08823529411764706 136
# manager 0.007407407407407408 135
# developer 0.0072992700729927005 137
# driver 0.006535947712418301 153

# %%
error_rate_dict = get_error_rate_dict(occupation2_error, occupation2_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key], occupation2_count[key])
# Out:
# teacher 0.02127659574468085 141
# housekeeper 0.018867924528301886 159
# auditor 0.017391304347826087 115
# clerk 0.015748031496062992 127
# paralegal 0.013333333333333334 150
# cleaner 0.0072992700729927005 137
# secretary 0.0070921985815602835 141
# assistant 0.006622516556291391 151

# %%
error_rate_dict = get_error_rate_dict(action_error, action_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# baking 0.03278688524590164
# the game was excellent 0.029411764705882353
# the application was under review 0.024390243902439025
# painting 0.01694915254237288
# dancing 0.015873015873015872
# blogging 0.015873015873015872
# the work was appreciated 0.012658227848101266
# the performance was not up to the mark 0.011764705882352941
# the meat was eaten 0.010752688172043012
# the application was not approved 0.010638297872340425
# the delivery was made 0.009708737864077669

# %%
error_rate_dict = get_error_rate_dict(verb_error, verb_count)
for key in error_rate_dict:
    print(key, error_rate_dict[key])
# Out:
# asked 0.008305647840531562
# disclosed to 0.007104795737122558
# notified 0.0049261083743842365
# told 0.004792332268370607
